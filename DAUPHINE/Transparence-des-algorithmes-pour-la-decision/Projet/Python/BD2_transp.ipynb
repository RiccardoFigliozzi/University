# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def concordance_partiel_1(H, b, j, critere):
  H=new_data[new_data['productname']==H]
  b=profil[profil['profil']==b]
  c=0
  if critere == 'max':
    if H.iloc[0][j] >= b.iloc[0][j]:
      c=1
      return c
    else :
      return c
  if critere == 'min':
      if b.iloc[0][j] >= H.iloc[0][j]:
        c =1 
        return c
      else :
        return c
  return

# %%
def concordance_partiel_2(b, H, j, critere):
  H=new_data[new_data['productname']==H]
  b=profil[profil['profil']==b]
  c=0
  if critere == 'min':
    if H.iloc[0][j] >= b.iloc[0][j]:
      c=1
      return c
    else :
      return c
  if critere == 'max':
      if b.iloc[0][j] >= H.iloc[0][j]:
        c =1 
        return c
      else :
        return c
  return

# %%
def concondance_global_1(H_in, b_in, critere):
  H=new_data[new_data['productname']==H_in]
  b=profil[profil['profil']==b_in]
  num=0
  den=0
  for i in range(1,len(H.columns)):
    num += poids.iloc[0][i-1]*concordance_partiel_1(H_in, b_in, i, critere[i-1])
    den += poids.iloc[0][i-1]
  return num/den

# %%
def concondance_global_2(b_in, H_in, critere):
  H=new_data[new_data['productname']==H_in]
  b=profil[profil['profil']==b_in]
  num=0
  den=0
  for i in range(1,len(H.columns)):
    num += poids.iloc[0][i-1]*concordance_partiel_2(b_in, H_in, i, critere[i-1])
    den += poids.iloc[0][i-1]
  return num/den

# %%
def surclassament_1(H_in, b_in, lamb, critere):
    if concondance_global_1(H_in, b_in, critere) >= lamb:
      #print(str(H_in)+" S "+str(b_in)) 
      return 1
    else:
      #print(str(H_in)+" ne surclasse pas "+str(b_in))
      return
    return

# %%
def surclassament_2(b_in, H_in, lamb, critere):
    if concondance_global_2(b_in, H_in, critere) >= lamb:
      #print(str(b_in)+" S "+str(H_in)) 
      return 1
    else:
      #print(str(b_in)+" ne surclasse pas "+str(H_in)) 
      return 0
    return

# %%
def pessimiste(H_in, lamb, critere):
    for i in range(len(profil)):
      b_in= profil.iloc[i][0]
      if surclassament_1(H_in, b_in, lamb, critere) == 1:
        #print("cat:", nutri_cat[i-1])
        break
    return nutri_cat[i-1]

# %%
def optimiste(H_in, lamb, critere):
    for i in range(len(profil)-1,-0,-1):
        b_in= profil.iloc[i][0]
        if surclassament_2(b_in, H_in, lamb, critere) == 1 and i==len(profil)-1:
          return nutri_cat[len(profil)-2]
        if surclassament_2(b_in, H_in, lamb, critere) == 1:
        #print("cat:", nutri_cat[i])
            break
    return nutri_cat[i]

# %%
nutri_cat=['a','b','c','d']

# %%
notre_data = pd.read_excel("data1000.xlsx")

# %%
new_data= notre_data[["productname",'energy100g', 'saturatedfat100g', 'sugars100g','fiber100g','proteins100g','sodium100g']]

# %%
new_data
# Out:
#                                             productname  ...  sodium100g
# 0                                     Rillettes De thon  ...       0.140
# 1     Veggie - Falafels - Garbanzos, habas, hilantro...  ...       0.288
# 2                          Pain de mie grandes tranches  ...       0.440
# 3                                     Galettes De MaÃ¯s  ...       0.112
# 4                          Steak hachÃ© pur boeuf 5% MG  ...       0.000
# ...                                                 ...  ...         ...
# 1025                    MÃ©lange d'huiles colza & olive  ...       0.000
# 1026           Bloc de Foie Gras de Canard du Sud-Ouest  ...       0.600
# 1027                                  MÃ©lange 4 huiles  ...       0.000
# 1028  Huile d'olive - ComposÃ©e d'huiles d'olive raf...  ...       0.000
# 1029     Graisse de canard issue de canard du Sud-Ouest  ...       0.000
#
# [1030 rows x 7 columns]

# %%
poids = pd.read_csv("notre_poids.csv")
profil = pd.read_csv("profil_up.csv")

# %%
profil
# Out:
#   profil  energie  acide gras sat.  sucre  sodium  proteine  fibre
# 0     b5        0                0      0       0       100    100
# 1     b4      900               13     22       2        29     20
# 2     b3     1800               27     48       4        19     14
# 3     b2     2700               41     70       6        10      6
# 4     b1    10000              100    100      50         0      0

# %%
pessimiste("Galettes De MaÃ¯s", 0.5, ['max','min','min','min','max','max'])
# Out:
# Galettes De MaÃ¯s ne surclasse pas b5
# Galettes De MaÃ¯s ne surclasse pas b4
# Galettes De MaÃ¯s ne surclasse pas b3
# Galettes De MaÃ¯s ne surclasse pas b2
# Galettes De MaÃ¯s S b1
# 'd'

# %%
optimiste("Galettes De MaÃ¯s", 0.5, ['max','min','min','min','max','max'])
# Out:
# b1 ne surclasse pas Galettes De MaÃ¯s
# b2 S Galettes De MaÃ¯s
# 'd'

# %%
bd2=new_data.copy()
bd2["pessimiste_05"]=1

# %%
for i in range(len(bd2)):
    bd2["pessimiste_05"][i] = pessimiste(new_data.iloc[i]["productname"], 0.5, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["pessimiste_06"]=1

# %%
for i in range(len(bd2)):
    bd2["pessimiste_06"][i] = pessimiste(new_data.iloc[i]["productname"], 0.6, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["pessimiste_07"]=1

# %%
for i in range(len(bd2)):
    bd2["pessimiste_07"][i] = pessimiste(new_data.iloc[i]["productname"], 0.7, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["optimiste_05"]=1

# %%
for i in range(len(bd2)):
    #print(i)
    bd2["optimiste_05"][i] = optimiste(new_data.iloc[i]["productname"], 0.5, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["optimiste_06"]=1

# %%
for i in range(len(bd2)):
    #print(i)
    bd2["optimiste_06"][i] = optimiste(new_data.iloc[i]["productname"], 0.6, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["optimiste_07"]=1

# %%
for i in range(len(bd2)):
    #print(i)
    bd2["optimiste_07"][i] = optimiste(new_data.iloc[i]["productname"], 0.7, ['max','min','min','min','max','max'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bd2["nutriscoregrade"]=notre_data["nutritiongradefr"]

# %%
bd2["nova_group"] = notre_data["nova_group"]

# %%
bd2
# Out:
#                                             productname  ...  nova_group
# 0                                     Rillettes De thon  ...           4
# 1     Veggie - Falafels - Garbanzos, habas, hilantro...  ...           4
# 2                          Pain de mie grandes tranches  ...           4
# 3                                     Galettes De MaÃ¯s  ...           3
# 4                          Steak hachÃ© pur boeuf 5% MG  ...           1
# ...                                                 ...  ...         ...
# 1025                    MÃ©lange d'huiles colza & olive  ...           2
# 1026           Bloc de Foie Gras de Canard du Sud-Ouest  ...           2
# 1027                                  MÃ©lange 4 huiles  ...           2
# 1028  Huile d'olive - ComposÃ©e d'huiles d'olive raf...  ...           2
# 1029     Graisse de canard issue de canard du Sud-Ouest  ...           2
#
# [1030 rows x 15 columns]

# %%
from openpyxl.workbook import Workbook
bd2.to_excel("bd2.xlsx",
             sheet_name='lambda')

# %%
notre_data = pd.read_excel("data1000.xlsx")

# %%
notre_data
# Out:
#                                             productname  ...     Unnamed: 13
# 0                                     Rillettes De thon  ...  NutritionGrade
# 1     Veggie - Falafels - Garbanzos, habas, hilantro...  ...  NutritionGrade
# 2                          Pain de mie grandes tranches  ...  NutritionGrade
# 3                                     Galettes De MaÃ¯s  ...  NutritionGrade
# 4                          Steak hachÃ© pur boeuf 5% MG  ...           egaux
# ...                                                 ...  ...             ...
# 1025                    MÃ©lange d'huiles colza & olive  ...            Nova
# 1026           Bloc de Foie Gras de Canard du Sud-Ouest  ...            Nova
# 1027                                  MÃ©lange 4 huiles  ...            Nova
# 1028  Huile d'olive - ComposÃ©e d'huiles d'olive raf...  ...            Nova
# 1029     Graisse de canard issue de canard du Sud-Ouest  ...            Nova
#
# [1030 rows x 14 columns]

# %%
notre_data = notre_data.drop(['Unnamed: 13'], axis=1)

# %%
notre_data
# Out:
#                                             productname  ...  nutrition_grade_convert
# 0                                     Rillettes De thon  ...                        1
# 1     Veggie - Falafels - Garbanzos, habas, hilantro...  ...                        1
# 2                          Pain de mie grandes tranches  ...                        1
# 3                                     Galettes De MaÃ¯s  ...                        1
# 4                          Steak hachÃ© pur boeuf 5% MG  ...                        1
# ...                                                 ...  ...                      ...
# 1025                    MÃ©lange d'huiles colza & olive  ...                        3
# 1026           Bloc de Foie Gras de Canard du Sud-Ouest  ...                        4
# 1027                                  MÃ©lange 4 huiles  ...                        3
# 1028  Huile d'olive - ComposÃ©e d'huiles d'olive raf...  ...                        3
# 1029     Graisse de canard issue de canard du Sud-Ouest  ...                        4
#
# [1030 rows x 13 columns]

# %%
bd2 = pd.read_excel("bd2.xlsx")

# %%
bd2
# Out:
#       Unnamed: 0  ... nova_group
# 0              0  ...          4
# 1              1  ...          4
# 2              2  ...          4
# 3              3  ...          3
# 4              4  ...          1
# ...          ...  ...        ...
# 1025        1025  ...          2
# 1026        1026  ...          2
# 1027        1027  ...          2
# 1028        1028  ...          2
# 1029        1029  ...          2
#
# [1030 rows x 16 columns]

# %%
lista = ["pessimiste_05",	"pessimiste_06",	"pessimiste_07",	"optimiste_05",	"optimiste_06",	"optimiste_07"]

# %%
for el in lista:
  notre_data[el] = bd2[el]

# %%
notre_data
# Out:
#                                             productname  ...  optimiste_07
# 0                                     Rillettes De thon  ...             b
# 1     Veggie - Falafels - Garbanzos, habas, hilantro...  ...             c
# 2                          Pain de mie grandes tranches  ...             c
# 3                                     Galettes De MaÃ¯s  ...             c
# 4                          Steak hachÃ© pur boeuf 5% MG  ...             b
# ...                                                 ...  ...           ...
# 1025                    MÃ©lange d'huiles colza & olive  ...             b
# 1026           Bloc de Foie Gras de Canard du Sud-Ouest  ...             b
# 1027                                  MÃ©lange 4 huiles  ...             b
# 1028  Huile d'olive - ComposÃ©e d'huiles d'olive raf...  ...             b
# 1029     Graisse de canard issue de canard du Sud-Ouest  ...             b
#
# [1030 rows x 19 columns]

# %%
from openpyxl.workbook import Workbook
notre_data.to_excel("bd2_elec.xlsx",
             sheet_name='lambda')
