# %% [markdown]
# # Association Rules

# %%
# imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read of the training file preprocessed by the Data Understanding and Transformation 
dfTraining = pd.read_csv('Data/df1.csv',sep=';')

# %%
# drop of the not useful and redundant columns 
dfTraining = dfTraining.drop(['RefId', 'SubModel', 'Color',  'MMRCurrentAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice', 'MMRCurrentAuctionCleanPrice', 'MMRAcquisitionRetailAveragePrice', 'MMRCurrentRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice', 'MMRCurrentRetailCleanPrice', 'State|ZIPC', 'TopThreeAmericanName'], axis=1)
dfTraining
# Out:
#        IsBadBuy   PurchDate  Auction  VehicleAge       Make  \
# 0             1  10/25/2010    ADESA           2        KIA
# 1             0   5/27/2009  MANHEIM           3      DODGE
# 2             0   3/18/2010    OTHER           2      DODGE
# 3             0    6/8/2009    OTHER           4       FORD
# 4             0    3/4/2009  MANHEIM           4   CHRYSLER
# 5             0   5/21/2010    ADESA           5     NISSAN
# 6             0   9/24/2009  MANHEIM           1      DODGE
# 7             0    6/4/2009  MANHEIM           3     SUZUKI
# 8             0  10/13/2009  MANHEIM           5   CHRYSLER
# 9             0   2/10/2010  MANHEIM           3    PONTIAC
# 10            0   5/12/2010  MANHEIM           5      DODGE
# 11            0    6/5/2009  MANHEIM           5  CHEVROLET
# 12            0   8/11/2009    ADESA           2   CHRYSLER
# 13            0   7/23/2010    OTHER           3  CHEVROLET
# 14            0   5/20/2010  MANHEIM           4    PONTIAC
# 15            0   1/13/2010  MANHEIM           2  CHEVROLET
# 16            0   1/29/2009  MANHEIM           3     SATURN
# 17            0    7/8/2009  MANHEIM           7  CHEVROLET
# 18            0   5/27/2009  MANHEIM           4      DODGE
# 19            0   3/15/2010  MANHEIM           7      DODGE
# 20            0  11/25/2009    OTHER           5       FORD
# 21            0  10/28/2009    OTHER           4       FORD
# 22            0   7/29/2010    ADESA           6  CHEVROLET
# 23            0   2/11/2010    ADESA           3     SATURN
# 24            0   8/24/2010    OTHER           4    PONTIAC
# 25            0   9/29/2010  MANHEIM           3     NISSAN
# 26            0   2/25/2010    ADESA           7       FORD
# 27            0    2/3/2009  MANHEIM           4       FORD
# 28            0    5/5/2010    OTHER           4        KIA
# 29            0    8/2/2010  MANHEIM           2     SATURN
# ...         ...         ...      ...         ...        ...
# 50297         0   3/11/2009  MANHEIM           3  CHEVROLET
# 50298         0    2/2/2010  MANHEIM           3   CHRYSLER
# 50299         0   3/10/2010    OTHER           2      DODGE
# 50300         1   4/22/2010  MANHEIM           4  CHEVROLET
# 50301         1   8/13/2009  MANHEIM           2       FORD
# 50302         1   4/29/2010  MANHEIM           5    HYUNDAI
# 50303         1   5/25/2010  MANHEIM           6  CHEVROLET
# 50304         0   2/17/2010  MANHEIM           4      DODGE
# 50305         0    5/6/2010  MANHEIM           5       FORD
# 50306         0   1/27/2009  MANHEIM           4      DODGE
# 50307         0  12/14/2010  MANHEIM           7       FORD
# 50308         0   9/22/2009    OTHER           7       FORD
# 50309         0   4/23/2010    ADESA           3  CHEVROLET
# 50310         1   2/12/2009    ADESA           5  CHEVROLET
# 50311         0  11/30/2010  MANHEIM           7      DODGE
# 50312         0   4/16/2009    ADESA           5     NISSAN
# 50313         0   1/28/2010  MANHEIM           6      MAZDA
# 50314         0   8/27/2009    ADESA           5       FORD
# 50315         0    5/5/2009    OTHER           3      DODGE
# 50316         0   5/12/2010    ADESA           3  CHEVROLET
# 50317         0   8/30/2010    ADESA           6     TOYOTA
# 50318         0   4/20/2009    ADESA           5   CHRYSLER
# 50319         0    1/7/2009    OTHER           2  CHEVROLET
# 50320         0    4/5/2010  MANHEIM           6   CADILLAC
# 50321         0   7/13/2010  MANHEIM           5       FORD
# 50322         0    5/5/2009    OTHER           4      DODGE
# 50323         0    3/9/2010    OTHER           3  CHEVROLET
# 50324         0   1/26/2010    OTHER           4       FORD
# 50325         0  10/28/2010    OTHER           3  CHEVROLET
# 50326         1   12/1/2010  MANHEIM           5     NISSAN
#
#                       Model Trim Transmission  WheelTypeID  VehOdo  \
# 0                   SPECTRA   EX         AUTO            2   61184
# 1      STRATUS V6 2.7L V6 M  SXT         AUTO            2   92383
# 2                   CALIBER   SE         AUTO            2   45965
# 3      FREESTAR FWD V6 3.9L    S         AUTO            2   80169
# 4      TOWN & COUNTRY FWD V  Bas         AUTO            1   77372
# 5                    ALTIMA  Bas         AUTO            2   81478
# 6      AVENGER 4C 2.4L I4 S   SE         AUTO            2   56717
# 7       FORENZA 2.0L I4 EFI   LS       MANUAL            2   57337
# 8      PT CRUISER 2.4L I4 S  Bas         AUTO            2   85093
# 9                     G6 4C  Bas         AUTO            1   43883
# 10           DURANGO 4WD V8  SLT         AUTO            1   74251
# 11       IMPALA 3.4L V6 SFI  Bas         AUTO            1   99950
# 12     PT CRUISER 2.4L I4 S  Bas         AUTO            2   42442
# 13                   IMPALA   LS         AUTO            2   68178
# 14                    G6 V6  Bas         AUTO            1   74603
# 15                MALIBU 4C   LS         AUTO            2   43300
# 16             RELAY 2WD V6   SE         AUTO            1   51783
# 17     MALIBU V6 3.1L V6 SF  Bas         AUTO            2   68613
# 18     STRATUS V6 2.7L V6 M  SXT         AUTO            2   64427
# 19           DURANGO 2WD V8  SLT         AUTO            1   79150
# 20               MUSTANG V6  Bas         AUTO            1   79927
# 21     FREESTAR FWD V6 3.9L    S         AUTO            2   87106
# 22     1500 SILVERADO PICKU   LS         AUTO            2   75360
# 23                     AURA   XE         AUTO            2   64642
# 24               GRAND PRIX  Bas         AUTO            1   46626
# 25                   ALTIMA  Bas         AUTO            1   78056
# 26          EXPLORER 2WD V6  XLS         AUTO            1   85857
# 27     FREESTAR FWD V6 3.9L   SE         AUTO            2   88897
# 28              SORENTO 2WD   EX       MANUAL            1   89643
# 29                  AURA V6   XE         AUTO            2   65354
# ...                     ...  ...          ...          ...     ...
# 50297    IMPALA 3.5L V6 SFI   LT         AUTO            1   60267
# 50298            PT CRUISER  Bas         AUTO            2   49995
# 50299            AVENGER 4C   SE         AUTO            2   51951
# 50300                  AVEO   LS         AUTO            2   71286
# 50301  FUSION 4C 2.3L I4 EF    S         AUTO            1   74273
# 50302                ACCENT  GLS         AUTO            2   47033
# 50303        MALIBU MAXX V6   LS         AUTO            1   71867
# 50304            STRATUS 4C  SXT         AUTO            1   73992
# 50305      FREESTYLE 2WD V6  SEL         AUTO            1   88500
# 50306  STRATUS V6 2.7L V6 M  SXT         AUTO            1   85185
# 50307       WINDSTAR FWD V6   LS         AUTO            1   63496
# 50308    TAURUS 3.0L V6 EFI   SE         AUTO            1   46671
# 50309                   HHR   LS         AUTO            2   73314
# 50310  TRAILBLAZER 4WD 6C 4  Nor         AUTO            2   83049
# 50311                  NEON   SE         AUTO            1   64716
# 50312    MAXIMA 3.5L V6 MPI   SE         AUTO            1   70799
# 50313        TRIBUTE 2WD V6   LX         AUTO            1   77079
# 50314  MUSTANG V6 3.9L V6 E  Bas         AUTO            1   66815
# 50315  CARAVAN GRAND FWD V6  Bas         AUTO            2   78881
# 50316             IMPALA V6   LT         AUTO            1   70642
# 50317              CAMRY 4C   LE         AUTO            1   84235
# 50318  PT CRUISER 2.4L I4 S  Bas         AUTO            2   55544
# 50319   EQUINOX FWD V6 3.4L   LT         AUTO            1   77719
# 50320                   CTS  Bas         AUTO            1   87794
# 50321    F150 PICKUP 2WD V8  STX         AUTO            2   67944
# 50322  STRATUS V6 2.7L V6 M  SXT         AUTO            2   71840
# 50323           MONTE CARLO   LS         AUTO            1   78226
# 50324                 FOCUS  ZX4         AUTO            1   71169
# 50325                IMPALA   LS         AUTO            2   69795
# 50326                SENTRA  Bas         AUTO            1   85326
#
#           Nationality         Size  MMRAcquisitionAuctionAveragePrice  \
# 0         OTHER ASIAN       MEDIUM                              67960
# 1            AMERICAN       MEDIUM                              54800
# 2            AMERICAN       MEDIUM                              80670
# 3            AMERICAN          VAN                              48170
# 4            AMERICAN          VAN                              54300
# 5      TOP LINE ASIAN       MEDIUM                              63620
# 6            AMERICAN       MEDIUM                              84950
# 7         OTHER ASIAN       MEDIUM                              39130
# 8            AMERICAN       MEDIUM                              39360
# 9            AMERICAN       MEDIUM                              77730
# 10           AMERICAN   MEDIUM SUV                              82850
# 11           AMERICAN        LARGE                              36430
# 12           AMERICAN       MEDIUM                              63120
# 13           AMERICAN        LARGE                              80150
# 14           AMERICAN       MEDIUM                              66720
# 15           AMERICAN       MEDIUM                              75950
# 16           AMERICAN          VAN                              69490
# 17           AMERICAN       MEDIUM                              21040
# 18           AMERICAN       MEDIUM                              55690
# 19           AMERICAN   MEDIUM SUV                              49980
# 20           AMERICAN       SPORTS                              49730
# 21           AMERICAN          VAN                              34380
# 22           AMERICAN  LARGE TRUCK                              63900
# 23           AMERICAN       MEDIUM                              93960
# 24           AMERICAN        LARGE                              62380
# 25     TOP LINE ASIAN       MEDIUM                             104350
# 26           AMERICAN   MEDIUM SUV                              69160
# 27           AMERICAN          VAN                              42820
# 28        OTHER ASIAN   MEDIUM SUV                              94590
# 29           AMERICAN       MEDIUM                              96110
# ...               ...          ...                                ...
# 50297        AMERICAN        LARGE                              78700
# 50298        AMERICAN       MEDIUM                              56280
# 50299        AMERICAN       MEDIUM                              88600
# 50300        AMERICAN      COMPACT                              39260
# 50301        AMERICAN       MEDIUM                              84210
# 50302     OTHER ASIAN      COMPACT                              33700
# 50303        AMERICAN       MEDIUM                              54590
# 50304        AMERICAN       MEDIUM                              45230
# 50305        AMERICAN    CROSSOVER                              81030
# 50306        AMERICAN       MEDIUM                              34330
# 50307        AMERICAN          VAN                              35410
# 50308        AMERICAN       MEDIUM                              25160
# 50309        AMERICAN       MEDIUM                              68010
# 50310        AMERICAN   MEDIUM SUV                              63560
# 50311        AMERICAN      COMPACT                              22700
# 50312  TOP LINE ASIAN        LARGE                              82080
# 50313     OTHER ASIAN    SMALL SUV                              56100
# 50314        AMERICAN       SPORTS                              55160
# 50315        AMERICAN          VAN                              65440
# 50316        AMERICAN        LARGE                              91540
# 50317  TOP LINE ASIAN       MEDIUM                              61920
# 50318        AMERICAN       MEDIUM                              34870
# 50319        AMERICAN   MEDIUM SUV                              89070
# 50320        AMERICAN    SPECIALTY                              90860
# 50321        AMERICAN  LARGE TRUCK                              87110
# 50322        AMERICAN       MEDIUM                              55690
# 50323        AMERICAN        LARGE                              80810
# 50324        AMERICAN      COMPACT                              44110
# 50325        AMERICAN        LARGE                              75750
# 50326  TOP LINE ASIAN      COMPACT                              42780
#
#        VehBCost  WarrantyCost
# 0         61000           533
# 1         40000          1630
# 2         75000           693
# 3         47250          1633
# 4         56700          1623
# 5         76750           723
# 6         78100           920
# 7         48250           505
# 8         51250          1503
# 9         73000           764
# 10       101350          1623
# 11        41850          2351
# 12        63050           975
# 13        80000          1703
# 14        74250          1272
# 15        74400           764
# 16        56900          1583
# 17        37000          2198
# 18        46000          1215
# 19        72000          1689
# 20        74950           803
# 21        49000          1633
# 22        91700          1272
# 23        80650          1118
# 24        73050          1328
# 25       103500           686
# 26        93250          1543
# 27        43400          1633
# 28        68000          1893
# 29        86300          1118
# ...         ...           ...
# 50297     76850          1703
# 50298     64250           975
# 50299     82000           920
# 50300     61200           803
# 50301     71850           803
# 50302     55200           693
# 50303     67000          1272
# 50304     57000          1155
# 50305     81700          1633
# 50306     38600          1503
# 50307     50000          1906
# 50308     45500           993
# 50309     83150           803
# 50310     61900          2152
# 50311     47050           930
# 50312     92100          1155
# 50313     69700           920
# 50314     73450           728
# 50315     56000          1623
# 50316     84150          1974
# 50317     73000           594
# 50318     48000          1086
# 50319     87000          1389
# 50320     93350          1763
# 50321    104400           728
# 50322     41000          1389
# 50323     72050          1974
# 50324     46900          1155
# 50325     70000          1703
# 50326     55250           594
#
# [50327 rows x 15 columns]

# %%
# discretization of the numerical attributes 
# equal frequency binning i.e. in each bin there are N / k elements 
k = 6 # from sturgers' rule 
bin_size = dfTraining.shape[0]/k
# creation of new columns for the numerical values discretized in bins 
dfTraining['VehBCostBin'] = pd.cut(dfTraining['VehBCost'].astype(int), bin_size, right=False)
dfTraining['VehOdoBin'] = pd.cut(dfTraining['VehOdo'].astype(int), bin_size, right=False)
dfTraining['MMRAcquisitionAuctionAveragePriceBin'] = pd.cut(dfTraining['MMRAcquisitionAuctionAveragePrice'].astype(int), bin_size, right=False)
dfTraining['WarrantyCostBin'] = pd.cut(dfTraining['WarrantyCost'].astype(int), bin_size, right=False)
# drop of the columns no longer needed 
dfTraining.drop(['VehOdo', 'MMRAcquisitionAuctionAveragePrice','WarrantyCost', 'VehBCost'], axis=1, inplace=True)
# result
dfTraining.head()
# Out:
#    IsBadBuy   PurchDate  Auction  VehicleAge      Make                 Model  \
# 0         1  10/25/2010    ADESA           2       KIA               SPECTRA
# 1         0   5/27/2009  MANHEIM           3     DODGE  STRATUS V6 2.7L V6 M
# 2         0   3/18/2010    OTHER           2     DODGE               CALIBER
# 3         0    6/8/2009    OTHER           4      FORD  FREESTAR FWD V6 3.9L
# 4         0    3/4/2009  MANHEIM           4  CHRYSLER  TOWN & COUNTRY FWD V
#
#   Trim Transmission  WheelTypeID  Nationality    Size             VehBCostBin  \
# 0   EX         AUTO            2  OTHER ASIAN  MEDIUM  [60974.961, 61077.158)
# 1  SXT         AUTO            2     AMERICAN  MEDIUM   [39922.41, 40024.607)
# 2   SE         AUTO            2     AMERICAN  MEDIUM   [74975.93, 75078.127)
# 3    S         AUTO            2     AMERICAN     VAN  [47178.386, 47280.583)
# 4  Bas         AUTO            1     AMERICAN     VAN   [56682.693, 56784.89)
#
#                 VehOdoBin MMRAcquisitionAuctionAveragePriceBin  \
# 0  [61181.314, 61189.175)               [67954.391, 67966.832)
# 1  [92381.525, 92389.386)                 [54792.15, 54804.59)
# 2  [45962.466, 45970.327)               [80668.768, 80681.209)
# 3   [80165.569, 80173.43)               [48161.266, 48173.707)
# 4  [77367.062, 77374.923)               [54294.522, 54306.963)
#
#         WarrantyCostBin
# 0    [532.944, 533.182)
# 1   [1629.853, 1630.09)
# 2    [692.866, 693.103)
# 3  [1632.937, 1633.174)
# 4  [1622.972, 1623.209)

# %%
# transformation of the variable in string, concatenating an fixed identificator 
dfTraining['IsBadBuy'] = dfTraining['IsBadBuy'].astype(str) + '_IsBadBuy'
dfTraining['VehicleAge'] = dfTraining['VehicleAge'].astype(str) + '_VehicleAge'
dfTraining['WheelTypeID'] = dfTraining['WheelTypeID'].astype(str) + '_WheelTypeID'
dfTraining['VehBCostBin'] = dfTraining['VehBCostBin'].astype(str) + '_VehBCostBin'
dfTraining['VehOdoBin'] = dfTraining['VehOdoBin'].astype(str) + '_VehOdoBin'
dfTraining['Trim'] = dfTraining['Trim'].astype(str) + '_Trim'
dfTraining['MMRAcquisitionAuctionAveragePriceBin'] = dfTraining['MMRAcquisitionAuctionAveragePriceBin'].astype(str) + '_MMRAcquisitionAuctionAveragePriceBin'
dfTraining['WarrantyCostBin'] = dfTraining['WarrantyCostBin'].astype(str) + '_WarrantyCostBin'
# result
dfTraining
# Out:
#          IsBadBuy   PurchDate  Auction    VehicleAge       Make  \
# 0      1_IsBadBuy  10/25/2010    ADESA  2_VehicleAge        KIA
# 1      0_IsBadBuy   5/27/2009  MANHEIM  3_VehicleAge      DODGE
# 2      0_IsBadBuy   3/18/2010    OTHER  2_VehicleAge      DODGE
# 3      0_IsBadBuy    6/8/2009    OTHER  4_VehicleAge       FORD
# 4      0_IsBadBuy    3/4/2009  MANHEIM  4_VehicleAge   CHRYSLER
# 5      0_IsBadBuy   5/21/2010    ADESA  5_VehicleAge     NISSAN
# 6      0_IsBadBuy   9/24/2009  MANHEIM  1_VehicleAge      DODGE
# 7      0_IsBadBuy    6/4/2009  MANHEIM  3_VehicleAge     SUZUKI
# 8      0_IsBadBuy  10/13/2009  MANHEIM  5_VehicleAge   CHRYSLER
# 9      0_IsBadBuy   2/10/2010  MANHEIM  3_VehicleAge    PONTIAC
# 10     0_IsBadBuy   5/12/2010  MANHEIM  5_VehicleAge      DODGE
# 11     0_IsBadBuy    6/5/2009  MANHEIM  5_VehicleAge  CHEVROLET
# 12     0_IsBadBuy   8/11/2009    ADESA  2_VehicleAge   CHRYSLER
# 13     0_IsBadBuy   7/23/2010    OTHER  3_VehicleAge  CHEVROLET
# 14     0_IsBadBuy   5/20/2010  MANHEIM  4_VehicleAge    PONTIAC
# 15     0_IsBadBuy   1/13/2010  MANHEIM  2_VehicleAge  CHEVROLET
# 16     0_IsBadBuy   1/29/2009  MANHEIM  3_VehicleAge     SATURN
# 17     0_IsBadBuy    7/8/2009  MANHEIM  7_VehicleAge  CHEVROLET
# 18     0_IsBadBuy   5/27/2009  MANHEIM  4_VehicleAge      DODGE
# 19     0_IsBadBuy   3/15/2010  MANHEIM  7_VehicleAge      DODGE
# 20     0_IsBadBuy  11/25/2009    OTHER  5_VehicleAge       FORD
# 21     0_IsBadBuy  10/28/2009    OTHER  4_VehicleAge       FORD
# 22     0_IsBadBuy   7/29/2010    ADESA  6_VehicleAge  CHEVROLET
# 23     0_IsBadBuy   2/11/2010    ADESA  3_VehicleAge     SATURN
# 24     0_IsBadBuy   8/24/2010    OTHER  4_VehicleAge    PONTIAC
# 25     0_IsBadBuy   9/29/2010  MANHEIM  3_VehicleAge     NISSAN
# 26     0_IsBadBuy   2/25/2010    ADESA  7_VehicleAge       FORD
# 27     0_IsBadBuy    2/3/2009  MANHEIM  4_VehicleAge       FORD
# 28     0_IsBadBuy    5/5/2010    OTHER  4_VehicleAge        KIA
# 29     0_IsBadBuy    8/2/2010  MANHEIM  2_VehicleAge     SATURN
# ...           ...         ...      ...           ...        ...
# 50297  0_IsBadBuy   3/11/2009  MANHEIM  3_VehicleAge  CHEVROLET
# 50298  0_IsBadBuy    2/2/2010  MANHEIM  3_VehicleAge   CHRYSLER
# 50299  0_IsBadBuy   3/10/2010    OTHER  2_VehicleAge      DODGE
# 50300  1_IsBadBuy   4/22/2010  MANHEIM  4_VehicleAge  CHEVROLET
# 50301  1_IsBadBuy   8/13/2009  MANHEIM  2_VehicleAge       FORD
# 50302  1_IsBadBuy   4/29/2010  MANHEIM  5_VehicleAge    HYUNDAI
# 50303  1_IsBadBuy   5/25/2010  MANHEIM  6_VehicleAge  CHEVROLET
# 50304  0_IsBadBuy   2/17/2010  MANHEIM  4_VehicleAge      DODGE
# 50305  0_IsBadBuy    5/6/2010  MANHEIM  5_VehicleAge       FORD
# 50306  0_IsBadBuy   1/27/2009  MANHEIM  4_VehicleAge      DODGE
# 50307  0_IsBadBuy  12/14/2010  MANHEIM  7_VehicleAge       FORD
# 50308  0_IsBadBuy   9/22/2009    OTHER  7_VehicleAge       FORD
# 50309  0_IsBadBuy   4/23/2010    ADESA  3_VehicleAge  CHEVROLET
# 50310  1_IsBadBuy   2/12/2009    ADESA  5_VehicleAge  CHEVROLET
# 50311  0_IsBadBuy  11/30/2010  MANHEIM  7_VehicleAge      DODGE
# 50312  0_IsBadBuy   4/16/2009    ADESA  5_VehicleAge     NISSAN
# 50313  0_IsBadBuy   1/28/2010  MANHEIM  6_VehicleAge      MAZDA
# 50314  0_IsBadBuy   8/27/2009    ADESA  5_VehicleAge       FORD
# 50315  0_IsBadBuy    5/5/2009    OTHER  3_VehicleAge      DODGE
# 50316  0_IsBadBuy   5/12/2010    ADESA  3_VehicleAge  CHEVROLET
# 50317  0_IsBadBuy   8/30/2010    ADESA  6_VehicleAge     TOYOTA
# 50318  0_IsBadBuy   4/20/2009    ADESA  5_VehicleAge   CHRYSLER
# 50319  0_IsBadBuy    1/7/2009    OTHER  2_VehicleAge  CHEVROLET
# 50320  0_IsBadBuy    4/5/2010  MANHEIM  6_VehicleAge   CADILLAC
# 50321  0_IsBadBuy   7/13/2010  MANHEIM  5_VehicleAge       FORD
# 50322  0_IsBadBuy    5/5/2009    OTHER  4_VehicleAge      DODGE
# 50323  0_IsBadBuy    3/9/2010    OTHER  3_VehicleAge  CHEVROLET
# 50324  0_IsBadBuy   1/26/2010    OTHER  4_VehicleAge       FORD
# 50325  0_IsBadBuy  10/28/2010    OTHER  3_VehicleAge  CHEVROLET
# 50326  1_IsBadBuy   12/1/2010  MANHEIM  5_VehicleAge     NISSAN
#
#                       Model      Trim Transmission    WheelTypeID  \
# 0                   SPECTRA   EX_Trim         AUTO  2_WheelTypeID
# 1      STRATUS V6 2.7L V6 M  SXT_Trim         AUTO  2_WheelTypeID
# 2                   CALIBER   SE_Trim         AUTO  2_WheelTypeID
# 3      FREESTAR FWD V6 3.9L    S_Trim         AUTO  2_WheelTypeID
# 4      TOWN & COUNTRY FWD V  Bas_Trim         AUTO  1_WheelTypeID
# 5                    ALTIMA  Bas_Trim         AUTO  2_WheelTypeID
# 6      AVENGER 4C 2.4L I4 S   SE_Trim         AUTO  2_WheelTypeID
# 7       FORENZA 2.0L I4 EFI   LS_Trim       MANUAL  2_WheelTypeID
# 8      PT CRUISER 2.4L I4 S  Bas_Trim         AUTO  2_WheelTypeID
# 9                     G6 4C  Bas_Trim         AUTO  1_WheelTypeID
# 10           DURANGO 4WD V8  SLT_Trim         AUTO  1_WheelTypeID
# 11       IMPALA 3.4L V6 SFI  Bas_Trim         AUTO  1_WheelTypeID
# 12     PT CRUISER 2.4L I4 S  Bas_Trim         AUTO  2_WheelTypeID
# 13                   IMPALA   LS_Trim         AUTO  2_WheelTypeID
# 14                    G6 V6  Bas_Trim         AUTO  1_WheelTypeID
# 15                MALIBU 4C   LS_Trim         AUTO  2_WheelTypeID
# 16             RELAY 2WD V6   SE_Trim         AUTO  1_WheelTypeID
# 17     MALIBU V6 3.1L V6 SF  Bas_Trim         AUTO  2_WheelTypeID
# 18     STRATUS V6 2.7L V6 M  SXT_Trim         AUTO  2_WheelTypeID
# 19           DURANGO 2WD V8  SLT_Trim         AUTO  1_WheelTypeID
# 20               MUSTANG V6  Bas_Trim         AUTO  1_WheelTypeID
# 21     FREESTAR FWD V6 3.9L    S_Trim         AUTO  2_WheelTypeID
# 22     1500 SILVERADO PICKU   LS_Trim         AUTO  2_WheelTypeID
# 23                     AURA   XE_Trim         AUTO  2_WheelTypeID
# 24               GRAND PRIX  Bas_Trim         AUTO  1_WheelTypeID
# 25                   ALTIMA  Bas_Trim         AUTO  1_WheelTypeID
# 26          EXPLORER 2WD V6  XLS_Trim         AUTO  1_WheelTypeID
# 27     FREESTAR FWD V6 3.9L   SE_Trim         AUTO  2_WheelTypeID
# 28              SORENTO 2WD   EX_Trim       MANUAL  1_WheelTypeID
# 29                  AURA V6   XE_Trim         AUTO  2_WheelTypeID
# ...                     ...       ...          ...            ...
# 50297    IMPALA 3.5L V6 SFI   LT_Trim         AUTO  1_WheelTypeID
# 50298            PT CRUISER  Bas_Trim         AUTO  2_WheelTypeID
# 50299            AVENGER 4C   SE_Trim         AUTO  2_WheelTypeID
# 50300                  AVEO   LS_Trim         AUTO  2_WheelTypeID
# 50301  FUSION 4C 2.3L I4 EF    S_Trim         AUTO  1_WheelTypeID
# 50302                ACCENT  GLS_Trim         AUTO  2_WheelTypeID
# 50303        MALIBU MAXX V6   LS_Trim         AUTO  1_WheelTypeID
# 50304            STRATUS 4C  SXT_Trim         AUTO  1_WheelTypeID
# 50305      FREESTYLE 2WD V6  SEL_Trim         AUTO  1_WheelTypeID
# 50306  STRATUS V6 2.7L V6 M  SXT_Trim         AUTO  1_WheelTypeID
# 50307       WINDSTAR FWD V6   LS_Trim         AUTO  1_WheelTypeID
# 50308    TAURUS 3.0L V6 EFI   SE_Trim         AUTO  1_WheelTypeID
# 50309                   HHR   LS_Trim         AUTO  2_WheelTypeID
# 50310  TRAILBLAZER 4WD 6C 4  Nor_Trim         AUTO  2_WheelTypeID
# 50311                  NEON   SE_Trim         AUTO  1_WheelTypeID
# 50312    MAXIMA 3.5L V6 MPI   SE_Trim         AUTO  1_WheelTypeID
# 50313        TRIBUTE 2WD V6   LX_Trim         AUTO  1_WheelTypeID
# 50314  MUSTANG V6 3.9L V6 E  Bas_Trim         AUTO  1_WheelTypeID
# 50315  CARAVAN GRAND FWD V6  Bas_Trim         AUTO  2_WheelTypeID
# 50316             IMPALA V6   LT_Trim         AUTO  1_WheelTypeID
# 50317              CAMRY 4C   LE_Trim         AUTO  1_WheelTypeID
# 50318  PT CRUISER 2.4L I4 S  Bas_Trim         AUTO  2_WheelTypeID
# 50319   EQUINOX FWD V6 3.4L   LT_Trim         AUTO  1_WheelTypeID
# 50320                   CTS  Bas_Trim         AUTO  1_WheelTypeID
# 50321    F150 PICKUP 2WD V8  STX_Trim         AUTO  2_WheelTypeID
# 50322  STRATUS V6 2.7L V6 M  SXT_Trim         AUTO  2_WheelTypeID
# 50323           MONTE CARLO   LS_Trim         AUTO  1_WheelTypeID
# 50324                 FOCUS  ZX4_Trim         AUTO  1_WheelTypeID
# 50325                IMPALA   LS_Trim         AUTO  2_WheelTypeID
# 50326                SENTRA  Bas_Trim         AUTO  1_WheelTypeID
#
#           Nationality         Size                           VehBCostBin  \
# 0         OTHER ASIAN       MEDIUM    [60974.961, 61077.158)_VehBCostBin
# 1            AMERICAN       MEDIUM     [39922.41, 40024.607)_VehBCostBin
# 2            AMERICAN       MEDIUM     [74975.93, 75078.127)_VehBCostBin
# 3            AMERICAN          VAN    [47178.386, 47280.583)_VehBCostBin
# 4            AMERICAN          VAN     [56682.693, 56784.89)_VehBCostBin
# 5      TOP LINE ASIAN       MEDIUM    [76713.276, 76815.473)_VehBCostBin
# 6            AMERICAN       MEDIUM    [78041.836, 78144.032)_VehBCostBin
# 7         OTHER ASIAN       MEDIUM    [48200.355, 48302.552)_VehBCostBin
# 8            AMERICAN       MEDIUM     [51164.063, 51266.26)_VehBCostBin
# 9            AMERICAN       MEDIUM     [72931.993, 73034.19)_VehBCostBin
# 10           AMERICAN   MEDIUM SUV  [101342.718, 101444.915)_VehBCostBin
# 11           AMERICAN        LARGE     [41761.953, 41864.15)_VehBCostBin
# 12           AMERICAN       MEDIUM    [63018.898, 63121.095)_VehBCostBin
# 13           AMERICAN        LARGE    [79983.576, 80085.773)_VehBCostBin
# 14           AMERICAN       MEDIUM    [74158.355, 74260.552)_VehBCostBin
# 15           AMERICAN       MEDIUM    [74362.749, 74464.946)_VehBCostBin
# 16           AMERICAN          VAN    [56887.087, 56989.284)_VehBCostBin
# 17           AMERICAN       MEDIUM    [36958.701, 37060.898)_VehBCostBin
# 18           AMERICAN       MEDIUM    [45952.024, 46054.221)_VehBCostBin
# 19           AMERICAN   MEDIUM SUV    [71910.024, 72012.221)_VehBCostBin
# 20           AMERICAN       SPORTS     [74873.733, 74975.93)_VehBCostBin
# 21           AMERICAN          VAN     [48915.733, 49017.93)_VehBCostBin
# 22           AMERICAN  LARGE TRUCK    [91634.017, 91736.214)_VehBCostBin
# 23           AMERICAN       MEDIUM    [80596.757, 80698.954)_VehBCostBin
# 24           AMERICAN        LARGE     [73034.19, 73136.387)_VehBCostBin
# 25     TOP LINE ASIAN       MEDIUM  [103488.852, 103591.049)_VehBCostBin
# 26           AMERICAN   MEDIUM SUV     [93166.97, 93269.167)_VehBCostBin
# 27           AMERICAN          VAN      [43397.103, 43499.3)_VehBCostBin
# 28        OTHER ASIAN   MEDIUM SUV    [67924.347, 68026.544)_VehBCostBin
# 29           AMERICAN       MEDIUM    [86217.584, 86319.781)_VehBCostBin
# ...               ...          ...                                   ...
# 50297        AMERICAN        LARGE     [76815.473, 76917.67)_VehBCostBin
# 50298        AMERICAN       MEDIUM    [64245.261, 64347.457)_VehBCostBin
# 50299        AMERICAN       MEDIUM    [81925.316, 82027.513)_VehBCostBin
# 50300        AMERICAN      COMPACT    [61179.355, 61281.552)_VehBCostBin
# 50301        AMERICAN       MEDIUM    [71807.828, 71910.024)_VehBCostBin
# 50302     OTHER ASIAN      COMPACT    [55149.741, 55251.938)_VehBCostBin
# 50303        AMERICAN       MEDIUM    [66902.379, 67004.576)_VehBCostBin
# 50304        AMERICAN       MEDIUM    [56989.284, 57091.481)_VehBCostBin
# 50305        AMERICAN    CROSSOVER    [81618.725, 81720.922)_VehBCostBin
# 50306        AMERICAN       MEDIUM    [38593.851, 38696.047)_VehBCostBin
# 50307        AMERICAN          VAN    [49937.701, 50039.898)_VehBCostBin
# 50308        AMERICAN       MEDIUM     [45441.04, 45543.237)_VehBCostBin
# 50309        AMERICAN       MEDIUM    [83049.481, 83151.678)_VehBCostBin
# 50310        AMERICAN   MEDIUM SUV     [61894.733, 61996.93)_VehBCostBin
# 50311        AMERICAN      COMPACT    [46973.992, 47076.189)_VehBCostBin
# 50312  TOP LINE ASIAN        LARGE    [92042.804, 92145.001)_VehBCostBin
# 50313     OTHER ASIAN    SMALL SUV    [69661.694, 69763.891)_VehBCostBin
# 50314        AMERICAN       SPORTS    [73442.977, 73545.174)_VehBCostBin
# 50315        AMERICAN          VAN    [55967.315, 56069.512)_VehBCostBin
# 50316        AMERICAN        LARGE     [84071.45, 84173.647)_VehBCostBin
# 50317  TOP LINE ASIAN       MEDIUM     [72931.993, 73034.19)_VehBCostBin
# 50318        AMERICAN       MEDIUM    [47995.961, 48098.158)_VehBCostBin
# 50319        AMERICAN   MEDIUM SUV    [86932.962, 87035.159)_VehBCostBin
# 50320        AMERICAN    SPECIALTY    [93269.167, 93371.363)_VehBCostBin
# 50321        AMERICAN  LARGE TRUCK  [104306.427, 104408.623)_VehBCostBin
# 50322        AMERICAN       MEDIUM    [40944.378, 41046.575)_VehBCostBin
# 50323        AMERICAN        LARGE    [72012.221, 72114.418)_VehBCostBin
# 50324        AMERICAN      COMPACT    [46871.796, 46973.992)_VehBCostBin
# 50325        AMERICAN        LARGE    [69968.284, 70070.481)_VehBCostBin
# 50326  TOP LINE ASIAN      COMPACT    [55149.741, 55251.938)_VehBCostBin
#
#                               VehOdoBin  \
# 0      [61181.314, 61189.175)_VehOdoBin
# 1      [92381.525, 92389.386)_VehOdoBin
# 2      [45962.466, 45970.327)_VehOdoBin
# 3       [80165.569, 80173.43)_VehOdoBin
# 4      [77367.062, 77374.923)_VehOdoBin
# 5      [81470.491, 81478.352)_VehOdoBin
# 6       [56716.28, 56724.141)_VehOdoBin
# 7      [57329.436, 57337.297)_VehOdoBin
# 8       [85086.54, 85094.401)_VehOdoBin
# 9      [43879.307, 43887.168)_VehOdoBin
# 10     [74246.255, 74254.116)_VehOdoBin
# 11     [99943.783, 99951.644)_VehOdoBin
# 12      [42440.749, 42448.61)_VehOdoBin
# 13     [68177.582, 68185.443)_VehOdoBin
# 14      [74599.999, 74607.86)_VehOdoBin
# 15     [43297.595, 43305.456)_VehOdoBin
# 16     [51779.587, 51787.448)_VehOdoBin
# 17     [68609.935, 68617.796)_VehOdoBin
# 18     [64420.036, 64427.897)_VehOdoBin
# 19     [79143.642, 79151.503)_VehOdoBin
# 20      [79921.879, 79929.74)_VehOdoBin
# 21      [87098.949, 87106.81)_VehOdoBin
# 22     [75354.652, 75362.513)_VehOdoBin
# 23     [64640.143, 64648.004)_VehOdoBin
# 24     [46622.788, 46630.649)_VehOdoBin
# 25     [78050.967, 78058.828)_VehOdoBin
# 26     [85856.915, 85864.776)_VehOdoBin
# 27     [88891.252, 88899.113)_VehOdoBin
# 28     [89638.044, 89645.905)_VehOdoBin
# 29     [65347.631, 65355.492)_VehOdoBin
# ...                                 ...
# 50297   [60261.58, 60269.441)_VehOdoBin
# 50298  [49987.285, 49995.146)_VehOdoBin
# 50299  [51944.668, 51952.529)_VehOdoBin
# 50300  [71282.667, 71290.528)_VehOdoBin
# 50301  [74269.838, 74277.699)_VehOdoBin
# 50302  [47031.558, 47039.419)_VehOdoBin
# 50303   [71864.379, 71872.24)_VehOdoBin
# 50304  [73986.843, 73994.704)_VehOdoBin
# 50305  [88498.203, 88506.064)_VehOdoBin
# 50306  [85180.871, 85188.732)_VehOdoBin
# 50307  [63492.441, 63500.302)_VehOdoBin
# 50308  [46669.953, 46677.814)_VehOdoBin
# 50309   [73310.799, 73318.66)_VehOdoBin
# 50310  [83042.686, 83050.547)_VehOdoBin
# 50311  [64710.892, 64718.753)_VehOdoBin
# 50312  [70795.287, 70803.148)_VehOdoBin
# 50313  [77076.206, 77084.067)_VehOdoBin
# 50314  [66809.772, 66817.633)_VehOdoBin
# 50315   [78876.369, 78884.23)_VehOdoBin
# 50316  [70638.067, 70645.928)_VehOdoBin
# 50317  [84229.693, 84237.554)_VehOdoBin
# 50318  [55537.134, 55544.995)_VehOdoBin
# 50319  [77712.945, 77720.806)_VehOdoBin
# 50320  [87790.715, 87798.576)_VehOdoBin
# 50321  [67941.753, 67949.614)_VehOdoBin
# 50322  [71832.935, 71840.796)_VehOdoBin
# 50323  [78223.908, 78231.769)_VehOdoBin
# 50324  [71164.752, 71172.613)_VehOdoBin
# 50325  [69789.082, 69796.943)_VehOdoBin
# 50326   [85322.369, 85330.23)_VehOdoBin
#
#                     MMRAcquisitionAuctionAveragePriceBin  \
# 0      [67954.391, 67966.832)_MMRAcquisitionAuctionAv...
# 1      [54792.15, 54804.59)_MMRAcquisitionAuctionAver...
# 2      [80668.768, 80681.209)_MMRAcquisitionAuctionAv...
# 3      [48161.266, 48173.707)_MMRAcquisitionAuctionAv...
# 4      [54294.522, 54306.963)_MMRAcquisitionAuctionAv...
# 5      [63612.593, 63625.034)_MMRAcquisitionAuctionAv...
# 6      [84948.363, 84960.804)_MMRAcquisitionAuctionAv...
# 7      [39129.331, 39141.772)_MMRAcquisitionAuctionAv...
# 8      [39353.263, 39365.704)_MMRAcquisitionAuctionAv...
# 9      [77720.327, 77732.767)_MMRAcquisitionAuctionAv...
# 10     [82845.888, 82858.328)_MMRAcquisitionAuctionAv...
# 11     [36429.703, 36442.144)_MMRAcquisitionAuctionAv...
# 12     [63114.966, 63127.407)_MMRAcquisitionAuctionAv...
# 13     [80146.26, 80158.7)_MMRAcquisitionAuctionAvera...
# 14     [66710.323, 66722.764)_MMRAcquisitionAuctionAv...
# 15     [75941.309, 75953.75)_MMRAcquisitionAuctionAve...
# 16     [69484.595, 69497.036)_MMRAcquisitionAuctionAv...
# 17     [21028.139, 21040.579)_MMRAcquisitionAuctionAv...
# 18     [55687.879, 55700.32)_MMRAcquisitionAuctionAve...
# 19     [49977.606, 49990.047)_MMRAcquisitionAuctionAv...
# 20     [49728.792, 49741.233)_MMRAcquisitionAuctionAv...
# 21     [34376.991, 34389.431)_MMRAcquisitionAuctionAv...
# 22     [63898.729, 63911.17)_MMRAcquisitionAuctionAve...
# 23     [93955.417, 93967.857)_MMRAcquisitionAuctionAv...
# 24     [62368.525, 62380.966)_MMRAcquisitionAuctionAv...
# 25     [104343.386, 104355.827)_MMRAcquisitionAuction...
# 26     [69148.697, 69161.137)_MMRAcquisitionAuctionAv...
# 27     [42811.773, 42824.214)_MMRAcquisitionAuctionAv...
# 28     [94589.891, 94602.332)_MMRAcquisitionAuctionAv...
# 29     [96107.655, 96120.095)_MMRAcquisitionAuctionAv...
# ...                                                  ...
# 50297  [78690.7, 78703.141)_MMRAcquisitionAuctionAver...
# 50298  [56272.591, 56285.032)_MMRAcquisitionAuctionAv...
# 50299  [88593.483, 88605.923)_MMRAcquisitionAuctionAv...
# 50300  [39253.738, 39266.179)_MMRAcquisitionAuctionAv...
# 50301  [84201.922, 84214.363)_MMRAcquisitionAuctionAv...
# 50302  [33692.753, 33705.194)_MMRAcquisitionAuctionAv...
# 50303  [54580.658, 54593.099)_MMRAcquisitionAuctionAv...
# 50304  [45225.265, 45237.706)_MMRAcquisitionAuctionAv...
# 50305  [81029.548, 81041.989)_MMRAcquisitionAuctionAv...
# 50306  [34327.228, 34339.669)_MMRAcquisitionAuctionAv...
# 50307  [35409.567, 35422.008)_MMRAcquisitionAuctionAv...
# 50308  [25158.445, 25170.886)_MMRAcquisitionAuctionAv...
# 50309  [68004.154, 68016.595)_MMRAcquisitionAuctionAv...
# 50310  [63550.39, 63562.831)_MMRAcquisitionAuctionAve...
# 50311  [22695.19, 22707.631)_MMRAcquisitionAuctionAve...
# 50312  [82074.565, 82087.006)_MMRAcquisitionAuctionAv...
# 50313  [56098.421, 56110.862)_MMRAcquisitionAuctionAv...
# 50314  [55152.93, 55165.37)_MMRAcquisitionAuctionAver...
# 50315  [65428.933, 65441.374)_MMRAcquisitionAuctionAv...
# 50316  [91529.484, 91541.924)_MMRAcquisitionAuctionAv...
# 50317  [61908.22, 61920.661)_MMRAcquisitionAuctionAve...
# 50318  [34862.177, 34874.618)_MMRAcquisitionAuctionAv...
# 50319  [89066.229, 89078.669)_MMRAcquisitionAuctionAv...
# 50320  [90857.687, 90870.128)_MMRAcquisitionAuctionAv...
# 50321  [87100.601, 87113.042)_MMRAcquisitionAuctionAv...
# 50322  [55687.879, 55700.32)_MMRAcquisitionAuctionAve...
# 50323  [80805.616, 80818.057)_MMRAcquisitionAuctionAv...
# 50324  [44105.604, 44118.045)_MMRAcquisitionAuctionAv...
# 50325  [75742.258, 75754.699)_MMRAcquisitionAuctionAv...
# 50326  [42774.451, 42786.892)_MMRAcquisitionAuctionAv...
#
#                             WarrantyCostBin
# 0        [532.944, 533.182)_WarrantyCostBin
# 1       [1629.853, 1630.09)_WarrantyCostBin
# 2        [692.866, 693.103)_WarrantyCostBin
# 3      [1632.937, 1633.174)_WarrantyCostBin
# 4      [1622.972, 1623.209)_WarrantyCostBin
# 5        [722.999, 723.236)_WarrantyCostBin
# 6        [919.935, 920.172)_WarrantyCostBin
# 7        [504.946, 505.183)_WarrantyCostBin
# 8      [1502.912, 1503.149)_WarrantyCostBin
# 9         [763.81, 764.047)_WarrantyCostBin
# 10     [1622.972, 1623.209)_WarrantyCostBin
# 11     [2350.922, 2351.159)_WarrantyCostBin
# 12       [974.982, 975.219)_WarrantyCostBin
# 13      [1702.932, 1703.17)_WarrantyCostBin
# 14     [1271.809, 1272.047)_WarrantyCostBin
# 15        [763.81, 764.047)_WarrantyCostBin
# 16      [1582.873, 1583.11)_WarrantyCostBin
# 17     [2197.882, 2198.119)_WarrantyCostBin
# 18     [1214.864, 1215.101)_WarrantyCostBin
# 19     [1688.933, 1689.171)_WarrantyCostBin
# 20        [802.96, 803.197)_WarrantyCostBin
# 21     [1632.937, 1633.174)_WarrantyCostBin
# 22     [1271.809, 1272.047)_WarrantyCostBin
# 23      [1117.82, 1118.057)_WarrantyCostBin
# 24     [1327.805, 1328.043)_WarrantyCostBin
# 25       [685.985, 686.222)_WarrantyCostBin
# 26     [1542.774, 1543.011)_WarrantyCostBin
# 27     [1632.937, 1633.174)_WarrantyCostBin
# 28     [1892.987, 1893.225)_WarrantyCostBin
# 29      [1117.82, 1118.057)_WarrantyCostBin
# ...                                     ...
# 50297   [1702.932, 1703.17)_WarrantyCostBin
# 50298    [974.982, 975.219)_WarrantyCostBin
# 50299    [919.935, 920.172)_WarrantyCostBin
# 50300     [802.96, 803.197)_WarrantyCostBin
# 50301     [802.96, 803.197)_WarrantyCostBin
# 50302    [692.866, 693.103)_WarrantyCostBin
# 50303  [1271.809, 1272.047)_WarrantyCostBin
# 50304  [1154.834, 1155.071)_WarrantyCostBin
# 50305  [1632.937, 1633.174)_WarrantyCostBin
# 50306  [1502.912, 1503.149)_WarrantyCostBin
# 50307    [1905.8, 1906.037)_WarrantyCostBin
# 50308    [992.777, 993.015)_WarrantyCostBin
# 50309     [802.96, 803.197)_WarrantyCostBin
# 50310  [2151.851, 2152.088)_WarrantyCostBin
# 50311      [929.9, 930.138)_WarrantyCostBin
# 50312  [1154.834, 1155.071)_WarrantyCostBin
# 50313    [919.935, 920.172)_WarrantyCostBin
# 50314    [727.982, 728.219)_WarrantyCostBin
# 50315  [1622.972, 1623.209)_WarrantyCostBin
# 50316  [1973.897, 1974.134)_WarrantyCostBin
# 50317     [593.923, 594.16)_WarrantyCostBin
# 50318  [1085.788, 1086.025)_WarrantyCostBin
# 50319  [1388.784, 1389.022)_WarrantyCostBin
# 50320  [1762.962, 1763.199)_WarrantyCostBin
# 50321    [727.982, 728.219)_WarrantyCostBin
# 50322  [1388.784, 1389.022)_WarrantyCostBin
# 50323  [1973.897, 1974.134)_WarrantyCostBin
# 50324  [1154.834, 1155.071)_WarrantyCostBin
# 50325   [1702.932, 1703.17)_WarrantyCostBin
# 50326     [593.923, 594.16)_WarrantyCostBin
#
# [50327 rows x 15 columns]

# %%
# import essential to perform AR 
from fim import apriori

# %%
baskets = dfTraining.values
# extracting only frequent patterns through the algorithm apriori and its parameters
# supp = support 
# zmin = minimum number of items per item set
# target 'a' = all frequent item sets
itemsets = apriori(baskets, supp=6, zmin=2, target='a')

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift for negated head) (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             k     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value from (unnormalized) chi^2 measure  (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value from Yates-corrected chi^2 measure (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value from G statistic/info. difference  (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: a)
#             b     basic      standard algorithm (only choice)
#     mode    operation mode indicators/flags        (default: None)
#             x     do not use perfect extension pruning
#             t/T   do not organize transactions as a prefix tree
#             y     a-posteriori pruning of infrequent item sets
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %%
print('Number of itemsets:', len(itemsets))
# Out:
# Number of itemsets: 679

# %%
# result: item and occurrence number of the item in the dataset 
itemsets[:]
# Out:
# [(('VAN', 'AMERICAN'), 3671),
#  (('VAN', 'AMERICAN', '0_IsBadBuy'), 3255),
#  (('VAN', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3254),
#  (('VAN', 'AMERICAN', 'AUTO'), 3670),
#  (('VAN', '0_IsBadBuy'), 3334),
#  (('VAN', '0_IsBadBuy', 'AUTO'), 3333),
#  (('VAN', 'AUTO'), 3766),
#  (('COMPACT', '2_WheelTypeID'), 3344),
#  (('COMPACT', 'AMERICAN'), 3840),
#  (('COMPACT', 'AMERICAN', '0_IsBadBuy'), 3235),
#  (('COMPACT', 'AMERICAN', 'AUTO'), 3452),
#  (('COMPACT', '0_IsBadBuy'), 4394),
#  (('COMPACT', '0_IsBadBuy', 'AUTO'), 3901),
#  (('COMPACT', 'AUTO'), 4632),
#  (('MEDIUM SUV', '1_WheelTypeID'), 4621),
#  (('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN'), 3825),
#  (('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3321),
#  (('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3272),
#  (('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 3771),
#  (('MEDIUM SUV', '1_WheelTypeID', '0_IsBadBuy'), 3991),
#  (('MEDIUM SUV', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3905),
#  (('MEDIUM SUV', '1_WheelTypeID', 'AUTO'), 4527),
#  (('MEDIUM SUV', 'MANHEIM'), 3250),
#  (('MEDIUM SUV', 'MANHEIM', 'AUTO'), 3175),
#  (('MEDIUM SUV', 'AMERICAN'), 4462),
#  (('MEDIUM SUV', 'AMERICAN', '0_IsBadBuy'), 3838),
#  (('MEDIUM SUV', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3776),
#  (('MEDIUM SUV', 'AMERICAN', 'AUTO'), 4393),
#  (('MEDIUM SUV', '0_IsBadBuy'), 4542),
#  (('MEDIUM SUV', '0_IsBadBuy', 'AUTO'), 4438),
#  (('MEDIUM SUV', 'AUTO'), 5201),
#  (('6_VehicleAge', '1_WheelTypeID'), 3898),
#  (('6_VehicleAge', '1_WheelTypeID', 'AMERICAN'), 3253),
#  (('6_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 3134),
#  (('6_VehicleAge', '1_WheelTypeID', '0_IsBadBuy'), 3265),
#  (('6_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3116),
#  (('6_VehicleAge', '1_WheelTypeID', 'AUTO'), 3729),
#  (('6_VehicleAge', 'MANHEIM'), 3362),
#  (('6_VehicleAge', 'MANHEIM', 'AUTO'), 3180),
#  (('6_VehicleAge', 'AMERICAN'), 4627),
#  (('6_VehicleAge', 'AMERICAN', '0_IsBadBuy'), 3831),
#  (('6_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3650),
#  (('6_VehicleAge', 'AMERICAN', 'AUTO'), 4418),
#  (('6_VehicleAge', '0_IsBadBuy'), 4686),
#  (('6_VehicleAge', '0_IsBadBuy', 'AUTO'), 4428),
#  (('6_VehicleAge', 'AUTO'), 5375),
#  (('OTHER ASIAN', 'MEDIUM'), 3593),
#  (('OTHER ASIAN', 'MEDIUM', '0_IsBadBuy'), 3166),
#  (('OTHER ASIAN', 'MEDIUM', 'AUTO'), 3277),
#  (('OTHER ASIAN', 'MANHEIM'), 3206),
#  (('OTHER ASIAN', '0_IsBadBuy'), 4950),
#  (('OTHER ASIAN', '0_IsBadBuy', 'AUTO'), 4497),
#  (('OTHER ASIAN', 'AUTO'), 5198),
#  (('2_VehicleAge', 'MEDIUM'), 3153),
#  (('2_VehicleAge', 'MEDIUM', 'AUTO'), 3115),
#  (('2_VehicleAge', '2_WheelTypeID'), 3993),
#  (('2_VehicleAge', '2_WheelTypeID', 'AMERICAN'), 3547),
#  (('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3337),
#  (('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3317),
#  (('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 3524),
#  (('2_VehicleAge', '2_WheelTypeID', '0_IsBadBuy'), 3746),
#  (('2_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3696),
#  (('2_VehicleAge', '2_WheelTypeID', 'AUTO'), 3938),
#  (('2_VehicleAge', 'AMERICAN'), 5138),
#  (('2_VehicleAge', 'AMERICAN', '0_IsBadBuy'), 4807),
#  (('2_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4779),
#  (('2_VehicleAge', 'AMERICAN', 'AUTO'), 5107),
#  (('2_VehicleAge', '0_IsBadBuy'), 5357),
#  (('2_VehicleAge', '0_IsBadBuy', 'AUTO'), 5293),
#  (('2_VehicleAge', 'AUTO'), 5666),
#  (('1_IsBadBuy', '1_WheelTypeID'), 3207),
#  (('1_IsBadBuy', '1_WheelTypeID', 'AUTO'), 3125),
#  (('1_IsBadBuy', 'AMERICAN'), 4760),
#  (('1_IsBadBuy', 'AMERICAN', 'AUTO'), 4640),
#  (('1_IsBadBuy', 'AUTO'), 5642),
#  (('CHRYSLER', 'AMERICAN'), 6335),
#  (('CHRYSLER', 'Bas_Trim', 'AMERICAN'), 3077),
#  (('CHRYSLER', 'Bas_Trim'), 3077),
#  (('CHRYSLER', 'MEDIUM', 'AMERICAN'), 4539),
#  (('CHRYSLER', 'MEDIUM'), 4539),
#  (('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AMERICAN'), 3943),
#  (('CHRYSLER', 'MEDIUM', '0_IsBadBuy'), 3943),
#  (('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3835),
#  (('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 3835),
#  (('CHRYSLER', 'MEDIUM', 'AUTO', 'AMERICAN'), 4408),
#  (('CHRYSLER', 'MEDIUM', 'AUTO'), 4408),
#  (('CHRYSLER', '2_WheelTypeID', 'AMERICAN'), 3986),
#  (('CHRYSLER', '2_WheelTypeID'), 3986),
#  (('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 3572),
#  (('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy'), 3572),
#  (('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3495),
#  (('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3495),
#  (('CHRYSLER', '2_WheelTypeID', 'AUTO', 'AMERICAN'), 3896),
#  (('CHRYSLER', '2_WheelTypeID', 'AUTO'), 3896),
#  (('CHRYSLER', 'MANHEIM', 'AMERICAN'), 3377),
#  (('CHRYSLER', 'MANHEIM'), 3377),
#  (('CHRYSLER', 'MANHEIM', 'AUTO', 'AMERICAN'), 3299),
#  (('CHRYSLER', 'MANHEIM', 'AUTO'), 3299),
#  (('CHRYSLER', '0_IsBadBuy', 'AMERICAN'), 5554),
#  (('CHRYSLER', '0_IsBadBuy'), 5554),
#  (('CHRYSLER', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 5446),
#  (('CHRYSLER', '0_IsBadBuy', 'AUTO'), 5446),
#  (('CHRYSLER', 'AUTO', 'AMERICAN'), 6204),
#  (('CHRYSLER', 'AUTO'), 6204),
#  (('LARGE', 'AUTO'), 6605),
#  (('LARGE', 'CHEVROLET', 'AUTO', 'AMERICAN'), 3982),
#  (('LARGE', 'CHEVROLET', 'AUTO'), 3982),
#  (('LARGE', 'CHEVROLET', 'AMERICAN'), 3982),
#  (('LARGE', 'CHEVROLET'), 3982),
#  (('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3705),
#  (('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AUTO'), 3705),
#  (('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AMERICAN'), 3705),
#  (('LARGE', 'CHEVROLET', '0_IsBadBuy'), 3705),
#  (('LARGE', '1_WheelTypeID', 'AUTO'), 3461),
#  (('LARGE', '1_WheelTypeID'), 3461),
#  (('LARGE', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 3328),
#  (('LARGE', '1_WheelTypeID', 'AMERICAN'), 3328),
#  (('LARGE', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3039),
#  (('LARGE', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3039),
#  (('LARGE', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3134),
#  (('LARGE', '1_WheelTypeID', '0_IsBadBuy'), 3134),
#  (('LARGE', '2_WheelTypeID', 'AUTO'), 3109),
#  (('LARGE', '2_WheelTypeID'), 3109),
#  (('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 3093),
#  (('LARGE', '2_WheelTypeID', 'AMERICAN'), 3093),
#  (('LARGE', 'MANHEIM', 'AUTO'), 3794),
#  (('LARGE', 'MANHEIM'), 3794),
#  (('LARGE', 'MANHEIM', 'AMERICAN', 'AUTO'), 3699),
#  (('LARGE', 'MANHEIM', 'AMERICAN'), 3699),
#  (('LARGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3448),
#  (('LARGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 3448),
#  (('LARGE', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3518),
#  (('LARGE', 'MANHEIM', '0_IsBadBuy'), 3518),
#  (('LARGE', 'AMERICAN', 'AUTO'), 6455),
#  (('LARGE', 'AMERICAN'), 6455),
#  (('LARGE', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5951),
#  (('LARGE', 'AMERICAN', '0_IsBadBuy'), 5951),
#  (('LARGE', '0_IsBadBuy', 'AUTO'), 6059),
#  (('LARGE', '0_IsBadBuy'), 6059),
#  (('SE_Trim', 'DODGE', 'AMERICAN'), 3528),
#  (('SE_Trim', 'DODGE'), 3528),
#  (('SE_Trim', 'DODGE', '0_IsBadBuy', 'AMERICAN'), 3198),
#  (('SE_Trim', 'DODGE', '0_IsBadBuy'), 3198),
#  (('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3188),
#  (('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO'), 3188),
#  (('SE_Trim', 'DODGE', 'AUTO', 'AMERICAN'), 3517),
#  (('SE_Trim', 'DODGE', 'AUTO'), 3517),
#  (('SE_Trim', 'MEDIUM'), 4203),
#  (('SE_Trim', 'MEDIUM', 'AMERICAN'), 3934),
#  (('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy'), 3528),
#  (('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3512),
#  (('SE_Trim', 'MEDIUM', 'AMERICAN', 'AUTO'), 3915),
#  (('SE_Trim', 'MEDIUM', '0_IsBadBuy'), 3759),
#  (('SE_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 3725),
#  (('SE_Trim', 'MEDIUM', 'AUTO'), 4165),
#  (('SE_Trim', '2_WheelTypeID'), 4439),
#  (('SE_Trim', '2_WheelTypeID', 'AMERICAN'), 4210),
#  (('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3816),
#  (('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3791),
#  (('SE_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 4180),
#  (('SE_Trim', '2_WheelTypeID', '0_IsBadBuy'), 4007),
#  (('SE_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3967),
#  (('SE_Trim', '2_WheelTypeID', 'AUTO'), 4392),
#  (('SE_Trim', 'MANHEIM'), 3449),
#  (('SE_Trim', 'MANHEIM', 'AMERICAN'), 3121),
#  (('SE_Trim', 'MANHEIM', 'AMERICAN', 'AUTO'), 3084),
#  (('SE_Trim', 'MANHEIM', '0_IsBadBuy'), 3038),
#  (('SE_Trim', 'MANHEIM', 'AUTO'), 3396),
#  (('SE_Trim', 'AMERICAN'), 6630),
#  (('SE_Trim', 'AMERICAN', '0_IsBadBuy'), 5874),
#  (('SE_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5818),
#  (('SE_Trim', 'AMERICAN', 'AUTO'), 6565),
#  (('SE_Trim', '0_IsBadBuy'), 6329),
#  (('SE_Trim', '0_IsBadBuy', 'AUTO'), 6245),
#  (('SE_Trim', 'AUTO'), 7101),
#  (('FORD', 'AMERICAN'), 7443),
#  (('FORD', '1_WheelTypeID', 'AMERICAN'), 5344),
#  (('FORD', '1_WheelTypeID'), 5344),
#  (('FORD', '1_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3216),
#  (('FORD', '1_WheelTypeID', 'MANHEIM'), 3216),
#  (('FORD', '1_WheelTypeID', 'MANHEIM', 'AUTO', 'AMERICAN'), 3084),
#  (('FORD', '1_WheelTypeID', 'MANHEIM', 'AUTO'), 3084),
#  (('FORD', '1_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 4557),
#  (('FORD', '1_WheelTypeID', '0_IsBadBuy'), 4557),
#  (('FORD', '1_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 4358),
#  (('FORD', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4358),
#  (('FORD', '1_WheelTypeID', 'AUTO', 'AMERICAN'), 5127),
#  (('FORD', '1_WheelTypeID', 'AUTO'), 5127),
#  (('FORD', 'MANHEIM', 'AMERICAN'), 4367),
#  (('FORD', 'MANHEIM'), 4367),
#  (('FORD', 'MANHEIM', '0_IsBadBuy', 'AMERICAN'), 3739),
#  (('FORD', 'MANHEIM', '0_IsBadBuy'), 3739),
#  (('FORD', 'MANHEIM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3558),
#  (('FORD', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3558),
#  (('FORD', 'MANHEIM', 'AUTO', 'AMERICAN'), 4164),
#  (('FORD', 'MANHEIM', 'AUTO'), 4164),
#  (('FORD', '0_IsBadBuy', 'AMERICAN'), 6347),
#  (('FORD', '0_IsBadBuy'), 6347),
#  (('FORD', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 6030),
#  (('FORD', '0_IsBadBuy', 'AUTO'), 6030),
#  (('FORD', 'AUTO', 'AMERICAN'), 7097),
#  (('FORD', 'AUTO'), 7097),
#  (('LS_Trim', 'CHEVROLET', 'AMERICAN'), 6932),
#  (('LS_Trim', 'CHEVROLET'), 6932),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN'), 4507),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID'), 4507),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 4232),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy'), 4232),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'),
#   4138),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4138),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AUTO', 'AMERICAN'), 4399),
#  (('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AUTO'), 4399),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN'), 3921),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM'), 3921),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AMERICAN'), 3662),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy'), 3662),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3598),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3598),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO', 'AMERICAN'), 3849),
#  (('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO'), 3849),
#  (('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AMERICAN'), 6373),
#  (('LS_Trim', 'CHEVROLET', '0_IsBadBuy'), 6373),
#  (('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 6246),
#  (('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO'), 6246),
#  (('LS_Trim', 'CHEVROLET', 'AUTO', 'AMERICAN'), 6788),
#  (('LS_Trim', 'CHEVROLET', 'AUTO'), 6788),
#  (('LS_Trim', '2_WheelTypeID'), 4816),
#  (('LS_Trim', '2_WheelTypeID', 'AMERICAN'), 4578),
#  (('LS_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 4290),
#  (('LS_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4186),
#  (('LS_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 4459),
#  (('LS_Trim', '2_WheelTypeID', '0_IsBadBuy'), 4499),
#  (('LS_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4363),
#  (('LS_Trim', '2_WheelTypeID', 'AUTO'), 4665),
#  (('LS_Trim', 'MANHEIM'), 4405),
#  (('LS_Trim', 'MANHEIM', 'AMERICAN'), 4138),
#  (('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 3846),
#  (('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3766),
#  (('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO'), 4050),
#  (('LS_Trim', 'MANHEIM', '0_IsBadBuy'), 4087),
#  (('LS_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3987),
#  (('LS_Trim', 'MANHEIM', 'AUTO'), 4297),
#  (('LS_Trim', 'AMERICAN'), 7282),
#  (('LS_Trim', 'AMERICAN', '0_IsBadBuy'), 6663),
#  (('LS_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 6508),
#  (('LS_Trim', 'AMERICAN', 'AUTO'), 7109),
#  (('LS_Trim', '0_IsBadBuy'), 7086),
#  (('LS_Trim', '0_IsBadBuy', 'AUTO'), 6892),
#  (('LS_Trim', 'AUTO'), 7548),
#  (('DODGE', 'AMERICAN'), 9177),
#  (('DODGE', 'MEDIUM', 'AMERICAN'), 4254),
#  (('DODGE', 'MEDIUM'), 4254),
#  (('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN'), 3188),
#  (('DODGE', 'MEDIUM', '2_WheelTypeID'), 3188),
#  (('DODGE', 'MEDIUM', '2_WheelTypeID', 'AUTO', 'AMERICAN'), 3179),
#  (('DODGE', 'MEDIUM', '2_WheelTypeID', 'AUTO'), 3179),
#  (('DODGE', 'MEDIUM', '0_IsBadBuy', 'AMERICAN'), 3904),
#  (('DODGE', 'MEDIUM', '0_IsBadBuy'), 3904),
#  (('DODGE', 'MEDIUM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3892),
#  (('DODGE', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 3892),
#  (('DODGE', 'MEDIUM', 'AUTO', 'AMERICAN'), 4239),
#  (('DODGE', 'MEDIUM', 'AUTO'), 4239),
#  (('DODGE', '1_WheelTypeID', 'AMERICAN'), 3685),
#  (('DODGE', '1_WheelTypeID'), 3685),
#  (('DODGE', '1_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 3239),
#  (('DODGE', '1_WheelTypeID', '0_IsBadBuy'), 3239),
#  (('DODGE', '1_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3183),
#  (('DODGE', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3183),
#  (('DODGE', '1_WheelTypeID', 'AUTO', 'AMERICAN'), 3618),
#  (('DODGE', '1_WheelTypeID', 'AUTO'), 3618),
#  (('DODGE', '2_WheelTypeID', 'AMERICAN'), 5409),
#  (('DODGE', '2_WheelTypeID'), 5409),
#  (('DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 4945),
#  (('DODGE', '2_WheelTypeID', '0_IsBadBuy'), 4945),
#  (('DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 4920),
#  (('DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4920),
#  (('DODGE', '2_WheelTypeID', 'AUTO', 'AMERICAN'), 5381),
#  (('DODGE', '2_WheelTypeID', 'AUTO'), 5381),
#  (('DODGE', 'MANHEIM', 'AMERICAN'), 4764),
#  (('DODGE', 'MANHEIM'), 4764),
#  (('DODGE', 'MANHEIM', '0_IsBadBuy', 'AMERICAN'), 4317),
#  (('DODGE', 'MANHEIM', '0_IsBadBuy'), 4317),
#  (('DODGE', 'MANHEIM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 4267),
#  (('DODGE', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 4267),
#  (('DODGE', 'MANHEIM', 'AUTO', 'AMERICAN'), 4706),
#  (('DODGE', 'MANHEIM', 'AUTO'), 4706),
#  (('DODGE', '0_IsBadBuy', 'AMERICAN'), 8258),
#  (('DODGE', '0_IsBadBuy'), 8258),
#  (('DODGE', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 8175),
#  (('DODGE', '0_IsBadBuy', 'AUTO'), 8175),
#  (('DODGE', 'AUTO', 'AMERICAN'), 9080),
#  (('DODGE', 'AUTO'), 9080),
#  (('5_VehicleAge', 'MEDIUM'), 3415),
#  (('5_VehicleAge', 'MEDIUM', 'AUTO'), 3260),
#  (('5_VehicleAge', '1_WheelTypeID'), 5812),
#  (('5_VehicleAge', '1_WheelTypeID', 'MANHEIM'), 3437),
#  (('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO'), 3310),
#  (('5_VehicleAge', '1_WheelTypeID', 'AMERICAN'), 4905),
#  (('5_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 4202),
#  (('5_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4076),
#  (('5_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 4762),
#  (('5_VehicleAge', '1_WheelTypeID', '0_IsBadBuy'), 4957),
#  (('5_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4771),
#  (('5_VehicleAge', '1_WheelTypeID', 'AUTO'), 5598),
#  (('5_VehicleAge', '2_WheelTypeID'), 3540),
#  (('5_VehicleAge', '2_WheelTypeID', 'AUTO'), 3342),
#  (('5_VehicleAge', 'MANHEIM'), 5525),
#  (('5_VehicleAge', 'MANHEIM', 'AMERICAN'), 4465),
#  (('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 3870),
#  (('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3736),
#  (('5_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO'), 4317),
#  (('5_VehicleAge', 'MANHEIM', '0_IsBadBuy'), 4779),
#  (('5_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 4561),
#  (('5_VehicleAge', 'MANHEIM', 'AUTO'), 5281),
#  (('5_VehicleAge', 'AMERICAN'), 7718),
#  (('5_VehicleAge', 'AMERICAN', '0_IsBadBuy'), 6587),
#  (('5_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 6345),
#  (('5_VehicleAge', 'AMERICAN', 'AUTO'), 7447),
#  (('5_VehicleAge', '0_IsBadBuy'), 8076),
#  (('5_VehicleAge', '0_IsBadBuy', 'AUTO'), 7701),
#  (('5_VehicleAge', 'AUTO'), 9055),
#  (('ADESA', 'MEDIUM'), 4148),
#  (('ADESA', 'MEDIUM', '0_IsBadBuy'), 3530),
#  (('ADESA', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 3382),
#  (('ADESA', 'MEDIUM', 'AUTO'), 3986),
#  (('ADESA', '1_WheelTypeID'), 5304),
#  (('ADESA', '1_WheelTypeID', 'AMERICAN'), 4485),
#  (('ADESA', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3863),
#  (('ADESA', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3764),
#  (('ADESA', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 4379),
#  (('ADESA', '1_WheelTypeID', '0_IsBadBuy'), 4532),
#  (('ADESA', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4392),
#  (('ADESA', '1_WheelTypeID', 'AUTO'), 5154),
#  (('ADESA', '2_WheelTypeID'), 4689),
#  (('ADESA', '2_WheelTypeID', 'AMERICAN'), 3649),
#  (('ADESA', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3084),
#  (('ADESA', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 3507),
#  (('ADESA', '2_WheelTypeID', '0_IsBadBuy'), 3976),
#  (('ADESA', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3771),
#  (('ADESA', '2_WheelTypeID', 'AUTO'), 4455),
#  (('ADESA', 'AMERICAN'), 8219),
#  (('ADESA', 'AMERICAN', '0_IsBadBuy'), 7025),
#  (('ADESA', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 6803),
#  (('ADESA', 'AMERICAN', 'AUTO'), 7967),
#  (('ADESA', '0_IsBadBuy'), 8608),
#  (('ADESA', '0_IsBadBuy', 'AUTO'), 8256),
#  (('ADESA', 'AUTO'), 9711),
#  (('Bas_Trim', 'MEDIUM'), 4765),
#  (('Bas_Trim', 'MEDIUM', '2_WheelTypeID'), 3476),
#  (('Bas_Trim', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy'), 3096),
#  (('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO'), 3334),
#  (('Bas_Trim', 'MEDIUM', 'AMERICAN'), 3628),
#  (('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy'), 3195),
#  (('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3097),
#  (('Bas_Trim', 'MEDIUM', 'AMERICAN', 'AUTO'), 3509),
#  (('Bas_Trim', 'MEDIUM', '0_IsBadBuy'), 4205),
#  (('Bas_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 4056),
#  (('Bas_Trim', 'MEDIUM', 'AUTO'), 4588),
#  (('Bas_Trim', '1_WheelTypeID'), 3758),
#  (('Bas_Trim', '1_WheelTypeID', 'AMERICAN'), 3177),
#  (('Bas_Trim', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 3048),
#  (('Bas_Trim', '1_WheelTypeID', '0_IsBadBuy'), 3278),
#  (('Bas_Trim', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3127),
#  (('Bas_Trim', '1_WheelTypeID', 'AUTO'), 3585),
#  (('Bas_Trim', '2_WheelTypeID'), 6542),
#  (('Bas_Trim', '2_WheelTypeID', 'MANHEIM'), 3543),
#  (('Bas_Trim', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 3173),
#  (('Bas_Trim', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3044),
#  (('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AUTO'), 3395),
#  (('Bas_Trim', '2_WheelTypeID', 'AMERICAN'), 5284),
#  (('Bas_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 4701),
#  (('Bas_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4561),
#  (('Bas_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 5123),
#  (('Bas_Trim', '2_WheelTypeID', '0_IsBadBuy'), 5827),
#  (('Bas_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 5602),
#  (('Bas_Trim', '2_WheelTypeID', 'AUTO'), 6285),
#  (('Bas_Trim', 'MANHEIM'), 5761),
#  (('Bas_Trim', 'MANHEIM', 'AMERICAN'), 4731),
#  (('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 4226),
#  (('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4084),
#  (('Bas_Trim', 'MANHEIM', 'AMERICAN', 'AUTO'), 4561),
#  (('Bas_Trim', 'MANHEIM', '0_IsBadBuy'), 5147),
#  (('Bas_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 4933),
#  (('Bas_Trim', 'MANHEIM', 'AUTO'), 5509),
#  (('Bas_Trim', 'AMERICAN'), 8533),
#  (('Bas_Trim', 'AMERICAN', '0_IsBadBuy'), 7556),
#  (('Bas_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 7294),
#  (('Bas_Trim', 'AMERICAN', 'AUTO'), 8233),
#  (('Bas_Trim', '0_IsBadBuy'), 9184),
#  (('Bas_Trim', '0_IsBadBuy', 'AUTO'), 8797),
#  (('Bas_Trim', 'AUTO'), 9947),
#  (('3_VehicleAge', 'CHEVROLET', 'AMERICAN'), 3559),
#  (('3_VehicleAge', 'CHEVROLET'), 3559),
#  (('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AMERICAN'), 3335),
#  (('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy'), 3335),
#  (('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 3281),
#  (('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AUTO'), 3281),
#  (('3_VehicleAge', 'CHEVROLET', 'AUTO', 'AMERICAN'), 3497),
#  (('3_VehicleAge', 'CHEVROLET', 'AUTO'), 3497),
#  (('3_VehicleAge', 'MEDIUM'), 5391),
#  (('3_VehicleAge', 'MEDIUM', '2_WheelTypeID'), 3601),
#  (('3_VehicleAge', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy'), 3305),
#  (('3_VehicleAge', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3183),
#  (('3_VehicleAge', 'MEDIUM', '2_WheelTypeID', 'AUTO'), 3471),
#  (('3_VehicleAge', 'MEDIUM', 'MANHEIM'), 3175),
#  (('3_VehicleAge', 'MEDIUM', 'MANHEIM', 'AUTO'), 3083),
#  (('3_VehicleAge', 'MEDIUM', 'AMERICAN'), 4129),
#  (('3_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy'), 3758),
#  (('3_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3696),
#  (('3_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO'), 4059),
#  (('3_VehicleAge', 'MEDIUM', '0_IsBadBuy'), 4896),
#  (('3_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 4736),
#  (('3_VehicleAge', 'MEDIUM', 'AUTO'), 5219),
#  (('3_VehicleAge', '1_WheelTypeID'), 4445),
#  (('3_VehicleAge', '1_WheelTypeID', 'AMERICAN'), 3855),
#  (('3_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3521),
#  (('3_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3454),
#  (('3_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 3784),
#  (('3_VehicleAge', '1_WheelTypeID', '0_IsBadBuy'), 4038),
#  (('3_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3933),
#  (('3_VehicleAge', '1_WheelTypeID', 'AUTO'), 4333),
#  (('3_VehicleAge', '2_WheelTypeID'), 6952),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM'), 4139),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3471),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'),
#   3255),
#  (('3_VehicleAge',
#    '2_WheelTypeID',
#    'MANHEIM',
#    'AMERICAN',
#    '0_IsBadBuy',
#    'AUTO'),
#   3194),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 3403),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 3871),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3749),
#  (('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO'), 4008),
#  (('3_VehicleAge', '2_WheelTypeID', 'AMERICAN'), 5790),
#  (('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 5362),
#  (('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5254),
#  (('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 5668),
#  (('3_VehicleAge', '2_WheelTypeID', '0_IsBadBuy'), 6430),
#  (('3_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 6215),
#  (('3_VehicleAge', '2_WheelTypeID', 'AUTO'), 6721),
#  (('3_VehicleAge', 'MANHEIM'), 6769),
#  (('3_VehicleAge', 'MANHEIM', 'AMERICAN'), 5736),
#  (('3_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 5358),
#  (('3_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5254),
#  (('3_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO'), 5622),
#  (('3_VehicleAge', 'MANHEIM', '0_IsBadBuy'), 6305),
#  (('3_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 6120),
#  (('3_VehicleAge', 'MANHEIM', 'AUTO'), 6569),
#  (('3_VehicleAge', 'AMERICAN'), 9696),
#  (('3_VehicleAge', 'AMERICAN', '0_IsBadBuy'), 8933),
#  (('3_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 8754),
#  (('3_VehicleAge', 'AMERICAN', 'AUTO'), 9499),
#  (('3_VehicleAge', '0_IsBadBuy'), 10532),
#  (('3_VehicleAge', '0_IsBadBuy', 'AUTO'), 10205),
#  (('3_VehicleAge', 'AUTO'), 11113),
#  (('OTHER', 'MEDIUM'), 6323),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID'), 4400),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN'), 3712),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3428),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'),
#   3383),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 3664),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy'), 4048),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 3967),
#  (('OTHER', 'MEDIUM', '2_WheelTypeID', 'AUTO'), 4311),
#  (('OTHER', 'MEDIUM', 'AMERICAN'), 5296),
#  (('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy'), 4773),
#  (('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4704),
#  (('OTHER', 'MEDIUM', 'AMERICAN', 'AUTO'), 5222),
#  (('OTHER', 'MEDIUM', '0_IsBadBuy'), 5685),
#  (('OTHER', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 5556),
#  (('OTHER', 'MEDIUM', 'AUTO'), 6181),
#  (('OTHER', '1_WheelTypeID'), 5027),
#  (('OTHER', '1_WheelTypeID', 'AMERICAN'), 4314),
#  (('OTHER', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 3746),
#  (('OTHER', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3647),
#  (('OTHER', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 4208),
#  (('OTHER', '1_WheelTypeID', '0_IsBadBuy'), 4345),
#  (('OTHER', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4189),
#  (('OTHER', '1_WheelTypeID', 'AUTO'), 4860),
#  (('OTHER', '2_WheelTypeID'), 7140),
#  (('OTHER', '2_WheelTypeID', 'AMERICAN'), 6157),
#  (('OTHER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 5593),
#  (('OTHER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5493),
#  (('OTHER', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 6050),
#  (('OTHER', '2_WheelTypeID', '0_IsBadBuy'), 6459),
#  (('OTHER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 6297),
#  (('OTHER', '2_WheelTypeID', 'AUTO'), 6962),
#  (('OTHER', 'AMERICAN'), 10538),
#  (('OTHER', 'AMERICAN', '0_IsBadBuy'), 9400),
#  (('OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 9193),
#  (('OTHER', 'AMERICAN', 'AUTO'), 10317),
#  (('OTHER', '0_IsBadBuy'), 10881),
#  (('OTHER', '0_IsBadBuy', 'AUTO'), 10553),
#  (('OTHER', 'AUTO'), 11895),
#  (('CHEVROLET', 'AMERICAN'), 12341),
#  (('CHEVROLET', '4_VehicleAge', 'AMERICAN'), 3208),
#  (('CHEVROLET', '4_VehicleAge'), 3208),
#  (('CHEVROLET', '4_VehicleAge', 'AUTO', 'AMERICAN'), 3130),
#  (('CHEVROLET', '4_VehicleAge', 'AUTO'), 3130),
#  (('CHEVROLET', 'MEDIUM', 'AMERICAN'), 3095),
#  (('CHEVROLET', 'MEDIUM'), 3095),
#  (('CHEVROLET', 'MEDIUM', 'AUTO', 'AMERICAN'), 3069),
#  (('CHEVROLET', 'MEDIUM', 'AUTO'), 3069),
#  (('CHEVROLET', '1_WheelTypeID', 'AMERICAN'), 5285),
#  (('CHEVROLET', '1_WheelTypeID'), 5285),
#  (('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3022),
#  (('CHEVROLET', '1_WheelTypeID', 'MANHEIM'), 3022),
#  (('CHEVROLET', '1_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 4741),
#  (('CHEVROLET', '1_WheelTypeID', '0_IsBadBuy'), 4741),
#  (('CHEVROLET', '1_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 4675),
#  (('CHEVROLET', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 4675),
#  (('CHEVROLET', '1_WheelTypeID', 'AUTO', 'AMERICAN'), 5215),
#  (('CHEVROLET', '1_WheelTypeID', 'AUTO'), 5215),
#  (('CHEVROLET', '2_WheelTypeID', 'AMERICAN'), 6950),
#  (('CHEVROLET', '2_WheelTypeID'), 6950),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3883),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM'), 3883),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AMERICAN'), 3624),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 3624),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO', 'AMERICAN'),
#   3548),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3548),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO', 'AMERICAN'), 3796),
#  (('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO'), 3796),
#  (('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AMERICAN'), 6393),
#  (('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy'), 6393),
#  (('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 6248),
#  (('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 6248),
#  (('CHEVROLET', '2_WheelTypeID', 'AUTO', 'AMERICAN'), 6785),
#  (('CHEVROLET', '2_WheelTypeID', 'AUTO'), 6785),
#  (('CHEVROLET', 'MANHEIM', 'AMERICAN'), 6967),
#  (('CHEVROLET', 'MANHEIM'), 6967),
#  (('CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AMERICAN'), 6427),
#  (('CHEVROLET', 'MANHEIM', '0_IsBadBuy'), 6427),
#  (('CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 6317),
#  (('CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 6317),
#  (('CHEVROLET', 'MANHEIM', 'AUTO', 'AMERICAN'), 6845),
#  (('CHEVROLET', 'MANHEIM', 'AUTO'), 6845),
#  (('CHEVROLET', '0_IsBadBuy', 'AMERICAN'), 11233),
#  (('CHEVROLET', '0_IsBadBuy'), 11233),
#  (('CHEVROLET', '0_IsBadBuy', 'AUTO', 'AMERICAN'), 11014),
#  (('CHEVROLET', '0_IsBadBuy', 'AUTO'), 11014),
#  (('CHEVROLET', 'AUTO', 'AMERICAN'), 12098),
#  (('CHEVROLET', 'AUTO'), 12098),
#  (('4_VehicleAge', 'MEDIUM'), 5383),
#  (('4_VehicleAge', 'MEDIUM', '2_WheelTypeID'), 3029),
#  (('4_VehicleAge', 'MEDIUM', 'MANHEIM'), 3078),
#  (('4_VehicleAge', 'MEDIUM', 'AMERICAN'), 3966),
#  (('4_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy'), 3526),
#  (('4_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 3438),
#  (('4_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO'), 3867),
#  (('4_VehicleAge', 'MEDIUM', '0_IsBadBuy'), 4789),
#  (('4_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO'), 4613),
#  (('4_VehicleAge', 'MEDIUM', 'AUTO'), 5184),
#  (('4_VehicleAge', '1_WheelTypeID'), 6393),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM'), 3804),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3138),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 3076),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 3413),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3313),
#  (('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO'), 3693),
#  (('4_VehicleAge', '1_WheelTypeID', 'AMERICAN'), 5329),
#  (('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 4751),
#  (('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4654),
#  (('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 5221),
#  (('4_VehicleAge', '1_WheelTypeID', '0_IsBadBuy'), 5680),
#  (('4_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 5515),
#  (('4_VehicleAge', '1_WheelTypeID', 'AUTO'), 6212),
#  (('4_VehicleAge', '2_WheelTypeID'), 6112),
#  (('4_VehicleAge', '2_WheelTypeID', 'MANHEIM'), 3487),
#  (('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 3180),
#  (('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 3052),
#  (('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO'), 3341),
#  (('4_VehicleAge', '2_WheelTypeID', 'AMERICAN'), 4946),
#  (('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 4423),
#  (('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 4282),
#  (('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 4787),
#  (('4_VehicleAge', '2_WheelTypeID', '0_IsBadBuy'), 5468),
#  (('4_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 5232),
#  (('4_VehicleAge', '2_WheelTypeID', 'AUTO'), 5847),
#  (('4_VehicleAge', 'MANHEIM'), 7366),
#  (('4_VehicleAge', 'MANHEIM', 'AMERICAN'), 6012),
#  (('4_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 5433),
#  (('4_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5302),
#  (('4_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO'), 5863),
#  (('4_VehicleAge', 'MANHEIM', '0_IsBadBuy'), 6659),
#  (('4_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 6426),
#  (('4_VehicleAge', 'MANHEIM', 'AUTO'), 7104),
#  (('4_VehicleAge', 'AMERICAN'), 10376),
#  (('4_VehicleAge', 'AMERICAN', '0_IsBadBuy'), 9269),
#  (('4_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 9026),
#  (('4_VehicleAge', 'AMERICAN', 'AUTO'), 10104),
#  (('4_VehicleAge', '0_IsBadBuy'), 11267),
#  (('4_VehicleAge', '0_IsBadBuy', 'AUTO'), 10858),
#  (('4_VehicleAge', 'AUTO'), 12179),
#  (('MEDIUM', '1_WheelTypeID'), 8442),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM'), 4806),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN'), 3753),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 3314),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'),
#   3244),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 3671),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 4248),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 4117),
#  (('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AUTO'), 4653),
#  (('MEDIUM', '1_WheelTypeID', 'AMERICAN'), 6690),
#  (('MEDIUM', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 5816),
#  (('MEDIUM', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 5706),
#  (('MEDIUM', '1_WheelTypeID', 'AMERICAN', 'AUTO'), 6566),
#  (('MEDIUM', '1_WheelTypeID', '0_IsBadBuy'), 7341),
#  (('MEDIUM', '1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 7132),
#  (('MEDIUM', '1_WheelTypeID', 'AUTO'), 8207),
#  (('MEDIUM', '2_WheelTypeID'), 13424),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM'), 6668),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN'), 4975),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 4556),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'),
#   4451),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 4852),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 6095),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 5869),
#  (('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AUTO'), 6411),
#  (('MEDIUM', '2_WheelTypeID', 'AMERICAN'), 10284),
#  (('MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 9331),
#  (('MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 9132),
#  (('MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO'), 10054),
#  (('MEDIUM', '2_WheelTypeID', '0_IsBadBuy'), 12145),
#  (('MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 11725),
#  (('MEDIUM', '2_WheelTypeID', 'AUTO'), 12951),
#  (('MEDIUM', 'MANHEIM'), 11585),
#  (('MEDIUM', 'MANHEIM', 'AMERICAN'), 8815),
#  (('MEDIUM', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 7945),
#  (('MEDIUM', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 7763),
#  (('MEDIUM', 'MANHEIM', 'AMERICAN', 'AUTO'), 8602),
#  (('MEDIUM', 'MANHEIM', '0_IsBadBuy'), 10440),
#  (('MEDIUM', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 10071),
#  (('MEDIUM', 'MANHEIM', 'AUTO'), 11162),
#  (('MEDIUM', 'AMERICAN'), 17110),
#  (('MEDIUM', 'AMERICAN', '0_IsBadBuy'), 15267),
#  (('MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 14948),
#  (('MEDIUM', 'AMERICAN', 'AUTO'), 16745),
#  (('MEDIUM', '0_IsBadBuy'), 19654),
#  (('MEDIUM', '0_IsBadBuy', 'AUTO'), 19008),
#  (('MEDIUM', 'AUTO'), 21328),
#  (('1_WheelTypeID', 'MANHEIM'), 14515),
#  (('1_WheelTypeID', 'MANHEIM', 'AMERICAN'), 12243),
#  (('1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 10785),
#  (('1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 10513),
#  (('1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 11930),
#  (('1_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 12755),
#  (('1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 12339),
#  (('1_WheelTypeID', 'MANHEIM', 'AUTO'), 14038),
#  (('1_WheelTypeID', 'AMERICAN'), 21042),
#  (('1_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 18394),
#  (('1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 17924),
#  (('1_WheelTypeID', 'AMERICAN', 'AUTO'), 20517),
#  (('1_WheelTypeID', '0_IsBadBuy'), 21587),
#  (('1_WheelTypeID', '0_IsBadBuy', 'AUTO'), 20880),
#  (('1_WheelTypeID', 'AUTO'), 24005),
#  (('2_WheelTypeID', 'MANHEIM'), 13262),
#  (('2_WheelTypeID', 'MANHEIM', 'AMERICAN'), 10901),
#  (('2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy'), 9960),
#  (('2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 9699),
#  (('2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO'), 10606),
#  (('2_WheelTypeID', 'MANHEIM', '0_IsBadBuy'), 12083),
#  (('2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO'), 11620),
#  (('2_WheelTypeID', 'MANHEIM', 'AUTO'), 12743),
#  (('2_WheelTypeID', 'AMERICAN'), 20707),
#  (('2_WheelTypeID', 'AMERICAN', '0_IsBadBuy'), 18637),
#  (('2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 18157),
#  (('2_WheelTypeID', 'AMERICAN', 'AUTO'), 20163),
#  (('2_WheelTypeID', '0_IsBadBuy'), 22484),
#  (('2_WheelTypeID', '0_IsBadBuy', 'AUTO'), 21659),
#  (('2_WheelTypeID', 'AUTO'), 24127),
#  (('MANHEIM', 'AMERICAN'), 23380),
#  (('MANHEIM', 'AMERICAN', '0_IsBadBuy'), 20952),
#  (('MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO'), 20403),
#  (('MANHEIM', 'AMERICAN', 'AUTO'), 22755),
#  (('MANHEIM', '0_IsBadBuy'), 25089),
#  (('MANHEIM', '0_IsBadBuy', 'AUTO'), 24186),
#  (('MANHEIM', 'AUTO'), 27042),
#  (('AMERICAN', '0_IsBadBuy'), 37377),
#  (('AMERICAN', '0_IsBadBuy', 'AUTO'), 36399),
#  (('AMERICAN', 'AUTO'), 41039),
#  (('0_IsBadBuy', 'AUTO'), 42926)]

# %%
# trying other type of support

# %%
# target 'c' = close frequent item sets
itemsetsClosed = apriori(baskets, supp=6, zmin=2, target='c')

# %%
print('Number of itemsets:', len(itemsetsClosed))
# Out:
# Number of itemsets: 568

# %%
# target 'm' = maximal frequent item sets
itemsetsMaximal = apriori(baskets, supp=6, zmin=2, target='m')

# %%
print('Number of itemsets:', len(itemsetsMaximal))
# Out:
# Number of itemsets: 84

# %%
# extract decision rules
# target 'r' = rules 
rules = apriori(baskets, supp=5, zmin=5, target='r', conf=0.8, 
                report='acl') 
# report = 'acl'
# 'a' = absolute support
# 'c' = rule confidence 
# 'l' = lift value (confidence divided by prior)

# %%
print('Number of rules:', len(rules))
# Out:
# Number of rules: 45213

# %%
# printing most significant rules 
count = 0
for r in rules:
    if r[4] > 1 and r[3] > 0.6:
        print(r[0], '-->', r[1], ' support', r[2], ' conf', r[3], ' lift', r[4])
        count += 1
# Out:
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 1772  conf 0.6973632428177883  lift 1.4155118142006466
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 1888  conf 0.6908159531650201  lift 1.4022220890108885
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# AUTO --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2523  conf 0.9929161747343566  lift 1.0288768803709432
# 0_IsBadBuy --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2523  conf 0.9231613611416026  lift 1.0440670986353275
# AMERICAN --> ('LT_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2523  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LT_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2523  conf 1.0  lift 4.078032574345677
# 1_WheelTypeID --> ('LT_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# MEDIUM --> ('SXT_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1760  conf 0.6967537608867775  lift 1.5899127873112153
# MEDIUM --> ('SXT_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 1763  conf 0.6884029675907849  lift 1.5708572273834245
# MEDIUM --> ('SXT_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 1905  conf 0.6803571428571429  lift 1.5524975710075462
# MEDIUM --> ('SXT_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 1760  conf 0.6967537608867775  lift 1.5899127873112153
# AUTO --> ('SXT_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 2526  conf 0.9863334634908238  lift 1.022055761347033
# 0_IsBadBuy --> ('SXT_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 2526  conf 0.9021428571428571  lift 1.0202958172414789
# AMERICAN --> ('SXT_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 2526  conf 1.0  lift 1.1943659966300402
# DODGE --> ('SXT_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2526  conf 1.0  lift 5.4840361774000215
# MEDIUM --> ('SXT_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1760  conf 0.6967537608867775  lift 1.5899127873112153
# Bas_Trim --> ('PONTIAC', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1824  conf 0.6890819795995466  lift 3.337769854408699
# 1_WheelTypeID --> ('PONTIAC', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6845485455232339  lift 1.389500469893837
# 2_WheelTypeID --> ('VAN', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2269  conf 0.6972956361401352  lift 1.400742325470985
# MANHEIM --> ('VAN', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1976  conf 0.6072526121696373  lift 1.0889824049551504
# 2_WheelTypeID --> ('COMPACT', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1827  conf 0.6319612590799032  lift 1.2694972372855262
# MANHEIM --> ('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2010  conf 0.6143031784841075  lift 1.1016261425160234
# MANHEIM --> ('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2042  conf 0.6148750376392653  lift 1.1026516540504312
# MANHEIM --> ('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 2326  conf 0.616812516573853  lift 1.1061261232045434
# 1_WheelTypeID --> ('MEDIUM SUV', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2326  conf 0.863720757519495  lift 1.7531852288329284
# MANHEIM --> ('MEDIUM SUV', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2398  conf 0.6140845070422535  lift 1.1012340003533172
# 1_WheelTypeID --> ('MEDIUM SUV', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2398  conf 0.8758217677136596  lift 1.7777479270680547
# AUTO --> ('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3272  conf 0.9852454080096357  lift 1.0209282994749822
# AMERICAN --> ('MEDIUM SUV', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3272  conf 0.8379001280409731  lift 1.0007594215040951
# 1_WheelTypeID --> ('MEDIUM SUV', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3272  conf 0.8665254237288136  lift 1.7588781560054851
# AMERICAN --> ('MEDIUM SUV', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2331  conf 0.8513513513513513  lift 1.0168251052390882
# MANHEIM --> ('MEDIUM SUV', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2331  conf 0.6173199152542372  lift 1.1070360381627709
# MANHEIM --> ('6_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1596  conf 0.6063829787234043  lift 1.087422896601082
# MANHEIM --> ('6_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 1657  conf 0.6054073803434418  lift 1.085673361977779
# MANHEIM --> ('6_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 1885  conf 0.6014677728142949  lift 1.0786084878287134
# 1_WheelTypeID --> ('6_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 1885  conf 0.7244427363566487  lift 1.4704779217803121
# MANHEIM --> ('6_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 1908  conf 0.6123234916559692  lift 1.0980759822038897
# 1_WheelTypeID --> ('6_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 1908  conf 0.7143391988019469  lift 1.449969704690876
# AMERICAN --> ('6_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2632  conf 0.8446726572528883  lift 1.0088483001059902
# 1_WheelTypeID --> ('6_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2632  conf 0.7210958904109589  lift 1.463684475143677
# 2_WheelTypeID --> ('OTHER ASIAN', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 1821  conf 0.6325112886418895  lift 1.2706021483846395
# MEDIUM --> ('OTHER ASIAN', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 1613  conf 0.6276264591439689  lift 1.4321721518630026
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1938  conf 0.7644970414201183  lift 1.535737939709827
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 1947  conf 0.7644287396937574  lift 1.535600733747165
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2075  conf 0.7603517772077684  lift 1.5274108446707124
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2218  conf 0.7688041594454073  lift 1.5443901701356728
# MEDIUM --> ('2_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2218  conf 0.6001082251082251  lift 1.3693786735443956
# AUTO --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2535  conf 0.9952885747938751  lift 1.0313352022659232
# 0_IsBadBuy --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2535  conf 0.9289116892634665  lift 1.0505705428338272
# AMERICAN --> ('2_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2535  conf 0.878682842287695  lift 1.0494689086506592
# AUTO --> ('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3317  conf 0.9940065927479772  lift 1.0300067903398833
# 0_IsBadBuy --> ('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3317  conf 0.9412599318955732  lift 1.0645360253603118
# AMERICAN --> ('2_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3317  conf 0.89745670995671  lift 1.0718917778197627
# 2_WheelTypeID --> ('2_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3317  conf 0.6940782590500104  lift 1.3942791898459217
# CHRYSLER --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1735  conf 0.6865848832607835  lift 5.454421060752242
# Bas_Trim --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 1819  conf 0.6031167108753316  lift 2.9213719642177876
# CHRYSLER --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 1819  conf 0.692952380952381  lift 5.505006231442853
# MEDIUM --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1890  conf 0.7260852862082213  lift 1.6568439899796488
# CHRYSLER --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1890  conf 0.6102680012915724  lift 4.848138547908598
# MEDIUM --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy')  support 1975  conf 0.7347470238095238  lift 1.6766090894247065
# CHRYSLER --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 1975  conf 0.6181533646322379  lift 4.910782065011308
# MEDIUM --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', 'AUTO')  support 2172  conf 0.7305751765893037  lift 1.667089408851049
# CHRYSLER --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2172  conf 0.6189797663151895  lift 4.917347229572935
# MEDIUM --> ('CHRYSLER', 'Bas_Trim', '0_IsBadBuy', 'AUTO')  support 1890  conf 0.7260852862082213  lift 1.6568439899796488
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2065  conf 0.7933154053015751  lift 1.5936288828728045
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy')  support 2136  conf 0.7946428571428571  lift 1.5962954964047646
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', 'AUTO')  support 2313  conf 0.7780020181634713  lift 1.5628670246323002
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', '0_IsBadBuy', 'AUTO')  support 2065  conf 0.7933154053015751  lift 1.5936288828728045
# AUTO --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy')  support 2603  conf 0.9683779761904762  lift 1.0034499754516986
# AMERICAN --> ('CHRYSLER', 'Bas_Trim', '0_IsBadBuy', 'AUTO')  support 2603  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2616  conf 0.9714073523950985  lift 1.0065890673692166
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2616  conf 0.8940533151059467  lift 1.0111467940703607
# AMERICAN --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2616  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.6821382007822686  lift 1.3702937464882141
# MEDIUM --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.7484978540772532  lift 1.7079869191632702
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2693  conf 0.8929045092838196  lift 1.009847530028243
# AMERICAN --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2693  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2693  conf 0.682982500634035  lift 1.3719897940130554
# MEDIUM --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2693  conf 0.753919372900336  lift 1.7203582081140425
# AUTO --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2926  conf 0.9701591511936339  lift 1.005295659737317
# AMERICAN --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2926  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2926  conf 0.6637931034482759  lift 1.3334417242342784
# MEDIUM --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2926  conf 0.7510266940451745  lift 1.713757444171911
# AUTO --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2616  conf 0.9714073523950985  lift 1.0065890673692166
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2616  conf 0.8940533151059467  lift 1.0111467940703607
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.6821382007822686  lift 1.3702937464882141
# MEDIUM --> ('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.7484978540772532  lift 1.7079869191632702
# MEDIUM --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1967  conf 0.6715602594742233  lift 1.532424084269292
# MEDIUM --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2026  conf 0.678045515394913  lift 1.5472227002167211
# MEDIUM --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2232  conf 0.6765686571688391  lift 1.5438526778207282
# MEDIUM --> ('CHRYSLER', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 1967  conf 0.6715602594742233  lift 1.532424084269292
# AUTO --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3835  conf 0.9726096880547807  lift 1.0078349483349724
# AMERICAN --> ('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3835  conf 1.0  lift 1.1943659966300402
# MEDIUM --> ('CHRYSLER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3835  conf 0.704186558942343  lift 1.6068735865740782
# 2_WheelTypeID --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 1795  conf 0.6007362784471219  lift 1.2067718311343272
# AUTO --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3495  conf 0.9784434490481523  lift 1.013879992180991
# 0_IsBadBuy --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3495  conf 0.8970739219712526  lift 1.014563007506848
# AMERICAN --> ('CHRYSLER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3495  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('CHRYSLER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3495  conf 0.6417554168196842  lift 1.28917194995746
# AUTO --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2929  conf 0.9802543507362784  lift 1.0157564797707272
# 0_IsBadBuy --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2929  conf 0.8878448014549863  lift 1.0041251561344098
# AMERICAN --> ('CHRYSLER', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2929  conf 1.0  lift 1.1943659966300402
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6291666666666667  lift 4.079895739380664
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 1812  conf 0.6291666666666667  lift 4.079895739380664
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1887  conf 0.6100872938894277  lift 3.9561735909770945
# LS_Trim --> ('LARGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6265560165975104  lift 4.062966711416429
# 0_IsBadBuy --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2476  conf 0.9403721990125332  lift 1.0635320267804615
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# CHEVROLET --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.8597222222222223  lift 3.505975227111075
# 0_IsBadBuy --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 2476  conf 0.9403721990125332  lift 1.0635320267804615
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# CHEVROLET --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2476  conf 0.8597222222222223  lift 3.505975227111075
# AUTO --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 2633  conf 1.0  lift 1.0362172623949926
# AMERICAN --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 2633  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2633  conf 0.661225514816675  lift 1.3282838975044429
# CHEVROLET --> ('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2633  conf 0.8512770772712577  lift 3.4715356509059707
# 0_IsBadBuy --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 2476  conf 0.9403721990125332  lift 1.0635320267804615
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# CHEVROLET --> ('LARGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.8561549100968188  lift 3.491427612060822
# CHEVROLET --> ('LARGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2152  conf 0.6241299303944315  lift 2.545222186772592
# CHEVROLET --> ('LARGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2152  conf 0.6241299303944315  lift 2.545222186772592
# CHEVROLET --> ('LARGE', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2283  conf 0.6171938361719383  lift 2.516936568594534
# CHEVROLET --> ('LARGE', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2152  conf 0.6117111995451961  lift 2.494578197837378
# AUTO --> ('LARGE', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 3705  conf 1.0  lift 1.0362172623949926
# 0_IsBadBuy --> ('LARGE', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 3705  conf 0.9304369663485685  lift 1.0522955842923303
# AMERICAN --> ('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 3705  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LARGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3705  conf 0.6225844395899849  lift 2.5389196249287065
# AUTO --> ('LARGE', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3039  conf 1.0  lift 1.0362172623949926
# 0_IsBadBuy --> ('LARGE', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 3039  conf 0.9131610576923077  lift 1.0327570630908733
# AMERICAN --> ('LARGE', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3039  conf 0.9696873005743459  lift 1.1581615391699718
# AUTO --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2880  conf 1.0  lift 1.0362172623949926
# 0_IsBadBuy --> ('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2880  conf 0.9311348205625606  lift 1.0530848359390546
# AMERICAN --> ('LARGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2880  conf 0.995850622406639  lift 1.1894101211253512
# AUTO --> ('LARGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3448  conf 1.0  lift 1.0362172623949926
# 0_IsBadBuy --> ('LARGE', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3448  conf 0.9321438226547716  lift 1.0542259862636618
# AMERICAN --> ('LARGE', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3448  conf 0.9801023308698124  lift 1.1706008972087487
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1585  conf 0.606582472254114  lift 4.241694606243268
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 1587  conf 0.6043412033511043  lift 4.226021917611647
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 1734  conf 0.6025017373175816  lift 4.213158945947191
# SE_Trim --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 1585  conf 0.606582472254114  lift 4.241694606243268
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1723  conf 0.6238233164373642  lift 1.4234938130284847
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 1724  conf 0.6223826714801444  lift 1.4202064251907154
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1837  conf 0.6117216117216118  lift 1.3958791001185016
# DODGE --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1837  conf 0.7145079735511474  lift 3.91838757599527
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN')  support 1838  conf 0.6102257636122178  lift 1.3924657449699427
# DODGE --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 1838  conf 0.7126793330748352  lift 3.9083592454677163
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 1723  conf 0.6238233164373642  lift 1.4234938130284847
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', '0_IsBadBuy')  support 1724  conf 0.6223826714801444  lift 1.4202064251907154
# DODGE --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 1724  conf 0.6798107255520505  lift 3.7281066127120024
# MEDIUM --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AUTO')  support 1837  conf 0.6117216117216118  lift 1.3958791001185016
# DODGE --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 1837  conf 0.6719092904169714  lift 3.6847748565778495
# MEDIUM --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1954  conf 0.6129234629861983  lift 1.3986215879259305
# MEDIUM --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 1956  conf 0.6116322701688556  lift 1.395675232862752
# MEDIUM --> ('SE_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 2119  conf 0.6025021324992892  lift 1.3748412977688382
# MEDIUM --> ('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 1954  conf 0.6129234629861983  lift 1.3986215879259305
# AUTO --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2762  conf 0.9971119133574007  lift 1.0332245771606388
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2762  conf 0.9197469197469198  lift 1.0402054704623303
# AMERICAN --> ('SE_Trim', 'DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2762  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.8663739021329987  lift 1.7403903473694737
# DODGE --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.7285676602479557  lift 3.9954914064834766
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN')  support 2770  conf 0.9196547144754316  lift 1.040101189136948
# AMERICAN --> ('SE_Trim', 'DODGE', '2_WheelTypeID', '0_IsBadBuy')  support 2770  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 2770  conf 0.866166353971232  lift 1.7399734202015804
# DODGE --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2770  conf 0.7258909853249476  lift 3.9808124243705607
# AUTO --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN')  support 3003  conf 0.9970119521912351  lift 1.0331209956746887
# AMERICAN --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AUTO')  support 3003  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 3003  conf 0.8538527153824282  lift 1.7152375207380939
# DODGE --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3003  conf 0.718421052631579  lift 3.939847043237384
# AUTO --> ('SE_Trim', 'DODGE', '2_WheelTypeID', '0_IsBadBuy')  support 2762  conf 0.9971119133574007  lift 1.0332245771606388
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AUTO')  support 2762  conf 0.9197469197469198  lift 1.0402054704623303
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.8663739021329987  lift 1.7403903473694737
# DODGE --> ('SE_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.6962440131081422  lift 3.8182273561832267
# AUTO --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 3188  conf 0.9968730456535334  lift 1.032977058322463
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 3188  conf 0.9064543645152118  lift 1.0251719994372248
# AMERICAN --> ('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 3188  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2374  conf 0.9233761182419292  lift 1.0443099823088513
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2374  conf 0.6759681093394078  lift 1.3578991353819652
# MEDIUM --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2374  conf 0.6262199947243471  lift 1.4289627601220685
# 0_IsBadBuy --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2380  conf 0.9228383094222566  lift 1.0437017370793482
# AMERICAN --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2380  conf 0.9384858044164038  lift 1.120895533114943
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2380  conf 0.6746031746031746  lift 1.3551572254122848
# MEDIUM --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2380  conf 0.6236897274633124  lift 1.4231889781929776
# AUTO --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2571  conf 0.9968980224893369  lift 1.0330029397508824
# AMERICAN --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2571  conf 0.9403803950256036  lift 1.1231583677161057
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2571  conf 0.6567049808429118  lift 1.3192029525757885
# MEDIUM --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2571  conf 0.6150717703349282  lift 1.4035237808046217
# AUTO --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2516  conf 0.9921135646687698  lift 1.02804520196601
# 0_IsBadBuy --> ('SE_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2516  conf 0.9202633504023409  lift 1.0407895376457585
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2516  conf 0.6754362416107382  lift 1.356830708160445
# MEDIUM --> ('SE_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2516  conf 0.6342324174439122  lift 1.4472461969031862
# AUTO --> ('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3512  conf 0.9954648526077098  lift 1.0315178643795957
# 0_IsBadBuy --> ('SE_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3512  conf 0.8970625798212005  lift 1.0145501798840773
# AMERICAN --> ('SE_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3512  conf 0.9428187919463087  lift 1.1260707060844835
# MEDIUM --> ('SE_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3512  conf 0.603643863870746  lift 1.3774465988221734
# AUTO --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3791  conf 0.9934486373165619  lift 1.0294286272902036
# 0_IsBadBuy --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3791  conf 0.9069377990430622  lift 1.0257187490154878
# AMERICAN --> ('SE_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3791  conf 0.9556339803377868  lift 1.1413767313396728
# 2_WheelTypeID --> ('SE_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3791  conf 0.6515984874527329  lift 1.3089449198911782
# AUTO --> ('SE_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2747  conf 0.9884850665707089  lift 1.024285289600232
# 0_IsBadBuy --> ('SE_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2747  conf 0.8907263294422828  lift 1.0073840756385932
# AMERICAN --> ('SE_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2747  conf 0.9181149732620321  lift 1.0965653050610695
# AMERICAN --> ('FORD', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2605  conf 1.0  lift 1.1943659966300402
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2605  conf 0.7321528948847668  lift 1.4861280447231449
# AMERICAN --> ('FORD', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2720  conf 1.0  lift 1.1943659966300402
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2720  conf 0.7274672372292057  lift 1.476617070582973
# AMERICAN --> ('FORD', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 3084  conf 1.0  lift 1.1943659966300402
# MANHEIM --> ('FORD', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 3084  conf 0.6015213575190169  lift 1.0787045809528066
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3084  conf 0.7406340057636888  lift 1.5033430510635302
# 1_WheelTypeID --> ('FORD', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2605  conf 0.7321528948847668  lift 1.4861280447231449
# AMERICAN --> ('FORD', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4358  conf 1.0  lift 1.1943659966300402
# 1_WheelTypeID --> ('FORD', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4358  conf 0.7227197346600331  lift 1.466980563290937
# AMERICAN --> ('FORD', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3558  conf 1.0  lift 1.1943659966300402
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2240  conf 0.6827186833282536  lift 4.4271592804871815
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2287  conf 0.6857571214392804  lift 4.446862343857062
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2379  conf 0.6802973977695167  lift 4.411458206100563
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2240  conf 0.6827186833282536  lift 4.4271592804871815
# CHEVROLET --> ('LS_Trim', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 2338  conf 0.8999230177059276  lift 3.6699153806082343
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6620344635908838  lift 1.3299089310317491
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6713641488162345  lift 4.353529637607864
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2431  conf 0.951840250587314  lift 1.0765020402999563
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2431  conf 0.6638448935008192  lift 1.333545761194896
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2431  conf 0.6708057395143487  lift 4.349908575253012
# AUTO --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2497  conf 0.9776820673453407  lift 1.0130910353172657
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2497  conf 0.648739932449987  lift 1.3032025937177383
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2497  conf 0.9857876036320569  lift 4.020073958997693
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2497  conf 0.6577976817702845  lift 4.2655564914899
# AMERICAN --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'MANHEIM')  support 2554  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN')  support 2554  conf 0.6513644478449375  lift 1.3084747761422653
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2554  conf 0.9842003853564547  lift 4.013601231167191
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2554  conf 0.6577388617048674  lift 4.265175066746664
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6620344635908838  lift 1.3299089310317491
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6713641488162345  lift 4.353529637607864
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'MANHEIM')  support 2431  conf 0.951840250587314  lift 1.0765020402999563
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy')  support 2431  conf 0.6638448935008192  lift 1.333545761194896
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2431  conf 0.9448115040808395  lift 3.8529720902581968
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2431  conf 0.6708057395143487  lift 4.349908575253012
# AUTO --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'MANHEIM')  support 2497  conf 0.9776820673453407  lift 1.0130910353172657
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO')  support 2497  conf 0.648739932449987  lift 1.3032025937177383
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2497  conf 0.9476280834914611  lift 3.8644581928429433
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2497  conf 0.6577976817702845  lift 4.2655564914899
# AUTO --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4138  conf 0.9777882797731569  lift 1.0132010944684497
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4138  conf 0.9406683337122074  lift 1.063866946015287
# AMERICAN --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4138  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.6625040025616394  lift 1.3308521509168414
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.9885332059245103  lift 4.031270614582516
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.662291933418694  lift 4.294699926963357
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 4232  conf 0.9389838029731529  lift 1.0619617935735604
# AMERICAN --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy')  support 4232  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 4232  conf 0.6640514671269417  lift 1.333960730694831
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4232  conf 0.9864801864801864  lift 4.022898334412798
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4232  conf 0.6619740340997966  lift 4.292638476245389
# AUTO --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 4399  conf 0.9760372753494564  lift 1.0113866734580812
# AMERICAN --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 4399  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 4399  conf 0.6480553918680023  lift 1.3018274740167228
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4399  conf 0.9865440681767212  lift 4.023158846052172
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4399  conf 0.6483419307295505  lift 4.204239704654824
# AUTO --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', '0_IsBadBuy')  support 4138  conf 0.9777882797731569  lift 1.0132010944684497
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 4138  conf 0.9406683337122074  lift 1.063866946015287
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.6625040025616394  lift 1.3308521509168414
# CHEVROLET --> ('LS_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.9484299793719917  lift 3.8677283503649806
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.662291933418694  lift 4.294699926963357
# AUTO --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3598  conf 0.9825232113599126  lift 1.0181075123149053
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3598  conf 0.9347882566900494  lift 1.0572167598022453
# AMERICAN --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3598  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3598  conf 0.9553903345724907  lift 3.896112905601632
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN')  support 3662  conf 0.9339454220862025  lift 1.0562635397948787
# AMERICAN --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy')  support 3662  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3662  conf 0.9521580863234529  lift 3.8829316919536843
# AUTO --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN')  support 3849  conf 0.981637337413925  lift 1.017189554439767
# AMERICAN --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO')  support 3849  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3849  conf 0.9503703703703704  lift 3.875641328063336
# AUTO --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy')  support 3598  conf 0.9825232113599126  lift 1.0181075123149053
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO')  support 3598  conf 0.9347882566900494  lift 1.0572167598022453
# CHEVROLET --> ('LS_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3598  conf 0.9024329069475796  lift 3.6801507906936908
# AUTO --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 6246  conf 0.9800721795072964  lift 1.0155677107985444
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 6246  conf 0.9201532115497938  lift 1.0406649739919205
# AMERICAN --> ('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 6246  conf 1.0  lift 1.1943659966300402
# CHEVROLET --> ('LS_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 6246  conf 0.9597418561770129  lift 3.9138585524528424
# 0_IsBadBuy --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2412  conf 0.952230556652191  lift 1.076943464451669
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2412  conf 0.6404673393520978  lift 1.286584432506008
# 0_IsBadBuy --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2466  conf 0.9502890173410404  lift 1.0747476432217027
# AMERICAN --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2466  conf 0.9584143023707734  lift 1.1446974534355534
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2466  conf 0.641185647425897  lift 1.2880273850637896
# AUTO --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2533  conf 0.9761078998073218  lift 1.0114598557404686
# AMERICAN --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2533  conf 0.9612903225806452  lift 1.148132474179845
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2533  conf 0.6254320987654322  lift 1.2563813209822337
# AUTO --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2501  conf 0.9720171006607073  lift 1.007220899047756
# 0_IsBadBuy --> ('LS_Trim', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2501  conf 0.949146110056926  lift 1.0734550502446103
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2501  conf 0.6272886882367695  lift 1.2601108774554703
# AUTO --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4186  conf 0.9757575757575757  lift 1.0110968439126897
# 0_IsBadBuy --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4186  conf 0.9387755102040817  lift 1.061726220859813
# AMERICAN --> ('LS_Trim', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4186  conf 0.9594315837726335  lift 1.1459124597509391
# 2_WheelTypeID --> ('LS_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4186  conf 0.6432083589428396  lift 1.2920906510404457
# AUTO --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3766  conf 0.9791991679667187  lift 1.0146630811699278
# 0_IsBadBuy --> ('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3766  conf 0.9298765432098766  lift 1.0516617629637397
# AMERICAN --> ('LS_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3766  conf 0.944569852019062  lift 1.1281621126934365
# MEDIUM --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1783  conf 0.6823574435514734  lift 1.5570620295450013
# MEDIUM --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 1784  conf 0.6793602437166794  lift 1.5502227606225039
# MEDIUM --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 1928  conf 0.669909659485754  lift 1.5286576029444363
# MEDIUM --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 1783  conf 0.6823574435514734  lift 1.5570620295450013
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1874  conf 0.7171833141982396  lift 1.440693116738706
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 1879  conf 0.7155369383092155  lift 1.4373858417869274
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 2023  conf 0.7029186935371786  lift 1.4120380429348016
# 2_WheelTypeID --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 1874  conf 0.7171833141982396  lift 1.440693116738706
# AUTO --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 2613  conf 0.995049504950495  lift 1.0310874739672946
# 0_IsBadBuy --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 2613  conf 0.907922168172342  lift 1.0268320402168465
# AMERICAN --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 2613  conf 1.0  lift 1.1943659966300402
# AUTO --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2962  conf 0.9973063973063973  lift 1.0334261047858477
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2962  conf 0.9317395407360806  lift 1.053768755851249
# AMERICAN --> ('DODGE', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2962  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.7610483042137718  lift 1.528810042955594
# MEDIUM --> ('DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.6020325203252033  lift 1.3737696962324417
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2970  conf 0.9316185696361355  lift 1.053631941258855
# AMERICAN --> ('DODGE', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2970  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2970  conf 0.7607581967213115  lift 1.5282272688457847
# MEDIUM --> ('DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 2970  conf 0.6006066734074823  lift 1.3705160758366974
# AUTO --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 3179  conf 0.9971769134253451  lift 1.0332919313530995
# AMERICAN --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 3179  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3179  conf 0.7499410238263742  lift 1.5064975015411302
# AUTO --> ('DODGE', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 2962  conf 0.9973063973063973  lift 1.0334261047858477
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2962  conf 0.9317395407360806  lift 1.053768755851249
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.7610483042137718  lift 1.528810042955594
# MEDIUM --> ('DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.6020325203252033  lift 1.3737696962324417
# AUTO --> ('DODGE', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3892  conf 0.9969262295081968  lift 1.0330321683507457
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3892  conf 0.918141071007313  lift 1.038389304941348
# AMERICAN --> ('DODGE', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3892  conf 1.0  lift 1.1943659966300402
# AUTO --> ('DODGE', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3183  conf 0.9827107131830812  lift 1.0183018049408032
# AMERICAN --> ('DODGE', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3183  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('DODGE', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2389  conf 0.9216820987654321  lift 1.0423940983969955
# 0_IsBadBuy --> ('DODGE', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2402  conf 0.9217191097467383  lift 1.0424359566782198
# AUTO --> ('DODGE', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2592  conf 0.9946277820414429  lift 1.0306504774089873
# AMERICAN --> ('DODGE', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2592  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('DODGE', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2389  conf 0.9216820987654321  lift 1.0423940983969955
# AUTO --> ('DODGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4920  conf 0.9949443882709808  lift 1.0309785502494162
# 0_IsBadBuy --> ('DODGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4920  conf 0.9143281917859134  lift 1.0340770558441688
# AMERICAN --> ('DODGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4920  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4920  conf 0.6018348623853211  lift 1.2089786899479524
# AUTO --> ('DODGE', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 4267  conf 0.9884178827889738  lift 1.0242156726058451
# 0_IsBadBuy --> ('DODGE', 'MANHEIM', 'AMERICAN', 'AUTO')  support 4267  conf 0.9067148321291968  lift 1.0254665802954244
# AMERICAN --> ('DODGE', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 4267  conf 1.0  lift 1.1943659966300402
# AMERICAN --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2415  conf 0.8518518518518519  lift 1.0174228860181822
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2415  conf 0.6464132762312634  lift 1.3120932867988542
# AMERICAN --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2486  conf 0.8441426146010187  lift 1.0082152351858336
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2486  conf 0.6423772609819122  lift 1.3039009604515888
# AUTO --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2809  conf 0.9723087573554863  lift 1.0075231187495792
# AMERICAN --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 2809  conf 0.8486404833836858  lift 1.0135873367171548
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2809  conf 0.6506833449154505  lift 1.3207606961184108
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2835  conf 0.6215742161806621  lift 1.261674823655892
# AUTO --> ('5_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4076  conf 0.9700142789148025  lift 1.0051455405811494
# AMERICAN --> ('5_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4076  conf 0.8543282330748271  lift 1.020380591545597
# 1_WheelTypeID --> ('5_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4076  conf 0.6423955870764382  lift 1.3039381588608494
# AUTO --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3736  conf 0.965374677002584  lift 1.0003379049890677
# AUTO --> ('ADESA', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2481  conf 0.9733228717143978  lift 1.0085739615543259
# AUTO --> ('ADESA', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3764  conf 0.9743722495469842  lift 1.0096613449792264
# AMERICAN --> ('ADESA', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3764  conf 0.8570127504553734  lift 1.023586887822284
# 2_WheelTypeID --> ('Bas_Trim', '3_VehicleAge', '0_IsBadBuy', 'AUTO')  support 1636  conf 0.6494640730448591  lift 1.3046572627680766
# MANHEIM --> ('Bas_Trim', '3_VehicleAge', '0_IsBadBuy', 'AUTO')  support 1512  conf 0.6002381897578404  lift 1.076403484034451
# AMERICAN --> ('Bas_Trim', '3_VehicleAge', '0_IsBadBuy', 'AUTO')  support 2178  conf 0.8646288209606987  lift 1.0326832634617813
# 0_IsBadBuy --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 2242  conf 0.8872180451127819  lift 1.00341631399337
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2242  conf 0.7239263803680982  lift 1.454238731680249
# 0_IsBadBuy --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 2325  conf 0.8857142857142857  lift 1.0017156083764323
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2325  conf 0.7276995305164319  lift 1.4618183160619673
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2527  conf 0.7201481903676261  lift 1.446649023136212
# 0_IsBadBuy --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2974  conf 0.8920215956808638  lift 1.0088489819059043
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2974  conf 0.7332347140039448  lift 1.4729375105447065
# AUTO --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3097  conf 0.9693270735524256  lift 1.004433446521844
# AMERICAN --> ('Bas_Trim', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 2678  conf 0.8564118963863128  lift 1.022869248153261
# AUTO --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2485  conf 0.9695669137729224  lift 1.0046819730985395
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2485  conf 0.8948505581562838  lift 1.0120484514333197
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2485  conf 0.6084720861900098  lift 1.2223116864920218
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2563  conf 0.8933426280934124  lift 1.0103430289232829
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2563  conf 0.6064836725035495  lift 1.2183173187277425
# AUTO --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2777  conf 0.9679330777274312  lift 1.0029889639842784
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2777  conf 0.60885770664328  lift 1.223086329071822
# ...
# MANHEIM --> ('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3403  conf 0.6003881439661256  lift 1.0766723960013969
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3403  conf 0.6053006047669869  lift 1.2159407470605574
# AUTO --> ('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 3749  conf 0.9684835959700335  lift 1.0035594204905263
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 3749  conf 0.935379241516966  lift 1.0578851454599958
# MANHEIM --> ('3_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3749  conf 0.6032180209171359  lift 1.0817471970744263
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3749  conf 0.6125816993464053  lift 1.2305671649306085
# AUTO --> ('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 5254  conf 0.9798582618425961  lift 1.0153460456216508
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 5254  conf 0.9269583627381792  lift 1.0483613906273028
# AMERICAN --> ('3_VehicleAge', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 5254  conf 0.8453740949316171  lift 1.009686073418219
# 2_WheelTypeID --> ('3_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 5254  conf 0.6001827735892163  lift 1.2056599387867517
# AUTO --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 5254  conf 0.9805897723030982  lift 1.0161040493884455
# 0_IsBadBuy --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 5254  conf 0.9345428673070082  lift 1.0569392319593653
# AMERICAN --> ('3_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 5254  conf 0.8584967320261437  lift 1.0253593049500378
# MANHEIM --> ('3_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 5254  conf 0.6001827735892163  lift 1.0763041065573151
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1690  conf 0.633195953540652  lift 1.271977517815846
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 1719  conf 0.6326831063673168  lift 1.2709472994909974
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 1837  conf 0.6246174770486229  lift 1.2547448915270045
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 1690  conf 0.633195953540652  lift 1.271977517815846
# AUTO --> ('OTHER', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2669  conf 0.9823334560176665  lift 1.0179108845536382
# 0_IsBadBuy --> ('OTHER', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2669  conf 0.9075144508670521  lift 1.026370924487879
# AMERICAN --> ('OTHER', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2669  conf 1.0  lift 1.1943659966300402
# AUTO --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3383  conf 0.9868728121353559  lift 1.0226146437229462
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3383  conf 0.9233078602620087  lift 1.0442327846335
# AMERICAN --> ('OTHER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3383  conf 0.8527854802117469  lift 1.0185379799847305
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3383  conf 0.7191751700680272  lift 1.4446943992341679
# MEDIUM --> ('OTHER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3383  conf 0.6158747496814128  lift 1.405356088289116
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 3428  conf 0.9234913793103449  lift 1.0444403390312529
# AMERICAN --> ('OTHER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 3428  conf 0.8468379446640316  lift 1.0114344457627908
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3428  conf 0.7182065786716949  lift 1.4427486722073362
# MEDIUM --> ('OTHER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3428  conf 0.6129089933845879  lift 1.3985885699417888
# AUTO --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 3664  conf 0.9870689655172413  lift 1.0228179012433332
# AMERICAN --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 3664  conf 0.8499188123405242  lift 1.0151141293557102
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3664  conf 0.7016468785905783  lift 1.40948319398188
# MEDIUM --> ('OTHER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 3664  conf 0.6056198347107438  lift 1.3819555394009342
# AUTO --> ('OTHER', 'MEDIUM', '2_WheelTypeID', '0_IsBadBuy')  support 3967  conf 0.9799901185770751  lift 1.0154826778460808
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 3967  conf 0.9202041289723962  lift 1.0407225600304228
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3967  conf 0.7140028797696184  lift 1.4343041923189075
# MEDIUM --> ('OTHER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3967  conf 0.6299825313641416  lift 1.4375484405333556
# AUTO --> ('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 4704  conf 0.9855436832181018  lift 1.0212373773949392
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 4704  conf 0.900804289544236  lift 1.0187819384681176
# AMERICAN --> ('OTHER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 4704  conf 0.8466522678185745  lift 1.0112126796522154
# AUTO --> ('OTHER', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 3647  conf 0.9735718099305927  lift 1.0088319156312167
# AMERICAN --> ('OTHER', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3647  conf 0.8706135115779422  lift 1.0398311744353679
# AUTO --> ('OTHER', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 5493  conf 0.9821205077775791  lift 1.017690223911263
# 0_IsBadBuy --> ('OTHER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 5493  conf 0.9079338842975206  lift 1.0268452907939802
# AMERICAN --> ('OTHER', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 5493  conf 0.8723201524535493  lift 1.041869528265652
# AUTO --> ('CHEVROLET', '4_VehicleAge', 'AMERICAN', '0_IsBadBuy')  support 2822  conf 0.9747841105354059  lift 1.0100881224451361
# 0_IsBadBuy --> ('CHEVROLET', '4_VehicleAge', 'AMERICAN', 'AUTO')  support 2822  conf 0.9015974440894569  lift 1.019678971857572
# AMERICAN --> ('CHEVROLET', '4_VehicleAge', '0_IsBadBuy', 'AUTO')  support 2822  conf 1.0  lift 1.1943659966300402
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1729  conf 0.6075193253689388  lift 1.220397760261948
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 1742  conf 0.6071802021610317  lift 1.2197165223389712
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', 'AUTO')  support 1855  conf 0.6044314108830238  lift 1.2141946918736255
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 1729  conf 0.6075193253689388  lift 1.220397760261948
# AUTO --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2846  conf 0.9919832694318578  lift 1.027910187792314
# 0_IsBadBuy --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2846  conf 0.9273378950798306  lift 1.048790630029498
# AMERICAN --> ('CHEVROLET', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2846  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2715  conf 0.9890710382513661  lift 1.0248924835710036
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2715  conf 0.9077231695085256  lift 1.0266069788502117
# AMERICAN --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2715  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2745  conf 0.9083388484447386  lift 1.0273032927858685
# AMERICAN --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2745  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2991  conf 0.9897418927862343  lift 1.0255876346205899
# AMERICAN --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 2991  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2715  conf 0.9890710382513661  lift 1.0248924835710036
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 2715  conf 0.9077231695085256  lift 1.0266069788502117
# AUTO --> ('CHEVROLET', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4675  conf 0.9860788863109049  lift 1.021791964078589
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 4675  conf 0.8964525407478428  lift 1.013860244459801
# AMERICAN --> ('CHEVROLET', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4675  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3548  conf 0.9790286975717439  lift 1.0144864368039277
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3548  conf 0.934668071654373  lift 1.0570808342243563
# AMERICAN --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3548  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 3624  conf 0.9332989956219419  lift 1.0555324513509396
# AMERICAN --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 3624  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 3796  conf 0.977594643317023  lift 1.0130004450299748
# AMERICAN --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 3796  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 3548  conf 0.9790286975717439  lift 1.0144864368039277
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 3548  conf 0.934668071654373  lift 1.0570808342243563
# AUTO --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 6248  conf 0.9773189425934616  lift 1.0127147591809658
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 6248  conf 0.9208548268238762  lift 1.0414584792818988
# AMERICAN --> ('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 6248  conf 1.0  lift 1.1943659966300402
# AUTO --> ('CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 6317  conf 0.9828847051501478  lift 1.0184820984205956
# 0_IsBadBuy --> ('CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 6317  conf 0.9228634039444851  lift 1.043730118211962
# AMERICAN --> ('CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 6317  conf 1.0  lift 1.1943659966300402
# 0_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 2581  conf 0.8915371329879102  lift 1.0083010695045407
# 0_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', 'MANHEIM', 'AUTO')  support 2680  conf 0.9057113889827645  lift 1.024331716967473
# AUTO --> ('4_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3438  conf 0.9750425411230856  lift 1.0103559126812207
# 0_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3438  conf 0.8890612878200155  lift 1.0055009647883755
# AUTO --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2756  conf 0.9804340092493774  lift 1.0159426450233366
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2756  conf 0.8959687906371911  lift 1.0133131379670985
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2811  conf 0.8957934990439771  lift 1.013114888567973
# AUTO --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 3076  conf 0.9802421924792861  lift 1.0157438811749513
# AUTO --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 3313  conf 0.9707002636976267  lift 1.0058563698548522
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 3313  conf 0.8971026265908475  lift 1.01459547154852
# MANHEIM --> ('4_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 3313  conf 0.6007252946509519  lift 1.0772770062677615
# AUTO --> ('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4654  conf 0.9795832456324984  lift 1.0150610690773092
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 4654  conf 0.8914001149205133  lift 1.0081461062856396
# AMERICAN --> ('4_VehicleAge', '1_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4654  conf 0.8438803263825929  lift 1.007901967056429
# AUTO --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2494  conf 0.9715621347876899  lift 1.0067494555563348
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2494  conf 0.9138878710150238  lift 1.033579066598645
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2567  conf 0.9125488801990758  lift 1.032064709179507
# AUTO --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2729  conf 0.9701386420191966  lift 1.0052744077767277
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 3052  conf 0.9134989524094582  lift 1.0331392116207287
# AUTO --> ('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4282  conf 0.968121184716256  lift 1.0031838836932756
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4282  conf 0.8945059536243994  lift 1.011658714309426
# AUTO --> ('4_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 5302  conf 0.9758880912939444  lift 1.0112320863644857
# 0_IsBadBuy --> ('4_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 5302  conf 0.9043151969981238  lift 1.0227526667863227
# AUTO --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3244  conf 0.9788774894387448  lift 1.0143297523262993
# AUTO --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 3671  conf 0.9781508126831868  lift 1.013576757328009
# AUTO --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 4117  conf 0.9691619585687382  lift 1.0042623515254672
# 0_IsBadBuy --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 4117  conf 0.8848055018267784  lift 1.0006878017581582
# AUTO --> ('MEDIUM', '1_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 5706  conf 0.9810866574965612  lift 1.0166189304033404
# AUTO --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 4451  conf 0.9769534679543459  lift 1.0123360480509465
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 4451  conf 0.917353668590272  lift 1.0374987770319024
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 4556  conf 0.9157788944723618  lift 1.0357177559520563
# AUTO --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 4852  conf 0.9752763819095477  lift 1.0105982225408048
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 5869  conf 0.9154578068944003  lift 1.0353546157795563
# AUTO --> ('MEDIUM', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 9132  conf 0.9786732397385061  lift 1.014118105261073
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 9132  conf 0.9082952058882037  lift 1.0272539343970792
# 2_WheelTypeID --> ('MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 9132  conf 0.6109178485416109  lift 1.227224785995835
# AUTO --> ('MEDIUM', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 7763  conf 0.9770925110132158  lift 1.0124801268687638
# 0_IsBadBuy --> ('MEDIUM', 'MANHEIM', 'AMERICAN', 'AUTO')  support 7763  conf 0.9024645431295047  lift 1.0206596341957928
# AUTO --> ('1_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 10513  conf 0.9747797867408438  lift 1.0100836420545718
# AMERICAN --> ('1_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 10513  conf 0.8520139395412918  lift 1.0176164780429218
# AUTO --> ('2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 9699  conf 0.9737951807228916  lift 1.0090633763021117
# 0_IsBadBuy --> ('2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 9699  conf 0.914482368470677  lift 1.0342514249314312

# %%
print('Number of rules found :' ,count)
# Out:
# Number of rules found : 556

# %%
# first "basket" satisying the first rule
for b in baskets:
    if set(rules[0][1]) < set(b):
        print(b)
        break
# Out:
# ['0_IsBadBuy' '9/21/2010' 'ADESA' '5_VehicleAge' 'CHEVROLET'
#  'MALIBU MAXX V6' 'LS_Trim' 'AUTO' '1_WheelTypeID' 'AMERICAN' 'MEDIUM'
#  '[70274.875, 70377.072)_VehBCostBin' '[70134.965, 70142.826)_VehOdoBin'
#  '[50462.792, 50475.233)_MMRAcquisitionAuctionAveragePriceBin'
#  '[1271.809, 1272.047)_WarrantyCostBin']

# %%
baskets = dfTraining.values
for c in np.arange(0.5,1,0.1):
    for mi in range(2,6):
        for sup in range(10,60,10):
            itemsets = apriori(baskets, supp=sup, zmin=mi, target='a')
            print("conf = ",c," zmin = ", mi," supp= ",sup)
            print('Number of itemsets:', len(itemsetsClosed))
            itemsetsMaximal = apriori(baskets, supp=sup, zmin=mi, target='m')
            print('Number of itemsets:', len(itemsetsMaximal))
            rules = apriori(baskets, supp=sup, zmin=mi, target='r', conf=c, report='acl') 
            print('Number of rules:', len(rules))
# Out:
# conf =  0.5  zmin =  2  supp=  10
# Number of itemsets: 568
# Number of itemsets: 44
# Number of rules: 55911
# conf =  0.5  zmin =  2  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 17145
# conf =  0.5  zmin =  2  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 7568
# conf =  0.5  zmin =  2  supp=  40
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 5936
# conf =  0.5  zmin =  2  supp=  50
# Number of itemsets: 568
# Number of itemsets: 2
# Number of rules: 1904
# conf =  0.5  zmin =  3  supp=  10
# Number of itemsets: 568
# Number of itemsets: 40
# Number of rules: 50893
# conf =  0.5  zmin =  3  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 14507
# conf =  0.5  zmin =  3  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 6106
# conf =  0.5  zmin =  3  supp=  40
# Number of itemsets: 568
# Number of itemsets: 5
# Number of rules: 4474
# conf =  0.5  zmin =  3  supp=  50
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1039
# conf =  0.5  zmin =  4  supp=  10
# Number of itemsets: 568
# Number of itemsets: 31
# Number of rules: 34808
# conf =  0.5  zmin =  4  supp=  20
# Number of itemsets: 568
# Number of itemsets: 8
# Number of rules: 8581
# conf =  0.5  zmin =  4  supp=  30
# Number of itemsets: 568
# Number of itemsets: 3
# Number of rules: 3108
# conf =  0.5  zmin =  4  supp=  40
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1835
# conf =  0.5  zmin =  4  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 203
# conf =  0.5  zmin =  5  supp=  10
# Number of itemsets: 568
# Number of itemsets: 13
# Number of rules: 13862
# conf =  0.5  zmin =  5  supp=  20
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 2454
# conf =  0.5  zmin =  5  supp=  30
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 583
# conf =  0.5  zmin =  5  supp=  40
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 211
# conf =  0.5  zmin =  5  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 0
# conf =  0.6  zmin =  2  supp=  10
# Number of itemsets: 568
# Number of itemsets: 44
# Number of rules: 46464
# conf =  0.6  zmin =  2  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 14529
# conf =  0.6  zmin =  2  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 6466
# conf =  0.6  zmin =  2  supp=  40
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 5050
# conf =  0.6  zmin =  2  supp=  50
# Number of itemsets: 568
# Number of itemsets: 2
# Number of rules: 1644
# conf =  0.6  zmin =  3  supp=  10
# Number of itemsets: 568
# Number of itemsets: 40
# Number of rules: 42264
# conf =  0.6  zmin =  3  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 12267
# conf =  0.6  zmin =  3  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 5193
# conf =  0.6  zmin =  3  supp=  40
# Number of itemsets: 568
# Number of itemsets: 5
# Number of rules: 3777
# conf =  0.6  zmin =  3  supp=  50
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 901
# conf =  0.6  zmin =  4  supp=  10
# Number of itemsets: 568
# Number of itemsets: 31
# Number of rules: 28871
# conf =  0.6  zmin =  4  supp=  20
# Number of itemsets: 568
# Number of itemsets: 8
# Number of rules: 7198
# conf =  0.6  zmin =  4  supp=  30
# Number of itemsets: 568
# Number of itemsets: 3
# Number of rules: 2605
# conf =  0.6  zmin =  4  supp=  40
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1509
# conf =  0.6  zmin =  4  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 176
# conf =  0.6  zmin =  5  supp=  10
# Number of itemsets: 568
# Number of itemsets: 13
# Number of rules: 11494
# conf =  0.6  zmin =  5  supp=  20
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 2020
# conf =  0.6  zmin =  5  supp=  30
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 481
# conf =  0.6  zmin =  5  supp=  40
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 163
# conf =  0.6  zmin =  5  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 0
# conf =  0.7  zmin =  2  supp=  10
# Number of itemsets: 568
# Number of itemsets: 44
# Number of rules: 41081
# conf =  0.7  zmin =  2  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 12845
# conf =  0.7  zmin =  2  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 5709
# conf =  0.7  zmin =  2  supp=  40
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 4427
# conf =  0.7  zmin =  2  supp=  50
# Number of itemsets: 568
# Number of itemsets: 2
# Number of rules: 1440
# conf =  0.7  zmin =  3  supp=  10
# Number of itemsets: 568
# Number of itemsets: 40
# Number of rules: 37358
# conf =  0.7  zmin =  3  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 10829
# conf =  0.7  zmin =  3  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 4595
# conf =  0.7  zmin =  3  supp=  40
# Number of itemsets: 568
# Number of itemsets: 5
# Number of rules: 3313
# conf =  0.7  zmin =  3  supp=  50
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 795
# conf =  0.7  zmin =  4  supp=  10
# Number of itemsets: 568
# Number of itemsets: 31
# Number of rules: 25474
# conf =  0.7  zmin =  4  supp=  20
# Number of itemsets: 568
# Number of itemsets: 8
# Number of rules: 6327
# conf =  0.7  zmin =  4  supp=  30
# Number of itemsets: 568
# Number of itemsets: 3
# Number of rules: 2308
# conf =  0.7  zmin =  4  supp=  40
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1319
# conf =  0.7  zmin =  4  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 156
# conf =  0.7  zmin =  5  supp=  10
# Number of itemsets: 568
# Number of itemsets: 13
# Number of rules: 10101
# conf =  0.7  zmin =  5  supp=  20
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1756
# conf =  0.7  zmin =  5  supp=  30
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 420
# conf =  0.7  zmin =  5  supp=  40
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 138
# conf =  0.7  zmin =  5  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 0
# conf =  0.7999999999999999  zmin =  2  supp=  10
# Number of itemsets: 568
# Number of itemsets: 44
# Number of rules: 36805
# conf =  0.7999999999999999  zmin =  2  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 11455
# conf =  0.7999999999999999  zmin =  2  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 5039
# conf =  0.7999999999999999  zmin =  2  supp=  40
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 3887
# conf =  0.7999999999999999  zmin =  2  supp=  50
# Number of itemsets: 568
# Number of itemsets: 2
# Number of rules: 1225
# conf =  0.7999999999999999  zmin =  3  supp=  10
# Number of itemsets: 568
# Number of itemsets: 40
# Number of rules: 33498
# conf =  0.7999999999999999  zmin =  3  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 9675
# conf =  0.7999999999999999  zmin =  3  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 4066
# conf =  0.7999999999999999  zmin =  3  supp=  40
# Number of itemsets: 568
# Number of itemsets: 5
# Number of rules: 2914
# conf =  0.7999999999999999  zmin =  3  supp=  50
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 676
# conf =  0.7999999999999999  zmin =  4  supp=  10
# Number of itemsets: 568
# Number of itemsets: 31
# Number of rules: 22849
# conf =  0.7999999999999999  zmin =  4  supp=  20
# Number of itemsets: 568
# Number of itemsets: 8
# Number of rules: 5667
# conf =  0.7999999999999999  zmin =  4  supp=  30
# Number of itemsets: 568
# Number of itemsets: 3
# Number of rules: 2054
# conf =  0.7999999999999999  zmin =  4  supp=  40
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1168
# conf =  0.7999999999999999  zmin =  4  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 135
# conf =  0.7999999999999999  zmin =  5  supp=  10
# Number of itemsets: 568
# Number of itemsets: 13
# Number of rules: 9062
# conf =  0.7999999999999999  zmin =  5  supp=  20
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1575
# conf =  0.7999999999999999  zmin =  5  supp=  30
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 379
# conf =  0.7999999999999999  zmin =  5  supp=  40
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 126
# conf =  0.7999999999999999  zmin =  5  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 0
# conf =  0.8999999999999999  zmin =  2  supp=  10
# Number of itemsets: 568
# Number of itemsets: 44
# Number of rules: 33457
# conf =  0.8999999999999999  zmin =  2  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 10381
# conf =  0.8999999999999999  zmin =  2  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 4559
# conf =  0.8999999999999999  zmin =  2  supp=  40
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 3510
# conf =  0.8999999999999999  zmin =  2  supp=  50
# Number of itemsets: 568
# Number of itemsets: 2
# Number of rules: 1104
# conf =  0.8999999999999999  zmin =  3  supp=  10
# Number of itemsets: 568
# Number of itemsets: 40
# Number of rules: 30454
# conf =  0.8999999999999999  zmin =  3  supp=  20
# Number of itemsets: 568
# Number of itemsets: 14
# Number of rules: 8757
# conf =  0.8999999999999999  zmin =  3  supp=  30
# Number of itemsets: 568
# Number of itemsets: 6
# Number of rules: 3670
# conf =  0.8999999999999999  zmin =  3  supp=  40
# Number of itemsets: 568
# Number of itemsets: 5
# Number of rules: 2621
# conf =  0.8999999999999999  zmin =  3  supp=  50
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 604
# conf =  0.8999999999999999  zmin =  4  supp=  10
# Number of itemsets: 568
# Number of itemsets: 31
# Number of rules: 20769
# conf =  0.8999999999999999  zmin =  4  supp=  20
# Number of itemsets: 568
# Number of itemsets: 8
# Number of rules: 5131
# conf =  0.8999999999999999  zmin =  4  supp=  30
# Number of itemsets: 568
# Number of itemsets: 3
# Number of rules: 1848
# conf =  0.8999999999999999  zmin =  4  supp=  40
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1044
# conf =  0.8999999999999999  zmin =  4  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 118
# conf =  0.8999999999999999  zmin =  5  supp=  10
# Number of itemsets: 568
# Number of itemsets: 13
# Number of rules: 8222
# conf =  0.8999999999999999  zmin =  5  supp=  20
# Number of itemsets: 568
# Number of itemsets: 1
# Number of rules: 1426
# conf =  0.8999999999999999  zmin =  5  supp=  30
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 334
# conf =  0.8999999999999999  zmin =  5  supp=  40
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 108
# conf =  0.8999999999999999  zmin =  5  supp=  50
# Number of itemsets: 568
# Number of itemsets: 0
# Number of rules: 0

# %% [markdown]
# ### Missing values

# %%
# we recovered the original training file, not preprocessed 
df1 = pd.read_csv('Data/training.csv')
df1
# Out:
#        RefId  IsBadBuy   PurchDate  Auction  VehYear  VehicleAge       Make  \
# 0        326         1  10/25/2010    ADESA     2008           2        KIA
# 1      42991         0   5/27/2009  MANHEIM     2006           3      DODGE
# 2      55273         0   3/18/2010    OTHER     2008           2      DODGE
# 3      29058         0    6/8/2009    OTHER     2005           4       FORD
# 4      34991         0    3/4/2009  MANHEIM     2005           4   CHRYSLER
# 5      62522         0   4/22/2009    ADESA     2007           2        KIA
# 6       1653         0   5/21/2010    ADESA     2005           5     NISSAN
# 7      40878         0   9/24/2009  MANHEIM     2008           1      DODGE
# 8      55149         0    7/6/2010  MANHEIM     2006           4     SUZUKI
# 9       7255         0    6/4/2009  MANHEIM     2006           3     SUZUKI
# 10     63516         0  10/13/2009  MANHEIM     2004           5   CHRYSLER
# 11     16842         0   2/10/2010  MANHEIM     2007           3    PONTIAC
# 12     52022         0   5/12/2010  MANHEIM     2005           5      DODGE
# 13     37991         0    6/5/2009  MANHEIM     2004           5  CHEVROLET
# 14     67625         0   8/11/2009    ADESA     2007           2   CHRYSLER
# 15     21383         0   7/23/2010    OTHER     2007           3  CHEVROLET
# 16     52699         0   5/20/2010  MANHEIM     2006           4    PONTIAC
# 17     50691         0   1/13/2010  MANHEIM     2008           2  CHEVROLET
# 18     40617         0   1/29/2009  MANHEIM     2006           3     SATURN
# 19     27941         0    7/8/2009  MANHEIM     2002           7  CHEVROLET
# 20     24536         0   5/27/2009  MANHEIM     2005           4      DODGE
# 21     11325         0   3/15/2010  MANHEIM     2003           7      DODGE
# 22     51038         0  11/25/2009    OTHER     2004           5       FORD
# 23     29109         0  10/28/2009    OTHER     2005           4       FORD
# 24     66864         0   7/29/2010    ADESA     2004           6  CHEVROLET
# 25     71633         0   2/11/2010    ADESA     2007           3     SATURN
# 26     21465         0   8/24/2010    OTHER     2006           4    PONTIAC
# 27     38302         0   9/29/2010  MANHEIM     2007           3     NISSAN
# 28     68449         0   2/25/2010    ADESA     2003           7       FORD
# 29     46291         0    2/3/2009  MANHEIM     2005           4       FORD
# ...      ...       ...         ...      ...      ...         ...        ...
# 58356  59417         1   4/22/2010  MANHEIM     2006           4  CHEVROLET
# 58357  38858         1   8/13/2009  MANHEIM     2007           2       FORD
# 58358  59447         1   4/29/2010  MANHEIM     2005           5    HYUNDAI
# 58359   6529         1   5/25/2010  MANHEIM     2004           6  CHEVROLET
# 58360  16848         0   2/17/2010  MANHEIM     2006           4      DODGE
# 58361  41231         0    5/6/2010  MANHEIM     2005           5       FORD
# 58362   4659         0   1/27/2009  MANHEIM     2005           4      DODGE
# 58363  64903         0  12/14/2010  MANHEIM     2003           7       FORD
# 58364  56437         0   9/22/2009    OTHER     2002           7       FORD
# 58365  62043         0   4/23/2010    ADESA     2007           3  CHEVROLET
# 58366  68144         1   2/12/2009    ADESA     2004           5  CHEVROLET
# 58367  44402         0  11/30/2010  MANHEIM     2003           7      DODGE
# 58368  71903         0   4/16/2009    ADESA     2004           5     NISSAN
# 58369  39699         0   1/28/2010  MANHEIM     2004           6      MAZDA
# 58370  66180         0   8/27/2009    ADESA     2004           5       FORD
# 58371  10308         0    5/5/2009    OTHER     2006           3      DODGE
# 58372  64402         0   5/12/2010    ADESA     2007           3  CHEVROLET
# 58373   2130         0   8/30/2010    ADESA     2004           6     TOYOTA
# 58374   1889         0   4/20/2009    ADESA     2004           5   CHRYSLER
# 58375  70379         0  10/28/2010    ADESA     2005           5     TOYOTA
# 58376  23926         0    1/7/2009    OTHER     2007           2  CHEVROLET
# 58377  16257         0    2/4/2009  MANHEIM     2006           3     SUZUKI
# 58378  11415         0    4/5/2010  MANHEIM     2004           6   CADILLAC
# 58379   5871         0   7/13/2010  MANHEIM     2005           5       FORD
# 58380  10289         0    5/5/2009    OTHER     2005           4      DODGE
# 58381  20065         0    3/9/2010    OTHER     2007           3  CHEVROLET
# 58382  12550         0   1/26/2010    OTHER     2006           4       FORD
# 58383  15626         0  10/28/2010    OTHER     2007           3  CHEVROLET
# 58384  21224         1   12/1/2010  MANHEIM     2005           5     NISSAN
# 58385  40898         1   10/8/2009  MANHEIM     2001           8  CHEVROLET
#
#                       Model Trim                SubModel  ...  \
# 0                   SPECTRA   EX             4D SEDAN EX  ...
# 1      STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV  ...
# 2                   CALIBER   SE                4D WAGON  ...
# 3      FREESTAR FWD V6 3.9L    S          PASSENGER 3.9L  ...
# 4      TOWN & COUNTRY FWD V  Bas            MINIVAN 3.3L  ...
# 5       SPECTRA 2.0L I4 EFI   EX             4D SEDAN EX  ...
# 6                    ALTIMA  Bas                4D SEDAN  ...
# 7      AVENGER 4C 2.4L I4 S   SE                4D SEDAN  ...
# 8                   FORENZA  NaN                4D SEDAN  ...
# 9       FORENZA 2.0L I4 EFI  NaN                4D SEDAN  ...
# 10     PT CRUISER 2.4L I4 S  Bas                4D SEDAN  ...
# 11                    G6 4C  Bas            4D SEDAN SE1  ...
# 12           DURANGO 4WD V8  SLT             4D SUV 4.7L  ...
# 13       IMPALA 3.4L V6 SFI  Bas                4D SEDAN  ...
# 14     PT CRUISER 2.4L I4 S  Bas                4D SEDAN  ...
# 15                   IMPALA   LS             4D SEDAN LS  ...
# 16                    G6 V6  Bas                4D SEDAN  ...
# 17                MALIBU 4C   LS     4D SEDAN LS CLASSIC  ...
# 18             RELAY 2WD V6  NaN        4D SPORT UTILITY  ...
# 19     MALIBU V6 3.1L V6 SF  Bas                4D SEDAN  ...
# 20     STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV  ...
# 21           DURANGO 2WD V8  SLT         4D SUV 4.7L SLT  ...
# 22               MUSTANG V6  Bas                2D COUPE  ...
# 23     FREESTAR FWD V6 3.9L    S          PASSENGER 3.9L  ...
# 24     1500 SILVERADO PICKU   LS            EXT CAB 4.3L  ...
# 25                     AURA   XE             4D SEDAN XE  ...
# 26               GRAND PRIX  Bas                4D SEDAN  ...
# 27                   ALTIMA  Bas                4D SEDAN  ...
# 28          EXPLORER 2WD V6  XLS  4D SUV 4.0L SPORT TRAC  ...
# 29     FREESTAR FWD V6 3.9L   SE       PASSENGER 3.9L SE  ...
# ...                     ...  ...                     ...  ...
# 58356                  AVEO   LS             4D SEDAN LS  ...
# 58357  FUSION 4C 2.3L I4 EF    S              4D SEDAN S  ...
# 58358                ACCENT  GLS            4D SEDAN GLS  ...
# 58359        MALIBU MAXX V6   LS             4D SEDAN LS  ...
# 58360            STRATUS 4C  SXT                4D SEDAN  ...
# 58361      FREESTYLE 2WD V6  SEL         4D CUV 3.0L SEL  ...
# 58362  STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV  ...
# 58363       WINDSTAR FWD V6  NaN   4D PASSENGER 3.8L SEL  ...
# 58364    TAURUS 3.0L V6 EFI   SE             4D SEDAN SE  ...
# 58365                   HHR   LS          4D SUV 2.2L LS  ...
# 58366  TRAILBLAZER 4WD 6C 4  Nor          4D SUV 4.2L LS  ...
# 58367                  NEON   SE             4D SEDAN SE  ...
# 58368    MAXIMA 3.5L V6 MPI   SE             4D SEDAN SE  ...
# 58369        TRIBUTE 2WD V6   LX     4D SPORT UTILITY LX  ...
# 58370  MUSTANG V6 3.9L V6 E  Bas                2D COUPE  ...
# 58371  CARAVAN GRAND FWD V6  Bas            MINIVAN 3.3L  ...
# 58372             IMPALA V6   LT        4D SEDAN LT 3.9L  ...
# 58373              CAMRY 4C   LE             4D SEDAN LE  ...
# 58374  PT CRUISER 2.4L I4 S  Bas                4D SEDAN  ...
# 58375     HIGHLANDER 2WD V6  Bas        4D SPORT UTILITY  ...
# 58376   EQUINOX FWD V6 3.4L   LT               4D SUV LT  ...
# 58377   FORENZA 2.0L I4 EFI  NaN                4D SEDAN  ...
# 58378                   CTS  Bas                4D SEDAN  ...
# 58379    F150 PICKUP 2WD V8  STX        EXT CAB 4.6L STX  ...
# 58380  STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV  ...
# 58381           MONTE CARLO   LS             2D COUPE LS  ...
# 58382                 FOCUS  ZX4            4D SEDAN ZX4  ...
# 58383                IMPALA   LS             4D SEDAN LS  ...
# 58384                SENTRA  Bas            4D SEDAN 1.8  ...
# 58385  CAVALIER 4C 2.2L I 4  Bas                4D SEDAN  ...
#
#       MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT  \
# 0                           9605.0                    10650.0        NaN
# 1                           6418.0                     7478.0        NaN
# 2                          10721.0                    11350.0        NaN
# 3                           5702.0                     7691.0        NaN
# 4                           6300.0                     7856.0        NaN
# 5                           5087.0                     6143.0        NaN
# 6                           9518.0                    11377.0        NaN
# 7                          11871.0                    12554.0        NaN
# 8                           6935.0                     8216.0        NaN
# 9                           4726.0                     5756.0        NaN
# 10                          6895.0                     8636.0        NaN
# 11                         11996.0                    13259.0        NaN
# 12                         12771.0                    14315.0        NaN
# 13                          4434.0                     5803.0        NaN
# 14                          7298.0                     8488.0        NaN
# 15                         11883.0                    13162.0        NaN
# 16                         10137.0                    11670.0        NaN
# 17                         11741.0                    12800.0        NaN
# 18                          9544.0                    10639.0        NaN
# 19                          2772.0                     3772.0        NaN
# 20                          6515.0                     7611.0        NaN
# 21                          9029.0                    10141.0        NaN
# 22                          8414.0                     9890.0        NaN
# 23                          8480.0                     9675.0        NaN
# 24                          9285.0                    11403.0        NaN
# 25                         13445.0                    14581.0        NaN
# 26                          9434.0                    11041.0        NaN
# 27                         13657.0                    15336.0        NaN
# 28                          9986.0                    11417.0        NaN
# 29                          6195.0                     7345.0        NaN
# ...                            ...                        ...        ...
# 58356                       7394.0                     7928.0        NaN
# 58357                       9773.0                    11832.0        NaN
# 58358                       5936.0                     6764.0        NaN
# 58359                       7818.0                     8771.0        NaN
# 58360                       7722.0                     9096.0        NaN
# 58361                      11399.0                    13045.0        NaN
# 58362                       4803.0                     5818.0        NaN
# 58363                       6677.0                     8304.0         NO
# 58364                       5230.0                     6630.0        NaN
# 58365                      10570.0                    11576.0        NaN
# 58366                       7372.0                     9041.0        NaN
# 58367                       4878.0                     5559.0        NaN
# 58368                       9365.0                    11476.0        NaN
# 58369                       9390.0                    10588.0        NaN
# 58370                       6261.0                     7854.0        NaN
# 58371                       7568.0                     9324.0        NaN
# 58372                      13295.0                    15513.0        NaN
# 58373                       9159.0                    10846.0        NaN
# 58374                       4266.0                     5347.0        NaN
# 58375                      15628.0                    17975.0        NaN
# 58376                      11694.0                    13320.0        NaN
# 58377                       5717.0                     6766.0        NaN
# 58378                      11547.0                    13601.0        NaN
# 58379                      12647.0                    14758.0        NaN
# 58380                       6515.0                     7611.0        NaN
# 58381                      11325.0                    12762.0        NaN
# 58382                       8401.0                     9193.0        NaN
# 58383                      10120.0                    11695.0        NaN
# 58384                       7179.0                     8436.0        NaN
# 58385                       2089.0                     2587.0        NaN
#
#       AUCGUART  BYRNO VNZIP1 VNST VehBCost  IsOnlineSale  WarrantyCost
# 0          NaN   5546  33619   FL   6100.0             0           533
# 1          NaN  99750  32124   FL   4000.0             0          1630
# 2          NaN  99761  74135   OK   7500.0             0           693
# 3          NaN  99761  85018   AZ   4725.0             0          1633
# 4          NaN  20833  75236   TX   5670.0             0          1623
# 5          NaN  21053  85226   AZ   5430.0             0           462
# 6          NaN   5546  34203   FL   7675.0             0           723
# 7          NaN  99740  29532   SC   7810.0             0           920
# 8          NaN  20234  97217   OR   5870.0             0           462
# 9          NaN  18880  30272   GA   4825.0             0           505
# 10         NaN  18111  37210   TN   5125.0             0          1503
# 11         NaN  19619  32824   FL   7300.0             0           764
# 12         NaN  18822  78219   TX  10135.0             0          1623
# 13         NaN  22916  89165   NV   4185.0             0          2351
# 14         NaN  20833  78754   TX   6305.0             0           975
# 15         NaN  99750  95673   CA   8000.0             0          1703
# 16         NaN  17212  39402   MS   7425.0             0          1272
# 17         NaN  20833  78219   TX   7440.0             0           764
# 18         NaN  20740  29532   SC   5690.0             0          1583
# 19         NaN  19619  32824   FL   3700.0             0          2198
# 20         NaN  99750  32124   FL   4600.0             0          1215
# 21         NaN  18880  27542   NC   7200.0             0          1689
# 22         NaN    835  85009   AZ   7495.0             0           803
# 23         NaN  99761  85018   AZ   4900.0             0          1633
# 24         NaN  17675  28273   NC   9170.0             0          1272
# 25         NaN  17675  28273   NC   8065.0             0          1118
# 26         NaN  21053  95673   CA   7305.0             0          1328
# 27         NaN  52598  75236   TX  10350.0             0           686
# 28         NaN   3453  80817   CO   9325.0             0          1543
# 29         NaN  23359  91770   CA   4340.0             0          1633
# ...        ...    ...    ...  ...      ...           ...           ...
# 58356      NaN  16926  92337   CA   6120.0             0           803
# 58357      NaN  17212  76040   TX   7185.0             0           803
# 58358      NaN  16926  92337   CA   5520.0             0           693
# 58359      NaN    835  85040   AZ   6700.0             0          1272
# 58360      NaN  19619  32824   FL   5700.0             0          1155
# 58361      NaN  17675  29532   SC   8170.0             0          1633
# 58362      NaN    835  85040   AZ   3860.0             0          1503
# 58363    GREEN  18880  37210   TN   5000.0             0          1906
# 58364      NaN  18880  29070   SC   4550.0             0           993
# 58365      NaN  16926  91752   CA   8315.0             0           803
# 58366      NaN  21053  80817   CO   6190.0             0          2152
# 58367      NaN  16044  19440   PA   4705.0             0           930
# 58368      NaN   3453  80817   CO   9210.0             0          1155
# 58369      NaN  20234  85353   AZ   6970.0             0           920
# 58370      NaN  17675  28273   NC   7345.0             0           728
# 58371      NaN  99750  21014   MD   5600.0             0          1623
# 58372      NaN  21053  85226   AZ   8415.0             0          1974
# 58373      NaN  19638  33619   FL   7300.0             0           594
# 58374      NaN  19638  33619   FL   4800.0             0          1086
# 58375      NaN  20740  32219   FL   9600.0             0           620
# 58376      NaN  18880  29697   SC   8700.0             0          1389
# 58377      NaN  19619  32824   FL   5400.0             0           462
# 58378      NaN   8172  27542   NC   9335.0             0          1763
# 58379      NaN    835  85040   AZ  10440.0             0           728
# 58380      NaN  99750  21014   MD   4100.0             0          1389
# 58381      NaN  21053  95673   CA   7205.0             0          1974
# 58382      NaN  21053  95673   CA   4690.0             0          1155
# 58383      NaN  99750  21014   MD   7000.0             0          1703
# 58384      NaN  52644  75236   TX   5525.0             0           594
# 58385      NaN  18880  29532   SC   3240.0             0          1455
#
# [58386 rows x 34 columns]

# %%
# drop of the not useful columns 
df1 = df1.drop(['SubModel','Color','MMRCurrentAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice', 'MMRCurrentAuctionCleanPrice', 'MMRAcquisitionRetailAveragePrice', 'MMRCurrentRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice', 'MMRCurrentRetailCleanPrice','VNST', 'VNZIP1', 'TopThreeAmericanName', 'WheelType', 'PRIMEUNIT', 'AUCGUART','BYRNO','IsOnlineSale'], axis=1)
df1['Transmission'] = df1['Transmission'].str.upper()
df1['Transmission']=df1['Transmission'].fillna(df1['Transmission'].mode()[0])
df1=df1[df1['Nationality'].notnull()]
df1=df1[df1['Size'].notnull()]
df1=df1[df1['MMRAcquisitionAuctionAveragePrice'].notnull()]
df1=df1[df1['WheelTypeID']!=0]
df1.isnull().sum()
# we decide to replace 
# 1) the first three most frequent value in the column Trim 
# 2) WheelTypeID 
# because PRIMEUNIT and AUCGUARD are totally missing and not derived from other attributes i.e. we dropped those columns, 
# while the missing numerical values have been already treated with statistical methods in the Data Understanding
# Out:
# RefId                                   0
# IsBadBuy                                0
# PurchDate                               0
# Auction                                 0
# VehYear                                 0
# VehicleAge                              0
# Make                                    0
# Model                                   0
# Trim                                 1911
# Transmission                            0
# WheelTypeID                          2573
# VehOdo                                  0
# Nationality                             0
# Size                                    0
# MMRAcquisitionAuctionAveragePrice       0
# VehBCost                                0
# WarrantyCost                            0
# dtype: int64

# %%
# discretization of the numerical attributes 
# equal frequency binning i.e. in each bin there are N / k elements 
k = 6 # from sturgers' rule
p=indexMV=df1[df1['Trim'].isnull()].index
bin_size = df1.shape[0]/k
# creation of new columns for the numerical values discretized in bins 
df1['VehBCostBin'] = pd.cut(df1['VehBCost'].astype(int), bin_size, right=False)
df1['VehOdoBin'] = pd.cut(df1['VehOdo'].astype(int), bin_size, right=False)
df1['MMRAcquisitionAuctionAveragePriceBin'] = pd.cut(df1['MMRAcquisitionAuctionAveragePrice'].astype(int), bin_size, right=False)
df1['WarrantyCostBin'] = pd.cut(df1['WarrantyCost'].astype(int), bin_size, right=False)
# drop of the columns no longer needed 
df1.drop(['VehOdo', 'MMRAcquisitionAuctionAveragePrice','WarrantyCost', 'VehBCost'], axis=1, inplace=True)
# result
df1
# Out:
#        RefId  IsBadBuy   PurchDate  Auction  VehYear  VehicleAge       Make  \
# 0        326         1  10/25/2010    ADESA     2008           2        KIA
# 1      42991         0   5/27/2009  MANHEIM     2006           3      DODGE
# 2      55273         0   3/18/2010    OTHER     2008           2      DODGE
# 3      29058         0    6/8/2009    OTHER     2005           4       FORD
# 4      34991         0    3/4/2009  MANHEIM     2005           4   CHRYSLER
# 5      62522         0   4/22/2009    ADESA     2007           2        KIA
# 6       1653         0   5/21/2010    ADESA     2005           5     NISSAN
# 7      40878         0   9/24/2009  MANHEIM     2008           1      DODGE
# 8      55149         0    7/6/2010  MANHEIM     2006           4     SUZUKI
# 9       7255         0    6/4/2009  MANHEIM     2006           3     SUZUKI
# 10     63516         0  10/13/2009  MANHEIM     2004           5   CHRYSLER
# 11     16842         0   2/10/2010  MANHEIM     2007           3    PONTIAC
# 12     52022         0   5/12/2010  MANHEIM     2005           5      DODGE
# 13     37991         0    6/5/2009  MANHEIM     2004           5  CHEVROLET
# 14     67625         0   8/11/2009    ADESA     2007           2   CHRYSLER
# 15     21383         0   7/23/2010    OTHER     2007           3  CHEVROLET
# 16     52699         0   5/20/2010  MANHEIM     2006           4    PONTIAC
# 17     50691         0   1/13/2010  MANHEIM     2008           2  CHEVROLET
# 18     40617         0   1/29/2009  MANHEIM     2006           3     SATURN
# 19     27941         0    7/8/2009  MANHEIM     2002           7  CHEVROLET
# 20     24536         0   5/27/2009  MANHEIM     2005           4      DODGE
# 21     11325         0   3/15/2010  MANHEIM     2003           7      DODGE
# 22     51038         0  11/25/2009    OTHER     2004           5       FORD
# 23     29109         0  10/28/2009    OTHER     2005           4       FORD
# 24     66864         0   7/29/2010    ADESA     2004           6  CHEVROLET
# 25     71633         0   2/11/2010    ADESA     2007           3     SATURN
# 26     21465         0   8/24/2010    OTHER     2006           4    PONTIAC
# 27     38302         0   9/29/2010  MANHEIM     2007           3     NISSAN
# 28     68449         0   2/25/2010    ADESA     2003           7       FORD
# 29     46291         0    2/3/2009  MANHEIM     2005           4       FORD
# ...      ...       ...         ...      ...      ...         ...        ...
# 58356  59417         1   4/22/2010  MANHEIM     2006           4  CHEVROLET
# 58357  38858         1   8/13/2009  MANHEIM     2007           2       FORD
# 58358  59447         1   4/29/2010  MANHEIM     2005           5    HYUNDAI
# 58359   6529         1   5/25/2010  MANHEIM     2004           6  CHEVROLET
# 58360  16848         0   2/17/2010  MANHEIM     2006           4      DODGE
# 58361  41231         0    5/6/2010  MANHEIM     2005           5       FORD
# 58362   4659         0   1/27/2009  MANHEIM     2005           4      DODGE
# 58363  64903         0  12/14/2010  MANHEIM     2003           7       FORD
# 58364  56437         0   9/22/2009    OTHER     2002           7       FORD
# 58365  62043         0   4/23/2010    ADESA     2007           3  CHEVROLET
# 58366  68144         1   2/12/2009    ADESA     2004           5  CHEVROLET
# 58367  44402         0  11/30/2010  MANHEIM     2003           7      DODGE
# 58368  71903         0   4/16/2009    ADESA     2004           5     NISSAN
# 58369  39699         0   1/28/2010  MANHEIM     2004           6      MAZDA
# 58370  66180         0   8/27/2009    ADESA     2004           5       FORD
# 58371  10308         0    5/5/2009    OTHER     2006           3      DODGE
# 58372  64402         0   5/12/2010    ADESA     2007           3  CHEVROLET
# 58373   2130         0   8/30/2010    ADESA     2004           6     TOYOTA
# 58374   1889         0   4/20/2009    ADESA     2004           5   CHRYSLER
# 58375  70379         0  10/28/2010    ADESA     2005           5     TOYOTA
# 58376  23926         0    1/7/2009    OTHER     2007           2  CHEVROLET
# 58377  16257         0    2/4/2009  MANHEIM     2006           3     SUZUKI
# 58378  11415         0    4/5/2010  MANHEIM     2004           6   CADILLAC
# 58379   5871         0   7/13/2010  MANHEIM     2005           5       FORD
# 58380  10289         0    5/5/2009    OTHER     2005           4      DODGE
# 58381  20065         0    3/9/2010    OTHER     2007           3  CHEVROLET
# 58382  12550         0   1/26/2010    OTHER     2006           4       FORD
# 58383  15626         0  10/28/2010    OTHER     2007           3  CHEVROLET
# 58384  21224         1   12/1/2010  MANHEIM     2005           5     NISSAN
# 58385  40898         1   10/8/2009  MANHEIM     2001           8  CHEVROLET
#
#                       Model Trim Transmission  WheelTypeID     Nationality  \
# 0                   SPECTRA   EX         AUTO          2.0     OTHER ASIAN
# 1      STRATUS V6 2.7L V6 M  SXT         AUTO          2.0        AMERICAN
# 2                   CALIBER   SE         AUTO          2.0        AMERICAN
# 3      FREESTAR FWD V6 3.9L    S         AUTO          2.0        AMERICAN
# 4      TOWN & COUNTRY FWD V  Bas         AUTO          1.0        AMERICAN
# 5       SPECTRA 2.0L I4 EFI   EX         AUTO          2.0     OTHER ASIAN
# 6                    ALTIMA  Bas         AUTO          2.0  TOP LINE ASIAN
# 7      AVENGER 4C 2.4L I4 S   SE         AUTO          2.0        AMERICAN
# 8                   FORENZA  NaN         AUTO          2.0     OTHER ASIAN
# 9       FORENZA 2.0L I4 EFI  NaN       MANUAL          2.0     OTHER ASIAN
# 10     PT CRUISER 2.4L I4 S  Bas         AUTO          2.0        AMERICAN
# 11                    G6 4C  Bas         AUTO          1.0        AMERICAN
# 12           DURANGO 4WD V8  SLT         AUTO          1.0        AMERICAN
# 13       IMPALA 3.4L V6 SFI  Bas         AUTO          1.0        AMERICAN
# 14     PT CRUISER 2.4L I4 S  Bas         AUTO          2.0        AMERICAN
# 15                   IMPALA   LS         AUTO          2.0        AMERICAN
# 16                    G6 V6  Bas         AUTO          1.0        AMERICAN
# 17                MALIBU 4C   LS         AUTO          2.0        AMERICAN
# 18             RELAY 2WD V6  NaN         AUTO          1.0        AMERICAN
# 19     MALIBU V6 3.1L V6 SF  Bas         AUTO          2.0        AMERICAN
# 20     STRATUS V6 2.7L V6 M  SXT         AUTO          2.0        AMERICAN
# 21           DURANGO 2WD V8  SLT         AUTO          1.0        AMERICAN
# 22               MUSTANG V6  Bas         AUTO          1.0        AMERICAN
# 23     FREESTAR FWD V6 3.9L    S         AUTO          2.0        AMERICAN
# 24     1500 SILVERADO PICKU   LS         AUTO          2.0        AMERICAN
# 25                     AURA   XE         AUTO          2.0        AMERICAN
# 26               GRAND PRIX  Bas         AUTO          1.0        AMERICAN
# 27                   ALTIMA  Bas         AUTO          1.0  TOP LINE ASIAN
# 28          EXPLORER 2WD V6  XLS         AUTO          1.0        AMERICAN
# 29     FREESTAR FWD V6 3.9L   SE         AUTO          2.0        AMERICAN
# ...                     ...  ...          ...          ...             ...
# 58356                  AVEO   LS         AUTO          2.0        AMERICAN
# 58357  FUSION 4C 2.3L I4 EF    S         AUTO          1.0        AMERICAN
# 58358                ACCENT  GLS         AUTO          2.0     OTHER ASIAN
# 58359        MALIBU MAXX V6   LS         AUTO          1.0        AMERICAN
# 58360            STRATUS 4C  SXT         AUTO          1.0        AMERICAN
# 58361      FREESTYLE 2WD V6  SEL         AUTO          1.0        AMERICAN
# 58362  STRATUS V6 2.7L V6 M  SXT         AUTO          1.0        AMERICAN
# 58363       WINDSTAR FWD V6  NaN         AUTO          1.0        AMERICAN
# 58364    TAURUS 3.0L V6 EFI   SE         AUTO          1.0        AMERICAN
# 58365                   HHR   LS         AUTO          2.0        AMERICAN
# 58366  TRAILBLAZER 4WD 6C 4  Nor         AUTO          NaN        AMERICAN
# 58367                  NEON   SE         AUTO          1.0        AMERICAN
# 58368    MAXIMA 3.5L V6 MPI   SE         AUTO          1.0  TOP LINE ASIAN
# 58369        TRIBUTE 2WD V6   LX         AUTO          1.0     OTHER ASIAN
# 58370  MUSTANG V6 3.9L V6 E  Bas         AUTO          1.0        AMERICAN
# 58371  CARAVAN GRAND FWD V6  Bas         AUTO          2.0        AMERICAN
# 58372             IMPALA V6   LT         AUTO          1.0        AMERICAN
# 58373              CAMRY 4C   LE         AUTO          1.0  TOP LINE ASIAN
# 58374  PT CRUISER 2.4L I4 S  Bas         AUTO          2.0        AMERICAN
# 58375     HIGHLANDER 2WD V6  Bas         AUTO          1.0  TOP LINE ASIAN
# 58376   EQUINOX FWD V6 3.4L   LT         AUTO          1.0        AMERICAN
# 58377   FORENZA 2.0L I4 EFI  NaN         AUTO          2.0     OTHER ASIAN
# 58378                   CTS  Bas         AUTO          1.0        AMERICAN
# 58379    F150 PICKUP 2WD V8  STX         AUTO          2.0        AMERICAN
# 58380  STRATUS V6 2.7L V6 M  SXT         AUTO          2.0        AMERICAN
# 58381           MONTE CARLO   LS         AUTO          1.0        AMERICAN
# 58382                 FOCUS  ZX4         AUTO          1.0        AMERICAN
# 58383                IMPALA   LS         AUTO          2.0        AMERICAN
# 58384                SENTRA  Bas         AUTO          1.0  TOP LINE ASIAN
# 58385  CAVALIER 4C 2.2L I 4  Bas         AUTO          2.0        AMERICAN
#
#               Size             VehBCostBin               VehOdoBin  \
# 0           MEDIUM    [6099.796, 6103.546)  [61177.334, 61188.735)
# 1           MEDIUM      [3999.349, 4003.1)  [92380.316, 92391.717)
# 2           MEDIUM    [7498.843, 7502.594)  [45957.758, 45969.158)
# 3              VAN    [4723.253, 4727.004)  [80159.053, 80170.454)
# 4              VAN    [5668.454, 5672.205)  [77365.947, 77377.348)
# 5           MEDIUM    [5428.403, 5432.154)  [24536.347, 24547.747)
# 6           MEDIUM     [7671.379, 7675.13)  [81470.103, 81481.503)
# 7           MEDIUM    [7806.408, 7810.159)  [56708.365, 56719.765)
# 8           MEDIUM    [5867.246, 5870.997)  [34614.328, 34625.729)
# 9           MEDIUM    [4824.525, 4828.275)  [57335.389, 57346.789)
# 10          MEDIUM    [5124.588, 5128.339)    [85084.04, 85095.44)
# 11          MEDIUM       [7296.3, 7300.05)   [43882.879, 43894.28)
# 12      MEDIUM SUV  [10131.902, 10135.653)   [74242.229, 74253.63)
# 13           LARGE    [4183.138, 4186.889)  [99938.802, 99950.203)
# 14          MEDIUM    [6302.339, 6306.089)  [42435.024, 42446.425)
# 15           LARGE    [7997.699, 8001.449)    [68177.199, 68188.6)
# 16          MEDIUM    [7423.827, 7427.578)  [74595.643, 74607.043)
# 17          MEDIUM     [7438.83, 7442.581)  [43290.057, 43301.457)
# 18             VAN    [5687.208, 5690.959)  [51771.978, 51783.379)
# 19          MEDIUM    [3699.286, 3703.036)  [68610.416, 68621.816)
# 20          MEDIUM    [4599.477, 4603.228)  [64426.457, 64437.858)
# 21      MEDIUM SUV     [7198.779, 7202.53)  [79144.415, 79155.815)
# 22          SPORTS    [7491.341, 7495.092)  [79919.644, 79931.045)
# 23             VAN    [4899.541, 4903.291)  [87101.916, 87113.317)
# 24     LARGE TRUCK    [9167.947, 9171.698)  [75359.471, 75370.872)
# 25          MEDIUM    [8061.462, 8065.213)  [64631.665, 64643.066)
# 26           LARGE    [7303.801, 7307.552)  [46618.983, 46630.383)
# 27          MEDIUM  [10349.448, 10353.199)  [78049.973, 78061.374)
# 28      MEDIUM SUV     [9321.73, 9325.481)  [85847.869, 85859.269)
# 29             VAN    [4336.921, 4340.672)  [88891.784, 88903.184)
# ...            ...                     ...                     ...
# 58356      COMPACT       [6118.55, 6122.3)  [71278.117, 71289.517)
# 58357       MEDIUM    [7183.776, 7187.527)    [74265.03, 74276.43)
# 58358      COMPACT    [5518.422, 5522.173)  [47029.398, 47040.799)
# 58359       MEDIUM    [6699.923, 6703.674)  [71859.539, 71870.939)
# 58360       MEDIUM     [5698.46, 5702.211)    [73991.42, 74002.82)
# 58361    CROSSOVER    [8166.485, 8170.235)  [88492.769, 88504.169)
# 58362       MEDIUM     [3856.819, 3860.57)  [85175.243, 85186.644)
# 58363          VAN    [4997.061, 5000.812)  [63491.622, 63503.022)
# 58364       MEDIUM    [4546.966, 4550.716)  [46664.585, 46675.985)
# 58365       MEDIUM    [8312.766, 8316.516)  [73307.394, 73318.794)
# 58366   MEDIUM SUV    [6189.815, 6193.565)  [83043.362, 83054.763)
# 58367      COMPACT     [4704.499, 4708.25)  [64711.468, 64722.869)
# 58368        LARGE    [9209.206, 9212.957)  [70787.898, 70799.299)
# 58369    SMALL SUV     [6969.98, 6973.731)  [77069.536, 77080.937)
# 58370       SPORTS     [7341.309, 7345.06)  [66809.148, 66820.548)
# 58371          VAN     [5597.189, 5600.94)  [78870.804, 78882.205)
# 58372        LARGE    [8414.037, 8417.788)  [70639.693, 70651.093)
# 58373       MEDIUM       [7296.3, 7300.05)  [84229.007, 84240.408)
# 58374       MEDIUM     [4798.269, 4802.02)  [55534.121, 55545.521)
# 58375   MEDIUM SUV     [9599.289, 9603.04)  [90408.041, 90419.442)
# 58376   MEDIUM SUV    [8699.098, 8702.848)   [77707.96, 77719.361)
# 58377       MEDIUM    [5398.397, 5402.147)  [34967.742, 34979.142)
# 58378    SPECIALTY    [9332.982, 9336.733)  [87785.942, 87797.343)
# 58379  LARGE TRUCK  [10439.467, 10443.218)   [67937.79, 67949.191)
# 58380       MEDIUM     [4096.87, 4100.621)  [71836.738, 71848.138)
# 58381        LARGE     [7202.53, 7206.281)    [78220.98, 78232.38)
# 58382      COMPACT    [4689.496, 4693.247)  [71164.113, 71175.513)
# 58383        LARGE    [6999.987, 7003.738)   [69784.66, 69796.061)
# 58384      COMPACT    [5522.173, 5525.924)  [85323.449, 85334.849)
# 58385      COMPACT    [3237.938, 3241.688)  [73307.394, 73318.794)
#
#       MMRAcquisitionAuctionAveragePriceBin       WarrantyCostBin
# 0                      [6794.047, 6797.72)    [532.888, 533.611)
# 1                      [5479.307, 5482.98)  [1629.483, 1630.206)
# 2                      [8064.718, 8068.39)    [692.748, 693.471)
# 3                     [4814.593, 4818.265)  [1632.376, 1633.099)
# 4                     [5427.893, 5431.566)  [1622.973, 1623.696)
# 5                     [4245.362, 4249.034)      [462.0, 462.723)
# 6                      [6360.697, 6364.37)    [722.405, 723.128)
# 7                     [8494.396, 8498.068)    [919.879, 920.602)
# 8                     [3936.875, 3940.548)      [462.0, 462.723)
# 9                      [3911.168, 3914.84)    [504.677, 505.401)
# 10                    [3933.203, 3936.875)   [1502.897, 1503.62)
# 11                    [7770.921, 7774.594)    [763.636, 764.359)
# 12                    [8281.393, 8285.065)  [1622.973, 1623.696)
# 13                    [3639.406, 3643.078)   [2350.66, 2351.383)
# 14                    [6309.283, 6312.955)    [974.853, 975.577)
# 15                    [8013.304, 8016.976)  [1702.541, 1703.264)
# 16                    [6669.184, 6672.856)  [1271.426, 1272.149)
# 17                    [7594.643, 7598.316)    [763.636, 764.359)
# 18                    [6948.291, 6951.963)  [1582.465, 1583.188)
# 19                    [2100.646, 2104.318)   [2197.31, 2198.034)
# 20                    [5567.446, 5571.119)  [1214.281, 1215.005)
# 21                    [4994.543, 4998.215)  [1688.797, 1689.521)
# 22                    [4972.508, 4976.181)     [802.697, 803.42)
# 23                    [3437.421, 3441.093)  [1632.376, 1633.099)
# 24                    [6386.405, 6390.077)  [1271.426, 1272.149)
# 25                     [9394.148, 9397.82)  [1117.353, 1118.076)
# 26                    [6235.834, 6239.506)   [1327.847, 1328.57)
# 27                  [10433.453, 10437.126)    [685.514, 686.238)
# 28                    [6915.239, 6918.911)  [1542.681, 1543.404)
# 29                    [4278.414, 4282.086)  [1632.376, 1633.099)
# ...                                    ...                   ...
# 58356                  [3925.858, 3929.53)     [802.697, 803.42)
# 58357                 [8420.946, 8424.619)     [802.697, 803.42)
# 58358                 [3367.644, 3371.317)    [692.748, 693.471)
# 58359                 [5457.273, 5460.945)  [1271.426, 1272.149)
# 58360                 [4520.796, 4524.468)   [1154.967, 1155.69)
# 58361                 [8101.443, 8105.115)  [1632.376, 1633.099)
# 58362                 [3430.076, 3433.748)   [1502.897, 1503.62)
# 58363                  [3540.25, 3543.922)  [1905.801, 1906.525)
# 58364                 [2515.634, 2519.306)     [992.937, 993.66)
# 58365                  [6797.72, 6801.392)     [802.697, 803.42)
# 58366                 [6353.353, 6357.025)  [2151.739, 2152.463)
# 58367                 [2269.579, 2273.252)    [929.282, 930.006)
# 58368                 [8207.944, 8211.616)   [1154.967, 1155.69)
# 58369                 [5607.844, 5611.516)    [919.879, 920.602)
# 58370                  [5512.36, 5516.032)    [727.468, 728.192)
# 58371                  [6540.648, 6544.32)  [1622.973, 1623.696)
# 58372                 [9151.766, 9155.438)  [1973.796, 1974.519)
# 58373                 [6191.764, 6195.437)    [593.649, 594.373)
# 58374                 [3485.163, 3488.835)  [1085.525, 1086.249)
# 58375                 [9882.585, 9886.257)     [619.69, 620.413)
# 58376                 [8905.711, 8909.383)  [1388.608, 1389.331)
# 58377                 [4238.017, 4241.689)      [462.0, 462.723)
# 58378                 [9085.661, 9089.334)  [1762.579, 1763.302)
# 58379                 [8707.398, 8711.071)    [727.468, 728.192)
# 58380                 [5567.446, 5571.119)  [1388.608, 1389.331)
# 58381                  [8079.408, 8083.08)  [1973.796, 1974.519)
# 58382                 [4410.622, 4414.295)   [1154.967, 1155.69)
# 58383                 [7572.609, 7576.281)  [1702.541, 1703.264)
# 58384                 [4274.741, 4278.414)    [593.649, 594.373)
# 58385                 [1248.636, 1252.308)  [1454.433, 1455.156)
#
# [58365 rows x 17 columns]

# %%
# transformation of the variable in string, concatenating an fixed identificator 
df1['IsBadBuy'] = df1['IsBadBuy'].astype(str) + '_IsBadBuy'
df1['VehicleAge'] = df1['VehicleAge'].astype(str) + '_VehicleAge'
df1['WheelTypeID'] = df1['WheelTypeID'].astype(str) + '_WheelTypeID'
df1['VehBCostBin'] = df1['VehBCostBin'].astype(str) + '_VehBCostBin'
df1['Trim'] = df1['Trim'].astype(str) + '_Trim'
df1['VehOdoBin'] = df1['VehOdoBin'].astype(str) + '_VehOdoBin'
df1['MMRAcquisitionAuctionAveragePriceBin'] = df1['MMRAcquisitionAuctionAveragePriceBin'].astype(str) + '_MMRAcquisitionAuctionAveragePriceBin'
df1['WarrantyCostBin'] = df1['WarrantyCostBin'].astype(str) + '_WarrantyCostBin'
# result

# %%
# rules most significant for value 'Bas' or 'LS' or 'SE' of Trim 
count = 0
rulesTrim=[]
for r in rules:
    if (r[0]=='Bas_Trim'or r[0]=='LS_Trim'or r[0]=='SE_Trim') and r[4] > 1 and r[3] > 0.6:
        print(r[0], '-->', r[1], ' support', r[2], ' conf', r[3], ' lift', r[4])
        count += 1
        rulesTrim.append(r)
print('\nNumber of rules found :' ,count)
rulesTrim=sorted(rulesTrim,key= lambda x:x[3],reverse=True)
# Out:
# Bas_Trim --> ('PONTIAC', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1824  conf 0.6890819795995466  lift 3.337769854408699
# Bas_Trim --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 1819  conf 0.6031167108753316  lift 2.9213719642177876
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 1885  conf 0.7159134067603494  lift 4.642413867031066
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6291666666666667  lift 4.079895739380664
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 1812  conf 0.6291666666666667  lift 4.079895739380664
# LS_Trim --> ('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1887  conf 0.6100872938894277  lift 3.9561735909770945
# LS_Trim --> ('LARGE', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6265560165975104  lift 4.062966711416429
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1585  conf 0.606582472254114  lift 4.241694606243268
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 1587  conf 0.6043412033511043  lift 4.226021917611647
# SE_Trim --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 1734  conf 0.6025017373175816  lift 4.213158945947191
# SE_Trim --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 1585  conf 0.606582472254114  lift 4.241694606243268
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2240  conf 0.6827186833282536  lift 4.4271592804871815
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2287  conf 0.6857571214392804  lift 4.446862343857062
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2379  conf 0.6802973977695167  lift 4.411458206100563
# LS_Trim --> ('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2240  conf 0.6827186833282536  lift 4.4271592804871815
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6713641488162345  lift 4.353529637607864
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2431  conf 0.6708057395143487  lift 4.349908575253012
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2497  conf 0.6577976817702845  lift 4.2655564914899
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 2554  conf 0.6577388617048674  lift 4.265175066746664
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6713641488162345  lift 4.353529637607864
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', '0_IsBadBuy')  support 2431  conf 0.6708057395143487  lift 4.349908575253012
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 2497  conf 0.6577976817702845  lift 4.2655564914899
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.662291933418694  lift 4.294699926963357
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', '0_IsBadBuy')  support 4232  conf 0.6619740340997966  lift 4.292638476245389
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 4399  conf 0.6483419307295505  lift 4.204239704654824
# LS_Trim --> ('CHEVROLET', '2_WheelTypeID', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.662291933418694  lift 4.294699926963357
#
# Number of rules found : 28

# %%
df1['Trim'].value_counts()
# Out:
# Bas_Trim    11210
# LS_Trim      8190
# SE_Trim      7473
# SXT_Trim     3059
# LT_Trim      2849
# LX_Trim      1918
# nan_Trim     1911
# Tou_Trim     1828
# EX_Trim      1703
# SEL_Trim     1093
# XLT_Trim     1085
# GLS_Trim     1083
# Spo_Trim      996
# SLT_Trim      946
# Lim_Trim      761
# Lar_Trim      697
# ST_Trim       696
# GT_Trim       643
# XLS_Trim      623
# 2_Trim        586
# ES_Trim       553
# S_Trim        493
# SES_Trim      481
# ZX4_Trim      471
# LE_Trim       455
# SLE_Trim      416
# i_Trim        385
# Cla_Trim      375
# XL_Trim       359
# Nor_Trim      348
#             ...
# LW2_Trim        6
# DS_Trim         6
# GX_Trim         6
# C_Trim          5
# Hig_Trim        5
# SE-_Trim        5
# eC_Trim         4
# XRS_Trim        4
# Spe_Trim        4
# ZTW_Trim        4
# Ove_Trim        4
# Ral_Trim        4
# 250_Trim        3
# Car_Trim        3
# ZR2_Trim        3
# Ent_Trim        3
# RS_Trim         3
# Dur_Trim        2
# XS_Trim         2
# GXP_Trim        2
# T5_Trim         2
# Hyb_Trim        2
# JLS_Trim        1
# Si_Trim         1
# JLX_Trim        1
# Ult_Trim        1
# Xsp_Trim        1
# LL_Trim         1
# Maz_Trim        1
# Out_Trim        1
# Name: Trim, Length: 132, dtype: int64

# %%
#After that we applied all the trasformations missing values are equal to the string 'nan_Trim'
df1.index = range(len(df1.index))#normalize index
df1Nan=df1[df1['Trim']=='nan_Trim'].index
for i in df1Nan:
    for r in rulesTrim:
        cont=0;
        for k in r[1] :
            if(k in df1.values[i]):
                cont=cont+1
            if(cont==len(r[1])):
                print(i)
                df1.loc[df1.index==i,'Trim']=r[0]
                break
        if(cont==len(r[1])):break             
df1.isnull().sum()
# Out:
# 1273
# 1361
# 1704
# 1737
# 1963
# 4103
# 4641
# 4722
# 4886
# 5368
# 5506
# 6791
# 6890
# 7277
# 7403
# 7602
# 8101
# 8136
# 8261
# 8582
# 8604
# 8734
# 8758
# 9077
# 9280
# 9305
# 9833
# 10126
# 10178
# 10789
# 10862
# 10880
# 11786
# 12022
# 12141
# 12399
# 12530
# 12607
# 13245
# 13370
# 13418
# 13885
# 14381
# 15467
# 15667
# 16202
# 16665
# 17002
# 17075
# 17520
# 17553
# 17663
# 17786
# 17954
# 18414
# 18418
# 18487
# 18924
# 19095
# 19149
# 19234
# 19284
# 19523
# 19855
# 20010
# 20201
# 20212
# 20270
# 20570
# 20910
# 20940
# 20966
# 21847
# 22559
# 23796
# 23954
# 24531
# 24686
# 25347
# 26548
# 26876
# 27228
# 27376
# 28721
# 28803
# 29136
# 29882
# 29885
# 30029
# 30118
# 30388
# 30671
# 31178
# 31323
# 31567
# 33120
# 33464
# 33609
# 33715
# 34797
# 35632
# 35796
# 36194
# 37317
# 37998
# 38141
# 38396
# 38460
# 38551
# 38586
# 38792
# 39090
# 39293
# 39370
# 39444
# 39464
# 39827
# 39949
# 40246
# 40573
# 40729
# 40850
# 40880
# 40899
# 41012
# 41184
# 41704
# 42055
# 42579
# 42689
# 42763
# 43086
# 43216
# 44038
# 44227
# 44444
# 44650
# 44876
# 45142
# 45159
# 45536
# 45604
# 46228
# 46707
# 46729
# 46730
# 47112
# 47469
# 48040
# 48110
# 49206
# 49462
# 49991
# 50839
# 51032
# 51087
# 51142
# 51202
# 51459
# 51500
# 51688
# 51737
# 52472
# 53617
# 53865
# 54757
# 54975
# 55379
# 55455
# 55512
# 55629
# 55974
# 57132
# 57257
# 57526
# 57593
# 57765
# 58257
# RefId                                   0
# IsBadBuy                                0
# PurchDate                               0
# Auction                                 0
# VehYear                                 0
# VehicleAge                              0
# Make                                    0
# Model                                   0
# Trim                                    0
# Transmission                            0
# WheelTypeID                             0
# Nationality                             0
# Size                                    0
# VehBCostBin                             0
# VehOdoBin                               0
# MMRAcquisitionAuctionAveragePriceBin    0
# WarrantyCostBin                         0
# dtype: int64

# %%
l1=len(indexMV)
l2=len(df1[df1['Trim']=='nan_Trim'].index)
print("Number of missing values solved", l1-l2)
# Out:
# Number of missing values solved 178

# %%
# rules most significant for WheelTypeID
count = 0
rulesWT=[]
for r in rules:
    if (r[0]=='1_WheelTypeID'or r[0]=='2_WheelTypeID'or r[0]=='3_WheelTypeID') and r[4] > 1 and r[3] > 0.6:
        print(r[0], '-->', r[1], ' support', r[2], ' conf', r[3], ' lift', r[4])
        count += 1
        rulesWT.append(r)
print('\nNumber of rules found :' ,count)
rulesWT=sorted(rulesWT,key= lambda x:x[3],reverse=True)
# Out:
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 1772  conf 0.6973632428177883  lift 1.4155118142006466
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 1888  conf 0.6908159531650201  lift 1.4022220890108885
# 1_WheelTypeID --> ('LT_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# 1_WheelTypeID --> ('LT_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1756  conf 0.6959968291716211  lift 1.412738260132297
# 1_WheelTypeID --> ('PONTIAC', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1812  conf 0.6845485455232339  lift 1.389500469893837
# 2_WheelTypeID --> ('VAN', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2269  conf 0.6972956361401352  lift 1.400742325470985
# 2_WheelTypeID --> ('COMPACT', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1827  conf 0.6319612590799032  lift 1.2694972372855262
# 1_WheelTypeID --> ('MEDIUM SUV', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2326  conf 0.863720757519495  lift 1.7531852288329284
# 1_WheelTypeID --> ('MEDIUM SUV', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2398  conf 0.8758217677136596  lift 1.7777479270680547
# 1_WheelTypeID --> ('MEDIUM SUV', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3272  conf 0.8665254237288136  lift 1.7588781560054851
# 1_WheelTypeID --> ('6_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 1885  conf 0.7244427363566487  lift 1.4704779217803121
# 1_WheelTypeID --> ('6_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 1908  conf 0.7143391988019469  lift 1.449969704690876
# 1_WheelTypeID --> ('6_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2632  conf 0.7210958904109589  lift 1.463684475143677
# 2_WheelTypeID --> ('OTHER ASIAN', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 1821  conf 0.6325112886418895  lift 1.2706021483846395
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1938  conf 0.7644970414201183  lift 1.535737939709827
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 1947  conf 0.7644287396937574  lift 1.535600733747165
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2075  conf 0.7603517772077684  lift 1.5274108446707124
# 2_WheelTypeID --> ('2_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2218  conf 0.7688041594454073  lift 1.5443901701356728
# 2_WheelTypeID --> ('2_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3317  conf 0.6940782590500104  lift 1.3942791898459217
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2065  conf 0.7933154053015751  lift 1.5936288828728045
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', '0_IsBadBuy')  support 2136  conf 0.7946428571428571  lift 1.5962954964047646
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', 'AUTO')  support 2313  conf 0.7780020181634713  lift 1.5628670246323002
# 2_WheelTypeID --> ('CHRYSLER', 'Bas_Trim', '0_IsBadBuy', 'AUTO')  support 2065  conf 0.7933154053015751  lift 1.5936288828728045
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.6821382007822686  lift 1.3702937464882141
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2693  conf 0.682982500634035  lift 1.3719897940130554
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2926  conf 0.6637931034482759  lift 1.3334417242342784
# 2_WheelTypeID --> ('CHRYSLER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2616  conf 0.6821382007822686  lift 1.3702937464882141
# 2_WheelTypeID --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 1795  conf 0.6007362784471219  lift 1.2067718311343272
# 2_WheelTypeID --> ('CHRYSLER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3495  conf 0.6417554168196842  lift 1.28917194995746
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2633  conf 0.661225514816675  lift 1.3282838975044429
# 2_WheelTypeID --> ('LARGE', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2476  conf 0.6682860998650473  lift 1.3424673511319296
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.8663739021329987  lift 1.7403903473694737
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', '0_IsBadBuy')  support 2770  conf 0.866166353971232  lift 1.7399734202015804
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 3003  conf 0.8538527153824282  lift 1.7152375207380939
# 2_WheelTypeID --> ('SE_Trim', 'DODGE', '0_IsBadBuy', 'AUTO')  support 2762  conf 0.8663739021329987  lift 1.7403903473694737
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2374  conf 0.6759681093394078  lift 1.3578991353819652
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2380  conf 0.6746031746031746  lift 1.3551572254122848
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2571  conf 0.6567049808429118  lift 1.3192029525757885
# 2_WheelTypeID --> ('SE_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2516  conf 0.6754362416107382  lift 1.356830708160445
# 2_WheelTypeID --> ('SE_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3791  conf 0.6515984874527329  lift 1.3089449198911782
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2605  conf 0.7321528948847668  lift 1.4861280447231449
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2720  conf 0.7274672372292057  lift 1.476617070582973
# 1_WheelTypeID --> ('FORD', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3084  conf 0.7406340057636888  lift 1.5033430510635302
# 1_WheelTypeID --> ('FORD', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2605  conf 0.7321528948847668  lift 1.4861280447231449
# 1_WheelTypeID --> ('FORD', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4358  conf 0.7227197346600331  lift 1.466980563290937
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6620344635908838  lift 1.3299089310317491
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2431  conf 0.6638448935008192  lift 1.333545761194896
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2497  conf 0.648739932449987  lift 1.3032025937177383
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN')  support 2554  conf 0.6513644478449375  lift 1.3084747761422653
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2382  conf 0.6620344635908838  lift 1.3299089310317491
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', '0_IsBadBuy')  support 2431  conf 0.6638448935008192  lift 1.333545761194896
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO')  support 2497  conf 0.648739932449987  lift 1.3032025937177383
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.6625040025616394  lift 1.3308521509168414
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 4232  conf 0.6640514671269417  lift 1.333960730694831
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 4399  conf 0.6480553918680023  lift 1.3018274740167228
# 2_WheelTypeID --> ('LS_Trim', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 4138  conf 0.6625040025616394  lift 1.3308521509168414
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2412  conf 0.6404673393520978  lift 1.286584432506008
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2466  conf 0.641185647425897  lift 1.2880273850637896
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2533  conf 0.6254320987654322  lift 1.2563813209822337
# 2_WheelTypeID --> ('LS_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2501  conf 0.6272886882367695  lift 1.2601108774554703
# 2_WheelTypeID --> ('LS_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4186  conf 0.6432083589428396  lift 1.2920906510404457
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1874  conf 0.7171833141982396  lift 1.440693116738706
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', '0_IsBadBuy')  support 1879  conf 0.7155369383092155  lift 1.4373858417869274
# 2_WheelTypeID --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 2023  conf 0.7029186935371786  lift 1.4120380429348016
# 2_WheelTypeID --> ('DODGE', 'OTHER', '0_IsBadBuy', 'AUTO')  support 1874  conf 0.7171833141982396  lift 1.440693116738706
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.7610483042137718  lift 1.528810042955594
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2970  conf 0.7607581967213115  lift 1.5282272688457847
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3179  conf 0.7499410238263742  lift 1.5064975015411302
# 2_WheelTypeID --> ('DODGE', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2962  conf 0.7610483042137718  lift 1.528810042955594
# 2_WheelTypeID --> ('DODGE', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4920  conf 0.6018348623853211  lift 1.2089786899479524
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2415  conf 0.6464132762312634  lift 1.3120932867988542
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2486  conf 0.6423772609819122  lift 1.3039009604515888
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2809  conf 0.6506833449154505  lift 1.3207606961184108
# 1_WheelTypeID --> ('5_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 2835  conf 0.6215742161806621  lift 1.261674823655892
# 1_WheelTypeID --> ('5_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4076  conf 0.6423955870764382  lift 1.3039381588608494
# 2_WheelTypeID --> ('Bas_Trim', '3_VehicleAge', '0_IsBadBuy', 'AUTO')  support 1636  conf 0.6494640730448591  lift 1.3046572627680766
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2242  conf 0.7239263803680982  lift 1.454238731680249
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2325  conf 0.7276995305164319  lift 1.4618183160619673
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2527  conf 0.7201481903676261  lift 1.446649023136212
# 2_WheelTypeID --> ('Bas_Trim', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 2974  conf 0.7332347140039448  lift 1.4729375105447065
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2485  conf 0.6084720861900098  lift 1.2223116864920218
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 2563  conf 0.6064836725035495  lift 1.2183173187277425
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 2777  conf 0.60885770664328  lift 1.223086329071822
# 2_WheelTypeID --> ('Bas_Trim', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3044  conf 0.6170687208595176  lift 1.2395807893145308
# 2_WheelTypeID --> ('Bas_Trim', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 4561  conf 0.6253084727173019  lift 1.2561329783436574
# 2_WheelTypeID --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2292  conf 0.6985675099055166  lift 1.403297292580327
# 2_WheelTypeID --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 2334  conf 0.6998500749625187  lift 1.405873736583989
# 2_WheelTypeID --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 2427  conf 0.6940234486702889  lift 1.394169085587739
# 2_WheelTypeID --> ('3_VehicleAge', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 2292  conf 0.6985675099055166  lift 1.403297292580327
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 1927  conf 0.6778051354203306  lift 1.3615893924998594
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'MANHEIM', '0_IsBadBuy')  support 1991  conf 0.6799863387978142  lift 1.3659710403016643
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'MANHEIM', 'AUTO')  support 2079  conf 0.6743431722348362  lift 1.354634927117016
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 2415  conf 0.6534090909090909  lift 1.3125820986780752
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 2460  conf 0.6546035125066525  lift 1.314981478223059
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 2630  conf 0.6479428430647943  lift 1.3016013835836786
# 2_WheelTypeID --> ('3_VehicleAge', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3183  conf 0.6720861486486487  lift 1.3501009700650837
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3194  conf 0.6079177769318614  lift 1.2211981782481056
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', '0_IsBadBuy')  support 3255  conf 0.6075027995520716  lift 1.2203645628490445
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 3403  conf 0.6053006047669869  lift 1.2159407470605574
# 2_WheelTypeID --> ('3_VehicleAge', 'MANHEIM', '0_IsBadBuy', 'AUTO')  support 3749  conf 0.6125816993464053  lift 1.2305671649306085
# 2_WheelTypeID --> ('3_VehicleAge', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 5254  conf 0.6001827735892163  lift 1.2056599387867517
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1690  conf 0.633195953540652  lift 1.271977517815846
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', '0_IsBadBuy')  support 1719  conf 0.6326831063673168  lift 1.2709472994909974
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 1837  conf 0.6246174770486229  lift 1.2547448915270045
# 2_WheelTypeID --> ('OTHER', 'CHEVROLET', '0_IsBadBuy', 'AUTO')  support 1690  conf 0.633195953540652  lift 1.271977517815846
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 3383  conf 0.7191751700680272  lift 1.4446943992341679
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 3428  conf 0.7182065786716949  lift 1.4427486722073362
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 3664  conf 0.7016468785905783  lift 1.40948319398188
# 2_WheelTypeID --> ('OTHER', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 3967  conf 0.7140028797696184  lift 1.4343041923189075
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 1729  conf 0.6075193253689388  lift 1.220397760261948
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', '0_IsBadBuy')  support 1742  conf 0.6071802021610317  lift 1.2197165223389712
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', 'AMERICAN', 'AUTO')  support 1855  conf 0.6044314108830238  lift 1.2141946918736255
# 2_WheelTypeID --> ('CHEVROLET', 'MEDIUM', '0_IsBadBuy', 'AUTO')  support 1729  conf 0.6075193253689388  lift 1.220397760261948
# 2_WheelTypeID --> ('MEDIUM', 'AMERICAN', '0_IsBadBuy', 'AUTO')  support 9132  conf 0.6109178485416109  lift 1.227224785995835
#
# Number of rules found : 117

# %%
df1['WheelTypeID'].value_counts()
# Out:
# 1.0_WheelTypeID    28723
# 2.0_WheelTypeID    26480
# nan_WheelTypeID     2573
# 3.0_WheelTypeID      589
# Name: WheelTypeID, dtype: int64

# %%
#missing values ='nan_WheelTypeID'
df1.index = range(len(df1.index))
df1Nan=df1[df1['WheelTypeID']=='nan_WheelTypeID'].index
print(df1Nan)
#df1Nan.index = range(len(df1Nan.index))
for i in df1Nan:
    for r in rulesWT:
        cont=0;
        for k in r[1] :
            if(k in df1.values[i]):
                cont=cont+1
            if(cont==len(r[1])):
                print(i)
                print(df1.values[i][10])
                df1.loc[df1.index==i,'WheelTypeID']=r[0]
                print(df1.values[i][10])
                break
        if(cont==len(r[1])):break
                
df1.isnull().sum()
# Out:
# Int64Index([   66,    71,    92,   124,   125,   143,   145,   146,   165,
#               183,
#             ...
#             58166, 58174, 58190, 58197, 58240, 58246, 58257, 58278, 58325,
#             58345],
#            dtype='int64', length=2573)
# 71
# nan_WheelTypeID
# 1_WheelTypeID
# 92
# nan_WheelTypeID
# 2_WheelTypeID
# 124
# nan_WheelTypeID
# 1_WheelTypeID
# 143
# nan_WheelTypeID
# 2_WheelTypeID
# 145
# nan_WheelTypeID
# 2_WheelTypeID
# 146
# nan_WheelTypeID
# 2_WheelTypeID
# 183
# nan_WheelTypeID
# 2_WheelTypeID
# 195
# nan_WheelTypeID
# 1_WheelTypeID
# 197
# nan_WheelTypeID
# 1_WheelTypeID
# 315
# nan_WheelTypeID
# 2_WheelTypeID
# 343
# nan_WheelTypeID
# 2_WheelTypeID
# 364
# nan_WheelTypeID
# 2_WheelTypeID
# 381
# nan_WheelTypeID
# 1_WheelTypeID
# 534
# nan_WheelTypeID
# 2_WheelTypeID
# 586
# nan_WheelTypeID
# 2_WheelTypeID
# 597
# nan_WheelTypeID
# 2_WheelTypeID
# 603
# nan_WheelTypeID
# 1_WheelTypeID
# 659
# nan_WheelTypeID
# 2_WheelTypeID
# 717
# nan_WheelTypeID
# 2_WheelTypeID
# 724
# nan_WheelTypeID
# 2_WheelTypeID
# 729
# nan_WheelTypeID
# 2_WheelTypeID
# 737
# nan_WheelTypeID
# 2_WheelTypeID
# 794
# nan_WheelTypeID
# 2_WheelTypeID
# 809
# nan_WheelTypeID
# 1_WheelTypeID
# 866
# nan_WheelTypeID
# 1_WheelTypeID
# 868
# nan_WheelTypeID
# 2_WheelTypeID
# 881
# nan_WheelTypeID
# 2_WheelTypeID
# 890
# nan_WheelTypeID
# 2_WheelTypeID
# 897
# nan_WheelTypeID
# 2_WheelTypeID
# 978
# nan_WheelTypeID
# 2_WheelTypeID
# 1012
# nan_WheelTypeID
# 1_WheelTypeID
# 1027
# nan_WheelTypeID
# 1_WheelTypeID
# 1042
# nan_WheelTypeID
# 2_WheelTypeID
# 1126
# nan_WheelTypeID
# 2_WheelTypeID
# 1185
# nan_WheelTypeID
# 2_WheelTypeID
# 1207
# nan_WheelTypeID
# 2_WheelTypeID
# 1218
# nan_WheelTypeID
# 1_WheelTypeID
# 1243
# nan_WheelTypeID
# 2_WheelTypeID
# 1245
# nan_WheelTypeID
# 2_WheelTypeID
# 1287
# nan_WheelTypeID
# 2_WheelTypeID
# 1314
# nan_WheelTypeID
# 2_WheelTypeID
# 1340
# nan_WheelTypeID
# 2_WheelTypeID
# 1354
# nan_WheelTypeID
# 2_WheelTypeID
# 1422
# nan_WheelTypeID
# 1_WheelTypeID
# 1433
# nan_WheelTypeID
# 1_WheelTypeID
# 1448
# nan_WheelTypeID
# 2_WheelTypeID
# 1507
# nan_WheelTypeID
# 2_WheelTypeID
# 1540
# nan_WheelTypeID
# 2_WheelTypeID
# 1662
# nan_WheelTypeID
# 2_WheelTypeID
# 1724
# nan_WheelTypeID
# 2_WheelTypeID
# 1759
# nan_WheelTypeID
# 2_WheelTypeID
# 1761
# nan_WheelTypeID
# 2_WheelTypeID
# 1797
# nan_WheelTypeID
# 2_WheelTypeID
# 1828
# nan_WheelTypeID
# 2_WheelTypeID
# 1842
# nan_WheelTypeID
# 2_WheelTypeID
# 1872
# nan_WheelTypeID
# 2_WheelTypeID
# 1895
# nan_WheelTypeID
# 1_WheelTypeID
# 1900
# nan_WheelTypeID
# 1_WheelTypeID
# 1984
# nan_WheelTypeID
# 2_WheelTypeID
# 2081
# nan_WheelTypeID
# 2_WheelTypeID
# 2107
# nan_WheelTypeID
# 1_WheelTypeID
# 2210
# nan_WheelTypeID
# 2_WheelTypeID
# 2241
# nan_WheelTypeID
# 2_WheelTypeID
# 2242
# nan_WheelTypeID
# 2_WheelTypeID
# 2289
# nan_WheelTypeID
# 1_WheelTypeID
# 2296
# nan_WheelTypeID
# 2_WheelTypeID
# 2329
# nan_WheelTypeID
# 2_WheelTypeID
# 2371
# nan_WheelTypeID
# 2_WheelTypeID
# 2387
# nan_WheelTypeID
# 1_WheelTypeID
# 2417
# nan_WheelTypeID
# 2_WheelTypeID
# 2418
# nan_WheelTypeID
# 2_WheelTypeID
# 2442
# nan_WheelTypeID
# 1_WheelTypeID
# 2450
# nan_WheelTypeID
# 2_WheelTypeID
# 2453
# nan_WheelTypeID
# 2_WheelTypeID
# 2501
# nan_WheelTypeID
# 1_WheelTypeID
# 2511
# nan_WheelTypeID
# 2_WheelTypeID
# 2571
# nan_WheelTypeID
# 2_WheelTypeID
# 2594
# nan_WheelTypeID
# 2_WheelTypeID
# 2613
# nan_WheelTypeID
# 2_WheelTypeID
# 2795
# nan_WheelTypeID
# 2_WheelTypeID
# 2813
# nan_WheelTypeID
# 2_WheelTypeID
# 2898
# nan_WheelTypeID
# 2_WheelTypeID
# 2973
# nan_WheelTypeID
# 2_WheelTypeID
# 2989
# nan_WheelTypeID
# 2_WheelTypeID
# 2994
# nan_WheelTypeID
# 2_WheelTypeID
# 2995
# nan_WheelTypeID
# 2_WheelTypeID
# 3009
# nan_WheelTypeID
# 1_WheelTypeID
# 3033
# nan_WheelTypeID
# 2_WheelTypeID
# 3049
# nan_WheelTypeID
# 2_WheelTypeID
# 3092
# nan_WheelTypeID
# 1_WheelTypeID
# 3106
# nan_WheelTypeID
# 2_WheelTypeID
# 3141
# nan_WheelTypeID
# 2_WheelTypeID
# 3215
# nan_WheelTypeID
# 2_WheelTypeID
# 3222
# nan_WheelTypeID
# 2_WheelTypeID
# 3237
# nan_WheelTypeID
# 2_WheelTypeID
# 3241
# nan_WheelTypeID
# 2_WheelTypeID
# 3247
# nan_WheelTypeID
# 2_WheelTypeID
# 3264
# nan_WheelTypeID
# 2_WheelTypeID
# 3267
# nan_WheelTypeID
# 2_WheelTypeID
# 3334
# nan_WheelTypeID
# 1_WheelTypeID
# 3377
# nan_WheelTypeID
# 2_WheelTypeID
# 3386
# nan_WheelTypeID
# 2_WheelTypeID
# 3394
# nan_WheelTypeID
# 2_WheelTypeID
# 3396
# nan_WheelTypeID
# 2_WheelTypeID
# 3579
# nan_WheelTypeID
# 2_WheelTypeID
# 3733
# nan_WheelTypeID
# 2_WheelTypeID
# 3741
# nan_WheelTypeID
# 1_WheelTypeID
# 3778
# nan_WheelTypeID
# 2_WheelTypeID
# 3829
# nan_WheelTypeID
# 2_WheelTypeID
# 3857
# nan_WheelTypeID
# 2_WheelTypeID
# 3952
# nan_WheelTypeID
# 2_WheelTypeID
# 3960
# nan_WheelTypeID
# 2_WheelTypeID
# 3973
# nan_WheelTypeID
# 2_WheelTypeID
# 4041
# nan_WheelTypeID
# 2_WheelTypeID
# 4086
# nan_WheelTypeID
# 2_WheelTypeID
# 4142
# nan_WheelTypeID
# 2_WheelTypeID
# 4316
# nan_WheelTypeID
# 2_WheelTypeID
# 4326
# nan_WheelTypeID
# 2_WheelTypeID
# 4329
# nan_WheelTypeID
# 2_WheelTypeID
# 4368
# nan_WheelTypeID
# 2_WheelTypeID
# 4401
# nan_WheelTypeID
# 2_WheelTypeID
# 4451
# nan_WheelTypeID
# 2_WheelTypeID
# 4468
# nan_WheelTypeID
# 2_WheelTypeID
# 4475
# nan_WheelTypeID
# 2_WheelTypeID
# 4497
# nan_WheelTypeID
# 1_WheelTypeID
# 4564
# nan_WheelTypeID
# 2_WheelTypeID
# 4573
# nan_WheelTypeID
# 1_WheelTypeID
# 4612
# nan_WheelTypeID
# 1_WheelTypeID
# 4613
# nan_WheelTypeID
# 2_WheelTypeID
# 4630
# nan_WheelTypeID
# 2_WheelTypeID
# 4644
# nan_WheelTypeID
# 2_WheelTypeID
# 4668
# nan_WheelTypeID
# 1_WheelTypeID
# 4678
# nan_WheelTypeID
# 2_WheelTypeID
# 4715
# nan_WheelTypeID
# 2_WheelTypeID
# 4782
# nan_WheelTypeID
# 2_WheelTypeID
# 4800
# nan_WheelTypeID
# 2_WheelTypeID
# 4806
# nan_WheelTypeID
# 2_WheelTypeID
# 4836
# nan_WheelTypeID
# 2_WheelTypeID
# 4868
# nan_WheelTypeID
# 2_WheelTypeID
# 4953
# nan_WheelTypeID
# 2_WheelTypeID
# 4978
# nan_WheelTypeID
# 2_WheelTypeID
# 4986
# nan_WheelTypeID
# 1_WheelTypeID
# 5008
# nan_WheelTypeID
# 2_WheelTypeID
# 5032
# nan_WheelTypeID
# 2_WheelTypeID
# 5050
# nan_WheelTypeID
# 2_WheelTypeID
# 5091
# nan_WheelTypeID
# 2_WheelTypeID
# 5092
# nan_WheelTypeID
# 2_WheelTypeID
# 5119
# nan_WheelTypeID
# 1_WheelTypeID
# 5167
# nan_WheelTypeID
# 2_WheelTypeID
# 5224
# nan_WheelTypeID
# 2_WheelTypeID
# 5250
# nan_WheelTypeID
# 1_WheelTypeID
# 5289
# nan_WheelTypeID
# 2_WheelTypeID
# 5367
# nan_WheelTypeID
# 2_WheelTypeID
# 5376
# nan_WheelTypeID
# 1_WheelTypeID
# 5393
# nan_WheelTypeID
# 2_WheelTypeID
# 5431
# nan_WheelTypeID
# 1_WheelTypeID
# 5470
# nan_WheelTypeID
# 2_WheelTypeID
# 5479
# nan_WheelTypeID
# 2_WheelTypeID
# 5492
# nan_WheelTypeID
# 1_WheelTypeID
# 5501
# nan_WheelTypeID
# 2_WheelTypeID
# 5512
# nan_WheelTypeID
# 2_WheelTypeID
# 5559
# nan_WheelTypeID
# 1_WheelTypeID
# 5587
# nan_WheelTypeID
# 2_WheelTypeID
# 5596
# nan_WheelTypeID
# 2_WheelTypeID
# 5603
# nan_WheelTypeID
# 2_WheelTypeID
# 5703
# nan_WheelTypeID
# 2_WheelTypeID
# 5761
# nan_WheelTypeID
# 2_WheelTypeID
# 5778
# nan_WheelTypeID
# 2_WheelTypeID
# 5781
# nan_WheelTypeID
# 2_WheelTypeID
# 5851
# nan_WheelTypeID
# 2_WheelTypeID
# 5905
# nan_WheelTypeID
# 2_WheelTypeID
# 5975
# nan_WheelTypeID
# 1_WheelTypeID
# 6033
# nan_WheelTypeID
# 2_WheelTypeID
# 6057
# nan_WheelTypeID
# 1_WheelTypeID
# 6100
# nan_WheelTypeID
# 2_WheelTypeID
# 6116
# nan_WheelTypeID
# 2_WheelTypeID
# 6155
# nan_WheelTypeID
# 2_WheelTypeID
# 6157
# nan_WheelTypeID
# 2_WheelTypeID
# 6252
# nan_WheelTypeID
# 2_WheelTypeID
# 6271
# nan_WheelTypeID
# 2_WheelTypeID
# 6338
# nan_WheelTypeID
# 2_WheelTypeID
# 6352
# nan_WheelTypeID
# 2_WheelTypeID
# 6415
# nan_WheelTypeID
# 2_WheelTypeID
# 6453
# nan_WheelTypeID
# 1_WheelTypeID
# 6512
# nan_WheelTypeID
# 2_WheelTypeID
# 6528
# nan_WheelTypeID
# 1_WheelTypeID
# 6554
# nan_WheelTypeID
# 2_WheelTypeID
# 6587
# nan_WheelTypeID
# 2_WheelTypeID
# 6661
# nan_WheelTypeID
# 2_WheelTypeID
# 6690
# nan_WheelTypeID
# 2_WheelTypeID
# 6751
# nan_WheelTypeID
# 1_WheelTypeID
# 6792
# nan_WheelTypeID
# 2_WheelTypeID
# 6866
# nan_WheelTypeID
# 2_WheelTypeID
# 7023
# nan_WheelTypeID
# 2_WheelTypeID
# 7032
# nan_WheelTypeID
# 1_WheelTypeID
# 7202
# nan_WheelTypeID
# 2_WheelTypeID
# 7244
# nan_WheelTypeID
# 1_WheelTypeID
# 7267
# nan_WheelTypeID
# 2_WheelTypeID
# 7333
# nan_WheelTypeID
# 2_WheelTypeID
# 7378
# nan_WheelTypeID
# 2_WheelTypeID
# 7418
# nan_WheelTypeID
# 2_WheelTypeID
# 7429
# nan_WheelTypeID
# 1_WheelTypeID
# 7506
# nan_WheelTypeID
# 2_WheelTypeID
# 7511
# nan_WheelTypeID
# 2_WheelTypeID
# 7513
# nan_WheelTypeID
# 2_WheelTypeID
# 7524
# nan_WheelTypeID
# 2_WheelTypeID
# 7605
# nan_WheelTypeID
# 2_WheelTypeID
# 7607
# nan_WheelTypeID
# 1_WheelTypeID
# 7696
# nan_WheelTypeID
# 2_WheelTypeID
# 7731
# nan_WheelTypeID
# 2_WheelTypeID
# 7739
# nan_WheelTypeID
# 2_WheelTypeID
# 7754
# nan_WheelTypeID
# 1_WheelTypeID
# 7803
# nan_WheelTypeID
# 2_WheelTypeID
# 7851
# nan_WheelTypeID
# 2_WheelTypeID
# 7869
# nan_WheelTypeID
# 2_WheelTypeID
# 7899
# nan_WheelTypeID
# 2_WheelTypeID
# 7900
# nan_WheelTypeID
# 2_WheelTypeID
# 7921
# nan_WheelTypeID
# 2_WheelTypeID
# 7981
# nan_WheelTypeID
# 2_WheelTypeID
# 8026
# nan_WheelTypeID
# 1_WheelTypeID
# 8036
# nan_WheelTypeID
# 2_WheelTypeID
# 8042
# nan_WheelTypeID
# 2_WheelTypeID
# 8110
# nan_WheelTypeID
# 1_WheelTypeID
# 8119
# nan_WheelTypeID
# 2_WheelTypeID
# 8156
# nan_WheelTypeID
# 2_WheelTypeID
# 8220
# nan_WheelTypeID
# 1_WheelTypeID
# 8335
# nan_WheelTypeID
# 1_WheelTypeID
# 8341
# nan_WheelTypeID
# 2_WheelTypeID
# 8385
# nan_WheelTypeID
# 1_WheelTypeID
# 8435
# nan_WheelTypeID
# 1_WheelTypeID
# 8454
# nan_WheelTypeID
# 1_WheelTypeID
# 8484
# nan_WheelTypeID
# 2_WheelTypeID
# 8569
# nan_WheelTypeID
# 2_WheelTypeID
# 8590
# nan_WheelTypeID
# 2_WheelTypeID
# 8697
# nan_WheelTypeID
# 2_WheelTypeID
# 8719
# nan_WheelTypeID
# 1_WheelTypeID
# 8725
# nan_WheelTypeID
# 2_WheelTypeID
# 8775
# nan_WheelTypeID
# 2_WheelTypeID
# 8796
# nan_WheelTypeID
# 2_WheelTypeID
# 8839
# nan_WheelTypeID
# 2_WheelTypeID
# 8840
# nan_WheelTypeID
# 1_WheelTypeID
# 8896
# nan_WheelTypeID
# 2_WheelTypeID
# 8907
# nan_WheelTypeID
# 1_WheelTypeID
# 8933
# nan_WheelTypeID
# 2_WheelTypeID
# 8942
# nan_WheelTypeID
# 2_WheelTypeID
# 8946
# nan_WheelTypeID
# 1_WheelTypeID
# 8979
# nan_WheelTypeID
# 1_WheelTypeID
# 9070
# nan_WheelTypeID
# 1_WheelTypeID
# 9075
# nan_WheelTypeID
# 2_WheelTypeID
# 9158
# nan_WheelTypeID
# 2_WheelTypeID
# 9160
# nan_WheelTypeID
# 1_WheelTypeID
# 9186
# nan_WheelTypeID
# 2_WheelTypeID
# 9200
# nan_WheelTypeID
# 2_WheelTypeID
# 9217
# nan_WheelTypeID
# 2_WheelTypeID
# 9226
# nan_WheelTypeID
# 2_WheelTypeID
# 9269
# nan_WheelTypeID
# 2_WheelTypeID
# 9295
# nan_WheelTypeID
# 2_WheelTypeID
# 9400
# nan_WheelTypeID
# 2_WheelTypeID
# 9436
# nan_WheelTypeID
# 2_WheelTypeID
# 9445
# nan_WheelTypeID
# 2_WheelTypeID
# 9495
# nan_WheelTypeID
# 1_WheelTypeID
# 9536
# nan_WheelTypeID
# 2_WheelTypeID
# 9544
# nan_WheelTypeID
# 2_WheelTypeID
# 9546
# nan_WheelTypeID
# 2_WheelTypeID
# 9554
# nan_WheelTypeID
# 1_WheelTypeID
# 9575
# nan_WheelTypeID
# 2_WheelTypeID
# 9586
# nan_WheelTypeID
# 1_WheelTypeID
# 9609
# nan_WheelTypeID
# 2_WheelTypeID
# 9616
# nan_WheelTypeID
# 2_WheelTypeID
# 9620
# nan_WheelTypeID
# 2_WheelTypeID
# 9668
# nan_WheelTypeID
# 2_WheelTypeID
# 9681
# nan_WheelTypeID
# 2_WheelTypeID
# 9716
# nan_WheelTypeID
# 2_WheelTypeID
# 9766
# nan_WheelTypeID
# 2_WheelTypeID
# 9921
# nan_WheelTypeID
# 2_WheelTypeID
# 9963
# nan_WheelTypeID
# 2_WheelTypeID
# 9976
# nan_WheelTypeID
# 2_WheelTypeID
# 10070
# nan_WheelTypeID
# 2_WheelTypeID
# 10087
# nan_WheelTypeID
# 2_WheelTypeID
# 10095
# nan_WheelTypeID
# 2_WheelTypeID
# 10116
# nan_WheelTypeID
# 1_WheelTypeID
# 10225
# nan_WheelTypeID
# 2_WheelTypeID
# 10235
# nan_WheelTypeID
# 2_WheelTypeID
# 10258
# nan_WheelTypeID
# 2_WheelTypeID
# 10293
# nan_WheelTypeID
# 2_WheelTypeID
# 10297
# nan_WheelTypeID
# 2_WheelTypeID
# 10389
# nan_WheelTypeID
# 2_WheelTypeID
# 10392
# nan_WheelTypeID
# 2_WheelTypeID
# 10443
# nan_WheelTypeID
# 2_WheelTypeID
# 10446
# nan_WheelTypeID
# 2_WheelTypeID
# 10473
# nan_WheelTypeID
# 2_WheelTypeID
# 10556
# nan_WheelTypeID
# 1_WheelTypeID
# 10563
# nan_WheelTypeID
# 2_WheelTypeID
# 10566
# nan_WheelTypeID
# 2_WheelTypeID
# 10615
# nan_WheelTypeID
# 2_WheelTypeID
# 10722
# nan_WheelTypeID
# 2_WheelTypeID
# 10731
# nan_WheelTypeID
# 2_WheelTypeID
# 10787
# nan_WheelTypeID
# 1_WheelTypeID
# 10802
# nan_WheelTypeID
# 2_WheelTypeID
# 10831
# nan_WheelTypeID
# 2_WheelTypeID
# 10867
# nan_WheelTypeID
# 2_WheelTypeID
# 10904
# nan_WheelTypeID
# 2_WheelTypeID
# 10920
# nan_WheelTypeID
# 2_WheelTypeID
# 10938
# nan_WheelTypeID
# 2_WheelTypeID
# 10971
# nan_WheelTypeID
# 2_WheelTypeID
# 11074
# nan_WheelTypeID
# 2_WheelTypeID
# 11100
# nan_WheelTypeID
# 2_WheelTypeID
# 11263
# nan_WheelTypeID
# 2_WheelTypeID
# 11266
# nan_WheelTypeID
# 1_WheelTypeID
# 11323
# nan_WheelTypeID
# 2_WheelTypeID
# 11361
# nan_WheelTypeID
# 2_WheelTypeID
# 11423
# nan_WheelTypeID
# 2_WheelTypeID
# 11505
# nan_WheelTypeID
# 2_WheelTypeID
# 11584
# nan_WheelTypeID
# 1_WheelTypeID
# 11635
# nan_WheelTypeID
# 2_WheelTypeID
# 11673
# nan_WheelTypeID
# 1_WheelTypeID
# 11677
# nan_WheelTypeID
# 2_WheelTypeID
# 11686
# nan_WheelTypeID
# 2_WheelTypeID
# 11719
# nan_WheelTypeID
# 2_WheelTypeID
# 11773
# nan_WheelTypeID
# 1_WheelTypeID
# 11781
# nan_WheelTypeID
# 2_WheelTypeID
# 11828
# nan_WheelTypeID
# 1_WheelTypeID
# 11845
# nan_WheelTypeID
# 1_WheelTypeID
# 11871
# nan_WheelTypeID
# 2_WheelTypeID
# 11894
# nan_WheelTypeID
# 1_WheelTypeID
# 11909
# nan_WheelTypeID
# 2_WheelTypeID
# 11917
# nan_WheelTypeID
# 2_WheelTypeID
# 11953
# nan_WheelTypeID
# 1_WheelTypeID
# 11962
# nan_WheelTypeID
# 2_WheelTypeID
# 12081
# nan_WheelTypeID
# 2_WheelTypeID
# 12091
# nan_WheelTypeID
# 2_WheelTypeID
# 12160
# nan_WheelTypeID
# 1_WheelTypeID
# 12292
# nan_WheelTypeID
# 1_WheelTypeID
# 12312
# nan_WheelTypeID
# 2_WheelTypeID
# 12352
# nan_WheelTypeID
# 1_WheelTypeID
# 12388
# nan_WheelTypeID
# 2_WheelTypeID
# 12392
# nan_WheelTypeID
# 2_WheelTypeID
# 12453
# nan_WheelTypeID
# 2_WheelTypeID
# 12482
# nan_WheelTypeID
# 2_WheelTypeID
# 12483
# nan_WheelTypeID
# 2_WheelTypeID
# 12499
# nan_WheelTypeID
# 2_WheelTypeID
# 12571
# nan_WheelTypeID
# 2_WheelTypeID
# 12598
# nan_WheelTypeID
# 2_WheelTypeID
# 12642
# nan_WheelTypeID
# 1_WheelTypeID
# 12651
# nan_WheelTypeID
# 2_WheelTypeID
# 12663
# nan_WheelTypeID
# 2_WheelTypeID
# 12698
# nan_WheelTypeID
# 2_WheelTypeID
# 12702
# nan_WheelTypeID
# 2_WheelTypeID
# 12751
# nan_WheelTypeID
# 2_WheelTypeID
# 12786
# nan_WheelTypeID
# 2_WheelTypeID
# 12892
# nan_WheelTypeID
# 1_WheelTypeID
# 12897
# nan_WheelTypeID
# 2_WheelTypeID
# 12900
# nan_WheelTypeID
# 2_WheelTypeID
# 12989
# nan_WheelTypeID
# 2_WheelTypeID
# 13003
# nan_WheelTypeID
# 2_WheelTypeID
# 13044
# nan_WheelTypeID
# 2_WheelTypeID
# 13054
# nan_WheelTypeID
# 2_WheelTypeID
# 13065
# nan_WheelTypeID
# 1_WheelTypeID
# 13080
# nan_WheelTypeID
# 2_WheelTypeID
# 13094
# nan_WheelTypeID
# 2_WheelTypeID
# 13106
# nan_WheelTypeID
# 2_WheelTypeID
# 13108
# nan_WheelTypeID
# 2_WheelTypeID
# 13155
# nan_WheelTypeID
# 2_WheelTypeID
# 13171
# nan_WheelTypeID
# 2_WheelTypeID
# 13195
# nan_WheelTypeID
# 2_WheelTypeID
# 13209
# nan_WheelTypeID
# 2_WheelTypeID
# 13224
# nan_WheelTypeID
# 2_WheelTypeID
# 13231
# nan_WheelTypeID
# 2_WheelTypeID
# 13336
# nan_WheelTypeID
# 1_WheelTypeID
# 13355
# nan_WheelTypeID
# 2_WheelTypeID
# 13362
# nan_WheelTypeID
# 2_WheelTypeID
# 13385
# nan_WheelTypeID
# 2_WheelTypeID
# 13423
# nan_WheelTypeID
# 2_WheelTypeID
# 13458
# nan_WheelTypeID
# 2_WheelTypeID
# 13473
# nan_WheelTypeID
# 2_WheelTypeID
# 13506
# nan_WheelTypeID
# 2_WheelTypeID
# 13689
# nan_WheelTypeID
# 2_WheelTypeID
# 13690
# nan_WheelTypeID
# 2_WheelTypeID
# 13729
# nan_WheelTypeID
# 2_WheelTypeID
# 13774
# nan_WheelTypeID
# 2_WheelTypeID
# 13797
# nan_WheelTypeID
# 2_WheelTypeID
# 13812
# nan_WheelTypeID
# 1_WheelTypeID
# 13816
# nan_WheelTypeID
# 2_WheelTypeID
# 13834
# nan_WheelTypeID
# 2_WheelTypeID
# 13844
# nan_WheelTypeID
# 2_WheelTypeID
# 13865
# nan_WheelTypeID
# 2_WheelTypeID
# 13867
# nan_WheelTypeID
# 1_WheelTypeID
# 13898
# nan_WheelTypeID
# 2_WheelTypeID
# 13933
# nan_WheelTypeID
# 2_WheelTypeID
# 13952
# nan_WheelTypeID
# 1_WheelTypeID
# 13970
# nan_WheelTypeID
# 2_WheelTypeID
# 13976
# nan_WheelTypeID
# 2_WheelTypeID
# 14036
# nan_WheelTypeID
# 1_WheelTypeID
# 14059
# nan_WheelTypeID
# 2_WheelTypeID
# 14067
# nan_WheelTypeID
# 2_WheelTypeID
# 14113
# nan_WheelTypeID
# 2_WheelTypeID
# 14122
# nan_WheelTypeID
# 2_WheelTypeID
# 14177
# nan_WheelTypeID
# 2_WheelTypeID
# 14182
# nan_WheelTypeID
# 1_WheelTypeID
# 14193
# nan_WheelTypeID
# 2_WheelTypeID
# 14224
# nan_WheelTypeID
# 2_WheelTypeID
# 14395
# nan_WheelTypeID
# 2_WheelTypeID
# 14423
# nan_WheelTypeID
# 1_WheelTypeID
# 14449
# nan_WheelTypeID
# 2_WheelTypeID
# 14477
# nan_WheelTypeID
# 1_WheelTypeID
# 14491
# nan_WheelTypeID
# 2_WheelTypeID
# 14555
# nan_WheelTypeID
# 2_WheelTypeID
# 14588
# nan_WheelTypeID
# 1_WheelTypeID
# 14614
# nan_WheelTypeID
# 2_WheelTypeID
# 14617
# nan_WheelTypeID
# 2_WheelTypeID
# 14654
# nan_WheelTypeID
# 2_WheelTypeID
# 14663
# nan_WheelTypeID
# 2_WheelTypeID
# 14678
# nan_WheelTypeID
# 2_WheelTypeID
# 14709
# nan_WheelTypeID
# 1_WheelTypeID
# 14711
# nan_WheelTypeID
# 2_WheelTypeID
# 14740
# nan_WheelTypeID
# 2_WheelTypeID
# 14757
# nan_WheelTypeID
# 2_WheelTypeID
# 14797
# nan_WheelTypeID
# 2_WheelTypeID
# 14817
# nan_WheelTypeID
# 2_WheelTypeID
# 14854
# nan_WheelTypeID
# 1_WheelTypeID
# 14927
# nan_WheelTypeID
# 2_WheelTypeID
# 14940
# nan_WheelTypeID
# 2_WheelTypeID
# 14971
# nan_WheelTypeID
# 2_WheelTypeID
# 15048
# nan_WheelTypeID
# 2_WheelTypeID
# 15165
# nan_WheelTypeID
# 1_WheelTypeID
# 15211
# nan_WheelTypeID
# 2_WheelTypeID
# 15300
# nan_WheelTypeID
# 2_WheelTypeID
# 15306
# nan_WheelTypeID
# 2_WheelTypeID
# 15380
# nan_WheelTypeID
# 2_WheelTypeID
# 15399
# nan_WheelTypeID
# 2_WheelTypeID
# 15414
# nan_WheelTypeID
# 1_WheelTypeID
# 15472
# nan_WheelTypeID
# 2_WheelTypeID
# 15488
# nan_WheelTypeID
# 2_WheelTypeID
# 15688
# nan_WheelTypeID
# 1_WheelTypeID
# 15710
# nan_WheelTypeID
# 2_WheelTypeID
# 15714
# nan_WheelTypeID
# 2_WheelTypeID
# 15782
# nan_WheelTypeID
# 2_WheelTypeID
# 15823
# nan_WheelTypeID
# 2_WheelTypeID
# 15831
# nan_WheelTypeID
# 2_WheelTypeID
# 15853
# nan_WheelTypeID
# 2_WheelTypeID
# 15863
# nan_WheelTypeID
# 2_WheelTypeID
# 15882
# nan_WheelTypeID
# 2_WheelTypeID
# 15886
# nan_WheelTypeID
# 2_WheelTypeID
# 15907
# nan_WheelTypeID
# 2_WheelTypeID
# 15921
# nan_WheelTypeID
# 2_WheelTypeID
# 15922
# nan_WheelTypeID
# 2_WheelTypeID
# 15933
# nan_WheelTypeID
# 2_WheelTypeID
# 15964
# nan_WheelTypeID
# 2_WheelTypeID
# 16012
# nan_WheelTypeID
# 1_WheelTypeID
# 16030
# nan_WheelTypeID
# 2_WheelTypeID
# 16049
# nan_WheelTypeID
# 2_WheelTypeID
# 16145
# nan_WheelTypeID
# 2_WheelTypeID
# 16168
# nan_WheelTypeID
# 1_WheelTypeID
# 16242
# nan_WheelTypeID
# 2_WheelTypeID
# 16371
# nan_WheelTypeID
# 1_WheelTypeID
# 16469
# nan_WheelTypeID
# 2_WheelTypeID
# 16482
# nan_WheelTypeID
# 2_WheelTypeID
# 16487
# nan_WheelTypeID
# 2_WheelTypeID
# 16694
# nan_WheelTypeID
# 2_WheelTypeID
# 16731
# nan_WheelTypeID
# 1_WheelTypeID
# 16828
# nan_WheelTypeID
# 1_WheelTypeID
# 16832
# nan_WheelTypeID
# 2_WheelTypeID
# 16849
# nan_WheelTypeID
# 2_WheelTypeID
# 16884
# nan_WheelTypeID
# 2_WheelTypeID
# 16886
# nan_WheelTypeID
# 2_WheelTypeID
# 16946
# nan_WheelTypeID
# 2_WheelTypeID
# 16947
# nan_WheelTypeID
# 2_WheelTypeID
# 16953
# nan_WheelTypeID
# 2_WheelTypeID
# 16963
# nan_WheelTypeID
# 1_WheelTypeID
# 17001
# nan_WheelTypeID
# 1_WheelTypeID
# 17045
# nan_WheelTypeID
# 2_WheelTypeID
# 17059
# nan_WheelTypeID
# 2_WheelTypeID
# 17103
# nan_WheelTypeID
# 1_WheelTypeID
# 17157
# nan_WheelTypeID
# 2_WheelTypeID
# 17200
# nan_WheelTypeID
# 2_WheelTypeID
# 17219
# nan_WheelTypeID
# 2_WheelTypeID
# 17362
# nan_WheelTypeID
# 1_WheelTypeID
# 17404
# nan_WheelTypeID
# 1_WheelTypeID
# 17419
# nan_WheelTypeID
# 2_WheelTypeID
# 17428
# nan_WheelTypeID
# 2_WheelTypeID
# 17641
# nan_WheelTypeID
# 2_WheelTypeID
# 17712
# nan_WheelTypeID
# 1_WheelTypeID
# 17717
# nan_WheelTypeID
# 2_WheelTypeID
# 17815
# nan_WheelTypeID
# 2_WheelTypeID
# 17823
# nan_WheelTypeID
# 2_WheelTypeID
# 17888
# nan_WheelTypeID
# 1_WheelTypeID
# 17959
# nan_WheelTypeID
# 2_WheelTypeID
# 18078
# nan_WheelTypeID
# 2_WheelTypeID
# 18106
# nan_WheelTypeID
# 2_WheelTypeID
# 18161
# nan_WheelTypeID
# 2_WheelTypeID
# 18162
# nan_WheelTypeID
# 2_WheelTypeID
# 18183
# nan_WheelTypeID
# 2_WheelTypeID
# 18234
# nan_WheelTypeID
# 2_WheelTypeID
# 18248
# nan_WheelTypeID
# 2_WheelTypeID
# 18261
# nan_WheelTypeID
# 2_WheelTypeID
# 18282
# nan_WheelTypeID
# 1_WheelTypeID
# 18286
# nan_WheelTypeID
# 1_WheelTypeID
# 18305
# nan_WheelTypeID
# 2_WheelTypeID
# 18324
# nan_WheelTypeID
# 1_WheelTypeID
# 18339
# nan_WheelTypeID
# 2_WheelTypeID
# 18426
# nan_WheelTypeID
# 2_WheelTypeID
# 18438
# nan_WheelTypeID
# 1_WheelTypeID
# 18482
# nan_WheelTypeID
# 1_WheelTypeID
# 18513
# nan_WheelTypeID
# 2_WheelTypeID
# 18532
# nan_WheelTypeID
# 2_WheelTypeID
# 18533
# nan_WheelTypeID
# 2_WheelTypeID
# 18556
# nan_WheelTypeID
# 2_WheelTypeID
# 18571
# nan_WheelTypeID
# 2_WheelTypeID
# 18573
# nan_WheelTypeID
# 2_WheelTypeID
# 18639
# nan_WheelTypeID
# 2_WheelTypeID
# 18772
# nan_WheelTypeID
# 1_WheelTypeID
# 18853
# nan_WheelTypeID
# 2_WheelTypeID
# 18854
# nan_WheelTypeID
# 2_WheelTypeID
# 18959
# nan_WheelTypeID
# 2_WheelTypeID
# 18967
# nan_WheelTypeID
# 1_WheelTypeID
# 18979
# nan_WheelTypeID
# 1_WheelTypeID
# 19001
# nan_WheelTypeID
# 2_WheelTypeID
# 19015
# nan_WheelTypeID
# 1_WheelTypeID
# 19021
# nan_WheelTypeID
# 2_WheelTypeID
# 19070
# nan_WheelTypeID
# 2_WheelTypeID
# 19097
# nan_WheelTypeID
# 2_WheelTypeID
# 19119
# nan_WheelTypeID
# 2_WheelTypeID
# 19136
# nan_WheelTypeID
# 2_WheelTypeID
# 19151
# nan_WheelTypeID
# 2_WheelTypeID
# 19200
# nan_WheelTypeID
# 2_WheelTypeID
# 19214
# nan_WheelTypeID
# 2_WheelTypeID
# 19231
# nan_WheelTypeID
# 2_WheelTypeID
# 19266
# nan_WheelTypeID
# 1_WheelTypeID
# 19270
# nan_WheelTypeID
# 1_WheelTypeID
# 19341
# nan_WheelTypeID
# 2_WheelTypeID
# 19398
# nan_WheelTypeID
# 2_WheelTypeID
# 19404
# nan_WheelTypeID
# 2_WheelTypeID
# 19465
# nan_WheelTypeID
# 1_WheelTypeID
# 19558
# nan_WheelTypeID
# 2_WheelTypeID
# 19695
# nan_WheelTypeID
# 2_WheelTypeID
# 19726
# nan_WheelTypeID
# 1_WheelTypeID
# 19855
# nan_WheelTypeID
# 1_WheelTypeID
# 19872
# nan_WheelTypeID
# 2_WheelTypeID
# 19894
# nan_WheelTypeID
# 2_WheelTypeID
# 19981
# nan_WheelTypeID
# 2_WheelTypeID
# 19985
# nan_WheelTypeID
# 2_WheelTypeID
# 20041
# nan_WheelTypeID
# 1_WheelTypeID
# 20042
# nan_WheelTypeID
# 2_WheelTypeID
# 20043
# nan_WheelTypeID
# 2_WheelTypeID
# 20062
# nan_WheelTypeID
# 2_WheelTypeID
# 20070
# nan_WheelTypeID
# 2_WheelTypeID
# 20092
# nan_WheelTypeID
# 2_WheelTypeID
# 20112
# nan_WheelTypeID
# 2_WheelTypeID
# 20134
# nan_WheelTypeID
# 2_WheelTypeID
# 20191
# nan_WheelTypeID
# 2_WheelTypeID
# 20199
# nan_WheelTypeID
# 2_WheelTypeID
# 20213
# nan_WheelTypeID
# 1_WheelTypeID
# 20230
# nan_WheelTypeID
# 1_WheelTypeID
# 20266
# nan_WheelTypeID
# 1_WheelTypeID
# 20279
# nan_WheelTypeID
# 2_WheelTypeID
# 20288
# nan_WheelTypeID
# 2_WheelTypeID
# 20349
# nan_WheelTypeID
# 1_WheelTypeID
# 20433
# nan_WheelTypeID
# 1_WheelTypeID
# 20445
# nan_WheelTypeID
# 2_WheelTypeID
# 20446
# nan_WheelTypeID
# 2_WheelTypeID
# 20485
# nan_WheelTypeID
# 2_WheelTypeID
# 20502
# nan_WheelTypeID
# 2_WheelTypeID
# 20534
# nan_WheelTypeID
# 2_WheelTypeID
# 20555
# nan_WheelTypeID
# 1_WheelTypeID
# 20577
# nan_WheelTypeID
# 2_WheelTypeID
# 20629
# nan_WheelTypeID
# 2_WheelTypeID
# 20633
# nan_WheelTypeID
# 1_WheelTypeID
# 20642
# nan_WheelTypeID
# 2_WheelTypeID
# 20649
# nan_WheelTypeID
# 1_WheelTypeID
# 20654
# nan_WheelTypeID
# 1_WheelTypeID
# 20694
# nan_WheelTypeID
# 2_WheelTypeID
# 20755
# nan_WheelTypeID
# 2_WheelTypeID
# 20762
# nan_WheelTypeID
# 2_WheelTypeID
# 20818
# nan_WheelTypeID
# 2_WheelTypeID
# 20858
# nan_WheelTypeID
# 2_WheelTypeID
# 20924
# nan_WheelTypeID
# 2_WheelTypeID
# 20945
# nan_WheelTypeID
# 2_WheelTypeID
# 20960
# nan_WheelTypeID
# 2_WheelTypeID
# 20971
# nan_WheelTypeID
# 2_WheelTypeID
# 20973
# nan_WheelTypeID
# 2_WheelTypeID
# 21024
# nan_WheelTypeID
# 1_WheelTypeID
# 21050
# nan_WheelTypeID
# 1_WheelTypeID
# 21059
# nan_WheelTypeID
# 2_WheelTypeID
# 21061
# nan_WheelTypeID
# 2_WheelTypeID
# 21062
# nan_WheelTypeID
# 2_WheelTypeID
# 21063
# nan_WheelTypeID
# 2_WheelTypeID
# 21157
# nan_WheelTypeID
# 2_WheelTypeID
# 21161
# nan_WheelTypeID
# 2_WheelTypeID
# 21174
# nan_WheelTypeID
# 1_WheelTypeID
# 21232
# nan_WheelTypeID
# 2_WheelTypeID
# 21312
# nan_WheelTypeID
# 2_WheelTypeID
# 21328
# nan_WheelTypeID
# 1_WheelTypeID
# 21383
# nan_WheelTypeID
# 2_WheelTypeID
# 21496
# nan_WheelTypeID
# 2_WheelTypeID
# 21504
# nan_WheelTypeID
# 2_WheelTypeID
# 21513
# nan_WheelTypeID
# 2_WheelTypeID
# 21516
# nan_WheelTypeID
# 2_WheelTypeID
# 21519
# nan_WheelTypeID
# 1_WheelTypeID
# 21631
# nan_WheelTypeID
# 1_WheelTypeID
# 21636
# nan_WheelTypeID
# 2_WheelTypeID
# 21660
# nan_WheelTypeID
# 1_WheelTypeID
# 21662
# nan_WheelTypeID
# 2_WheelTypeID
# 21727
# nan_WheelTypeID
# 2_WheelTypeID
# 21745
# nan_WheelTypeID
# 2_WheelTypeID
# 21751
# nan_WheelTypeID
# 2_WheelTypeID
# 21790
# nan_WheelTypeID
# 2_WheelTypeID
# 21873
# nan_WheelTypeID
# 2_WheelTypeID
# 21876
# nan_WheelTypeID
# 2_WheelTypeID
# 21911
# nan_WheelTypeID
# 2_WheelTypeID
# 21915
# nan_WheelTypeID
# 2_WheelTypeID
# 21926
# nan_WheelTypeID
# 2_WheelTypeID
# 21931
# nan_WheelTypeID
# 2_WheelTypeID
# 21959
# nan_WheelTypeID
# 2_WheelTypeID
# 22029
# nan_WheelTypeID
# 2_WheelTypeID
# 22077
# nan_WheelTypeID
# 2_WheelTypeID
# 22131
# nan_WheelTypeID
# 2_WheelTypeID
# 22206
# nan_WheelTypeID
# 2_WheelTypeID
# 22324
# nan_WheelTypeID
# 2_WheelTypeID
# 22413
# nan_WheelTypeID
# 2_WheelTypeID
# 22431
# nan_WheelTypeID
# 2_WheelTypeID
# 22476
# nan_WheelTypeID
# 2_WheelTypeID
# 22528
# nan_WheelTypeID
# 2_WheelTypeID
# 22532
# nan_WheelTypeID
# 2_WheelTypeID
# 22673
# nan_WheelTypeID
# 1_WheelTypeID
# 22703
# nan_WheelTypeID
# 2_WheelTypeID
# 22713
# nan_WheelTypeID
# 2_WheelTypeID
# 22727
# nan_WheelTypeID
# 2_WheelTypeID
# 22780
# nan_WheelTypeID
# 2_WheelTypeID
# 22860
# nan_WheelTypeID
# 2_WheelTypeID
# 22862
# nan_WheelTypeID
# 1_WheelTypeID
# 22872
# nan_WheelTypeID
# 2_WheelTypeID
# 22887
# nan_WheelTypeID
# 1_WheelTypeID
# 22938
# nan_WheelTypeID
# 2_WheelTypeID
# 23010
# nan_WheelTypeID
# 2_WheelTypeID
# 23036
# nan_WheelTypeID
# 1_WheelTypeID
# 23053
# nan_WheelTypeID
# 2_WheelTypeID
# 23074
# nan_WheelTypeID
# 1_WheelTypeID
# 23099
# nan_WheelTypeID
# 2_WheelTypeID
# 23111
# nan_WheelTypeID
# 2_WheelTypeID
# 23188
# nan_WheelTypeID
# 1_WheelTypeID
# 23229
# nan_WheelTypeID
# 2_WheelTypeID
# 23253
# nan_WheelTypeID
# 2_WheelTypeID
# 23281
# nan_WheelTypeID
# 1_WheelTypeID
# 23287
# nan_WheelTypeID
# 2_WheelTypeID
# 23339
# nan_WheelTypeID
# 2_WheelTypeID
# 23387
# nan_WheelTypeID
# 1_WheelTypeID
# 23472
# nan_WheelTypeID
# 2_WheelTypeID
# 23529
# nan_WheelTypeID
# 2_WheelTypeID
# 23556
# nan_WheelTypeID
# 2_WheelTypeID
# 23566
# nan_WheelTypeID
# 2_WheelTypeID
# 23589
# nan_WheelTypeID
# 2_WheelTypeID
# 23595
# nan_WheelTypeID
# 2_WheelTypeID
# 23629
# nan_WheelTypeID
# 2_WheelTypeID
# 23678
# nan_WheelTypeID
# 2_WheelTypeID
# 23692
# nan_WheelTypeID
# 2_WheelTypeID
# 23710
# nan_WheelTypeID
# 2_WheelTypeID
# 23716
# nan_WheelTypeID
# 1_WheelTypeID
# 23803
# nan_WheelTypeID
# 2_WheelTypeID
# 23841
# nan_WheelTypeID
# 1_WheelTypeID
# 23889
# nan_WheelTypeID
# 2_WheelTypeID
# 23912
# nan_WheelTypeID
# 2_WheelTypeID
# 23938
# nan_WheelTypeID
# 2_WheelTypeID
# 23953
# nan_WheelTypeID
# 2_WheelTypeID
# 24039
# nan_WheelTypeID
# 2_WheelTypeID
# 24062
# nan_WheelTypeID
# 2_WheelTypeID
# 24085
# nan_WheelTypeID
# 2_WheelTypeID
# 24087
# nan_WheelTypeID
# 2_WheelTypeID
# 24115
# nan_WheelTypeID
# 2_WheelTypeID
# 24129
# nan_WheelTypeID
# 1_WheelTypeID
# 24195
# nan_WheelTypeID
# 2_WheelTypeID
# 24205
# nan_WheelTypeID
# 1_WheelTypeID
# 24210
# nan_WheelTypeID
# 2_WheelTypeID
# 24244
# nan_WheelTypeID
# 2_WheelTypeID
# 24253
# nan_WheelTypeID
# 1_WheelTypeID
# 24308
# nan_WheelTypeID
# 1_WheelTypeID
# 24362
# nan_WheelTypeID
# 2_WheelTypeID
# 24443
# nan_WheelTypeID
# 1_WheelTypeID
# 24446
# nan_WheelTypeID
# 2_WheelTypeID
# 24474
# nan_WheelTypeID
# 2_WheelTypeID
# 24510
# nan_WheelTypeID
# 2_WheelTypeID
# 24604
# nan_WheelTypeID
# 2_WheelTypeID
# 24641
# nan_WheelTypeID
# 2_WheelTypeID
# 24649
# nan_WheelTypeID
# 1_WheelTypeID
# 24749
# nan_WheelTypeID
# 2_WheelTypeID
# 24756
# nan_WheelTypeID
# 2_WheelTypeID
# 24792
# nan_WheelTypeID
# 2_WheelTypeID
# 24868
# nan_WheelTypeID
# 1_WheelTypeID
# 24889
# nan_WheelTypeID
# 2_WheelTypeID
# 24911
# nan_WheelTypeID
# 2_WheelTypeID
# 24914
# nan_WheelTypeID
# 2_WheelTypeID
# 24961
# nan_WheelTypeID
# 2_WheelTypeID
# 25022
# nan_WheelTypeID
# 2_WheelTypeID
# 25082
# nan_WheelTypeID
# 2_WheelTypeID
# 25091
# nan_WheelTypeID
# 2_WheelTypeID
# 25126
# nan_WheelTypeID
# 2_WheelTypeID
# 25171
# nan_WheelTypeID
# 2_WheelTypeID
# 25174
# nan_WheelTypeID
# 2_WheelTypeID
# 25190
# nan_WheelTypeID
# 2_WheelTypeID
# 25225
# nan_WheelTypeID
# 2_WheelTypeID
# 25243
# nan_WheelTypeID
# 2_WheelTypeID
# 25255
# nan_WheelTypeID
# 2_WheelTypeID
# 25306
# nan_WheelTypeID
# 2_WheelTypeID
# 25345
# nan_WheelTypeID
# 1_WheelTypeID
# 25361
# nan_WheelTypeID
# 2_WheelTypeID
# 25408
# nan_WheelTypeID
# 1_WheelTypeID
# 25425
# nan_WheelTypeID
# 2_WheelTypeID
# 25454
# nan_WheelTypeID
# 2_WheelTypeID
# 25462
# nan_WheelTypeID
# 1_WheelTypeID
# 25464
# nan_WheelTypeID
# 2_WheelTypeID
# 25490
# nan_WheelTypeID
# 2_WheelTypeID
# 25495
# nan_WheelTypeID
# 1_WheelTypeID
# 25507
# nan_WheelTypeID
# 2_WheelTypeID
# 25513
# nan_WheelTypeID
# 2_WheelTypeID
# 25518
# nan_WheelTypeID
# 2_WheelTypeID
# 25519
# nan_WheelTypeID
# 2_WheelTypeID
# 25540
# nan_WheelTypeID
# 2_WheelTypeID
# 25549
# nan_WheelTypeID
# 1_WheelTypeID
# 25552
# nan_WheelTypeID
# 2_WheelTypeID
# 25558
# nan_WheelTypeID
# 2_WheelTypeID
# 25635
# nan_WheelTypeID
# 2_WheelTypeID
# 25638
# nan_WheelTypeID
# 2_WheelTypeID
# 25681
# nan_WheelTypeID
# 2_WheelTypeID
# 25683
# nan_WheelTypeID
# 2_WheelTypeID
# 25691
# nan_WheelTypeID
# 1_WheelTypeID
# 25717
# nan_WheelTypeID
# 1_WheelTypeID
# 25725
# nan_WheelTypeID
# 1_WheelTypeID
# 25774
# nan_WheelTypeID
# 2_WheelTypeID
# 25822
# nan_WheelTypeID
# 2_WheelTypeID
# 25864
# nan_WheelTypeID
# 2_WheelTypeID
# 25866
# nan_WheelTypeID
# 1_WheelTypeID
# 25900
# nan_WheelTypeID
# 2_WheelTypeID
# 25967
# nan_WheelTypeID
# 2_WheelTypeID
# 25985
# nan_WheelTypeID
# 2_WheelTypeID
# 26123
# nan_WheelTypeID
# 2_WheelTypeID
# 26135
# nan_WheelTypeID
# 1_WheelTypeID
# 26187
# nan_WheelTypeID
# 2_WheelTypeID
# 26251
# nan_WheelTypeID
# 1_WheelTypeID
# 26252
# nan_WheelTypeID
# 1_WheelTypeID
# 26317
# nan_WheelTypeID
# 2_WheelTypeID
# 26331
# nan_WheelTypeID
# 2_WheelTypeID
# 26354
# nan_WheelTypeID
# 2_WheelTypeID
# 26375
# nan_WheelTypeID
# 2_WheelTypeID
# 26383
# nan_WheelTypeID
# 1_WheelTypeID
# 26390
# nan_WheelTypeID
# 2_WheelTypeID
# 26398
# nan_WheelTypeID
# 1_WheelTypeID
# 26460
# nan_WheelTypeID
# 2_WheelTypeID
# 26475
# nan_WheelTypeID
# 2_WheelTypeID
# 26577
# nan_WheelTypeID
# 1_WheelTypeID
# 26639
# nan_WheelTypeID
# 2_WheelTypeID
# 26720
# nan_WheelTypeID
# 2_WheelTypeID
# 26731
# nan_WheelTypeID
# 1_WheelTypeID
# 26734
# nan_WheelTypeID
# 1_WheelTypeID
# 26770
# nan_WheelTypeID
# 2_WheelTypeID
# 26788
# nan_WheelTypeID
# 1_WheelTypeID
# 26799
# nan_WheelTypeID
# 2_WheelTypeID
# 26937
# nan_WheelTypeID
# 1_WheelTypeID
# 26956
# nan_WheelTypeID
# 2_WheelTypeID
# 27041
# nan_WheelTypeID
# 2_WheelTypeID
# 27076
# nan_WheelTypeID
# 2_WheelTypeID
# 27078
# nan_WheelTypeID
# 2_WheelTypeID
# 27081
# nan_WheelTypeID
# 2_WheelTypeID
# 27083
# nan_WheelTypeID
# 1_WheelTypeID
# 27105
# nan_WheelTypeID
# 1_WheelTypeID
# 27111
# nan_WheelTypeID
# 2_WheelTypeID
# 27115
# nan_WheelTypeID
# 2_WheelTypeID
# 27142
# nan_WheelTypeID
# 2_WheelTypeID
# 27167
# nan_WheelTypeID
# 2_WheelTypeID
# 27172
# nan_WheelTypeID
# 2_WheelTypeID
# 27176
# nan_WheelTypeID
# 1_WheelTypeID
# 27196
# nan_WheelTypeID
# 2_WheelTypeID
# 27199
# nan_WheelTypeID
# 2_WheelTypeID
# 27205
# nan_WheelTypeID
# 2_WheelTypeID
# 27219
# nan_WheelTypeID
# 2_WheelTypeID
# 27262
# nan_WheelTypeID
# 2_WheelTypeID
# 27283
# nan_WheelTypeID
# 2_WheelTypeID
# 27367
# nan_WheelTypeID
# 1_WheelTypeID
# 27374
# nan_WheelTypeID
# 2_WheelTypeID
# 27377
# nan_WheelTypeID
# 2_WheelTypeID
# 27391
# nan_WheelTypeID
# 2_WheelTypeID
# 27419
# nan_WheelTypeID
# 2_WheelTypeID
# 27586
# nan_WheelTypeID
# 1_WheelTypeID
# 27588
# nan_WheelTypeID
# 2_WheelTypeID
# 27597
# nan_WheelTypeID
# 2_WheelTypeID
# 27614
# nan_WheelTypeID
# 2_WheelTypeID
# 27666
# nan_WheelTypeID
# 2_WheelTypeID
# 27692
# nan_WheelTypeID
# 2_WheelTypeID
# 27763
# nan_WheelTypeID
# 2_WheelTypeID
# 27783
# nan_WheelTypeID
# 2_WheelTypeID
# 27900
# nan_WheelTypeID
# 1_WheelTypeID
# 27925
# nan_WheelTypeID
# 2_WheelTypeID
# 27975
# nan_WheelTypeID
# 2_WheelTypeID
# 27989
# nan_WheelTypeID
# 2_WheelTypeID
# 28022
# nan_WheelTypeID
# 1_WheelTypeID
# 28107
# nan_WheelTypeID
# 2_WheelTypeID
# 28145
# nan_WheelTypeID
# 2_WheelTypeID
# 28186
# nan_WheelTypeID
# 2_WheelTypeID
# 28264
# nan_WheelTypeID
# 2_WheelTypeID
# 28269
# nan_WheelTypeID
# 1_WheelTypeID
# 28282
# nan_WheelTypeID
# 2_WheelTypeID
# 28298
# nan_WheelTypeID
# 2_WheelTypeID
# 28312
# nan_WheelTypeID
# 2_WheelTypeID
# 28313
# nan_WheelTypeID
# 2_WheelTypeID
# 28318
# nan_WheelTypeID
# 2_WheelTypeID
# 28338
# nan_WheelTypeID
# 2_WheelTypeID
# 28375
# nan_WheelTypeID
# 2_WheelTypeID
# 28403
# nan_WheelTypeID
# 2_WheelTypeID
# 28428
# nan_WheelTypeID
# 1_WheelTypeID
# 28460
# nan_WheelTypeID
# 1_WheelTypeID
# 28464
# nan_WheelTypeID
# 2_WheelTypeID
# 28470
# nan_WheelTypeID
# 2_WheelTypeID
# 28513
# nan_WheelTypeID
# 2_WheelTypeID
# 28551
# nan_WheelTypeID
# 2_WheelTypeID
# 28573
# nan_WheelTypeID
# 2_WheelTypeID
# 28578
# nan_WheelTypeID
# 2_WheelTypeID
# 28600
# nan_WheelTypeID
# 2_WheelTypeID
# 28605
# nan_WheelTypeID
# 2_WheelTypeID
# 28630
# nan_WheelTypeID
# 2_WheelTypeID
# 28720
# nan_WheelTypeID
# 2_WheelTypeID
# 28744
# nan_WheelTypeID
# 2_WheelTypeID
# 28789
# nan_WheelTypeID
# 2_WheelTypeID
# 28889
# nan_WheelTypeID
# 2_WheelTypeID
# 28890
# nan_WheelTypeID
# 2_WheelTypeID
# 28940
# nan_WheelTypeID
# 2_WheelTypeID
# 28950
# nan_WheelTypeID
# 1_WheelTypeID
# 29005
# nan_WheelTypeID
# 2_WheelTypeID
# 29079
# nan_WheelTypeID
# 2_WheelTypeID
# 29096
# nan_WheelTypeID
# 2_WheelTypeID
# 29115
# nan_WheelTypeID
# 1_WheelTypeID
# 29209
# nan_WheelTypeID
# 2_WheelTypeID
# 29262
# nan_WheelTypeID
# 2_WheelTypeID
# 29285
# nan_WheelTypeID
# 2_WheelTypeID
# 29379
# nan_WheelTypeID
# 2_WheelTypeID
# 29389
# nan_WheelTypeID
# 2_WheelTypeID
# 29410
# nan_WheelTypeID
# 1_WheelTypeID
# 29415
# nan_WheelTypeID
# 2_WheelTypeID
# 29495
# nan_WheelTypeID
# 2_WheelTypeID
# 29530
# nan_WheelTypeID
# 2_WheelTypeID
# 29542
# nan_WheelTypeID
# 2_WheelTypeID
# 29547
# nan_WheelTypeID
# 2_WheelTypeID
# 29577
# nan_WheelTypeID
# 2_WheelTypeID
# 29643
# nan_WheelTypeID
# 1_WheelTypeID
# 29645
# nan_WheelTypeID
# 2_WheelTypeID
# 29667
# nan_WheelTypeID
# 1_WheelTypeID
# 29689
# nan_WheelTypeID
# 2_WheelTypeID
# 29824
# nan_WheelTypeID
# 1_WheelTypeID
# 29854
# nan_WheelTypeID
# 2_WheelTypeID
# 29861
# nan_WheelTypeID
# 2_WheelTypeID
# 29894
# nan_WheelTypeID
# 1_WheelTypeID
# 29927
# nan_WheelTypeID
# 2_WheelTypeID
# 29931
# nan_WheelTypeID
# 2_WheelTypeID
# 29967
# nan_WheelTypeID
# 2_WheelTypeID
# 29982
# nan_WheelTypeID
# 2_WheelTypeID
# 29999
# nan_WheelTypeID
# 2_WheelTypeID
# 30053
# nan_WheelTypeID
# 1_WheelTypeID
# 30055
# nan_WheelTypeID
# 2_WheelTypeID
# 30124
# nan_WheelTypeID
# 2_WheelTypeID
# 30125
# nan_WheelTypeID
# 2_WheelTypeID
# 30145
# nan_WheelTypeID
# 2_WheelTypeID
# 30167
# nan_WheelTypeID
# 2_WheelTypeID
# 30180
# nan_WheelTypeID
# 1_WheelTypeID
# 30190
# nan_WheelTypeID
# 2_WheelTypeID
# 30297
# nan_WheelTypeID
# 2_WheelTypeID
# 30298
# nan_WheelTypeID
# 1_WheelTypeID
# 30324
# nan_WheelTypeID
# 2_WheelTypeID
# 30334
# nan_WheelTypeID
# 2_WheelTypeID
# 30339
# nan_WheelTypeID
# 2_WheelTypeID
# 30379
# nan_WheelTypeID
# 2_WheelTypeID
# 30422
# nan_WheelTypeID
# 2_WheelTypeID
# 30491
# nan_WheelTypeID
# 2_WheelTypeID
# 30598
# nan_WheelTypeID
# 2_WheelTypeID
# 30641
# nan_WheelTypeID
# 2_WheelTypeID
# 30645
# nan_WheelTypeID
# 1_WheelTypeID
# 30655
# nan_WheelTypeID
# 2_WheelTypeID
# 30693
# nan_WheelTypeID
# 2_WheelTypeID
# 30697
# nan_WheelTypeID
# 2_WheelTypeID
# 30698
# nan_WheelTypeID
# 2_WheelTypeID
# 30709
# nan_WheelTypeID
# 2_WheelTypeID
# 30752
# nan_WheelTypeID
# 1_WheelTypeID
# 30761
# nan_WheelTypeID
# 2_WheelTypeID
# 30809
# nan_WheelTypeID
# 2_WheelTypeID
# 30810
# nan_WheelTypeID
# 2_WheelTypeID
# 30878
# nan_WheelTypeID
# 2_WheelTypeID
# 30883
# nan_WheelTypeID
# 2_WheelTypeID
# 30946
# nan_WheelTypeID
# 1_WheelTypeID
# 30953
# nan_WheelTypeID
# 1_WheelTypeID
# 31029
# nan_WheelTypeID
# 2_WheelTypeID
# 31036
# nan_WheelTypeID
# 1_WheelTypeID
# 31092
# nan_WheelTypeID
# 2_WheelTypeID
# 31103
# nan_WheelTypeID
# 2_WheelTypeID
# 31135
# nan_WheelTypeID
# 2_WheelTypeID
# 31147
# nan_WheelTypeID
# 2_WheelTypeID
# 31160
# nan_WheelTypeID
# 2_WheelTypeID
# 31182
# nan_WheelTypeID
# 2_WheelTypeID
# 31200
# nan_WheelTypeID
# 2_WheelTypeID
# 31236
# nan_WheelTypeID
# 1_WheelTypeID
# 31264
# nan_WheelTypeID
# 2_WheelTypeID
# 31288
# nan_WheelTypeID
# 2_WheelTypeID
# 31323
# nan_WheelTypeID
# 2_WheelTypeID
# 31327
# nan_WheelTypeID
# 2_WheelTypeID
# 31349
# nan_WheelTypeID
# 1_WheelTypeID
# 31431
# nan_WheelTypeID
# 2_WheelTypeID
# 31489
# nan_WheelTypeID
# 2_WheelTypeID
# 31506
# nan_WheelTypeID
# 2_WheelTypeID
# 31550
# nan_WheelTypeID
# 2_WheelTypeID
# 31551
# nan_WheelTypeID
# 2_WheelTypeID
# 31600
# nan_WheelTypeID
# 1_WheelTypeID
# 31616
# nan_WheelTypeID
# 2_WheelTypeID
# 31660
# nan_WheelTypeID
# 2_WheelTypeID
# 31677
# nan_WheelTypeID
# 2_WheelTypeID
# 31678
# nan_WheelTypeID
# 2_WheelTypeID
# 31708
# nan_WheelTypeID
# 2_WheelTypeID
# 31743
# nan_WheelTypeID
# 2_WheelTypeID
# 31750
# nan_WheelTypeID
# 2_WheelTypeID
# 31775
# nan_WheelTypeID
# 2_WheelTypeID
# 31789
# nan_WheelTypeID
# 1_WheelTypeID
# 31796
# nan_WheelTypeID
# 2_WheelTypeID
# 31822
# nan_WheelTypeID
# 2_WheelTypeID
# 31827
# nan_WheelTypeID
# 1_WheelTypeID
# 31832
# nan_WheelTypeID
# 2_WheelTypeID
# 31843
# nan_WheelTypeID
# 2_WheelTypeID
# 31978
# nan_WheelTypeID
# 1_WheelTypeID
# 32013
# nan_WheelTypeID
# 2_WheelTypeID
# 32025
# nan_WheelTypeID
# 2_WheelTypeID
# 32045
# nan_WheelTypeID
# 1_WheelTypeID
# 32053
# nan_WheelTypeID
# 1_WheelTypeID
# 32076
# nan_WheelTypeID
# 1_WheelTypeID
# 32182
# nan_WheelTypeID
# 2_WheelTypeID
# 32299
# nan_WheelTypeID
# 1_WheelTypeID
# 32336
# nan_WheelTypeID
# 1_WheelTypeID
# 32371
# nan_WheelTypeID
# 2_WheelTypeID
# 32392
# nan_WheelTypeID
# 2_WheelTypeID
# 32393
# nan_WheelTypeID
# 2_WheelTypeID
# 32429
# nan_WheelTypeID
# 2_WheelTypeID
# 32439
# nan_WheelTypeID
# 2_WheelTypeID
# 32541
# nan_WheelTypeID
# 2_WheelTypeID
# 32573
# nan_WheelTypeID
# 2_WheelTypeID
# 32599
# nan_WheelTypeID
# 2_WheelTypeID
# 32619
# nan_WheelTypeID
# 2_WheelTypeID
# 32635
# nan_WheelTypeID
# 1_WheelTypeID
# 32681
# nan_WheelTypeID
# 2_WheelTypeID
# 32713
# nan_WheelTypeID
# 2_WheelTypeID
# 32751
# nan_WheelTypeID
# 2_WheelTypeID
# 32778
# nan_WheelTypeID
# 1_WheelTypeID
# 32795
# nan_WheelTypeID
# 1_WheelTypeID
# 32803
# nan_WheelTypeID
# 2_WheelTypeID
# 32845
# nan_WheelTypeID
# 1_WheelTypeID
# 32851
# nan_WheelTypeID
# 2_WheelTypeID
# 32866
# nan_WheelTypeID
# 2_WheelTypeID
# 32891
# nan_WheelTypeID
# 2_WheelTypeID
# 32894
# nan_WheelTypeID
# 2_WheelTypeID
# 32908
# nan_WheelTypeID
# 2_WheelTypeID
# 32930
# nan_WheelTypeID
# 2_WheelTypeID
# 33031
# nan_WheelTypeID
# 2_WheelTypeID
# 33042
# nan_WheelTypeID
# 2_WheelTypeID
# 33054
# nan_WheelTypeID
# 2_WheelTypeID
# 33071
# nan_WheelTypeID
# 2_WheelTypeID
# 33201
# nan_WheelTypeID
# 2_WheelTypeID
# 33238
# nan_WheelTypeID
# 1_WheelTypeID
# 33292
# nan_WheelTypeID
# 2_WheelTypeID
# 33295
# nan_WheelTypeID
# 2_WheelTypeID
# 33341
# nan_WheelTypeID
# 2_WheelTypeID
# 33353
# nan_WheelTypeID
# 1_WheelTypeID
# 33362
# nan_WheelTypeID
# 2_WheelTypeID
# 33382
# nan_WheelTypeID
# 2_WheelTypeID
# 33396
# nan_WheelTypeID
# 2_WheelTypeID
# 33433
# nan_WheelTypeID
# 1_WheelTypeID
# 33484
# nan_WheelTypeID
# 2_WheelTypeID
# 33503
# nan_WheelTypeID
# 1_WheelTypeID
# 33534
# nan_WheelTypeID
# 2_WheelTypeID
# 33550
# nan_WheelTypeID
# 1_WheelTypeID
# 33555
# nan_WheelTypeID
# 2_WheelTypeID
# 33571
# nan_WheelTypeID
# 1_WheelTypeID
# 33575
# nan_WheelTypeID
# 2_WheelTypeID
# 33599
# nan_WheelTypeID
# 2_WheelTypeID
# 33658
# nan_WheelTypeID
# 1_WheelTypeID
# 33695
# nan_WheelTypeID
# 2_WheelTypeID
# 33711
# nan_WheelTypeID
# 1_WheelTypeID
# 33729
# nan_WheelTypeID
# 1_WheelTypeID
# 33766
# nan_WheelTypeID
# 1_WheelTypeID
# 33829
# nan_WheelTypeID
# 2_WheelTypeID
# 33896
# nan_WheelTypeID
# 1_WheelTypeID
# 34034
# nan_WheelTypeID
# 1_WheelTypeID
# 34049
# nan_WheelTypeID
# 2_WheelTypeID
# 34057
# nan_WheelTypeID
# 2_WheelTypeID
# 34122
# nan_WheelTypeID
# 1_WheelTypeID
# 34191
# nan_WheelTypeID
# 1_WheelTypeID
# 34228
# nan_WheelTypeID
# 2_WheelTypeID
# 34270
# nan_WheelTypeID
# 1_WheelTypeID
# 34304
# nan_WheelTypeID
# 2_WheelTypeID
# 34307
# nan_WheelTypeID
# 2_WheelTypeID
# 34375
# nan_WheelTypeID
# 1_WheelTypeID
# 34377
# nan_WheelTypeID
# 1_WheelTypeID
# 34408
# nan_WheelTypeID
# 2_WheelTypeID
# 34428
# nan_WheelTypeID
# 1_WheelTypeID
# 34500
# nan_WheelTypeID
# 1_WheelTypeID
# 34532
# nan_WheelTypeID
# 2_WheelTypeID
# 34551
# nan_WheelTypeID
# 2_WheelTypeID
# 34691
# nan_WheelTypeID
# 2_WheelTypeID
# 34702
# nan_WheelTypeID
# 2_WheelTypeID
# 34710
# nan_WheelTypeID
# 2_WheelTypeID
# 34763
# nan_WheelTypeID
# 2_WheelTypeID
# 34804
# nan_WheelTypeID
# 2_WheelTypeID
# 34828
# nan_WheelTypeID
# 1_WheelTypeID
# 34874
# nan_WheelTypeID
# 1_WheelTypeID
# 34908
# nan_WheelTypeID
# 2_WheelTypeID
# 34923
# nan_WheelTypeID
# 1_WheelTypeID
# 34926
# nan_WheelTypeID
# 2_WheelTypeID
# 34928
# nan_WheelTypeID
# 2_WheelTypeID
# 34952
# nan_WheelTypeID
# 2_WheelTypeID
# 35021
# nan_WheelTypeID
# 1_WheelTypeID
# 35027
# nan_WheelTypeID
# 1_WheelTypeID
# 35082
# nan_WheelTypeID
# 1_WheelTypeID
# 35093
# nan_WheelTypeID
# 2_WheelTypeID
# 35116
# nan_WheelTypeID
# 2_WheelTypeID
# 35146
# nan_WheelTypeID
# 1_WheelTypeID
# 35160
# nan_WheelTypeID
# 2_WheelTypeID
# 35178
# nan_WheelTypeID
# 1_WheelTypeID
# 35192
# nan_WheelTypeID
# 2_WheelTypeID
# 35209
# nan_WheelTypeID
# 1_WheelTypeID
# 35212
# nan_WheelTypeID
# 2_WheelTypeID
# 35216
# nan_WheelTypeID
# 2_WheelTypeID
# 35233
# nan_WheelTypeID
# 2_WheelTypeID
# 35240
# nan_WheelTypeID
# 2_WheelTypeID
# 35244
# nan_WheelTypeID
# 2_WheelTypeID
# 35257
# nan_WheelTypeID
# 2_WheelTypeID
# 35333
# nan_WheelTypeID
# 2_WheelTypeID
# 35344
# nan_WheelTypeID
# 1_WheelTypeID
# 35351
# nan_WheelTypeID
# 2_WheelTypeID
# 35366
# nan_WheelTypeID
# 2_WheelTypeID
# 35372
# nan_WheelTypeID
# 2_WheelTypeID
# 35393
# nan_WheelTypeID
# 2_WheelTypeID
# 35408
# nan_WheelTypeID
# 1_WheelTypeID
# 35424
# nan_WheelTypeID
# 1_WheelTypeID
# 35448
# nan_WheelTypeID
# 1_WheelTypeID
# 35486
# nan_WheelTypeID
# 2_WheelTypeID
# 35573
# nan_WheelTypeID
# 2_WheelTypeID
# 35595
# nan_WheelTypeID
# 2_WheelTypeID
# 35642
# nan_WheelTypeID
# 2_WheelTypeID
# 35658
# nan_WheelTypeID
# 2_WheelTypeID
# 35677
# nan_WheelTypeID
# 1_WheelTypeID
# 35702
# nan_WheelTypeID
# 2_WheelTypeID
# 35776
# nan_WheelTypeID
# 2_WheelTypeID
# 35787
# nan_WheelTypeID
# 1_WheelTypeID
# 35848
# nan_WheelTypeID
# 2_WheelTypeID
# 35901
# nan_WheelTypeID
# 2_WheelTypeID
# 35997
# nan_WheelTypeID
# 2_WheelTypeID
# 36049
# nan_WheelTypeID
# 2_WheelTypeID
# 36051
# nan_WheelTypeID
# 2_WheelTypeID
# 36095
# nan_WheelTypeID
# 2_WheelTypeID
# 36150
# nan_WheelTypeID
# 2_WheelTypeID
# 36202
# nan_WheelTypeID
# 1_WheelTypeID
# 36211
# nan_WheelTypeID
# 2_WheelTypeID
# 36236
# nan_WheelTypeID
# 2_WheelTypeID
# 36237
# nan_WheelTypeID
# 2_WheelTypeID
# 36318
# nan_WheelTypeID
# 2_WheelTypeID
# 36331
# nan_WheelTypeID
# 2_WheelTypeID
# 36346
# nan_WheelTypeID
# 2_WheelTypeID
# 36375
# nan_WheelTypeID
# 1_WheelTypeID
# 36460
# nan_WheelTypeID
# 2_WheelTypeID
# 36493
# nan_WheelTypeID
# 2_WheelTypeID
# 36516
# nan_WheelTypeID
# 2_WheelTypeID
# 36553
# nan_WheelTypeID
# 2_WheelTypeID
# 36566
# nan_WheelTypeID
# 1_WheelTypeID
# 36605
# nan_WheelTypeID
# 1_WheelTypeID
# 36615
# nan_WheelTypeID
# 2_WheelTypeID
# 36616
# nan_WheelTypeID
# 2_WheelTypeID
# 36630
# nan_WheelTypeID
# 1_WheelTypeID
# 36631
# nan_WheelTypeID
# 1_WheelTypeID
# 36696
# nan_WheelTypeID
# 2_WheelTypeID
# 36698
# nan_WheelTypeID
# 2_WheelTypeID
# 36773
# nan_WheelTypeID
# 2_WheelTypeID
# 36776
# nan_WheelTypeID
# 2_WheelTypeID
# 36785
# nan_WheelTypeID
# 2_WheelTypeID
# 36824
# nan_WheelTypeID
# 1_WheelTypeID
# 36825
# nan_WheelTypeID
# 2_WheelTypeID
# 36854
# nan_WheelTypeID
# 2_WheelTypeID
# 36964
# nan_WheelTypeID
# 2_WheelTypeID
# 36972
# nan_WheelTypeID
# 2_WheelTypeID
# 37022
# nan_WheelTypeID
# 1_WheelTypeID
# 37035
# nan_WheelTypeID
# 1_WheelTypeID
# 37099
# nan_WheelTypeID
# 2_WheelTypeID
# 37101
# nan_WheelTypeID
# 2_WheelTypeID
# 37129
# nan_WheelTypeID
# 2_WheelTypeID
# 37135
# nan_WheelTypeID
# 2_WheelTypeID
# 37235
# nan_WheelTypeID
# 1_WheelTypeID
# 37303
# nan_WheelTypeID
# 1_WheelTypeID
# 37342
# nan_WheelTypeID
# 2_WheelTypeID
# 37380
# nan_WheelTypeID
# 2_WheelTypeID
# 37515
# nan_WheelTypeID
# 2_WheelTypeID
# 37520
# nan_WheelTypeID
# 2_WheelTypeID
# 37596
# nan_WheelTypeID
# 2_WheelTypeID
# 37597
# nan_WheelTypeID
# 2_WheelTypeID
# 37607
# nan_WheelTypeID
# 1_WheelTypeID
# 37649
# nan_WheelTypeID
# 2_WheelTypeID
# 37679
# nan_WheelTypeID
# 2_WheelTypeID
# 37712
# nan_WheelTypeID
# 2_WheelTypeID
# 37714
# nan_WheelTypeID
# 1_WheelTypeID
# 37747
# nan_WheelTypeID
# 2_WheelTypeID
# 37749
# nan_WheelTypeID
# 2_WheelTypeID
# 37797
# nan_WheelTypeID
# 1_WheelTypeID
# 37812
# nan_WheelTypeID
# 2_WheelTypeID
# 37824
# nan_WheelTypeID
# 2_WheelTypeID
# 37901
# nan_WheelTypeID
# 1_WheelTypeID
# 37957
# nan_WheelTypeID
# 2_WheelTypeID
# 38015
# nan_WheelTypeID
# 2_WheelTypeID
# 38039
# nan_WheelTypeID
# 2_WheelTypeID
# 38044
# nan_WheelTypeID
# 1_WheelTypeID
# 38064
# nan_WheelTypeID
# 1_WheelTypeID
# 38123
# nan_WheelTypeID
# 1_WheelTypeID
# 38170
# nan_WheelTypeID
# 2_WheelTypeID
# 38183
# nan_WheelTypeID
# 1_WheelTypeID
# 38232
# nan_WheelTypeID
# 2_WheelTypeID
# 38236
# nan_WheelTypeID
# 2_WheelTypeID
# 38266
# nan_WheelTypeID
# 2_WheelTypeID
# 38324
# nan_WheelTypeID
# 2_WheelTypeID
# 38401
# nan_WheelTypeID
# 1_WheelTypeID
# 38420
# nan_WheelTypeID
# 2_WheelTypeID
# 38426
# nan_WheelTypeID
# 2_WheelTypeID
# 38487
# nan_WheelTypeID
# 2_WheelTypeID
# 38502
# nan_WheelTypeID
# 2_WheelTypeID
# 38549
# nan_WheelTypeID
# 2_WheelTypeID
# 38596
# nan_WheelTypeID
# 2_WheelTypeID
# 38598
# nan_WheelTypeID
# 2_WheelTypeID
# 38646
# nan_WheelTypeID
# 2_WheelTypeID
# 38663
# nan_WheelTypeID
# 2_WheelTypeID
# 38704
# nan_WheelTypeID
# 2_WheelTypeID
# 38729
# nan_WheelTypeID
# 2_WheelTypeID
# 38760
# nan_WheelTypeID
# 2_WheelTypeID
# 38765
# nan_WheelTypeID
# 1_WheelTypeID
# 38804
# nan_WheelTypeID
# 2_WheelTypeID
# 38814
# nan_WheelTypeID
# 2_WheelTypeID
# 38819
# nan_WheelTypeID
# 2_WheelTypeID
# 38895
# nan_WheelTypeID
# 2_WheelTypeID
# 38914
# nan_WheelTypeID
# 2_WheelTypeID
# 38957
# nan_WheelTypeID
# 2_WheelTypeID
# 38974
# nan_WheelTypeID
# 1_WheelTypeID
# 38984
# nan_WheelTypeID
# 2_WheelTypeID
# 39011
# nan_WheelTypeID
# 2_WheelTypeID
# 39021
# nan_WheelTypeID
# 1_WheelTypeID
# 39079
# nan_WheelTypeID
# 2_WheelTypeID
# 39107
# nan_WheelTypeID
# 1_WheelTypeID
# 39173
# nan_WheelTypeID
# 1_WheelTypeID
# 39230
# nan_WheelTypeID
# 2_WheelTypeID
# 39266
# nan_WheelTypeID
# 1_WheelTypeID
# 39344
# nan_WheelTypeID
# 2_WheelTypeID
# 39351
# nan_WheelTypeID
# 2_WheelTypeID
# 39361
# nan_WheelTypeID
# 1_WheelTypeID
# 39363
# nan_WheelTypeID
# 2_WheelTypeID
# 39373
# nan_WheelTypeID
# 1_WheelTypeID
# 39454
# nan_WheelTypeID
# 2_WheelTypeID
# 39527
# nan_WheelTypeID
# 2_WheelTypeID
# 39543
# nan_WheelTypeID
# 2_WheelTypeID
# 39581
# nan_WheelTypeID
# 1_WheelTypeID
# 39596
# nan_WheelTypeID
# 1_WheelTypeID
# 39650
# nan_WheelTypeID
# 2_WheelTypeID
# 39804
# nan_WheelTypeID
# 2_WheelTypeID
# 39827
# nan_WheelTypeID
# 2_WheelTypeID
# 39940
# nan_WheelTypeID
# 2_WheelTypeID
# 39961
# nan_WheelTypeID
# 2_WheelTypeID
# 39972
# nan_WheelTypeID
# 2_WheelTypeID
# 40026
# nan_WheelTypeID
# 1_WheelTypeID
# 40077
# nan_WheelTypeID
# 2_WheelTypeID
# 40121
# nan_WheelTypeID
# 2_WheelTypeID
# 40127
# nan_WheelTypeID
# 1_WheelTypeID
# 40135
# nan_WheelTypeID
# 2_WheelTypeID
# 40228
# nan_WheelTypeID
# 2_WheelTypeID
# 40306
# nan_WheelTypeID
# 2_WheelTypeID
# 40360
# nan_WheelTypeID
# 2_WheelTypeID
# 40382
# nan_WheelTypeID
# 1_WheelTypeID
# 40461
# nan_WheelTypeID
# 1_WheelTypeID
# 40474
# nan_WheelTypeID
# 2_WheelTypeID
# 40482
# nan_WheelTypeID
# 2_WheelTypeID
# 40506
# nan_WheelTypeID
# 2_WheelTypeID
# 40545
# nan_WheelTypeID
# 2_WheelTypeID
# 40601
# nan_WheelTypeID
# 2_WheelTypeID
# 40612
# nan_WheelTypeID
# 2_WheelTypeID
# 40613
# nan_WheelTypeID
# 2_WheelTypeID
# 40714
# nan_WheelTypeID
# 2_WheelTypeID
# 40747
# nan_WheelTypeID
# 2_WheelTypeID
# 40771
# nan_WheelTypeID
# 1_WheelTypeID
# 40821
# nan_WheelTypeID
# 2_WheelTypeID
# 40824
# nan_WheelTypeID
# 2_WheelTypeID
# 40851
# nan_WheelTypeID
# 2_WheelTypeID
# 40896
# nan_WheelTypeID
# 2_WheelTypeID
# 40906
# nan_WheelTypeID
# 2_WheelTypeID
# 40910
# nan_WheelTypeID
# 2_WheelTypeID
# 40975
# nan_WheelTypeID
# 2_WheelTypeID
# 40980
# nan_WheelTypeID
# 2_WheelTypeID
# 40984
# nan_WheelTypeID
# 2_WheelTypeID
# 40994
# nan_WheelTypeID
# 1_WheelTypeID
# 41057
# nan_WheelTypeID
# 2_WheelTypeID
# 41126
# nan_WheelTypeID
# 1_WheelTypeID
# 41239
# nan_WheelTypeID
# 1_WheelTypeID
# 41309
# nan_WheelTypeID
# 2_WheelTypeID
# 41353
# nan_WheelTypeID
# 2_WheelTypeID
# 41410
# nan_WheelTypeID
# 2_WheelTypeID
# 41629
# nan_WheelTypeID
# 2_WheelTypeID
# 41642
# nan_WheelTypeID
# 2_WheelTypeID
# 41685
# nan_WheelTypeID
# 2_WheelTypeID
# 41692
# nan_WheelTypeID
# 2_WheelTypeID
# 41723
# nan_WheelTypeID
# 2_WheelTypeID
# 41766
# nan_WheelTypeID
# 2_WheelTypeID
# 41782
# nan_WheelTypeID
# 1_WheelTypeID
# 41814
# nan_WheelTypeID
# 2_WheelTypeID
# 41844
# nan_WheelTypeID
# 1_WheelTypeID
# 41870
# nan_WheelTypeID
# 2_WheelTypeID
# 41949
# nan_WheelTypeID
# 2_WheelTypeID
# 41990
# nan_WheelTypeID
# 2_WheelTypeID
# 42039
# nan_WheelTypeID
# 1_WheelTypeID
# 42093
# nan_WheelTypeID
# 1_WheelTypeID
# 42108
# nan_WheelTypeID
# 2_WheelTypeID
# 42134
# nan_WheelTypeID
# 2_WheelTypeID
# 42231
# nan_WheelTypeID
# 2_WheelTypeID
# 42274
# nan_WheelTypeID
# 1_WheelTypeID
# 42290
# nan_WheelTypeID
# 1_WheelTypeID
# 42344
# nan_WheelTypeID
# 2_WheelTypeID
# 42355
# nan_WheelTypeID
# 2_WheelTypeID
# 42440
# nan_WheelTypeID
# 1_WheelTypeID
# 42443
# nan_WheelTypeID
# 2_WheelTypeID
# 42473
# nan_WheelTypeID
# 1_WheelTypeID
# 42484
# nan_WheelTypeID
# 2_WheelTypeID
# 42514
# nan_WheelTypeID
# 1_WheelTypeID
# 42532
# nan_WheelTypeID
# 2_WheelTypeID
# 42577
# nan_WheelTypeID
# 2_WheelTypeID
# 42728
# nan_WheelTypeID
# 2_WheelTypeID
# 42740
# nan_WheelTypeID
# 2_WheelTypeID
# 42787
# nan_WheelTypeID
# 2_WheelTypeID
# 42826
# nan_WheelTypeID
# 1_WheelTypeID
# 42837
# nan_WheelTypeID
# 2_WheelTypeID
# 42912
# nan_WheelTypeID
# 2_WheelTypeID
# 42936
# nan_WheelTypeID
# 2_WheelTypeID
# 42944
# nan_WheelTypeID
# 2_WheelTypeID
# 42967
# nan_WheelTypeID
# 2_WheelTypeID
# 43032
# nan_WheelTypeID
# 2_WheelTypeID
# 43083
# nan_WheelTypeID
# 2_WheelTypeID
# 43141
# nan_WheelTypeID
# 2_WheelTypeID
# 43160
# nan_WheelTypeID
# 2_WheelTypeID
# 43216
# nan_WheelTypeID
# 1_WheelTypeID
# 43270
# nan_WheelTypeID
# 2_WheelTypeID
# 43286
# nan_WheelTypeID
# 2_WheelTypeID
# 43293
# nan_WheelTypeID
# 1_WheelTypeID
# 43355
# nan_WheelTypeID
# 2_WheelTypeID
# 43396
# nan_WheelTypeID
# 2_WheelTypeID
# 43408
# nan_WheelTypeID
# 2_WheelTypeID
# 43546
# nan_WheelTypeID
# 2_WheelTypeID
# 43552
# nan_WheelTypeID
# 2_WheelTypeID
# 43622
# nan_WheelTypeID
# 2_WheelTypeID
# 43645
# nan_WheelTypeID
# 2_WheelTypeID
# 43791
# nan_WheelTypeID
# 2_WheelTypeID
# 43815
# nan_WheelTypeID
# 2_WheelTypeID
# 43845
# nan_WheelTypeID
# 2_WheelTypeID
# 43860
# nan_WheelTypeID
# 1_WheelTypeID
# 43874
# nan_WheelTypeID
# 2_WheelTypeID
# 43879
# nan_WheelTypeID
# 2_WheelTypeID
# 43960
# nan_WheelTypeID
# 2_WheelTypeID
# 43977
# nan_WheelTypeID
# 2_WheelTypeID
# 44106
# nan_WheelTypeID
# 1_WheelTypeID
# 44128
# nan_WheelTypeID
# 2_WheelTypeID
# 44232
# nan_WheelTypeID
# 2_WheelTypeID
# 44241
# nan_WheelTypeID
# 2_WheelTypeID
# 44250
# nan_WheelTypeID
# 2_WheelTypeID
# 44330
# nan_WheelTypeID
# 2_WheelTypeID
# 44332
# nan_WheelTypeID
# 1_WheelTypeID
# 44438
# nan_WheelTypeID
# 1_WheelTypeID
# 44479
# nan_WheelTypeID
# 1_WheelTypeID
# 44506
# nan_WheelTypeID
# 2_WheelTypeID
# 44544
# nan_WheelTypeID
# 2_WheelTypeID
# 44644
# nan_WheelTypeID
# 2_WheelTypeID
# 44648
# nan_WheelTypeID
# 2_WheelTypeID
# 44660
# nan_WheelTypeID
# 2_WheelTypeID
# 44664
# nan_WheelTypeID
# 1_WheelTypeID
# 44735
# nan_WheelTypeID
# 2_WheelTypeID
# 44756
# nan_WheelTypeID
# 2_WheelTypeID
# 44765
# nan_WheelTypeID
# 2_WheelTypeID
# 44768
# nan_WheelTypeID
# 1_WheelTypeID
# 44844
# nan_WheelTypeID
# 2_WheelTypeID
# 44867
# nan_WheelTypeID
# 1_WheelTypeID
# 44886
# nan_WheelTypeID
# 2_WheelTypeID
# 45039
# nan_WheelTypeID
# 2_WheelTypeID
# 45145
# nan_WheelTypeID
# 2_WheelTypeID
# 45161
# nan_WheelTypeID
# 2_WheelTypeID
# 45176
# nan_WheelTypeID
# 1_WheelTypeID
# 45221
# nan_WheelTypeID
# 2_WheelTypeID
# 45233
# nan_WheelTypeID
# 2_WheelTypeID
# 45249
# nan_WheelTypeID
# 2_WheelTypeID
# 45270
# nan_WheelTypeID
# 1_WheelTypeID
# 45377
# nan_WheelTypeID
# 2_WheelTypeID
# 45454
# nan_WheelTypeID
# 2_WheelTypeID
# 45460
# nan_WheelTypeID
# 2_WheelTypeID
# 45546
# nan_WheelTypeID
# 2_WheelTypeID
# 45558
# nan_WheelTypeID
# 2_WheelTypeID
# 45625
# nan_WheelTypeID
# 2_WheelTypeID
# 45647
# nan_WheelTypeID
# 2_WheelTypeID
# 45683
# nan_WheelTypeID
# 2_WheelTypeID
# 45719
# nan_WheelTypeID
# 2_WheelTypeID
# 45770
# nan_WheelTypeID
# 1_WheelTypeID
# 45821
# nan_WheelTypeID
# 2_WheelTypeID
# 45830
# nan_WheelTypeID
# 1_WheelTypeID
# 45874
# nan_WheelTypeID
# 1_WheelTypeID
# 45881
# nan_WheelTypeID
# 2_WheelTypeID
# 45969
# nan_WheelTypeID
# 2_WheelTypeID
# 46073
# nan_WheelTypeID
# 1_WheelTypeID
# 46077
# nan_WheelTypeID
# 2_WheelTypeID
# 46084
# nan_WheelTypeID
# 2_WheelTypeID
# 46114
# nan_WheelTypeID
# 2_WheelTypeID
# 46135
# nan_WheelTypeID
# 2_WheelTypeID
# 46170
# nan_WheelTypeID
# 2_WheelTypeID
# 46205
# nan_WheelTypeID
# 2_WheelTypeID
# 46230
# nan_WheelTypeID
# 2_WheelTypeID
# 46288
# nan_WheelTypeID
# 2_WheelTypeID
# 46388
# nan_WheelTypeID
# 2_WheelTypeID
# 46434
# nan_WheelTypeID
# 2_WheelTypeID
# 46484
# nan_WheelTypeID
# 2_WheelTypeID
# 46493
# nan_WheelTypeID
# 2_WheelTypeID
# 46586
# nan_WheelTypeID
# 2_WheelTypeID
# 46596
# nan_WheelTypeID
# 2_WheelTypeID
# 46697
# nan_WheelTypeID
# 1_WheelTypeID
# 46713
# nan_WheelTypeID
# 1_WheelTypeID
# 46748
# nan_WheelTypeID
# 1_WheelTypeID
# 46803
# nan_WheelTypeID
# 2_WheelTypeID
# 46825
# nan_WheelTypeID
# 2_WheelTypeID
# 46864
# nan_WheelTypeID
# 1_WheelTypeID
# 46888
# nan_WheelTypeID
# 1_WheelTypeID
# 46912
# nan_WheelTypeID
# 2_WheelTypeID
# 47004
# nan_WheelTypeID
# 2_WheelTypeID
# 47018
# nan_WheelTypeID
# 2_WheelTypeID
# 47068
# nan_WheelTypeID
# 2_WheelTypeID
# 47091
# nan_WheelTypeID
# 1_WheelTypeID
# 47202
# nan_WheelTypeID
# 2_WheelTypeID
# 47257
# nan_WheelTypeID
# 1_WheelTypeID
# 47364
# nan_WheelTypeID
# 2_WheelTypeID
# 47399
# nan_WheelTypeID
# 2_WheelTypeID
# 47402
# nan_WheelTypeID
# 1_WheelTypeID
# 47415
# nan_WheelTypeID
# 2_WheelTypeID
# 47442
# nan_WheelTypeID
# 2_WheelTypeID
# 47494
# nan_WheelTypeID
# 1_WheelTypeID
# 47516
# nan_WheelTypeID
# 2_WheelTypeID
# 47598
# nan_WheelTypeID
# 2_WheelTypeID
# 47638
# nan_WheelTypeID
# 2_WheelTypeID
# 47642
# nan_WheelTypeID
# 2_WheelTypeID
# 47650
# nan_WheelTypeID
# 1_WheelTypeID
# 47693
# nan_WheelTypeID
# 1_WheelTypeID
# 47701
# nan_WheelTypeID
# 2_WheelTypeID
# 47705
# nan_WheelTypeID
# 1_WheelTypeID
# 47708
# nan_WheelTypeID
# 2_WheelTypeID
# 47768
# nan_WheelTypeID
# 1_WheelTypeID
# 47778
# nan_WheelTypeID
# 1_WheelTypeID
# 47801
# nan_WheelTypeID
# 1_WheelTypeID
# 47831
# nan_WheelTypeID
# 2_WheelTypeID
# 47893
# nan_WheelTypeID
# 2_WheelTypeID
# 47905
# nan_WheelTypeID
# 1_WheelTypeID
# 47997
# nan_WheelTypeID
# 2_WheelTypeID
# 48019
# nan_WheelTypeID
# 2_WheelTypeID
# 48034
# nan_WheelTypeID
# 2_WheelTypeID
# 48059
# nan_WheelTypeID
# 2_WheelTypeID
# 48073
# nan_WheelTypeID
# 2_WheelTypeID
# 48125
# nan_WheelTypeID
# 2_WheelTypeID
# 48187
# nan_WheelTypeID
# 1_WheelTypeID
# 48206
# nan_WheelTypeID
# 2_WheelTypeID
# 48224
# nan_WheelTypeID
# 2_WheelTypeID
# 48310
# nan_WheelTypeID
# 2_WheelTypeID
# 48316
# nan_WheelTypeID
# 2_WheelTypeID
# 48328
# nan_WheelTypeID
# 2_WheelTypeID
# 48370
# nan_WheelTypeID
# 1_WheelTypeID
# 48384
# nan_WheelTypeID
# 1_WheelTypeID
# 48441
# nan_WheelTypeID
# 2_WheelTypeID
# 48442
# nan_WheelTypeID
# 1_WheelTypeID
# 48454
# nan_WheelTypeID
# 1_WheelTypeID
# 48615
# nan_WheelTypeID
# 1_WheelTypeID
# 48623
# nan_WheelTypeID
# 2_WheelTypeID
# 48653
# nan_WheelTypeID
# 1_WheelTypeID
# 48762
# nan_WheelTypeID
# 2_WheelTypeID
# 48766
# nan_WheelTypeID
# 2_WheelTypeID
# 48779
# nan_WheelTypeID
# 1_WheelTypeID
# 48792
# nan_WheelTypeID
# 2_WheelTypeID
# 48851
# nan_WheelTypeID
# 1_WheelTypeID
# 48873
# nan_WheelTypeID
# 2_WheelTypeID
# 48950
# nan_WheelTypeID
# 2_WheelTypeID
# 48967
# nan_WheelTypeID
# 1_WheelTypeID
# 48995
# nan_WheelTypeID
# 1_WheelTypeID
# 49016
# nan_WheelTypeID
# 2_WheelTypeID
# 49019
# nan_WheelTypeID
# 1_WheelTypeID
# 49145
# nan_WheelTypeID
# 2_WheelTypeID
# 49171
# nan_WheelTypeID
# 1_WheelTypeID
# 49201
# nan_WheelTypeID
# 2_WheelTypeID
# 49237
# nan_WheelTypeID
# 2_WheelTypeID
# 49284
# nan_WheelTypeID
# 2_WheelTypeID
# 49316
# nan_WheelTypeID
# 2_WheelTypeID
# 49344
# nan_WheelTypeID
# 2_WheelTypeID
# 49381
# nan_WheelTypeID
# 1_WheelTypeID
# 49441
# nan_WheelTypeID
# 1_WheelTypeID
# 49493
# nan_WheelTypeID
# 2_WheelTypeID
# 49502
# nan_WheelTypeID
# 2_WheelTypeID
# 49542
# nan_WheelTypeID
# 2_WheelTypeID
# 49546
# nan_WheelTypeID
# 2_WheelTypeID
# 49556
# nan_WheelTypeID
# 2_WheelTypeID
# 49836
# nan_WheelTypeID
# 2_WheelTypeID
# 49846
# nan_WheelTypeID
# 2_WheelTypeID
# 49865
# nan_WheelTypeID
# 1_WheelTypeID
# 49872
# nan_WheelTypeID
# 2_WheelTypeID
# 49985
# nan_WheelTypeID
# 2_WheelTypeID
# 50049
# nan_WheelTypeID
# 2_WheelTypeID
# 50076
# nan_WheelTypeID
# 2_WheelTypeID
# 50081
# nan_WheelTypeID
# 2_WheelTypeID
# 50095
# nan_WheelTypeID
# 2_WheelTypeID
# 50181
# nan_WheelTypeID
# 1_WheelTypeID
# 50195
# nan_WheelTypeID
# 1_WheelTypeID
# 50209
# nan_WheelTypeID
# 2_WheelTypeID
# 50218
# nan_WheelTypeID
# 2_WheelTypeID
# 50255
# nan_WheelTypeID
# 2_WheelTypeID
# 50282
# nan_WheelTypeID
# 2_WheelTypeID
# 50291
# nan_WheelTypeID
# 1_WheelTypeID
# 50305
# nan_WheelTypeID
# 2_WheelTypeID
# 50327
# nan_WheelTypeID
# 1_WheelTypeID
# 50363
# nan_WheelTypeID
# 2_WheelTypeID
# 50423
# nan_WheelTypeID
# 2_WheelTypeID
# 50465
# nan_WheelTypeID
# 2_WheelTypeID
# 50517
# nan_WheelTypeID
# 1_WheelTypeID
# 50530
# nan_WheelTypeID
# 2_WheelTypeID
# 50538
# nan_WheelTypeID
# 2_WheelTypeID
# 50556
# nan_WheelTypeID
# 2_WheelTypeID
# 50584
# nan_WheelTypeID
# 2_WheelTypeID
# 50643
# nan_WheelTypeID
# 2_WheelTypeID
# 50695
# nan_WheelTypeID
# 2_WheelTypeID
# 50711
# nan_WheelTypeID
# 2_WheelTypeID
# 50854
# nan_WheelTypeID
# 1_WheelTypeID
# 50871
# nan_WheelTypeID
# 2_WheelTypeID
# 50895
# nan_WheelTypeID
# 1_WheelTypeID
# 50911
# nan_WheelTypeID
# 2_WheelTypeID
# 50920
# nan_WheelTypeID
# 1_WheelTypeID
# 50971
# nan_WheelTypeID
# 2_WheelTypeID
# 51082
# nan_WheelTypeID
# 2_WheelTypeID
# 51146
# nan_WheelTypeID
# 1_WheelTypeID
# 51155
# nan_WheelTypeID
# 2_WheelTypeID
# 51267
# nan_WheelTypeID
# 1_WheelTypeID
# 51310
# nan_WheelTypeID
# 1_WheelTypeID
# 51318
# nan_WheelTypeID
# 2_WheelTypeID
# 51321
# nan_WheelTypeID
# 1_WheelTypeID
# 51322
# nan_WheelTypeID
# 2_WheelTypeID
# 51325
# nan_WheelTypeID
# 2_WheelTypeID
# 51327
# nan_WheelTypeID
# 2_WheelTypeID
# 51367
# nan_WheelTypeID
# 2_WheelTypeID
# 51398
# nan_WheelTypeID
# 2_WheelTypeID
# 51442
# nan_WheelTypeID
# 2_WheelTypeID
# 51444
# nan_WheelTypeID
# 2_WheelTypeID
# 51456
# nan_WheelTypeID
# 1_WheelTypeID
# 51457
# nan_WheelTypeID
# 2_WheelTypeID
# 51465
# nan_WheelTypeID
# 1_WheelTypeID
# 51492
# nan_WheelTypeID
# 2_WheelTypeID
# 51494
# nan_WheelTypeID
# 2_WheelTypeID
# 51534
# nan_WheelTypeID
# 2_WheelTypeID
# 51541
# nan_WheelTypeID
# 2_WheelTypeID
# 51575
# nan_WheelTypeID
# 2_WheelTypeID
# 51587
# nan_WheelTypeID
# 2_WheelTypeID
# 51594
# nan_WheelTypeID
# 2_WheelTypeID
# 51605
# nan_WheelTypeID
# 2_WheelTypeID
# 51607
# nan_WheelTypeID
# 2_WheelTypeID
# 51639
# nan_WheelTypeID
# 2_WheelTypeID
# 51645
# nan_WheelTypeID
# 1_WheelTypeID
# 51670
# nan_WheelTypeID
# 2_WheelTypeID
# 51687
# nan_WheelTypeID
# 2_WheelTypeID
# 51707
# nan_WheelTypeID
# 2_WheelTypeID
# 51713
# nan_WheelTypeID
# 2_WheelTypeID
# 51789
# nan_WheelTypeID
# 2_WheelTypeID
# 51818
# nan_WheelTypeID
# 1_WheelTypeID
# 51826
# nan_WheelTypeID
# 2_WheelTypeID
# 51837
# nan_WheelTypeID
# 1_WheelTypeID
# 51839
# nan_WheelTypeID
# 1_WheelTypeID
# 51861
# nan_WheelTypeID
# 2_WheelTypeID
# 51872
# nan_WheelTypeID
# 2_WheelTypeID
# 51973
# nan_WheelTypeID
# 1_WheelTypeID
# 52038
# nan_WheelTypeID
# 2_WheelTypeID
# 52041
# nan_WheelTypeID
# 2_WheelTypeID
# 52094
# nan_WheelTypeID
# 2_WheelTypeID
# 52108
# nan_WheelTypeID
# 2_WheelTypeID
# 52156
# nan_WheelTypeID
# 2_WheelTypeID
# 52165
# nan_WheelTypeID
# 2_WheelTypeID
# 52181
# nan_WheelTypeID
# 1_WheelTypeID
# 52208
# nan_WheelTypeID
# 2_WheelTypeID
# 52221
# nan_WheelTypeID
# 2_WheelTypeID
# 52238
# nan_WheelTypeID
# 2_WheelTypeID
# 52269
# nan_WheelTypeID
# 2_WheelTypeID
# 52302
# nan_WheelTypeID
# 2_WheelTypeID
# 52329
# nan_WheelTypeID
# 2_WheelTypeID
# 52343
# nan_WheelTypeID
# 2_WheelTypeID
# 52351
# nan_WheelTypeID
# 2_WheelTypeID
# 52363
# nan_WheelTypeID
# 2_WheelTypeID
# 52398
# nan_WheelTypeID
# 2_WheelTypeID
# 52417
# nan_WheelTypeID
# 2_WheelTypeID
# 52431
# nan_WheelTypeID
# 2_WheelTypeID
# 52447
# nan_WheelTypeID
# 2_WheelTypeID
# 52457
# nan_WheelTypeID
# 1_WheelTypeID
# 52479
# nan_WheelTypeID
# 2_WheelTypeID
# 52487
# nan_WheelTypeID
# 2_WheelTypeID
# 52492
# nan_WheelTypeID
# 2_WheelTypeID
# 52523
# nan_WheelTypeID
# 2_WheelTypeID
# 52535
# nan_WheelTypeID
# 1_WheelTypeID
# 52583
# nan_WheelTypeID
# 1_WheelTypeID
# 52598
# nan_WheelTypeID
# 2_WheelTypeID
# 52616
# nan_WheelTypeID
# 2_WheelTypeID
# 52634
# nan_WheelTypeID
# 1_WheelTypeID
# 52654
# nan_WheelTypeID
# 2_WheelTypeID
# 52659
# nan_WheelTypeID
# 2_WheelTypeID
# 52698
# nan_WheelTypeID
# 2_WheelTypeID
# 52700
# nan_WheelTypeID
# 2_WheelTypeID
# 52729
# nan_WheelTypeID
# 2_WheelTypeID
# 52730
# nan_WheelTypeID
# 2_WheelTypeID
# 52772
# nan_WheelTypeID
# 2_WheelTypeID
# 52810
# nan_WheelTypeID
# 2_WheelTypeID
# 52838
# nan_WheelTypeID
# 2_WheelTypeID
# 52919
# nan_WheelTypeID
# 2_WheelTypeID
# 52968
# nan_WheelTypeID
# 1_WheelTypeID
# 52975
# nan_WheelTypeID
# 2_WheelTypeID
# 52981
# nan_WheelTypeID
# 2_WheelTypeID
# 53031
# nan_WheelTypeID
# 2_WheelTypeID
# 53042
# nan_WheelTypeID
# 2_WheelTypeID
# 53058
# nan_WheelTypeID
# 2_WheelTypeID
# 53124
# nan_WheelTypeID
# 2_WheelTypeID
# 53145
# nan_WheelTypeID
# 2_WheelTypeID
# 53163
# nan_WheelTypeID
# 2_WheelTypeID
# 53335
# nan_WheelTypeID
# 2_WheelTypeID
# 53341
# nan_WheelTypeID
# 2_WheelTypeID
# 53372
# nan_WheelTypeID
# 2_WheelTypeID
# 53397
# nan_WheelTypeID
# 2_WheelTypeID
# 53403
# nan_WheelTypeID
# 2_WheelTypeID
# 53431
# nan_WheelTypeID
# 2_WheelTypeID
# 53478
# nan_WheelTypeID
# 2_WheelTypeID
# 53551
# nan_WheelTypeID
# 1_WheelTypeID
# 53610
# nan_WheelTypeID
# 1_WheelTypeID
# 53629
# nan_WheelTypeID
# 1_WheelTypeID
# 53642
# nan_WheelTypeID
# 1_WheelTypeID
# 53654
# nan_WheelTypeID
# 2_WheelTypeID
# 53667
# nan_WheelTypeID
# 2_WheelTypeID
# 53690
# nan_WheelTypeID
# 2_WheelTypeID
# 53704
# nan_WheelTypeID
# 1_WheelTypeID
# 53768
# nan_WheelTypeID
# 1_WheelTypeID
# 53795
# nan_WheelTypeID
# 2_WheelTypeID
# 53807
# nan_WheelTypeID
# 2_WheelTypeID
# 53918
# nan_WheelTypeID
# 2_WheelTypeID
# 53932
# nan_WheelTypeID
# 2_WheelTypeID
# 53988
# nan_WheelTypeID
# 1_WheelTypeID
# 53989
# nan_WheelTypeID
# 2_WheelTypeID
# 54044
# nan_WheelTypeID
# 2_WheelTypeID
# 54117
# nan_WheelTypeID
# 1_WheelTypeID
# 54144
# nan_WheelTypeID
# 1_WheelTypeID
# 54155
# nan_WheelTypeID
# 1_WheelTypeID
# 54193
# nan_WheelTypeID
# 1_WheelTypeID
# 54235
# nan_WheelTypeID
# 2_WheelTypeID
# 54263
# nan_WheelTypeID
# 2_WheelTypeID
# 54341
# nan_WheelTypeID
# 1_WheelTypeID
# 54355
# nan_WheelTypeID
# 1_WheelTypeID
# 54383
# nan_WheelTypeID
# 1_WheelTypeID
# 54390
# nan_WheelTypeID
# 2_WheelTypeID
# 54394
# nan_WheelTypeID
# 2_WheelTypeID
# 54421
# nan_WheelTypeID
# 2_WheelTypeID
# 54532
# nan_WheelTypeID
# 2_WheelTypeID
# 54618
# nan_WheelTypeID
# 2_WheelTypeID
# 54674
# nan_WheelTypeID
# 2_WheelTypeID
# 54703
# nan_WheelTypeID
# 1_WheelTypeID
# 54764
# nan_WheelTypeID
# 2_WheelTypeID
# 54771
# nan_WheelTypeID
# 2_WheelTypeID
# 54857
# nan_WheelTypeID
# 2_WheelTypeID
# 54860
# nan_WheelTypeID
# 2_WheelTypeID
# 54897
# nan_WheelTypeID
# 1_WheelTypeID
# 54941
# nan_WheelTypeID
# 2_WheelTypeID
# 55003
# nan_WheelTypeID
# 1_WheelTypeID
# 55009
# nan_WheelTypeID
# 2_WheelTypeID
# 55033
# nan_WheelTypeID
# 1_WheelTypeID
# 55090
# nan_WheelTypeID
# 2_WheelTypeID
# 55139
# nan_WheelTypeID
# 2_WheelTypeID
# 55185
# nan_WheelTypeID
# 2_WheelTypeID
# 55273
# nan_WheelTypeID
# 2_WheelTypeID
# 55318
# nan_WheelTypeID
# 1_WheelTypeID
# 55341
# nan_WheelTypeID
# 2_WheelTypeID
# 55384
# nan_WheelTypeID
# 2_WheelTypeID
# 55489
# nan_WheelTypeID
# 2_WheelTypeID
# 55497
# nan_WheelTypeID
# 2_WheelTypeID
# 55544
# nan_WheelTypeID
# 2_WheelTypeID
# 55554
# nan_WheelTypeID
# 2_WheelTypeID
# 55558
# nan_WheelTypeID
# 2_WheelTypeID
# 55583
# nan_WheelTypeID
# 2_WheelTypeID
# 55624
# nan_WheelTypeID
# 1_WheelTypeID
# 55647
# nan_WheelTypeID
# 2_WheelTypeID
# 55700
# nan_WheelTypeID
# 2_WheelTypeID
# 55738
# nan_WheelTypeID
# 2_WheelTypeID
# 55751
# nan_WheelTypeID
# 1_WheelTypeID
# 55777
# nan_WheelTypeID
# 2_WheelTypeID
# 55791
# nan_WheelTypeID
# 2_WheelTypeID
# 55815
# nan_WheelTypeID
# 2_WheelTypeID
# 55855
# nan_WheelTypeID
# 2_WheelTypeID
# 55889
# nan_WheelTypeID
# 2_WheelTypeID
# 55979
# nan_WheelTypeID
# 1_WheelTypeID
# 55984
# nan_WheelTypeID
# 2_WheelTypeID
# 56018
# nan_WheelTypeID
# 1_WheelTypeID
# 56031
# nan_WheelTypeID
# 2_WheelTypeID
# 56077
# nan_WheelTypeID
# 1_WheelTypeID
# 56114
# nan_WheelTypeID
# 2_WheelTypeID
# 56115
# nan_WheelTypeID
# 2_WheelTypeID
# 56155
# nan_WheelTypeID
# 2_WheelTypeID
# 56244
# nan_WheelTypeID
# 1_WheelTypeID
# 56371
# nan_WheelTypeID
# 1_WheelTypeID
# 56375
# nan_WheelTypeID
# 2_WheelTypeID
# 56508
# nan_WheelTypeID
# 1_WheelTypeID
# 56571
# nan_WheelTypeID
# 1_WheelTypeID
# 56611
# nan_WheelTypeID
# 1_WheelTypeID
# 56623
# nan_WheelTypeID
# 1_WheelTypeID
# 56646
# nan_WheelTypeID
# 2_WheelTypeID
# 56665
# nan_WheelTypeID
# 2_WheelTypeID
# 56686
# nan_WheelTypeID
# 2_WheelTypeID
# 56691
# nan_WheelTypeID
# 1_WheelTypeID
# 56700
# nan_WheelTypeID
# 2_WheelTypeID
# 56706
# nan_WheelTypeID
# 2_WheelTypeID
# 56753
# nan_WheelTypeID
# 2_WheelTypeID
# 56783
# nan_WheelTypeID
# 2_WheelTypeID
# 56802
# nan_WheelTypeID
# 1_WheelTypeID
# 56805
# nan_WheelTypeID
# 2_WheelTypeID
# 56835
# nan_WheelTypeID
# 1_WheelTypeID
# 56838
# nan_WheelTypeID
# 2_WheelTypeID
# 57021
# nan_WheelTypeID
# 1_WheelTypeID
# 57088
# nan_WheelTypeID
# 2_WheelTypeID
# 57097
# nan_WheelTypeID
# 2_WheelTypeID
# 57101
# nan_WheelTypeID
# 2_WheelTypeID
# 57118
# nan_WheelTypeID
# 2_WheelTypeID
# 57166
# nan_WheelTypeID
# 1_WheelTypeID
# 57195
# nan_WheelTypeID
# 2_WheelTypeID
# 57228
# nan_WheelTypeID
# 2_WheelTypeID
# 57246
# nan_WheelTypeID
# 2_WheelTypeID
# 57377
# nan_WheelTypeID
# 2_WheelTypeID
# 57397
# nan_WheelTypeID
# 1_WheelTypeID
# 57409
# nan_WheelTypeID
# 1_WheelTypeID
# 57433
# nan_WheelTypeID
# 2_WheelTypeID
# 57552
# nan_WheelTypeID
# 2_WheelTypeID
# 57567
# nan_WheelTypeID
# 2_WheelTypeID
# 57569
# nan_WheelTypeID
# 2_WheelTypeID
# 57596
# nan_WheelTypeID
# 1_WheelTypeID
# 57729
# nan_WheelTypeID
# 2_WheelTypeID
# 57755
# nan_WheelTypeID
# 2_WheelTypeID
# 57785
# nan_WheelTypeID
# 1_WheelTypeID
# 57786
# nan_WheelTypeID
# 2_WheelTypeID
# 57790
# nan_WheelTypeID
# 2_WheelTypeID
# 57869
# nan_WheelTypeID
# 2_WheelTypeID
# 57871
# nan_WheelTypeID
# 2_WheelTypeID
# 57997
# nan_WheelTypeID
# 2_WheelTypeID
# 58024
# nan_WheelTypeID
# 2_WheelTypeID
# 58062
# nan_WheelTypeID
# 1_WheelTypeID
# 58108
# nan_WheelTypeID
# 2_WheelTypeID
# 58110
# nan_WheelTypeID
# 2_WheelTypeID
# 58153
# nan_WheelTypeID
# 2_WheelTypeID
# 58156
# nan_WheelTypeID
# 2_WheelTypeID
# 58162
# nan_WheelTypeID
# 2_WheelTypeID
# 58174
# nan_WheelTypeID
# 2_WheelTypeID
# 58190
# nan_WheelTypeID
# 1_WheelTypeID
# 58257
# nan_WheelTypeID
# 2_WheelTypeID
# RefId                                   0
# IsBadBuy                                0
# PurchDate                               0
# Auction                                 0
# VehYear                                 0
# VehicleAge                              0
# Make                                    0
# Model                                   0
# Trim                                    0
# Transmission                            0
# WheelTypeID                             0
# Nationality                             0
# Size                                    0
# VehBCostBin                             0
# VehOdoBin                               0
# MMRAcquisitionAuctionAveragePriceBin    0
# WarrantyCostBin                         0
# dtype: int64

# %%
l1=len(indexMV)
l2=len(df1[df1['WheelTypeID']=='nan_Trim'].index)
print("Number of missing values solved", l1-l2)
# Out:
# Number of missing values solved 1911

# %% [markdown]
# #### Evaluating accuracy

# %% [markdown]
# ### Class label

# %%
# read of the test file preprocessed by the Data Understanding and Transformation 
df2 = pd.read_csv('Data/df2.csv',sep=';') 
df2
# Out:
#        RefId  IsBadBuy   PurchDate  Auction  VehicleAge       Make  \
# 0      42116         0   1/27/2010    OTHER           4       FORD
# 1       5554         0    9/3/2009  MANHEIM           5      DODGE
# 2      25195         0   1/21/2010    OTHER           6    HYUNDAI
# 3      51232         0   3/18/2009  MANHEIM           5  CHEVROLET
# 4      26309         1  12/22/2010    OTHER           6       FORD
# 5      44763         0   1/18/2010    OTHER           2  CHEVROLET
# 6      60191         0   7/10/2009    ADESA           7   CHRYSLER
# 7      56467         0   6/15/2010    OTHER           4      DODGE
# 8      65666         0   3/19/2009  MANHEIM           7      BUICK
# 9      24089         0   4/15/2009    OTHER           3      DODGE
# 10     55160         0    8/3/2010  MANHEIM           5        KIA
# 11     25225         1   2/25/2010    OTHER           4    HYUNDAI
# 12     57368         1    3/2/2010    OTHER           4  CHEVROLET
# 13     42852         0   3/25/2009  MANHEIM           4       FORD
# 14      9057         0   2/16/2009  MANHEIM           6     TOYOTA
# 15     63995         0  10/21/2009    ADESA           3       FORD
# 16     65490         0   7/15/2009  MANHEIM           4      DODGE
# 17     17892         0    4/2/2010    OTHER           4  CHEVROLET
# 18     65176         0   1/28/2010  MANHEIM           4  CHEVROLET
# 19     19617         0   6/19/2009    OTHER           4      DODGE
# 20      6524         0   5/18/2010  MANHEIM           2    PONTIAC
# 21     24043         0   3/25/2009    OTHER           7       JEEP
# 22     38252         0    8/6/2010  MANHEIM           5      DODGE
# 23     48695         0   5/28/2010  MANHEIM           7       FORD
# 24     47692         0   10/5/2010  MANHEIM           3       FORD
# 25     58917         0   1/29/2009  MANHEIM           6       FORD
# 26     25859         0   7/21/2010    OTHER           3      DODGE
# 27     66296         1   9/24/2009    ADESA           4  CHEVROLET
# 28     35755         0   8/20/2009  MANHEIM           4      DODGE
# 29     35728         0   8/13/2009  MANHEIM           6   CHRYSLER
# ...      ...       ...         ...      ...         ...        ...
# 12524  52472         0   8/25/2010    OTHER           5  CHEVROLET
# 12525   3011         0   1/20/2009    OTHER           7        GMC
# 12526  58265         0   2/24/2009    ADESA           3  CHEVROLET
# 12527  65037         0   8/13/2009  MANHEIM           3   CHRYSLER
# 12528   6108         0    7/9/2009  MANHEIM           5       FORD
# 12529  58442         1    3/3/2010  MANHEIM           5     NISSAN
# 12530  14990         0   3/18/2009  MANHEIM           3  CHEVROLET
# 12531  47181         0   9/15/2009  MANHEIM           6      DODGE
# 12532  20078         0   3/15/2010    OTHER           3        KIA
# 12533  28908         0   4/21/2010  MANHEIM           3   CHRYSLER
# 12534  23209         0    8/5/2010  MANHEIM           6  CHEVROLET
# 12535  22514         0   7/16/2009  MANHEIM           3      DODGE
# 12536  52002         0  11/17/2010  MANHEIM           3   CHRYSLER
# 12537  41088         0  12/17/2009  MANHEIM           4      DODGE
# 12538   9810         0   12/8/2009  MANHEIM           3      DODGE
# 12539  61749         0   9/18/2009    ADESA           6      DODGE
# 12540  53483         0    9/2/2009    OTHER           1   CHRYSLER
# 12541  24642         0   2/17/2010  MANHEIM           3      DODGE
# 12542  63949         0   8/26/2009    ADESA           4       FORD
# 12543   8594         0   5/27/2010  MANHEIM           4        KIA
# 12544   5878         0   7/20/2010  MANHEIM           3      DODGE
# 12545  68079         0  12/16/2010    ADESA           6      DODGE
# 12546  32146         0   8/13/2010    OTHER           6       FORD
# 12547  68584         0   8/26/2010    ADESA           4    PONTIAC
# 12548  25153         0   3/26/2009    OTHER           6       FORD
# 12549  18997         1    9/1/2009  MANHEIM           5       FORD
# 12550  21452         0   8/20/2010    OTHER           4  CHEVROLET
# 12551  63741         0    7/1/2009    ADESA           5        KIA
# 12552  71353         0   6/11/2009    ADESA           4        KIA
# 12553  22531         0  11/12/2009  MANHEIM           3        KIA
#
#                       Model Trim                SubModel   Color  ...  \
# 0                MUSTANG V6  Bas                2D COUPE   BLACK  ...
# 1                STRATUS V6   ES                4D SEDAN   WHITE  ...
# 2                   TIBURON  Bas                2D COUPE    BLUE  ...
# 3      TRAILBLAZER 2WD 6C 4  Nor          4D SUV 4.2L LT   GREEN  ...
# 4           EXPLORER 2WD V6  XLS     4D SUV 4.0L FFV XLS   WHITE  ...
# 5                 IMPALA V6   LS    4D SEDAN LS 3.5L FFV    BLUE  ...
# 6      PT CRUISER 2.4L I4 M  Lim        4D SEDAN LIMITED  MAROON  ...
# 7            DURANGO 2WD V6  SXT             4D SUV 3.7L  SILVER  ...
# 8      CENTURY V6 3.1L V6 S  Cus         4D SEDAN CUSTOM  SILVER  ...
# 9      MAGNUM V6 2.7L V6 MP   SE              WAGON 2.7L   WHITE  ...
# 10                SPECTRA 5   SX             4D SEDAN EX   BLACK  ...
# 11                SONATA V6  GLS            4D SEDAN GLS    BLUE  ...
# 12                      HHR   LT          4D SUV 2.2L LT   BEIGE  ...
# 13       TAURUS 3.0L V6 EFI   SE             4D SEDAN SE     RED  ...
# 14     CAMRY 4C 2.4L I-4 EF   LE             4D SEDAN LE   WHITE  ...
# 15     FREESTAR FWD V6 3.9L   SE       PASSENGER 3.9L LX    GOLD  ...
# 16      DURANGO 4WD V8 4.7L  SLT             4D SUV 4.7L   WHITE  ...
# 17       TRAILBLAZER 2WD 6C   LS             4D SUV 4.2L    BLUE  ...
# 18                   COBALT   LS             4D SEDAN LS    BLUE  ...
# 19     STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV    GREY  ...
# 20                    G6 4C  Bas             4D SEDAN SE    BLUE  ...
# 21     GRAND CHEROKEE 2WD 6  Lar         4D WAGON LAREDO    GREY  ...
# 22               STRATUS V6  SXT        4D SEDAN SXT FFV  SILVER  ...
# 23                    FOCUS   LX             4D SEDAN LX  SILVER  ...
# 24             FIVE HUNDRED  SEL            4D SEDAN SEL    BLUE  ...
# 25        FOCUS 2.0L I4 SFI   SE             4D SEDAN SE    GREY  ...
# 26                  CALIBER  Bas             4D WAGON SE  MAROON  ...
# 27       COBALT 2.2L I4 MPI  Bas                4D SEDAN   WHITE  ...
# 28      CARAVAN FWD V6 3.3L   SE         MINIVAN 3.3L SE    BLUE  ...
# 29     PT CRUISER 2.4L I4 M  Bas                4D SEDAN    BLUE  ...
# ...                     ...  ...                     ...     ...  ...
# 12524    TRAILBLAZER 2WD 6C   LS             4D SUV 4.2L    BLUE  ...
# 12525  ENVOY 4WD 6C 4.2L I6  SLE     4D UTILITY 4.2L SLE    GOLD  ...
# 12526   TRAILBLAZER EXT 2WD   LS          4D SUV 4.2L LS    GOLD  ...
# 12527  TOWN & COUNTRY 2WD V  Bas            MINIVAN 3.3L  MAROON  ...
# 12528  ESCAPE 2WD V6 3.0L V  XLT         4D CUV 3.0L XLT   WHITE  ...
# 12529                MAXIMA   SE             4D SEDAN SE  SILVER  ...
# 12530  MALIBU V6 3.5L V6 SF   LS             4D SEDAN LS    GREY  ...
# 12531  STRATUS 4C 2.4L I4 M   SE             4D SEDAN SE  PURPLE  ...
# 12532             OPTIMA 4C   EX                4D SEDAN  SILVER  ...
# 12533            SEBRING 4C  Bas                4D SEDAN   WHITE  ...
# 12534             MALIBU V6   LS             4D SEDAN LS  SILVER  ...
# 12535  STRATUS V6 2.7L V6 M  SXT        4D SEDAN SXT FFV   WHITE  ...
# 12536                   300  Bas                4D SEDAN    GREY  ...
# 12537        DURANGO 2WD V8  SLT         4D SUV 5.7L SLT  SILVER  ...
# 12538             MAGNUM V6   SE              WAGON 2.7L   WHITE  ...
# 12539   DURANGO 2WD V8 4.7L  SLT         4D SUV 4.7L SLT   BLACK  ...
# 12540  SEBRING 4C 2.4L I4 E   LX             4D SEDAN LX   BLACK  ...
# 12541               CALIBER  Bas                4D WAGON  SILVER  ...
# 12542  FREESTYLE FWD V6 3.0   SE          4D CUV 3.0L SE   WHITE  ...
# 12543               SPECTRA   EX             4D SEDAN EX    BLUE  ...
# 12544            CHARGER V6  Bas           4D SEDAN 3.5L    GREY  ...
# 12545            STRATUS V6   ES             4D SEDAN ES    GOLD  ...
# 12546                TAURUS   SE             4D SEDAN SE   BEIGE  ...
# 12547                 G6 4C  Bas             4D SEDAN SE    GOLD  ...
# 12548  EXPLORER 4WD V6 4.0L  XLS  4D SUV 4.0L SPORT TRAC    BLUE  ...
# 12549  MUSTANG V6 3.9L V6 E  Bas          2D CONVERTIBLE   WHITE  ...
# 12550             MALIBU 4C   LT             4D SEDAN LT   GREEN  ...
# 12551  OPTIMA V6 2.7L V6 MP   EX             4D SEDAN EX    GOLD  ...
# 12552    AMANTI 3.5L V6 MPI   LS                4D SEDAN   BLACK  ...
# 12553           SORENTO 2WD   EX     4D SPORT UTILITY EX   BLACK  ...
#
#       MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 0                              102710                            127170
# 1                               39660                             35800
# 2                               52980                             78470
# 3                               75240                             75660
# 4                               60170                             85830
# 5                               92750                            114590
# 6                               42860                             40880
# 7                              110140                            141260
# 8                               45410                             44180
# 9                               87400                             86000
# 10                              52710                             70560
# 11                              82910                            103350
# 12                              80690                            111250
# 13                              49380                             48430
# 14                              68690                             72880
# 15                              73140                             71380
# 16                             111100                            103450
# 17                             117880                            137670
# 18                              53460                             83000
# 19                              65840                             65150
# 20                              97900                            120630
# 21                              56820                             56610
# 22                              69600                             88350
# 23                              36870                             54590
# 24                              96870                            118820
# 25                              36100                             35740
# 26                              76360                            106340
# 27                              61920                             57790
# 28                              61110                             61690
# 29                              37280                             36430
# ...                               ...                               ...
# 12524                           84580                            104800
# 12525                           60160                             56900
# 12526                          112420                            109120
# 12527                           80090                             80480
# 12528                           67610                             65460
# 12529                          108200                            137750
# 12530                           77160                             77230
# 12531                           29860                             26730
# 12532                           76240                            105180
# 12533                           92620                            114190
# 12534                           57460                             74980
# 12535                           64130                             64100
# 12536                          115330                            147060
# 12537                           91160                            115000
# 12538                           87940                            107340
# 12539                           54160                             48650
# 12540                           90690                             96820
# 12541                           81930                            109450
# 12542                           90650                             87710
# 12543                           63100                             84230
# 12544                          124640                            147500
# 12545                           38400                             61740
# 12546                           41410                             64880
# 12547                           75780                             94290
# 12548                           98250                             97660
# 12549                           84530                             78520
# 12550                           83520                            104020
# 12551                           34930                             35390
# 12552                           89250                             85320
# 12553                           94050                             90350
#
#        MMRAcquisitonRetailCleanPrice MMRCurrentAuctionAveragePrice  \
# 0                             145980                         92260
# 1                              47830                         28040
# 2                              87260                         46020
# 3                              86260                         61650
# 4                              98660                         39800
# 5                             133600                         84510
# 6                              51290                         32030
# 7                             150090                         90560
# 8                              54040                         69500
# 9                              99390                         75000
# 10                             83790                         37580
# 11                            118070                         69100
# 12                            131110                         68790
# 13                             58330                         38970
# 14                             79190                         62430
# 15                             83990                         62110
# 16                            124990                         90940
# 17                            157630                        101520
# 18                             92220                         48360
# 19                             76110                         55690
# 20                            136300                         84110
# 21                             66370                         38810
# 22                            100860                         57540
# 23                             67400                         24730
# 24                            138190                         71720
# 25                             43990                         33910
# 26                            116280                         58290
# 27                             71870                         48880
# 28                             71000                         38050
# 29                             45260                         31040
# ...                              ...                           ...
# 12524                         125390                         62020
# 12525                          69970                         50860
# 12526                         126410                         98560
# 12527                          91500                         72110
# 12528                          78020                         43820
# 12529                         152530                         93350
# 12530                          88330                         61920
# 12531                          37250                         17020
# 12532                         107830                         63950
# 12533                         126360                         75670
# 12534                          86850                         37010
# 12535                          74260                         57530
# 12536                         160570                        100950
# 12537                         132500                         66830
# 12538                         125250                         71950
# 12539                          63490                         43770
# 12540                         102950                         81370
# 12541                         120600                         76390
# 12542                         102900                         63120
# 12543                          97390                         44830
# 12544                         167090                        100430
# 12545                          69590                         23070
# 12546                          77910                         31420
# 12547                         106930                         55470
# 12548                         111110                         71290
# 12549                          96290                         65710
# 12550                         116370                         57760
# 12551                          42720                         28140
# 12552                         101390                         74370
# 12553                         106570                         76520
#
#       MMRCurrentAuctionCleanPrice MMRCurrentRetailAveragePrice  \
# 0                          106190                       129400
# 1                           40200                        35280
# 2                           62540                        76540
# 3                           72950                        71580
# 4                           52070                        77190
# 5                           96000                       123120
# 6                           41800                        39590
# 7                          109870                       138630
# 8                           81920                        80060
# 9                           87400                        86000
# 10                          49940                        67060
# 11                          82910                       103350
# 12                          80690                       111250
# 13                          49030                        47090
# 14                          74860                        72420
# 15                          87910                       101000
# 16                         109210                       103220
# 17                         118540                       143490
# 18                          58600                        85490
# 19                          65840                        65150
# 20                          94710                       125460
# 21                          48380                        46910
# 22                          69340                        91230
# 23                          32910                        57050
# 24                          89430                       112320
# 25                          42680                        41620
# 26                          68200                        97150
# 27                          61920                        57790
# 28                          50380                        72950
# 29                          38310                        38520
# ...                           ...                          ...
# 12524                       74830                       100880
# 12525                       64190                        59930
# 12526                      116880                       111440
# 12527                       81380                        82880
# 12528                       54980                        52330
# 12529                      110620                       139540
# 12530                       71270                        71870
# 12531                       24020                        23380
# 12532                       71230                        96140
# 12533                       86960                       114870
# 12534                       47430                        70310
# 12535                       64920                        67130
# 12536                      118700                       138130
# 12537                       78570                       111790
# 12538                       87520                       114360
# 12539                       55090                        79710
# 12540                       87330                        92880
# 12541                       88750                       110660
# 12542                       77130                       100670
# 12543                       53510                        75350
# 12544                      116700                       138640
# 12545                       34240                        48820
# 12546                       42600                        68700
# 12547                       68860                        90000
# 12548                       82390                        81990
# 12549                       75500                        75970
# 12550                       70730                        91830
# 12551                       34930                        35390
# 12552                       89250                        85320
# 12553                       93100                       121480
#
#        MMRCurrentRetailCleanPrice  VehBCost  WarrantyCost  State|ZIPC
# 0                          141600     77000           803    NC|27407
# 1                           48420     57000          1389    AZ|85040
# 2                           92860     51550           920    CO|80229
# 3                           83790     67850          1155    CO|80011
# 4                           88200     57000          1155    SC|29697
# 5                          138330     80000          2152    TX|76063
# 6                           50140     49700          1803    TN|37771
# 7                          150850     97500          1272    SC|29070
# 8                           93470     49100          2003    FL|33411
# 9                           99390     85000          1215    SC|29697
# 10                          85510     71700           594    OR|97217
# 11                         118070     70250           728    CO|80229
# 12                         131110     69000           803    IN|46239
# 13                          57950     40000           983    FL|32124
# 14                          85850     76000           894    NC|27542
# 15                         130320     66550          1506    AZ|85226
# 16                         122950     95000          1623    UT|84087
# 17                         160680     75250          1155    UT|84104
# 18                          96500     43950           728    TX|77061
# 19                          76110     53000           975    CA|95673
# 20                         136690     89400           837    AZ|85040
# 21                          57250     59000          2040    SC|29697
# 22                         101840     55550          1215    NV|89165
# 23                          62500     54400          1641    PA|17545
# 24                         142860     79850          1506    TX|75050
# 25                          51090     40550          1134    CA|92337
# 26                         107340     57000           920    SC|29697
# 27                          71870     49200           803    NC|28273
# 28                          86600     60000          1623    VA|22403
# 29                          46370     45000          1689    VA|22403
# ...                           ...       ...           ...         ...
# 12524                      112470     81200          1243    TN|38118
# 12525                       74330     72650          2003    TX|75061
# 12526                      131230     92250          1243    TX|78754
# 12527                       92890     49950          1918    TX|77061
# 12528                       64380     72600           920    GA|30272
# 12529                      154640     99900          1155    CA|92057
# 12530                       81970     55200          1272    CA|94544
# 12531                       30940     37100          1641    TX|75050
# 12532                      107080     77050           728    CA|95673
# 12533                      125850     71850          1243    CO|80011
# 12534                       82410     66600          1373    SC|29532
# 12535                       75110     56000           975    TX|76040
# 12536                      157360     86850          1389    CO|80011
# 12537                      121610     88100          1389    SC|29532
# 12538                      130420     74550          1215    MD|21075
# 12539                       87840     56500          1803    CA|91752
# 12540                       99320     77000           920    OK|74135
# 12541                      122470     74500           693    FL|32124
# 12542                      114360     84950          1313    AZ|85226
# 12543                       89240     61950           505    GA|30272
# 12544                      157300     95250          1389    AZ|85040
# 12545                       62650     31150          1503    NC|28273
# 12546                       93140     61000           754    SC|29461
# 12547                      110510     53650          1197    CO|80817
# 12548                       93980     87250          1808    CO|80229
# 12549                       86540     76300           803    CO|80022
# 12550                      105570     64000          1038    CA|95673
# 12551                       42720     53500           853    AZ|85226
# 12552                      101390     72450          1003    NC|28273
# 12553                      142040     68250          1508    TX|76040
#
# [12554 rows x 27 columns]

# %%
# drop of the not useful columns 
df2 = df2.drop(['SubModel','Color','PurchDate','RefId','MMRCurrentAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice', 'MMRCurrentAuctionCleanPrice', 'MMRAcquisitionRetailAveragePrice', 'MMRCurrentRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice', 'MMRCurrentRetailCleanPrice','State|ZIPC', 'TopThreeAmericanName'], axis=1)
df2['Transmission'] = df2['Transmission'].str.upper()
df2['Transmission']=df2['Transmission'].fillna(df2['Transmission'].mode()[0])
df2=df2[df2['Nationality'].notnull()]
df2=df2[df2['Size'].notnull()]
df2=df2[df2['MMRAcquisitionAuctionAveragePrice'].notnull()]
df2=df2[df2['WheelTypeID']!=0]
df2
# Out:
#        IsBadBuy  Auction  VehicleAge       Make                 Model Trim  \
# 0             0    OTHER           4       FORD            MUSTANG V6  Bas
# 1             0  MANHEIM           5      DODGE            STRATUS V6   ES
# 2             0    OTHER           6    HYUNDAI               TIBURON  Bas
# 3             0  MANHEIM           5  CHEVROLET  TRAILBLAZER 2WD 6C 4  Nor
# 4             1    OTHER           6       FORD       EXPLORER 2WD V6  XLS
# 5             0    OTHER           2  CHEVROLET             IMPALA V6   LS
# 6             0    ADESA           7   CHRYSLER  PT CRUISER 2.4L I4 M  Lim
# 7             0    OTHER           4      DODGE        DURANGO 2WD V6  SXT
# 8             0  MANHEIM           7      BUICK  CENTURY V6 3.1L V6 S  Cus
# 9             0    OTHER           3      DODGE  MAGNUM V6 2.7L V6 MP   SE
# 10            0  MANHEIM           5        KIA             SPECTRA 5   SX
# 11            1    OTHER           4    HYUNDAI             SONATA V6  GLS
# 12            1    OTHER           4  CHEVROLET                   HHR   LT
# 13            0  MANHEIM           4       FORD    TAURUS 3.0L V6 EFI   SE
# 14            0  MANHEIM           6     TOYOTA  CAMRY 4C 2.4L I-4 EF   LE
# 15            0    ADESA           3       FORD  FREESTAR FWD V6 3.9L   SE
# 16            0  MANHEIM           4      DODGE   DURANGO 4WD V8 4.7L  SLT
# 17            0    OTHER           4  CHEVROLET    TRAILBLAZER 2WD 6C   LS
# 18            0  MANHEIM           4  CHEVROLET                COBALT   LS
# 19            0    OTHER           4      DODGE  STRATUS V6 2.7L V6 M  SXT
# 20            0  MANHEIM           2    PONTIAC                 G6 4C  Bas
# 21            0    OTHER           7       JEEP  GRAND CHEROKEE 2WD 6  Lar
# 22            0  MANHEIM           5      DODGE            STRATUS V6  SXT
# 23            0  MANHEIM           7       FORD                 FOCUS   LX
# 24            0  MANHEIM           3       FORD          FIVE HUNDRED  SEL
# 25            0  MANHEIM           6       FORD     FOCUS 2.0L I4 SFI   SE
# 26            0    OTHER           3      DODGE               CALIBER  Bas
# 27            1    ADESA           4  CHEVROLET    COBALT 2.2L I4 MPI  Bas
# 28            0  MANHEIM           4      DODGE   CARAVAN FWD V6 3.3L   SE
# 29            0  MANHEIM           6   CHRYSLER  PT CRUISER 2.4L I4 M  Bas
# ...         ...      ...         ...        ...                   ...  ...
# 12524         0    OTHER           5  CHEVROLET    TRAILBLAZER 2WD 6C   LS
# 12525         0    OTHER           7        GMC  ENVOY 4WD 6C 4.2L I6  SLE
# 12526         0    ADESA           3  CHEVROLET   TRAILBLAZER EXT 2WD   LS
# 12527         0  MANHEIM           3   CHRYSLER  TOWN & COUNTRY 2WD V  Bas
# 12528         0  MANHEIM           5       FORD  ESCAPE 2WD V6 3.0L V  XLT
# 12529         1  MANHEIM           5     NISSAN                MAXIMA   SE
# 12530         0  MANHEIM           3  CHEVROLET  MALIBU V6 3.5L V6 SF   LS
# 12531         0  MANHEIM           6      DODGE  STRATUS 4C 2.4L I4 M   SE
# 12532         0    OTHER           3        KIA             OPTIMA 4C   EX
# 12533         0  MANHEIM           3   CHRYSLER            SEBRING 4C  Bas
# 12534         0  MANHEIM           6  CHEVROLET             MALIBU V6   LS
# 12535         0  MANHEIM           3      DODGE  STRATUS V6 2.7L V6 M  SXT
# 12536         0  MANHEIM           3   CHRYSLER                   300  Bas
# 12537         0  MANHEIM           4      DODGE        DURANGO 2WD V8  SLT
# 12538         0  MANHEIM           3      DODGE             MAGNUM V6   SE
# 12539         0    ADESA           6      DODGE   DURANGO 2WD V8 4.7L  SLT
# 12540         0    OTHER           1   CHRYSLER  SEBRING 4C 2.4L I4 E   LX
# 12541         0  MANHEIM           3      DODGE               CALIBER  Bas
# 12542         0    ADESA           4       FORD  FREESTYLE FWD V6 3.0   SE
# 12543         0  MANHEIM           4        KIA               SPECTRA   EX
# 12544         0  MANHEIM           3      DODGE            CHARGER V6  Bas
# 12545         0    ADESA           6      DODGE            STRATUS V6   ES
# 12546         0    OTHER           6       FORD                TAURUS   SE
# 12547         0    ADESA           4    PONTIAC                 G6 4C  Bas
# 12548         0    OTHER           6       FORD  EXPLORER 4WD V6 4.0L  XLS
# 12549         1  MANHEIM           5       FORD  MUSTANG V6 3.9L V6 E  Bas
# 12550         0    OTHER           4  CHEVROLET             MALIBU 4C   LT
# 12551         0    ADESA           5        KIA  OPTIMA V6 2.7L V6 MP   EX
# 12552         0    ADESA           4        KIA    AMANTI 3.5L V6 MPI   LS
# 12553         0  MANHEIM           3        KIA           SORENTO 2WD   EX
#
#       Transmission  WheelTypeID  VehOdo     Nationality        Size  \
# 0           MANUAL            1   73815        AMERICAN      SPORTS
# 1             AUTO            1   74213        AMERICAN      MEDIUM
# 2           MANUAL            1   77980     OTHER ASIAN      SPORTS
# 3             AUTO            1   77819        AMERICAN  MEDIUM SUV
# 4             AUTO            1   79600        AMERICAN  MEDIUM SUV
# 5             AUTO            2   86797        AMERICAN       LARGE
# 6             AUTO            1   84893        AMERICAN      MEDIUM
# 7             AUTO            1   75652        AMERICAN  MEDIUM SUV
# 8             AUTO            2   65179        AMERICAN      MEDIUM
# 9             AUTO            2   66004        AMERICAN   SPECIALTY
# 10            AUTO            1   83874     OTHER ASIAN      MEDIUM
# 11            AUTO            1   64569     OTHER ASIAN      MEDIUM
# 12            AUTO            2   71412        AMERICAN      MEDIUM
# 13            AUTO            2   85788        AMERICAN      MEDIUM
# 14            AUTO            2   82622  TOP LINE ASIAN      MEDIUM
# 15            AUTO            1   71005        AMERICAN         VAN
# 16            AUTO            1   73107        AMERICAN  MEDIUM SUV
# 17            AUTO            1   74523        AMERICAN  MEDIUM SUV
# 18            AUTO            2   66384        AMERICAN     COMPACT
# 19            AUTO            2   45310        AMERICAN      MEDIUM
# 20            AUTO            2   59881        AMERICAN      MEDIUM
# 21            AUTO            1   71537        AMERICAN  MEDIUM SUV
# 22            AUTO            2   62443        AMERICAN      MEDIUM
# 23            AUTO            2   91276        AMERICAN     COMPACT
# 24            AUTO            1   72601        AMERICAN       LARGE
# 25            AUTO            3   44085        AMERICAN     COMPACT
# 26            AUTO            2   75427        AMERICAN      MEDIUM
# 27            AUTO            1   76086        AMERICAN     COMPACT
# 28            AUTO            2   77457        AMERICAN         VAN
# 29            AUTO            2   76378        AMERICAN      MEDIUM
# ...            ...          ...     ...             ...         ...
# 12524         AUTO            1   82297        AMERICAN  MEDIUM SUV
# 12525         AUTO            1   63163        AMERICAN  MEDIUM SUV
# 12526         AUTO            1   81176        AMERICAN  MEDIUM SUV
# 12527         AUTO            2   99938        AMERICAN         VAN
# 12528         AUTO            1   71339        AMERICAN   SMALL SUV
# 12529         AUTO            1   78044  TOP LINE ASIAN       LARGE
# 12530         AUTO            1   76647        AMERICAN      MEDIUM
# 12531         AUTO            2   93037        AMERICAN      MEDIUM
# 12532         AUTO            1   60015     OTHER ASIAN      MEDIUM
# 12533         AUTO            2   80300        AMERICAN      MEDIUM
# 12534         AUTO            1   87577        AMERICAN      MEDIUM
# 12535         AUTO            2   41323        AMERICAN      MEDIUM
# 12536         AUTO            2   71977        AMERICAN   SPECIALTY
# 12537         AUTO            1   72072        AMERICAN  MEDIUM SUV
# 12538         AUTO            2   65724        AMERICAN   SPECIALTY
# 12539         AUTO            1   80468        AMERICAN  MEDIUM SUV
# 12540         AUTO            1   51532        AMERICAN      MEDIUM
# 12541         AUTO            2   45627        AMERICAN      MEDIUM
# 12542         AUTO            1   63801        AMERICAN   CROSSOVER
# 12543         AUTO            1   59512     OTHER ASIAN      MEDIUM
# 12544         AUTO            2   70857        AMERICAN   SPECIALTY
# 12545         AUTO            1   80350        AMERICAN      MEDIUM
# 12546         AUTO            2   50114        AMERICAN      MEDIUM
# 12547         AUTO            1   95958        AMERICAN      MEDIUM
# 12548         AUTO            1   68529        AMERICAN  MEDIUM SUV
# 12549         AUTO            3   78065        AMERICAN      SPORTS
# 12550         AUTO            2   72807        AMERICAN      MEDIUM
# 12551         AUTO            1   80293     OTHER ASIAN      MEDIUM
# 12552         AUTO            1   54865     OTHER ASIAN       LARGE
# 12553         AUTO            1   68235     OTHER ASIAN  MEDIUM SUV
#
#        MMRAcquisitionAuctionAveragePrice  VehBCost  WarrantyCost
# 0                                  88400     77000           803
# 1                                  28520     57000          1389
# 2                                  40540     51550           920
# 3                                  65430     67850          1155
# 4                                  48030     57000          1155
# 5                                  79730     80000          2152
# 6                                  33220     49700          1803
# 7                                  95740     97500          1272
# 8                                  36280     49100          2003
# 9                                  75000     85000          1215
# 10                                 40970     71700           594
# 11                                 69100     70250           728
# 12                                 68790     69000           803
# 13                                 40210     40000           983
# 14                                 62850     76000           894
# 15                                 61460     66550          1506
# 16                                 91160     95000          1623
# 17                                100220     75250          1155
# 18                                 43680     43950           728
# 19                                 55690     53000           975
# 20                                 86650     89400           837
# 21                                 47790     59000          2040
# 22                                 55900     55550          1215
# 23                                 26790     54400          1641
# 24                                 76290     79850          1506
# 25                                 28460     40550          1134
# 26                                 65910     57000           920
# 27                                 48880     49200           803
# 28                                 52490     60000          1623
# 29                                 29100     45000          1689
# ...                                  ...       ...           ...
# 12524                              66740     81200          1243
# 12525                              48060     72650          2003
# 12526                              96410     92250          1243
# 12527                              69890     49950          1918
# 12528                              55980     72600           920
# 12529                              91300     99900          1155
# 12530                              66880     55200          1272
# 12531                              20120     37100          1641
# 12532                              73220     77050           728
# 12533                              80340     71850          1243
# 12534                              45730     66600          1373
# 12535                              54720     56000           975
# 12536                              99570     86850          1389
# 12537                              75690     88100          1389
# 12538                              72400     74550          1215
# 12539                              40420     56500          1803
# 12540                              85020     77000           920
# 12541                              70800     74500           693
# 12542                              76580     84950          1313
# 12543                              51570     61950           505
# 12544                             107260     95250          1389
# 12545                              26280     31150          1503
# 12546                              29510     61000           754
# 12547                              61200     53650          1197
# 12548                              85800     87250          1808
# 12549                              68070     76300           803
# 12550                              71740     64000          1038
# 12551                              28140     53500           853
# 12552                              74370     72450          1003
# 12553                              79030     68250          1508
#
# [12554 rows x 14 columns]

# %%
# discretization of the numerical attributes 
# equal frequency binning i.e. in each bin there are N / k elements 
k = 6 # from sturgers' rule
p=indexMV=df2[df2['Trim'].isnull()].index
bin_size = df2.shape[0]/k
# creation of new columns for the numerical values discretized in bins 
df2['VehBCostBin'] = pd.cut(df2['VehBCost'].astype(int), bin_size, right=False)
df2['VehOdoBin'] = pd.cut(df2['VehOdo'].astype(int), bin_size, right=False)
df2['MMRAcquisitionAuctionAveragePriceBin'] = pd.cut(df2['MMRAcquisitionAuctionAveragePrice'].astype(int), bin_size, right=False)
df2['WarrantyCostBin'] = pd.cut(df2['WarrantyCost'].astype(int), bin_size, right=False)
# drop of the columns no longer needed 
df2.drop(['VehOdo', 'MMRAcquisitionAuctionAveragePrice','WarrantyCost', 'VehBCost'], axis=1, inplace=True)

# %%
# transformation of the variable in string, concatenating an fixed identificator 
df2['IsBadBuy'] = df2['IsBadBuy'].astype(str) + '_IsBadBuy'
df2['VehicleAge'] = df2['VehicleAge'].astype(str) + '_VehicleAge'
df2['WheelTypeID'] = df2['WheelTypeID'].astype(str) + '_WheelTypeID'
df2['VehBCostBin'] = df2['VehBCostBin'].astype(str) + '_VehBCostBin'
df2['Trim'] = df2['Trim'].astype(str) + '_Trim'
df2['VehOdoBin'] = df2['VehOdoBin'].astype(str) + '_VehOdoBin'
df2['MMRAcquisitionAuctionAveragePriceBin'] = df2['MMRAcquisitionAuctionAveragePriceBin'].astype(str) + '_MMRAcquisitionAuctionAveragePriceBin'
df2['WarrantyCostBin'] = df2['WarrantyCostBin'].astype(str) + '_WarrantyCostBin'
df2.index= range(len(df2.index))

# %%
#Making a subset of the training set 
dfTrainingZero=dfTraining[dfTraining['IsBadBuy']=='0_IsBadBuy']
dfTrainingUno=dfTraining[dfTraining['IsBadBuy']=='1_IsBadBuy']
c=dfTrainingUno['IsBadBuy'].value_counts()
dfTrainingE=dfTrainingUno.append(dfTrainingZero.sample(c["1_IsBadBuy"]))
dfTrainingE.index= range(len(dfTrainingE.index))

# %%
baskets = dfTrainingE.values
rules = apriori(baskets, supp=5, zmin=5, target='r', conf=0.8, 
                report='acl')

# %%
#Rules for 'IsBadBuy' usefull for classification
count = 0
rulesClass=[]
for r in rules:
    if (r[0] == '0_IsBadBuy' or r[0] == '1_IsBadBuy') and r[4] > 1 and r[3] > 0.50:
        count += 1
        print(r[0], '-->', r[1], ' support', r[2], ' conf', r[3], ' lift', r[4])
        rulesClass.append(r)
print('\nNumber of rules found :' ,count)
rulesClass=sorted(rulesClass,key= lambda x:x[3],reverse=True)
# Out:
# 0_IsBadBuy --> ('SXT_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 365  conf 0.5712050078247262  lift 1.1424100156494523
# 0_IsBadBuy --> ('2_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 423  conf 0.6714285714285714  lift 1.3428571428571427
# 0_IsBadBuy --> ('LARGE', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 477  conf 0.6326259946949602  lift 1.2652519893899203
# 0_IsBadBuy --> ('LARGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 375  conf 0.6377551020408163  lift 1.2755102040816326
# 0_IsBadBuy --> ('LARGE', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 387  conf 0.5724852071005917  lift 1.1449704142011834
# 0_IsBadBuy --> ('LARGE', 'MANHEIM', 'AMERICAN', 'AUTO')  support 429  conf 0.6308823529411764  lift 1.261764705882353
# 1_IsBadBuy --> ('MEDIUM SUV', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 319  conf 0.5415959252971138  lift 1.0831918505942275
# 1_IsBadBuy --> ('MEDIUM SUV', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 384  conf 0.5501432664756447  lift 1.1002865329512894
# 1_IsBadBuy --> ('MEDIUM SUV', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 499  conf 0.531416400425985  lift 1.06283280085197
# 1_IsBadBuy --> ('MEDIUM SUV', 'MANHEIM', 'AMERICAN', 'AUTO')  support 362  conf 0.5402985074626866  lift 1.0805970149253732
# 1_IsBadBuy --> ('CHRYSLER', 'Bas_Trim', 'AMERICAN', 'AUTO')  support 370  conf 0.5203938115330521  lift 1.0407876230661042
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 323  conf 0.5102685624012638  lift 1.0205371248025277
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 335  conf 0.5091185410334347  lift 1.0182370820668694
# 0_IsBadBuy --> ('CHRYSLER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 323  conf 0.5102685624012638  lift 1.0205371248025277
# 1_IsBadBuy --> ('CHRYSLER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 573  conf 0.5446768060836502  lift 1.0893536121673004
# 0_IsBadBuy --> ('CHRYSLER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 443  conf 0.5248815165876777  lift 1.0497630331753554
# 1_IsBadBuy --> ('CHRYSLER', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 345  conf 0.5897435897435898  lift 1.1794871794871795
# 1_IsBadBuy --> ('CHRYSLER', 'MANHEIM', 'AMERICAN', 'AUTO')  support 370  conf 0.5034013605442177  lift 1.0068027210884354
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 563  conf 0.683252427184466  lift 1.366504854368932
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AMERICAN')  support 571  conf 0.6749408983451537  lift 1.3498817966903074
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', '2_WheelTypeID', 'AUTO')  support 563  conf 0.683252427184466  lift 1.366504854368932
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 457  conf 0.6454802259887006  lift 1.2909604519774012
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AMERICAN')  support 464  conf 0.6417704011065007  lift 1.2835408022130015
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'MANHEIM', 'AUTO')  support 457  conf 0.6454802259887006  lift 1.2909604519774012
# 0_IsBadBuy --> ('LS_Trim', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 826  conf 0.6038011695906432  lift 1.2076023391812865
# 0_IsBadBuy --> ('LS_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 569  conf 0.6757719714964371  lift 1.3515439429928742
# 1_IsBadBuy --> ('LS_Trim', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 322  conf 0.540268456375839  lift 1.080536912751678
# 0_IsBadBuy --> ('LS_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 474  conf 0.6253298153034301  lift 1.2506596306068603
# 1_IsBadBuy --> ('6_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 358  conf 0.5774193548387097  lift 1.1548387096774193
# 1_IsBadBuy --> ('6_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 502  conf 0.5940828402366863  lift 1.1881656804733727
# 1_IsBadBuy --> ('6_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 416  conf 0.5909090909090909  lift 1.1818181818181819
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 373  conf 0.6074918566775245  lift 1.214983713355049
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AMERICAN')  support 375  conf 0.6077795786061588  lift 1.2155591572123177
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', '2_WheelTypeID', 'AUTO')  support 373  conf 0.6074918566775245  lift 1.214983713355049
# 0_IsBadBuy --> ('SE_Trim', 'DODGE', 'AMERICAN', 'AUTO')  support 441  conf 0.5727272727272728  lift 1.1454545454545455
# 0_IsBadBuy --> ('SE_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 443  conf 0.5236406619385343  lift 1.0472813238770686
# 0_IsBadBuy --> ('SE_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 501  conf 0.5629213483146067  lift 1.1258426966292134
# 1_IsBadBuy --> ('SE_Trim', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 353  conf 0.5603174603174603  lift 1.1206349206349207
# 0_IsBadBuy --> ('SE_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 375  conf 0.526685393258427  lift 1.053370786516854
# 1_IsBadBuy --> ('FORD', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 479  conf 0.5806060606060606  lift 1.1612121212121211
# 1_IsBadBuy --> ('FORD', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 496  conf 0.5801169590643275  lift 1.160233918128655
# 1_IsBadBuy --> ('FORD', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 479  conf 0.5806060606060606  lift 1.1612121212121211
# 1_IsBadBuy --> ('FORD', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 769  conf 0.5641966250917094  lift 1.1283932501834188
# 1_IsBadBuy --> ('FORD', 'MANHEIM', 'AMERICAN', 'AUTO')  support 606  conf 0.5631970260223048  lift 1.1263940520446096
# 0_IsBadBuy --> ('DODGE', 'OTHER', 'AMERICAN', 'AUTO')  support 337  conf 0.5598006644518272  lift 1.1196013289036544
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 380  conf 0.6365159128978225  lift 1.273031825795645
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 380  conf 0.6354515050167224  lift 1.2709030100334449
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 380  conf 0.6365159128978225  lift 1.273031825795645
# 0_IsBadBuy --> ('DODGE', 'MEDIUM', 'AMERICAN', 'AUTO')  support 519  conf 0.5993071593533488  lift 1.1986143187066975
# 0_IsBadBuy --> ('DODGE', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 657  conf 0.5876565295169947  lift 1.1753130590339893
# 0_IsBadBuy --> ('DODGE', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 449  conf 0.5079185520361991  lift 1.0158371040723981
# 0_IsBadBuy --> ('DODGE', 'MANHEIM', 'AMERICAN', 'AUTO')  support 617  conf 0.584280303030303  lift 1.168560606060606
# 0_IsBadBuy --> ('3_VehicleAge', 'CHEVROLET', 'AMERICAN', 'AUTO')  support 428  conf 0.6645962732919255  lift 1.329192546583851
# 0_IsBadBuy --> ('3_VehicleAge', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 392  conf 0.5764705882352941  lift 1.1529411764705881
# 0_IsBadBuy --> ('3_VehicleAge', 'MEDIUM', 'MANHEIM', 'AUTO')  support 350  conf 0.5932203389830508  lift 1.1864406779661016
# 0_IsBadBuy --> ('3_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 485  conf 0.5719339622641509  lift 1.1438679245283019
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 421  conf 0.6682539682539682  lift 1.3365079365079364
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 427  conf 0.6640746500777605  lift 1.328149300155521
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 481  conf 0.65  lift 1.3
# 0_IsBadBuy --> ('3_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 720  conf 0.6349206349206349  lift 1.2698412698412698
# 0_IsBadBuy --> ('3_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 450  conf 0.5769230769230769  lift 1.1538461538461537
# 0_IsBadBuy --> ('3_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 675  conf 0.6471716203259827  lift 1.2943432406519655
# 1_IsBadBuy --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 300  conf 0.5067567567567568  lift 1.0135135135135136
# 0_IsBadBuy --> ('Bas_Trim', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 368  conf 0.5054945054945055  lift 1.010989010989011
# 1_IsBadBuy --> ('Bas_Trim', 'MEDIUM', 'AMERICAN', 'AUTO')  support 412  conf 0.5118012422360249  lift 1.0236024844720497
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 313  conf 0.5173553719008265  lift 1.034710743801653
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 323  conf 0.5135135135135135  lift 1.027027027027027
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 384  conf 0.5224489795918368  lift 1.0448979591836736
# 0_IsBadBuy --> ('Bas_Trim', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 584  conf 0.5095986038394416  lift 1.019197207678883
# 1_IsBadBuy --> ('Bas_Trim', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 370  conf 0.5240793201133145  lift 1.048158640226629
# 0_IsBadBuy --> ('Bas_Trim', 'MANHEIM', 'AMERICAN', 'AUTO')  support 514  conf 0.5186680121089808  lift 1.0373360242179617
# 1_IsBadBuy --> ('5_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 353  conf 0.5815485996705108  lift 1.1630971993410215
# 1_IsBadBuy --> ('5_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 401  conf 0.576978417266187  lift 1.153956834532374
# 1_IsBadBuy --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 394  conf 0.5588652482269504  lift 1.1177304964539008
# 1_IsBadBuy --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 403  conf 0.5573997233748271  lift 1.1147994467496543
# 1_IsBadBuy --> ('5_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 475  conf 0.5654761904761905  lift 1.130952380952381
# 1_IsBadBuy --> ('5_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 686  conf 0.5613747954173486  lift 1.1227495908346972
# 1_IsBadBuy --> ('5_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 581  conf 0.5496688741721855  lift 1.099337748344371
# 0_IsBadBuy --> ('CHEVROLET', 'OTHER', 'AMERICAN', 'AUTO')  support 358  conf 0.5682539682539682  lift 1.1365079365079365
# 0_IsBadBuy --> ('CHEVROLET', '4_VehicleAge', 'AMERICAN', 'AUTO')  support 361  conf 0.5396113602391629  lift 1.0792227204783258
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 438  conf 0.6384839650145773  lift 1.2769679300291545
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 445  conf 0.6321022727272727  lift 1.2642045454545454
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 438  conf 0.6384839650145773  lift 1.2769679300291545
# 0_IsBadBuy --> ('CHEVROLET', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 816  conf 0.6031042128603105  lift 1.206208425720621
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 328  conf 0.543046357615894  lift 1.086092715231788
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 334  conf 0.546644844517185  lift 1.09328968903437
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 328  conf 0.543046357615894  lift 1.086092715231788
# 0_IsBadBuy --> ('CHEVROLET', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 584  conf 0.5195729537366548  lift 1.0391459074733096
# 0_IsBadBuy --> ('CHEVROLET', 'MANHEIM', 'AMERICAN', 'AUTO')  support 780  conf 0.5963302752293578  lift 1.1926605504587156
# 1_IsBadBuy --> ('ADESA', 'MEDIUM', 'AMERICAN', 'AUTO')  support 440  conf 0.5945945945945946  lift 1.1891891891891893
# 1_IsBadBuy --> ('ADESA', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 542  conf 0.5865800865800865  lift 1.173160173160173
# 1_IsBadBuy --> ('ADESA', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 615  conf 0.5476402493321461  lift 1.0952804986642921
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 450  conf 0.615595075239398  lift 1.231190150478796
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AMERICAN')  support 458  conf 0.6172506738544474  lift 1.2345013477088949
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 520  conf 0.6018518518518519  lift 1.2037037037037037
# 0_IsBadBuy --> ('OTHER', 'MEDIUM', 'AMERICAN', 'AUTO')  support 618  conf 0.5440140845070423  lift 1.0880281690140845
# 0_IsBadBuy --> ('OTHER', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 729  conf 0.5668740279937792  lift 1.1337480559875583
# 1_IsBadBuy --> ('OTHER', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 561  conf 0.5404624277456648  lift 1.0809248554913296
# 1_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', '2_WheelTypeID', 'AUTO')  support 314  conf 0.5097402597402597  lift 1.0194805194805194
# 1_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', 'AMERICAN', 'AUTO')  support 429  conf 0.5035211267605634  lift 1.0070422535211268
# 0_IsBadBuy --> ('4_VehicleAge', 'MEDIUM', 'MANHEIM', 'AUTO')  support 312  conf 0.5279187817258884  lift 1.0558375634517767
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 372  conf 0.5627836611195158  lift 1.1255673222390317
# 0_IsBadBuy --> ('4_VehicleAge', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 545  conf 0.5190476190476191  lift 1.0380952380952382
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 375  conf 0.539568345323741  lift 1.079136690647482
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 383  conf 0.5394366197183098  lift 1.0788732394366196
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 438  conf 0.5354523227383863  lift 1.0709046454767726
# 0_IsBadBuy --> ('4_VehicleAge', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 632  conf 0.5271059216013344  lift 1.0542118432026688
# 0_IsBadBuy --> ('4_VehicleAge', 'MANHEIM', 'AMERICAN', 'AUTO')  support 695  conf 0.553343949044586  lift 1.106687898089172
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 550  conf 0.5783385909568874  lift 1.1566771819137749
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 564  conf 0.5737538148524923  lift 1.1475076297049847
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'MANHEIM', 'AUTO')  support 718  conf 0.5698412698412698  lift 1.1396825396825396
# 0_IsBadBuy --> ('MEDIUM', '2_WheelTypeID', 'AMERICAN', 'AUTO')  support 1150  conf 0.555019305019305  lift 1.11003861003861
# 1_IsBadBuy --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 427  conf 0.5089392133492253  lift 1.0178784266984506
# 1_IsBadBuy --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AMERICAN')  support 439  conf 0.5063437139561707  lift 1.0126874279123415
# 1_IsBadBuy --> ('MEDIUM', '1_WheelTypeID', 'MANHEIM', 'AUTO')  support 536  conf 0.5004668534080299  lift 1.0009337068160598
# 1_IsBadBuy --> ('MEDIUM', '1_WheelTypeID', 'AMERICAN', 'AUTO')  support 860  conf 0.5419029615626969  lift 1.0838059231253938
# 0_IsBadBuy --> ('MEDIUM', 'MANHEIM', 'AMERICAN', 'AUTO')  support 973  conf 0.5369757174392936  lift 1.0739514348785872
# 0_IsBadBuy --> ('2_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 1246  conf 0.5787273571760334  lift 1.1574547143520668
# 1_IsBadBuy --> ('1_WheelTypeID', 'MANHEIM', 'AMERICAN', 'AUTO')  support 1417  conf 0.506433166547534  lift 1.012866333095068
#
# Number of rules found : 119

# %%
attributes = [col for col in dfTraining.columns if col != 'IsBadBuy']
X_train = dfTrainingE[attributes].values
y_train = dfTrainingE['IsBadBuy']

# %%
df2["Prediction"]="NotRetrived"
df2.index= range(len(df2.index))
df2
# Out:
#          IsBadBuy  Auction    VehicleAge       Make                 Model  \
# 0      0_IsBadBuy    OTHER  4_VehicleAge       FORD            MUSTANG V6
# 1      0_IsBadBuy  MANHEIM  5_VehicleAge      DODGE            STRATUS V6
# 2      0_IsBadBuy    OTHER  6_VehicleAge    HYUNDAI               TIBURON
# 3      0_IsBadBuy  MANHEIM  5_VehicleAge  CHEVROLET  TRAILBLAZER 2WD 6C 4
# 4      1_IsBadBuy    OTHER  6_VehicleAge       FORD       EXPLORER 2WD V6
# 5      0_IsBadBuy    OTHER  2_VehicleAge  CHEVROLET             IMPALA V6
# 6      0_IsBadBuy    ADESA  7_VehicleAge   CHRYSLER  PT CRUISER 2.4L I4 M
# 7      0_IsBadBuy    OTHER  4_VehicleAge      DODGE        DURANGO 2WD V6
# 8      0_IsBadBuy  MANHEIM  7_VehicleAge      BUICK  CENTURY V6 3.1L V6 S
# 9      0_IsBadBuy    OTHER  3_VehicleAge      DODGE  MAGNUM V6 2.7L V6 MP
# 10     0_IsBadBuy  MANHEIM  5_VehicleAge        KIA             SPECTRA 5
# 11     1_IsBadBuy    OTHER  4_VehicleAge    HYUNDAI             SONATA V6
# 12     1_IsBadBuy    OTHER  4_VehicleAge  CHEVROLET                   HHR
# 13     0_IsBadBuy  MANHEIM  4_VehicleAge       FORD    TAURUS 3.0L V6 EFI
# 14     0_IsBadBuy  MANHEIM  6_VehicleAge     TOYOTA  CAMRY 4C 2.4L I-4 EF
# 15     0_IsBadBuy    ADESA  3_VehicleAge       FORD  FREESTAR FWD V6 3.9L
# 16     0_IsBadBuy  MANHEIM  4_VehicleAge      DODGE   DURANGO 4WD V8 4.7L
# 17     0_IsBadBuy    OTHER  4_VehicleAge  CHEVROLET    TRAILBLAZER 2WD 6C
# 18     0_IsBadBuy  MANHEIM  4_VehicleAge  CHEVROLET                COBALT
# 19     0_IsBadBuy    OTHER  4_VehicleAge      DODGE  STRATUS V6 2.7L V6 M
# 20     0_IsBadBuy  MANHEIM  2_VehicleAge    PONTIAC                 G6 4C
# 21     0_IsBadBuy    OTHER  7_VehicleAge       JEEP  GRAND CHEROKEE 2WD 6
# 22     0_IsBadBuy  MANHEIM  5_VehicleAge      DODGE            STRATUS V6
# 23     0_IsBadBuy  MANHEIM  7_VehicleAge       FORD                 FOCUS
# 24     0_IsBadBuy  MANHEIM  3_VehicleAge       FORD          FIVE HUNDRED
# 25     0_IsBadBuy  MANHEIM  6_VehicleAge       FORD     FOCUS 2.0L I4 SFI
# 26     0_IsBadBuy    OTHER  3_VehicleAge      DODGE               CALIBER
# 27     1_IsBadBuy    ADESA  4_VehicleAge  CHEVROLET    COBALT 2.2L I4 MPI
# 28     0_IsBadBuy  MANHEIM  4_VehicleAge      DODGE   CARAVAN FWD V6 3.3L
# 29     0_IsBadBuy  MANHEIM  6_VehicleAge   CHRYSLER  PT CRUISER 2.4L I4 M
# ...           ...      ...           ...        ...                   ...
# 12524  0_IsBadBuy    OTHER  5_VehicleAge  CHEVROLET    TRAILBLAZER 2WD 6C
# 12525  0_IsBadBuy    OTHER  7_VehicleAge        GMC  ENVOY 4WD 6C 4.2L I6
# 12526  0_IsBadBuy    ADESA  3_VehicleAge  CHEVROLET   TRAILBLAZER EXT 2WD
# 12527  0_IsBadBuy  MANHEIM  3_VehicleAge   CHRYSLER  TOWN & COUNTRY 2WD V
# 12528  0_IsBadBuy  MANHEIM  5_VehicleAge       FORD  ESCAPE 2WD V6 3.0L V
# 12529  1_IsBadBuy  MANHEIM  5_VehicleAge     NISSAN                MAXIMA
# 12530  0_IsBadBuy  MANHEIM  3_VehicleAge  CHEVROLET  MALIBU V6 3.5L V6 SF
# 12531  0_IsBadBuy  MANHEIM  6_VehicleAge      DODGE  STRATUS 4C 2.4L I4 M
# 12532  0_IsBadBuy    OTHER  3_VehicleAge        KIA             OPTIMA 4C
# 12533  0_IsBadBuy  MANHEIM  3_VehicleAge   CHRYSLER            SEBRING 4C
# 12534  0_IsBadBuy  MANHEIM  6_VehicleAge  CHEVROLET             MALIBU V6
# 12535  0_IsBadBuy  MANHEIM  3_VehicleAge      DODGE  STRATUS V6 2.7L V6 M
# 12536  0_IsBadBuy  MANHEIM  3_VehicleAge   CHRYSLER                   300
# 12537  0_IsBadBuy  MANHEIM  4_VehicleAge      DODGE        DURANGO 2WD V8
# 12538  0_IsBadBuy  MANHEIM  3_VehicleAge      DODGE             MAGNUM V6
# 12539  0_IsBadBuy    ADESA  6_VehicleAge      DODGE   DURANGO 2WD V8 4.7L
# 12540  0_IsBadBuy    OTHER  1_VehicleAge   CHRYSLER  SEBRING 4C 2.4L I4 E
# 12541  0_IsBadBuy  MANHEIM  3_VehicleAge      DODGE               CALIBER
# 12542  0_IsBadBuy    ADESA  4_VehicleAge       FORD  FREESTYLE FWD V6 3.0
# 12543  0_IsBadBuy  MANHEIM  4_VehicleAge        KIA               SPECTRA
# 12544  0_IsBadBuy  MANHEIM  3_VehicleAge      DODGE            CHARGER V6
# 12545  0_IsBadBuy    ADESA  6_VehicleAge      DODGE            STRATUS V6
# 12546  0_IsBadBuy    OTHER  6_VehicleAge       FORD                TAURUS
# 12547  0_IsBadBuy    ADESA  4_VehicleAge    PONTIAC                 G6 4C
# 12548  0_IsBadBuy    OTHER  6_VehicleAge       FORD  EXPLORER 4WD V6 4.0L
# 12549  1_IsBadBuy  MANHEIM  5_VehicleAge       FORD  MUSTANG V6 3.9L V6 E
# 12550  0_IsBadBuy    OTHER  4_VehicleAge  CHEVROLET             MALIBU 4C
# 12551  0_IsBadBuy    ADESA  5_VehicleAge        KIA  OPTIMA V6 2.7L V6 MP
# 12552  0_IsBadBuy    ADESA  4_VehicleAge        KIA    AMANTI 3.5L V6 MPI
# 12553  0_IsBadBuy  MANHEIM  3_VehicleAge        KIA           SORENTO 2WD
#
#            Trim Transmission    WheelTypeID     Nationality        Size  \
# 0      Bas_Trim       MANUAL  1_WheelTypeID        AMERICAN      SPORTS
# 1       ES_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 2      Bas_Trim       MANUAL  1_WheelTypeID     OTHER ASIAN      SPORTS
# 3      Nor_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 4      XLS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 5       LS_Trim         AUTO  2_WheelTypeID        AMERICAN       LARGE
# 6      Lim_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 7      SXT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 8      Cus_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 9       SE_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 10      SX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 11     GLS_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12      LT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 13      SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 14      LE_Trim         AUTO  2_WheelTypeID  TOP LINE ASIAN      MEDIUM
# 15      SE_Trim         AUTO  1_WheelTypeID        AMERICAN         VAN
# 16     SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 17      LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 18      LS_Trim         AUTO  2_WheelTypeID        AMERICAN     COMPACT
# 19     SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 20     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 21     Lar_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 22     SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 23      LX_Trim         AUTO  2_WheelTypeID        AMERICAN     COMPACT
# 24     SEL_Trim         AUTO  1_WheelTypeID        AMERICAN       LARGE
# 25      SE_Trim         AUTO  3_WheelTypeID        AMERICAN     COMPACT
# 26     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 27     Bas_Trim         AUTO  1_WheelTypeID        AMERICAN     COMPACT
# 28      SE_Trim         AUTO  2_WheelTypeID        AMERICAN         VAN
# 29     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# ...         ...          ...            ...             ...         ...
# 12524   LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12525  SLE_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12526   LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12527  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN         VAN
# 12528  XLT_Trim         AUTO  1_WheelTypeID        AMERICAN   SMALL SUV
# 12529   SE_Trim         AUTO  1_WheelTypeID  TOP LINE ASIAN       LARGE
# 12530   LS_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12531   SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12532   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12533  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12534   LS_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12535  SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12536  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12537  SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12538   SE_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12539  SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12540   LX_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12541  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12542   SE_Trim         AUTO  1_WheelTypeID        AMERICAN   CROSSOVER
# 12543   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12544  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12545   ES_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12546   SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12547  Bas_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12548  XLS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12549  Bas_Trim         AUTO  3_WheelTypeID        AMERICAN      SPORTS
# 12550   LT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12551   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12552   LS_Trim         AUTO  1_WheelTypeID     OTHER ASIAN       LARGE
# 12553   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN  MEDIUM SUV
#
#                                VehBCostBin                         VehOdoBin  \
# 0       [76713.492, 77122.849)_VehBCostBin   [73798.18, 73829.373)_VehOdoBin
# 1       [56654.995, 57064.352)_VehBCostBin   [74203.696, 74234.89)_VehOdoBin
# 2        [51333.353, 51742.71)_VehBCostBin  [77978.121, 78009.315)_VehOdoBin
# 3       [67707.636, 68116.993)_VehBCostBin   [77790.96, 77822.153)_VehOdoBin
# 4       [56654.995, 57064.352)_VehBCostBin  [79568.995, 79600.188)_VehOdoBin
# 5       [79988.348, 80397.706)_VehBCostBin  [86774.715, 86805.909)_VehOdoBin
# 6       [49695.925, 50105.282)_VehBCostBin  [84871.906, 84903.099)_VehOdoBin
# 7       [97181.346, 97590.703)_VehBCostBin  [75638.602, 75669.795)_VehOdoBin
# 8       [48877.211, 49286.568)_VehBCostBin  [65157.554, 65188.748)_VehOdoBin
# 9        [84900.633, 85309.99)_VehBCostBin  [65999.781, 66030.975)_VehOdoBin
# 10       [71391.85, 71801.207)_VehBCostBin  [83873.711, 83904.904)_VehOdoBin
# 11      [70163.779, 70573.136)_VehBCostBin  [64564.876, 64596.069)_VehOdoBin
# 12      [68935.707, 69345.065)_VehBCostBin  [71396.273, 71427.467)_VehOdoBin
# 13      [39871.355, 40280.712)_VehBCostBin   [85776.52, 85807.714)_VehOdoBin
# 14      [75894.778, 76304.135)_VehBCostBin  [82594.773, 82625.967)_VehOdoBin
# 15      [66479.565, 66888.922)_VehBCostBin   [70990.756, 71021.95)_VehOdoBin
# 16       [94725.203, 95134.56)_VehBCostBin  [73080.727, 73111.921)_VehOdoBin
# 17      [75076.064, 75485.421)_VehBCostBin  [74515.632, 74546.826)_VehOdoBin
# 18      [43555.569, 43964.926)_VehBCostBin  [66374.104, 66405.298)_VehOdoBin
# 19      [52970.782, 53380.139)_VehBCostBin  [45287.234, 45318.428)_VehOdoBin
# 20      [88994.204, 89403.561)_VehBCostBin  [59854.643, 59885.837)_VehOdoBin
# 21      [58701.781, 59111.138)_VehBCostBin  [71521.047, 71552.241)_VehOdoBin
# 22      [55426.924, 55836.281)_VehBCostBin  [62412.518, 62443.711)_VehOdoBin
# 23       [54198.853, 54608.21)_VehBCostBin  [91266.593, 91297.786)_VehOdoBin
# 24      [79578.991, 79988.348)_VehBCostBin   [72581.63, 72612.823)_VehOdoBin
# 25      [40280.712, 40690.069)_VehBCostBin  [44070.684, 44101.878)_VehOdoBin
# 26      [56654.995, 57064.352)_VehBCostBin   [75420.247, 75451.44)_VehOdoBin
# 27      [48877.211, 49286.568)_VehBCostBin  [76075.312, 76106.506)_VehOdoBin
# 28      [59929.852, 60339.209)_VehBCostBin   [77447.83, 77479.024)_VehOdoBin
# 29       [44783.64, 45192.997)_VehBCostBin  [76356.054, 76387.248)_VehOdoBin
# ...                                    ...                               ...
# 12524    [80807.063, 81216.42)_VehBCostBin  [82282.837, 82314.031)_VehOdoBin
# 12525   [72619.921, 73029.278)_VehBCostBin  [63161.164, 63192.358)_VehOdoBin
# 12526   [91859.704, 92269.061)_VehBCostBin  [81159.868, 81191.062)_VehOdoBin
# 12527   [49695.925, 50105.282)_VehBCostBin  [99907.218, 99938.412)_VehOdoBin
# 12528   [72210.564, 72619.921)_VehBCostBin  [71333.886, 71365.079)_VehOdoBin
# 12529  [99637.488, 100046.845)_VehBCostBin  [78040.509, 78071.702)_VehOdoBin
# 12530   [55017.567, 55426.924)_VehBCostBin   [76636.797, 76667.99)_VehOdoBin
# 12531   [37005.856, 37415.213)_VehBCostBin  [93013.434, 93044.628)_VehOdoBin
# 12532   [76713.492, 77122.849)_VehBCostBin  [60010.611, 60041.804)_VehOdoBin
# 12533   [71801.207, 72210.564)_VehBCostBin  [80286.447, 80317.641)_VehOdoBin
# 12534   [66479.565, 66888.922)_VehBCostBin  [87554.555, 87585.749)_VehOdoBin
# 12535   [55836.281, 56245.638)_VehBCostBin  [41294.454, 41325.648)_VehOdoBin
# 12536   [86538.062, 86947.419)_VehBCostBin  [71957.758, 71988.951)_VehOdoBin
# 12537    [87766.133, 88175.49)_VehBCostBin  [72051.338, 72082.532)_VehOdoBin
# 12538   [74257.349, 74666.707)_VehBCostBin  [65719.039, 65750.232)_VehOdoBin
# 12539   [56245.638, 56654.995)_VehBCostBin  [80442.415, 80473.609)_VehOdoBin
# 12540   [76713.492, 77122.849)_VehBCostBin  [51525.953, 51557.147)_VehOdoBin
# 12541   [74257.349, 74666.707)_VehBCostBin   [45599.17, 45630.364)_VehOdoBin
# 12542    [84900.633, 85309.99)_VehBCostBin  [63785.036, 63816.229)_VehOdoBin
# 12543    [61567.28, 61976.637)_VehBCostBin  [59511.513, 59542.707)_VehOdoBin
# 12544    [95134.56, 95543.917)_VehBCostBin  [70834.788, 70865.982)_VehOdoBin
# 12545     [30865.5, 31274.857)_VehBCostBin  [80348.835, 80380.028)_VehOdoBin
# 12546   [60748.566, 61157.923)_VehBCostBin  [50091.048, 50122.241)_VehOdoBin
# 12547   [53380.139, 53789.496)_VehBCostBin  [95945.632, 95976.826)_VehOdoBin
# 12548   [86947.419, 87356.776)_VehBCostBin  [68526.462, 68557.656)_VehOdoBin
# 12549   [75894.778, 76304.135)_VehBCostBin  [78040.509, 78071.702)_VehOdoBin
# 12550   [63614.065, 64023.423)_VehBCostBin  [72799.985, 72831.178)_VehOdoBin
# 12551   [53380.139, 53789.496)_VehBCostBin  [80286.447, 80317.641)_VehOdoBin
# 12552   [72210.564, 72619.921)_VehBCostBin  [54863.668, 54894.861)_VehOdoBin
# 12553    [68116.993, 68526.35)_VehBCostBin   [68214.526, 68245.72)_VehOdoBin
#
#                     MMRAcquisitionAuctionAveragePriceBin  \
# 0      [88381.549, 88429.417)_MMRAcquisitionAuctionAv...
# 1      [28498.595, 28546.463)_MMRAcquisitionAuctionAv...
# 2      [40513.48, 40561.348)_MMRAcquisitionAuctionAve...
# 3      [65404.876, 65452.744)_MMRAcquisitionAuctionAv...
# 4      [48028.767, 48076.635)_MMRAcquisitionAuctionAv...
# 5      [79717.428, 79765.296)_MMRAcquisitionAuctionAv...
# 6      [33189.665, 33237.533)_MMRAcquisitionAuctionAv...
# 7      [95705.363, 95753.231)_MMRAcquisitionAuctionAv...
# 8      [36253.222, 36301.09)_MMRAcquisitionAuctionAve...
# 9      [74978.489, 75026.358)_MMRAcquisitionAuctionAv...
# 10     [40944.293, 40992.161)_MMRAcquisitionAuctionAv...
# 11     [69090.717, 69138.585)_MMRAcquisitionAuctionAv...
# 12     [68755.641, 68803.509)_MMRAcquisitionAuctionAv...
# 13     [40178.403, 40226.272)_MMRAcquisitionAuctionAv...
# 14     [62820.0, 62867.868)_MMRAcquisitionAuctionAver...
# 15     [61431.826, 61479.694)_MMRAcquisitionAuctionAv...
# 16     [91157.897, 91205.765)_MMRAcquisitionAuctionAv...
# 17     [100204.962, 100252.83)_MMRAcquisitionAuctionA...
# 18     [43672.772, 43720.641)_MMRAcquisitionAuctionAv...
# 19     [55687.658, 55735.526)_MMRAcquisitionAuctionAv...
# 20     [86610.43, 86658.298)_MMRAcquisitionAuctionAve...
# 21     [47789.426, 47837.294)_MMRAcquisitionAuctionAv...
# 22     [55879.13, 55926.998)_MMRAcquisitionAuctionAve...
# 23     [26775.344, 26823.212)_MMRAcquisitionAuctionAv...
# 24     [76270.927, 76318.795)_MMRAcquisitionAuctionAv...
# 25     [28450.727, 28498.595)_MMRAcquisitionAuctionAv...
# 26     [65883.556, 65931.424)_MMRAcquisitionAuctionAv...
# 27     [48842.524, 48890.392)_MMRAcquisitionAuctionAv...
# 28     [52480.497, 52528.365)_MMRAcquisitionAuctionAv...
# 29     [29073.011, 29120.88)_MMRAcquisitionAuctionAve...
# ...                                                  ...
# 12524  [66697.314, 66745.182)_MMRAcquisitionAuctionAv...
# 12525  [48028.767, 48076.635)_MMRAcquisitionAuctionAv...
# 12526  [96375.516, 96423.384)_MMRAcquisitionAuctionAv...
# 12527  [69856.606, 69904.474)_MMRAcquisitionAuctionAv...
# 12528  [55974.866, 56022.734)_MMRAcquisitionAuctionAv...
# 12529  [91253.633, 91301.501)_MMRAcquisitionAuctionAv...
# 12530  [66840.918, 66888.786)_MMRAcquisitionAuctionAv...
# 12531  [20073.815, 20121.683)_MMRAcquisitionAuctionAv...
# 12532  [73207.371, 73255.239)_MMRAcquisitionAuctionAv...
# 12533  [80339.713, 80387.581)_MMRAcquisitionAuctionAv...
# 12534  [45683.231, 45731.099)_MMRAcquisitionAuctionAv...
# 12535  [54682.428, 54730.296)_MMRAcquisitionAuctionAv...
# 12536  [99534.809, 99582.677)_MMRAcquisitionAuctionAv...
# 12537  [75648.642, 75696.511)_MMRAcquisitionAuctionAv...
# 12538  [72393.614, 72441.482)_MMRAcquisitionAuctionAv...
# 12539  [40417.744, 40465.612)_MMRAcquisitionAuctionAv...
# 12540  [84982.916, 85030.784)_MMRAcquisitionAuctionAv...
# 12541  [70766.099, 70813.967)_MMRAcquisitionAuctionAv...
# 12542  [76558.136, 76606.004)_MMRAcquisitionAuctionAv...
# 12543  [51523.136, 51571.004)_MMRAcquisitionAuctionAv...
# 12544  [107241.568, 107289.436)_MMRAcquisitionAuction...
# 12545  [26248.795, 26296.663)_MMRAcquisitionAuctionAv...
# 12546  [29503.824, 29551.692)_MMRAcquisitionAuctionAv...
# 12547  [61192.486, 61240.354)_MMRAcquisitionAuctionAv...
# 12548  [85796.673, 85844.541)_MMRAcquisitionAuctionAv...
# 12549  [68037.62, 68085.488)_MMRAcquisitionAuctionAve...
# 12550  [71723.461, 71771.329)_MMRAcquisitionAuctionAv...
# 12551  [28115.65, 28163.518)_MMRAcquisitionAuctionAve...
# 12552  [74356.205, 74404.073)_MMRAcquisitionAuctionAv...
# 12553  [78999.407, 79047.275)_MMRAcquisitionAuctionAv...
#
#                             WarrantyCostBin   Prediction
# 0        [802.545, 803.496)_WarrantyCostBin  NotRetrived
# 1      [1388.511, 1389.462)_WarrantyCostBin  NotRetrived
# 2        [919.548, 920.499)_WarrantyCostBin  NotRetrived
# 3      [1154.505, 1155.456)_WarrantyCostBin  NotRetrived
# 4      [1154.505, 1155.456)_WarrantyCostBin  NotRetrived
# 5      [2151.407, 2152.359)_WarrantyCostBin  NotRetrived
# 6      [1802.301, 1803.252)_WarrantyCostBin  NotRetrived
# 7      [1271.508, 1272.459)_WarrantyCostBin  NotRetrived
# 8      [2002.062, 2003.013)_WarrantyCostBin  NotRetrived
# 9      [1214.433, 1215.384)_WarrantyCostBin  NotRetrived
# 10       [593.272, 594.223)_WarrantyCostBin  NotRetrived
# 11       [727.397, 728.348)_WarrantyCostBin  NotRetrived
# 12       [802.545, 803.496)_WarrantyCostBin  NotRetrived
# 13        [982.33, 983.281)_WarrantyCostBin  NotRetrived
# 14       [893.864, 894.815)_WarrantyCostBin  NotRetrived
# 15     [1505.513, 1506.465)_WarrantyCostBin  NotRetrived
# 16     [1622.516, 1623.467)_WarrantyCostBin  NotRetrived
# 17     [1154.505, 1155.456)_WarrantyCostBin  NotRetrived
# 18       [727.397, 728.348)_WarrantyCostBin  NotRetrived
# 19        [974.72, 975.671)_WarrantyCostBin  NotRetrived
# 20        [836.79, 837.741)_WarrantyCostBin  NotRetrived
# 21     [2039.161, 2040.112)_WarrantyCostBin  NotRetrived
# 22     [1214.433, 1215.384)_WarrantyCostBin  NotRetrived
# 23      [1640.59, 1641.541)_WarrantyCostBin  NotRetrived
# 24     [1505.513, 1506.465)_WarrantyCostBin  NotRetrived
# 25     [1133.577, 1134.529)_WarrantyCostBin  NotRetrived
# 26       [919.548, 920.499)_WarrantyCostBin  NotRetrived
# 27       [802.545, 803.496)_WarrantyCostBin  NotRetrived
# 28     [1622.516, 1623.467)_WarrantyCostBin  NotRetrived
# 29     [1688.152, 1689.103)_WarrantyCostBin  NotRetrived
# ...                                     ...          ...
# 12524   [1242.97, 1243.922)_WarrantyCostBin  NotRetrived
# 12525  [2002.062, 2003.013)_WarrantyCostBin  NotRetrived
# 12526   [1242.97, 1243.922)_WarrantyCostBin  NotRetrived
# 12527  [1917.402, 1918.353)_WarrantyCostBin  NotRetrived
# 12528    [919.548, 920.499)_WarrantyCostBin  NotRetrived
# 12529  [1154.505, 1155.456)_WarrantyCostBin  NotRetrived
# 12530  [1271.508, 1272.459)_WarrantyCostBin  NotRetrived
# 12531   [1640.59, 1641.541)_WarrantyCostBin  NotRetrived
# 12532    [727.397, 728.348)_WarrantyCostBin  NotRetrived
# 12533   [1242.97, 1243.922)_WarrantyCostBin  NotRetrived
# 12534  [1372.339, 1373.291)_WarrantyCostBin  NotRetrived
# 12535     [974.72, 975.671)_WarrantyCostBin  NotRetrived
# 12536  [1388.511, 1389.462)_WarrantyCostBin  NotRetrived
# 12537  [1388.511, 1389.462)_WarrantyCostBin  NotRetrived
# 12538  [1214.433, 1215.384)_WarrantyCostBin  NotRetrived
# 12539  [1802.301, 1803.252)_WarrantyCostBin  NotRetrived
# 12540    [919.548, 920.499)_WarrantyCostBin  NotRetrived
# 12541    [692.201, 693.152)_WarrantyCostBin  NotRetrived
# 12542  [1312.411, 1313.362)_WarrantyCostBin  NotRetrived
# 12543    [504.806, 505.757)_WarrantyCostBin  NotRetrived
# 12544  [1388.511, 1389.462)_WarrantyCostBin  NotRetrived
# 12545   [1502.66, 1503.611)_WarrantyCostBin  NotRetrived
# 12546     [753.08, 754.032)_WarrantyCostBin  NotRetrived
# 12547  [1196.359, 1197.311)_WarrantyCostBin  NotRetrived
# 12548  [1807.057, 1808.009)_WarrantyCostBin  NotRetrived
# 12549    [802.545, 803.496)_WarrantyCostBin  NotRetrived
# 12550  [1037.502, 1038.453)_WarrantyCostBin  NotRetrived
# 12551    [852.961, 853.912)_WarrantyCostBin  NotRetrived
# 12552  [1002.306, 1003.257)_WarrantyCostBin  NotRetrived
# 12553  [1507.416, 1508.367)_WarrantyCostBin  NotRetrived
#
# [12554 rows x 15 columns]

# %%
#Prediction phase
for i in df2.index:
    for r in rulesClass:
        cont=0;
        for k in r[1] :
            if(k in df2.values[i]):
                cont=cont+1
            if(cont==len(r[1])):
                print(i)
                print(df2.values[i][14])
                df2.loc[df2.index==i,'Prediction']=r[0]
                print(df2.values[i][14])
                break
        if(cont==len(r[1])):break
                
df2
# Out:
# 1
# NotRetrived
# 0_IsBadBuy
# 3
# NotRetrived
# 0_IsBadBuy
# 4
# NotRetrived
# 1_IsBadBuy
# 5
# NotRetrived
# 0_IsBadBuy
# 6
# NotRetrived
# 1_IsBadBuy
# 7
# NotRetrived
# 0_IsBadBuy
# 8
# NotRetrived
# 0_IsBadBuy
# 9
# NotRetrived
# 0_IsBadBuy
# 10
# NotRetrived
# 1_IsBadBuy
# 12
# NotRetrived
# 0_IsBadBuy
# 13
# NotRetrived
# 0_IsBadBuy
# 14
# NotRetrived
# 0_IsBadBuy
# 15
# NotRetrived
# 0_IsBadBuy
# 16
# NotRetrived
# 0_IsBadBuy
# 17
# NotRetrived
# 0_IsBadBuy
# 18
# NotRetrived
# 0_IsBadBuy
# 19
# NotRetrived
# 0_IsBadBuy
# 20
# NotRetrived
# 0_IsBadBuy
# 21
# NotRetrived
# 1_IsBadBuy
# 22
# NotRetrived
# 0_IsBadBuy
# 23
# NotRetrived
# 0_IsBadBuy
# 24
# NotRetrived
# 0_IsBadBuy
# 25
# NotRetrived
# 1_IsBadBuy
# 26
# NotRetrived
# 0_IsBadBuy
# 27
# NotRetrived
# 1_IsBadBuy
# 28
# NotRetrived
# 0_IsBadBuy
# 29
# NotRetrived
# 1_IsBadBuy
# 30
# NotRetrived
# 1_IsBadBuy
# 31
# NotRetrived
# 1_IsBadBuy
# 32
# NotRetrived
# 1_IsBadBuy
# 33
# NotRetrived
# 1_IsBadBuy
# 34
# NotRetrived
# 1_IsBadBuy
# 35
# NotRetrived
# 0_IsBadBuy
# 36
# NotRetrived
# 1_IsBadBuy
# 37
# NotRetrived
# 0_IsBadBuy
# 38
# NotRetrived
# 0_IsBadBuy
# 39
# NotRetrived
# 1_IsBadBuy
# 40
# NotRetrived
# 1_IsBadBuy
# 41
# NotRetrived
# 0_IsBadBuy
# 42
# NotRetrived
# 0_IsBadBuy
# 43
# NotRetrived
# 0_IsBadBuy
# 44
# NotRetrived
# 1_IsBadBuy
# 45
# NotRetrived
# 0_IsBadBuy
# 46
# NotRetrived
# 0_IsBadBuy
# 47
# NotRetrived
# 0_IsBadBuy
# 48
# NotRetrived
# 1_IsBadBuy
# 49
# NotRetrived
# 0_IsBadBuy
# 50
# NotRetrived
# 1_IsBadBuy
# 51
# NotRetrived
# 0_IsBadBuy
# 52
# NotRetrived
# 0_IsBadBuy
# 53
# NotRetrived
# 0_IsBadBuy
# 55
# NotRetrived
# 1_IsBadBuy
# 56
# NotRetrived
# 0_IsBadBuy
# 57
# NotRetrived
# 0_IsBadBuy
# 58
# NotRetrived
# 1_IsBadBuy
# 59
# NotRetrived
# 0_IsBadBuy
# 60
# NotRetrived
# 0_IsBadBuy
# 61
# NotRetrived
# 1_IsBadBuy
# 62
# NotRetrived
# 1_IsBadBuy
# 63
# NotRetrived
# 0_IsBadBuy
# 64
# NotRetrived
# 0_IsBadBuy
# 65
# NotRetrived
# 0_IsBadBuy
# 66
# NotRetrived
# 0_IsBadBuy
# 68
# NotRetrived
# 1_IsBadBuy
# 69
# NotRetrived
# 1_IsBadBuy
# 70
# NotRetrived
# 0_IsBadBuy
# 71
# NotRetrived
# 0_IsBadBuy
# 72
# NotRetrived
# 1_IsBadBuy
# 73
# NotRetrived
# 0_IsBadBuy
# 74
# NotRetrived
# 1_IsBadBuy
# 75
# NotRetrived
# 0_IsBadBuy
# 76
# NotRetrived
# 0_IsBadBuy
# 78
# NotRetrived
# 0_IsBadBuy
# 79
# NotRetrived
# 1_IsBadBuy
# 80
# NotRetrived
# 0_IsBadBuy
# 81
# NotRetrived
# 0_IsBadBuy
# 83
# NotRetrived
# 0_IsBadBuy
# 84
# NotRetrived
# 0_IsBadBuy
# 85
# NotRetrived
# 0_IsBadBuy
# 86
# NotRetrived
# 1_IsBadBuy
# 87
# NotRetrived
# 0_IsBadBuy
# 88
# NotRetrived
# 0_IsBadBuy
# 89
# NotRetrived
# 0_IsBadBuy
# 90
# NotRetrived
# 0_IsBadBuy
# 91
# NotRetrived
# 0_IsBadBuy
# 92
# NotRetrived
# 0_IsBadBuy
# 94
# NotRetrived
# 1_IsBadBuy
# 95
# NotRetrived
# 0_IsBadBuy
# 96
# NotRetrived
# 0_IsBadBuy
# 97
# NotRetrived
# 0_IsBadBuy
# 98
# NotRetrived
# 1_IsBadBuy
# 99
# NotRetrived
# 0_IsBadBuy
# 100
# NotRetrived
# 0_IsBadBuy
# 101
# NotRetrived
# 0_IsBadBuy
# 102
# NotRetrived
# 0_IsBadBuy
# 103
# NotRetrived
# 0_IsBadBuy
# 104
# NotRetrived
# 0_IsBadBuy
# 105
# NotRetrived
# 1_IsBadBuy
# 106
# NotRetrived
# 0_IsBadBuy
# 107
# NotRetrived
# 0_IsBadBuy
# 108
# NotRetrived
# 0_IsBadBuy
# 109
# NotRetrived
# 1_IsBadBuy
# 112
# NotRetrived
# 1_IsBadBuy
# 113
# NotRetrived
# 1_IsBadBuy
# 114
# NotRetrived
# 1_IsBadBuy
# 115
# NotRetrived
# 1_IsBadBuy
# 116
# NotRetrived
# 1_IsBadBuy
# 117
# NotRetrived
# 0_IsBadBuy
# 118
# NotRetrived
# 0_IsBadBuy
# 119
# NotRetrived
# 0_IsBadBuy
# 120
# NotRetrived
# 0_IsBadBuy
# 121
# NotRetrived
# 0_IsBadBuy
# 122
# NotRetrived
# 0_IsBadBuy
# 123
# NotRetrived
# 0_IsBadBuy
# 124
# NotRetrived
# 0_IsBadBuy
# 125
# NotRetrived
# 1_IsBadBuy
# 126
# NotRetrived
# 0_IsBadBuy
# 127
# NotRetrived
# 0_IsBadBuy
# 128
# NotRetrived
# 0_IsBadBuy
# 129
# NotRetrived
# 0_IsBadBuy
# 130
# NotRetrived
# 0_IsBadBuy
# 131
# NotRetrived
# 0_IsBadBuy
# 132
# NotRetrived
# 0_IsBadBuy
# 133
# NotRetrived
# 0_IsBadBuy
# 134
# NotRetrived
# 1_IsBadBuy
# 135
# NotRetrived
# 0_IsBadBuy
# 136
# NotRetrived
# 0_IsBadBuy
# 137
# NotRetrived
# 0_IsBadBuy
# 138
# NotRetrived
# 0_IsBadBuy
# 139
# NotRetrived
# 0_IsBadBuy
# 140
# NotRetrived
# 0_IsBadBuy
# 141
# NotRetrived
# 0_IsBadBuy
# 142
# NotRetrived
# 0_IsBadBuy
# 143
# NotRetrived
# 0_IsBadBuy
# 144
# NotRetrived
# 1_IsBadBuy
# 145
# NotRetrived
# 0_IsBadBuy
# 146
# NotRetrived
# 0_IsBadBuy
# 147
# NotRetrived
# 0_IsBadBuy
# 148
# NotRetrived
# 0_IsBadBuy
# 149
# NotRetrived
# 1_IsBadBuy
# 150
# NotRetrived
# 0_IsBadBuy
# 151
# NotRetrived
# 1_IsBadBuy
# 152
# NotRetrived
# 0_IsBadBuy
# 153
# NotRetrived
# 0_IsBadBuy
# 154
# NotRetrived
# 1_IsBadBuy
# 155
# NotRetrived
# 0_IsBadBuy
# 156
# NotRetrived
# 0_IsBadBuy
# 157
# NotRetrived
# 1_IsBadBuy
# 158
# NotRetrived
# 0_IsBadBuy
# 159
# NotRetrived
# 0_IsBadBuy
# 160
# NotRetrived
# 0_IsBadBuy
# 161
# NotRetrived
# 0_IsBadBuy
# 162
# NotRetrived
# 0_IsBadBuy
# 163
# NotRetrived
# 0_IsBadBuy
# 164
# NotRetrived
# 0_IsBadBuy
# 165
# NotRetrived
# 0_IsBadBuy
# 166
# NotRetrived
# 1_IsBadBuy
# 167
# NotRetrived
# 0_IsBadBuy
# 168
# NotRetrived
# 1_IsBadBuy
# 169
# NotRetrived
# 0_IsBadBuy
# 170
# NotRetrived
# 1_IsBadBuy
# 171
# NotRetrived
# 0_IsBadBuy
# 172
# NotRetrived
# 0_IsBadBuy
# 173
# NotRetrived
# 1_IsBadBuy
# 174
# NotRetrived
# 0_IsBadBuy
# 175
# NotRetrived
# 0_IsBadBuy
# 176
# NotRetrived
# 0_IsBadBuy
# 177
# NotRetrived
# 0_IsBadBuy
# 178
# NotRetrived
# 1_IsBadBuy
# 179
# NotRetrived
# 0_IsBadBuy
# 180
# NotRetrived
# 1_IsBadBuy
# 181
# NotRetrived
# 0_IsBadBuy
# 182
# NotRetrived
# 1_IsBadBuy
# 183
# NotRetrived
# 0_IsBadBuy
# 186
# NotRetrived
# 1_IsBadBuy
# 188
# NotRetrived
# 1_IsBadBuy
# 189
# NotRetrived
# 0_IsBadBuy
# 190
# NotRetrived
# 0_IsBadBuy
# 191
# NotRetrived
# 1_IsBadBuy
# 192
# NotRetrived
# 0_IsBadBuy
# 193
# NotRetrived
# 0_IsBadBuy
# 194
# NotRetrived
# 0_IsBadBuy
# 195
# NotRetrived
# 0_IsBadBuy
# 196
# NotRetrived
# 0_IsBadBuy
# 197
# NotRetrived
# 0_IsBadBuy
# 198
# NotRetrived
# 0_IsBadBuy
# 199
# NotRetrived
# 1_IsBadBuy
# 200
# NotRetrived
# 0_IsBadBuy
# 201
# NotRetrived
# 1_IsBadBuy
# 202
# NotRetrived
# 0_IsBadBuy
# 203
# NotRetrived
# 1_IsBadBuy
# 205
# NotRetrived
# 0_IsBadBuy
# 206
# NotRetrived
# 0_IsBadBuy
# 207
# NotRetrived
# 0_IsBadBuy
# 208
# NotRetrived
# 0_IsBadBuy
# 209
# NotRetrived
# 1_IsBadBuy
# 210
# NotRetrived
# 0_IsBadBuy
# 211
# NotRetrived
# 1_IsBadBuy
# 212
# NotRetrived
# 0_IsBadBuy
# 213
# NotRetrived
# 0_IsBadBuy
# 214
# NotRetrived
# 0_IsBadBuy
# 216
# NotRetrived
# 0_IsBadBuy
# 217
# NotRetrived
# 1_IsBadBuy
# 218
# NotRetrived
# 0_IsBadBuy
# 219
# NotRetrived
# 1_IsBadBuy
# 220
# NotRetrived
# 0_IsBadBuy
# 221
# NotRetrived
# 1_IsBadBuy
# 222
# NotRetrived
# 1_IsBadBuy
# 223
# NotRetrived
# 0_IsBadBuy
# 224
# NotRetrived
# 1_IsBadBuy
# 225
# NotRetrived
# 0_IsBadBuy
# 226
# NotRetrived
# 0_IsBadBuy
# 227
# NotRetrived
# 0_IsBadBuy
# 228
# NotRetrived
# 0_IsBadBuy
# 229
# NotRetrived
# 0_IsBadBuy
# 230
# NotRetrived
# 0_IsBadBuy
# 231
# NotRetrived
# 1_IsBadBuy
# 232
# NotRetrived
# 1_IsBadBuy
# 233
# NotRetrived
# 0_IsBadBuy
# 234
# NotRetrived
# 0_IsBadBuy
# 235
# NotRetrived
# 0_IsBadBuy
# 236
# NotRetrived
# 0_IsBadBuy
# 237
# NotRetrived
# 0_IsBadBuy
# 238
# NotRetrived
# 0_IsBadBuy
# 239
# NotRetrived
# 0_IsBadBuy
# 242
# NotRetrived
# 1_IsBadBuy
# 243
# NotRetrived
# 1_IsBadBuy
# 244
# NotRetrived
# 0_IsBadBuy
# 245
# NotRetrived
# 0_IsBadBuy
# 246
# NotRetrived
# 1_IsBadBuy
# 247
# NotRetrived
# 1_IsBadBuy
# 248
# NotRetrived
# 1_IsBadBuy
# 249
# NotRetrived
# 1_IsBadBuy
# 250
# NotRetrived
# 0_IsBadBuy
# 251
# NotRetrived
# 1_IsBadBuy
# 252
# NotRetrived
# 0_IsBadBuy
# 253
# NotRetrived
# 0_IsBadBuy
# 254
# NotRetrived
# 0_IsBadBuy
# 255
# NotRetrived
# 1_IsBadBuy
# 256
# NotRetrived
# 0_IsBadBuy
# 257
# NotRetrived
# 1_IsBadBuy
# 259
# NotRetrived
# 0_IsBadBuy
# 260
# NotRetrived
# 1_IsBadBuy
# 261
# NotRetrived
# 0_IsBadBuy
# 262
# NotRetrived
# 0_IsBadBuy
# 263
# NotRetrived
# 1_IsBadBuy
# 264
# NotRetrived
# 0_IsBadBuy
# 265
# NotRetrived
# 0_IsBadBuy
# 266
# NotRetrived
# 0_IsBadBuy
# 267
# NotRetrived
# 0_IsBadBuy
# 268
# NotRetrived
# 0_IsBadBuy
# 269
# NotRetrived
# 0_IsBadBuy
# 270
# NotRetrived
# 0_IsBadBuy
# 271
# NotRetrived
# 0_IsBadBuy
# 272
# NotRetrived
# 0_IsBadBuy
# 273
# NotRetrived
# 0_IsBadBuy
# 274
# NotRetrived
# 0_IsBadBuy
# 275
# NotRetrived
# 0_IsBadBuy
# 276
# NotRetrived
# 0_IsBadBuy
# 277
# NotRetrived
# 1_IsBadBuy
# 279
# NotRetrived
# 0_IsBadBuy
# 280
# NotRetrived
# 0_IsBadBuy
# 281
# NotRetrived
# 0_IsBadBuy
# 282
# NotRetrived
# 0_IsBadBuy
# 283
# NotRetrived
# 0_IsBadBuy
# 284
# NotRetrived
# 0_IsBadBuy
# 285
# NotRetrived
# 0_IsBadBuy
# 286
# NotRetrived
# 0_IsBadBuy
# 287
# NotRetrived
# 0_IsBadBuy
# 288
# NotRetrived
# 0_IsBadBuy
# 290
# NotRetrived
# 0_IsBadBuy
# 291
# NotRetrived
# 1_IsBadBuy
# 292
# NotRetrived
# 0_IsBadBuy
# 293
# NotRetrived
# 0_IsBadBuy
# 294
# NotRetrived
# 1_IsBadBuy
# 295
# NotRetrived
# 0_IsBadBuy
# 296
# NotRetrived
# 0_IsBadBuy
# 297
# NotRetrived
# 1_IsBadBuy
# 298
# NotRetrived
# 0_IsBadBuy
# 299
# NotRetrived
# 0_IsBadBuy
# 300
# NotRetrived
# 1_IsBadBuy
# 301
# NotRetrived
# 0_IsBadBuy
# 303
# NotRetrived
# 1_IsBadBuy
# 304
# NotRetrived
# 0_IsBadBuy
# 305
# NotRetrived
# 1_IsBadBuy
# 306
# NotRetrived
# 0_IsBadBuy
# 307
# NotRetrived
# 0_IsBadBuy
# 308
# NotRetrived
# 1_IsBadBuy
# 309
# NotRetrived
# 0_IsBadBuy
# 310
# NotRetrived
# 1_IsBadBuy
# 311
# NotRetrived
# 0_IsBadBuy
# 312
# NotRetrived
# 0_IsBadBuy
# 313
# NotRetrived
# 0_IsBadBuy
# 315
# NotRetrived
# 1_IsBadBuy
# 316
# NotRetrived
# 0_IsBadBuy
# 317
# NotRetrived
# 1_IsBadBuy
# 318
# NotRetrived
# 1_IsBadBuy
# 319
# NotRetrived
# 0_IsBadBuy
# 320
# NotRetrived
# 0_IsBadBuy
# 321
# NotRetrived
# 1_IsBadBuy
# 322
# NotRetrived
# 0_IsBadBuy
# 323
# NotRetrived
# 0_IsBadBuy
# 324
# NotRetrived
# 1_IsBadBuy
# 325
# NotRetrived
# 0_IsBadBuy
# 326
# NotRetrived
# 0_IsBadBuy
# 327
# NotRetrived
# 0_IsBadBuy
# 328
# NotRetrived
# 1_IsBadBuy
# 329
# NotRetrived
# 0_IsBadBuy
# 330
# NotRetrived
# 1_IsBadBuy
# 331
# NotRetrived
# 0_IsBadBuy
# 332
# NotRetrived
# 0_IsBadBuy
# 333
# NotRetrived
# 1_IsBadBuy
# 334
# NotRetrived
# 0_IsBadBuy
# 335
# NotRetrived
# 0_IsBadBuy
# 336
# NotRetrived
# 0_IsBadBuy
# 337
# NotRetrived
# 0_IsBadBuy
# 338
# NotRetrived
# 1_IsBadBuy
# 340
# NotRetrived
# 0_IsBadBuy
# 341
# NotRetrived
# 1_IsBadBuy
# 342
# NotRetrived
# 0_IsBadBuy
# 343
# NotRetrived
# 0_IsBadBuy
# 344
# NotRetrived
# 1_IsBadBuy
# 345
# NotRetrived
# 1_IsBadBuy
# 346
# NotRetrived
# 0_IsBadBuy
# 347
# NotRetrived
# 0_IsBadBuy
# 348
# NotRetrived
# 0_IsBadBuy
# 349
# NotRetrived
# 1_IsBadBuy
# 350
# NotRetrived
# 0_IsBadBuy
# 351
# NotRetrived
# 0_IsBadBuy
# 352
# NotRetrived
# 0_IsBadBuy
# 353
# NotRetrived
# 1_IsBadBuy
# 354
# NotRetrived
# 0_IsBadBuy
# 355
# NotRetrived
# 0_IsBadBuy
# 356
# NotRetrived
# 0_IsBadBuy
# 357
# NotRetrived
# 1_IsBadBuy
# 359
# NotRetrived
# 1_IsBadBuy
# 360
# NotRetrived
# 0_IsBadBuy
# 361
# NotRetrived
# 1_IsBadBuy
# 362
# NotRetrived
# 0_IsBadBuy
# 363
# NotRetrived
# 0_IsBadBuy
# 364
# NotRetrived
# 1_IsBadBuy
# 365
# NotRetrived
# 0_IsBadBuy
# 366
# NotRetrived
# 0_IsBadBuy
# 367
# NotRetrived
# 0_IsBadBuy
# 368
# NotRetrived
# 0_IsBadBuy
# 369
# NotRetrived
# 0_IsBadBuy
# 370
# NotRetrived
# 0_IsBadBuy
# 371
# NotRetrived
# 1_IsBadBuy
# 372
# NotRetrived
# 0_IsBadBuy
# 373
# NotRetrived
# 0_IsBadBuy
# 374
# NotRetrived
# 1_IsBadBuy
# 375
# NotRetrived
# 0_IsBadBuy
# 376
# NotRetrived
# 0_IsBadBuy
# 377
# NotRetrived
# 0_IsBadBuy
# 378
# NotRetrived
# 0_IsBadBuy
# 379
# NotRetrived
# 0_IsBadBuy
# 380
# NotRetrived
# 1_IsBadBuy
# 382
# NotRetrived
# 1_IsBadBuy
# 383
# NotRetrived
# 0_IsBadBuy
# 384
# NotRetrived
# 1_IsBadBuy
# 385
# NotRetrived
# 0_IsBadBuy
# 386
# NotRetrived
# 0_IsBadBuy
# 387
# NotRetrived
# 0_IsBadBuy
# 389
# NotRetrived
# 1_IsBadBuy
# 390
# NotRetrived
# 0_IsBadBuy
# 392
# NotRetrived
# 0_IsBadBuy
# 393
# NotRetrived
# 1_IsBadBuy
# 394
# NotRetrived
# 1_IsBadBuy
# 395
# NotRetrived
# 0_IsBadBuy
# 396
# NotRetrived
# 0_IsBadBuy
# 397
# NotRetrived
# 0_IsBadBuy
# 398
# NotRetrived
# 1_IsBadBuy
# 399
# NotRetrived
# 0_IsBadBuy
# 400
# NotRetrived
# 1_IsBadBuy
# 401
# NotRetrived
# 1_IsBadBuy
# 402
# NotRetrived
# 1_IsBadBuy
# 404
# NotRetrived
# 0_IsBadBuy
# 405
# NotRetrived
# 0_IsBadBuy
# 406
# NotRetrived
# 0_IsBadBuy
# 407
# NotRetrived
# 1_IsBadBuy
# 408
# NotRetrived
# 0_IsBadBuy
# 409
# NotRetrived
# 0_IsBadBuy
# 410
# NotRetrived
# 0_IsBadBuy
# 411
# NotRetrived
# 1_IsBadBuy
# 413
# NotRetrived
# 0_IsBadBuy
# 414
# NotRetrived
# 0_IsBadBuy
# 415
# NotRetrived
# 1_IsBadBuy
# 416
# NotRetrived
# 0_IsBadBuy
# 417
# NotRetrived
# 1_IsBadBuy
# 419
# NotRetrived
# 0_IsBadBuy
# 422
# NotRetrived
# 0_IsBadBuy
# 423
# NotRetrived
# 1_IsBadBuy
# 424
# NotRetrived
# 0_IsBadBuy
# 426
# NotRetrived
# 0_IsBadBuy
# 427
# NotRetrived
# 1_IsBadBuy
# 428
# NotRetrived
# 0_IsBadBuy
# 429
# NotRetrived
# 0_IsBadBuy
# 430
# NotRetrived
# 1_IsBadBuy
# 431
# NotRetrived
# 0_IsBadBuy
# 432
# NotRetrived
# 0_IsBadBuy
# 433
# NotRetrived
# 1_IsBadBuy
# 434
# NotRetrived
# 0_IsBadBuy
# 435
# NotRetrived
# 0_IsBadBuy
# 436
# NotRetrived
# 0_IsBadBuy
# 437
# NotRetrived
# 0_IsBadBuy
# 438
# NotRetrived
# 1_IsBadBuy
# 439
# NotRetrived
# 0_IsBadBuy
# 440
# NotRetrived
# 0_IsBadBuy
# 441
# NotRetrived
# 0_IsBadBuy
# 442
# NotRetrived
# 0_IsBadBuy
# 443
# NotRetrived
# 1_IsBadBuy
# 444
# NotRetrived
# 1_IsBadBuy
# 445
# NotRetrived
# 0_IsBadBuy
# 446
# NotRetrived
# 0_IsBadBuy
# 447
# NotRetrived
# 0_IsBadBuy
# 448
# NotRetrived
# 0_IsBadBuy
# 449
# NotRetrived
# 0_IsBadBuy
# 450
# NotRetrived
# 1_IsBadBuy
# 453
# NotRetrived
# 0_IsBadBuy
# 455
# NotRetrived
# 1_IsBadBuy
# 456
# NotRetrived
# 0_IsBadBuy
# 457
# NotRetrived
# 0_IsBadBuy
# 459
# NotRetrived
# 0_IsBadBuy
# 460
# NotRetrived
# 0_IsBadBuy
# 461
# NotRetrived
# 0_IsBadBuy
# 462
# NotRetrived
# 0_IsBadBuy
# 465
# NotRetrived
# 0_IsBadBuy
# 466
# NotRetrived
# 1_IsBadBuy
# 467
# NotRetrived
# 0_IsBadBuy
# 468
# NotRetrived
# 0_IsBadBuy
# 469
# NotRetrived
# 0_IsBadBuy
# 470
# NotRetrived
# 1_IsBadBuy
# 471
# NotRetrived
# 0_IsBadBuy
# 473
# NotRetrived
# 0_IsBadBuy
# 474
# NotRetrived
# 1_IsBadBuy
# 475
# NotRetrived
# 0_IsBadBuy
# 476
# NotRetrived
# 0_IsBadBuy
# 477
# NotRetrived
# 0_IsBadBuy
# 478
# NotRetrived
# 0_IsBadBuy
# 480
# NotRetrived
# 0_IsBadBuy
# 481
# NotRetrived
# 0_IsBadBuy
# 482
# NotRetrived
# 0_IsBadBuy
# 483
# NotRetrived
# 0_IsBadBuy
# 484
# NotRetrived
# 1_IsBadBuy
# 485
# NotRetrived
# 1_IsBadBuy
# 486
# NotRetrived
# 0_IsBadBuy
# 487
# NotRetrived
# 0_IsBadBuy
# 488
# NotRetrived
# 0_IsBadBuy
# 490
# NotRetrived
# 0_IsBadBuy
# 491
# NotRetrived
# 1_IsBadBuy
# 492
# NotRetrived
# 1_IsBadBuy
# 493
# NotRetrived
# 0_IsBadBuy
# 494
# NotRetrived
# 1_IsBadBuy
# 495
# NotRetrived
# 1_IsBadBuy
# 496
# NotRetrived
# 1_IsBadBuy
# 497
# NotRetrived
# 1_IsBadBuy
# 499
# NotRetrived
# 0_IsBadBuy
# 500
# NotRetrived
# 0_IsBadBuy
# 501
# NotRetrived
# 1_IsBadBuy
# 502
# NotRetrived
# 0_IsBadBuy
# 503
# NotRetrived
# 0_IsBadBuy
# 504
# NotRetrived
# 1_IsBadBuy
# 505
# NotRetrived
# 0_IsBadBuy
# 506
# NotRetrived
# 1_IsBadBuy
# 507
# NotRetrived
# 0_IsBadBuy
# 508
# NotRetrived
# 0_IsBadBuy
# 509
# NotRetrived
# 0_IsBadBuy
# 510
# NotRetrived
# 0_IsBadBuy
# 511
# NotRetrived
# 0_IsBadBuy
# 512
# NotRetrived
# 1_IsBadBuy
# 513
# NotRetrived
# 1_IsBadBuy
# 514
# NotRetrived
# 0_IsBadBuy
# 515
# NotRetrived
# 0_IsBadBuy
# 516
# NotRetrived
# 0_IsBadBuy
# 517
# NotRetrived
# 1_IsBadBuy
# 518
# NotRetrived
# 0_IsBadBuy
# 519
# NotRetrived
# 1_IsBadBuy
# 520
# NotRetrived
# 0_IsBadBuy
# 521
# NotRetrived
# 1_IsBadBuy
# 522
# NotRetrived
# 0_IsBadBuy
# 523
# NotRetrived
# 0_IsBadBuy
# 524
# NotRetrived
# 1_IsBadBuy
# 525
# NotRetrived
# 1_IsBadBuy
# 526
# NotRetrived
# 0_IsBadBuy
# 527
# NotRetrived
# 0_IsBadBuy
# 528
# NotRetrived
# 0_IsBadBuy
# 529
# NotRetrived
# 0_IsBadBuy
# 530
# NotRetrived
# 0_IsBadBuy
# 531
# NotRetrived
# 1_IsBadBuy
# 532
# NotRetrived
# 0_IsBadBuy
# 533
# NotRetrived
# 0_IsBadBuy
# 534
# NotRetrived
# 0_IsBadBuy
# 535
# NotRetrived
# 0_IsBadBuy
# 536
# NotRetrived
# 0_IsBadBuy
# 537
# NotRetrived
# 0_IsBadBuy
# 538
# NotRetrived
# 0_IsBadBuy
# 539
# NotRetrived
# 0_IsBadBuy
# 541
# NotRetrived
# 1_IsBadBuy
# 542
# NotRetrived
# 1_IsBadBuy
# 543
# NotRetrived
# 0_IsBadBuy
# 544
# NotRetrived
# 0_IsBadBuy
# 545
# NotRetrived
# 0_IsBadBuy
# 546
# NotRetrived
# 0_IsBadBuy
# 547
# NotRetrived
# 0_IsBadBuy
# 548
# NotRetrived
# 0_IsBadBuy
# 549
# NotRetrived
# 0_IsBadBuy
# 550
# NotRetrived
# 0_IsBadBuy
# 551
# NotRetrived
# 1_IsBadBuy
# 552
# NotRetrived
# 0_IsBadBuy
# 553
# NotRetrived
# 0_IsBadBuy
# 554
# NotRetrived
# 0_IsBadBuy
# 556
# NotRetrived
# 1_IsBadBuy
# 558
# NotRetrived
# 0_IsBadBuy
# 559
# NotRetrived
# 0_IsBadBuy
# 560
# NotRetrived
# 0_IsBadBuy
# 561
# NotRetrived
# 1_IsBadBuy
# 562
# NotRetrived
# 0_IsBadBuy
# 563
# NotRetrived
# 0_IsBadBuy
# 564
# NotRetrived
# 0_IsBadBuy
# 565
# NotRetrived
# 1_IsBadBuy
# 566
# NotRetrived
# 1_IsBadBuy
# 567
# NotRetrived
# 0_IsBadBuy
# 568
# NotRetrived
# 0_IsBadBuy
# 569
# NotRetrived
# 0_IsBadBuy
# 571
# NotRetrived
# 1_IsBadBuy
# 573
# NotRetrived
# 1_IsBadBuy
# 574
# NotRetrived
# 0_IsBadBuy
# 575
# NotRetrived
# 0_IsBadBuy
# 576
# NotRetrived
# 0_IsBadBuy
# 577
# NotRetrived
# 0_IsBadBuy
# 578
# NotRetrived
# 0_IsBadBuy
# 579
# NotRetrived
# 1_IsBadBuy
# 580
# NotRetrived
# 0_IsBadBuy
# 581
# NotRetrived
# 0_IsBadBuy
# 582
# NotRetrived
# 0_IsBadBuy
# 583
# NotRetrived
# 1_IsBadBuy
# 584
# NotRetrived
# 1_IsBadBuy
# 585
# NotRetrived
# 0_IsBadBuy
# 586
# NotRetrived
# 1_IsBadBuy
# 587
# NotRetrived
# 0_IsBadBuy
# 588
# NotRetrived
# 0_IsBadBuy
# 589
# NotRetrived
# 0_IsBadBuy
# 590
# NotRetrived
# 0_IsBadBuy
# 591
# NotRetrived
# 0_IsBadBuy
# 592
# NotRetrived
# 0_IsBadBuy
# 593
# NotRetrived
# 1_IsBadBuy
# 594
# NotRetrived
# 0_IsBadBuy
# 595
# NotRetrived
# 1_IsBadBuy
# 596
# NotRetrived
# 1_IsBadBuy
# 597
# NotRetrived
# 1_IsBadBuy
# 598
# NotRetrived
# 0_IsBadBuy
# 599
# NotRetrived
# 0_IsBadBuy
# 600
# NotRetrived
# 0_IsBadBuy
# 601
# NotRetrived
# 0_IsBadBuy
# 602
# NotRetrived
# 1_IsBadBuy
# 603
# NotRetrived
# 1_IsBadBuy
# 604
# NotRetrived
# 0_IsBadBuy
# 605
# NotRetrived
# 0_IsBadBuy
# 606
# NotRetrived
# 1_IsBadBuy
# 607
# NotRetrived
# 1_IsBadBuy
# 608
# NotRetrived
# 0_IsBadBuy
# 609
# NotRetrived
# 0_IsBadBuy
# 610
# NotRetrived
# 0_IsBadBuy
# 611
# NotRetrived
# 0_IsBadBuy
# 612
# NotRetrived
# 0_IsBadBuy
# 613
# NotRetrived
# 0_IsBadBuy
# 614
# NotRetrived
# 0_IsBadBuy
# 615
# NotRetrived
# 1_IsBadBuy
# 616
# NotRetrived
# 0_IsBadBuy
# 617
# NotRetrived
# 0_IsBadBuy
# 618
# NotRetrived
# 0_IsBadBuy
# 619
# NotRetrived
# 0_IsBadBuy
# 620
# NotRetrived
# 1_IsBadBuy
# 621
# NotRetrived
# 0_IsBadBuy
# 622
# NotRetrived
# 0_IsBadBuy
# 623
# NotRetrived
# 0_IsBadBuy
# 624
# NotRetrived
# 1_IsBadBuy
# 625
# NotRetrived
# 0_IsBadBuy
# 626
# NotRetrived
# 1_IsBadBuy
# 628
# NotRetrived
# 0_IsBadBuy
# 629
# NotRetrived
# 0_IsBadBuy
# 630
# NotRetrived
# 0_IsBadBuy
# 631
# NotRetrived
# 1_IsBadBuy
# 633
# NotRetrived
# 0_IsBadBuy
# 635
# NotRetrived
# 0_IsBadBuy
# 636
# NotRetrived
# 0_IsBadBuy
# 637
# NotRetrived
# 0_IsBadBuy
# 638
# NotRetrived
# 1_IsBadBuy
# 639
# NotRetrived
# 0_IsBadBuy
# 640
# NotRetrived
# 0_IsBadBuy
# 641
# NotRetrived
# 0_IsBadBuy
# 642
# NotRetrived
# 0_IsBadBuy
# 643
# NotRetrived
# 1_IsBadBuy
# 644
# NotRetrived
# 1_IsBadBuy
# 645
# NotRetrived
# 1_IsBadBuy
# 647
# NotRetrived
# 0_IsBadBuy
# 648
# NotRetrived
# 0_IsBadBuy
# 649
# NotRetrived
# 0_IsBadBuy
# 650
# NotRetrived
# 1_IsBadBuy
# 651
# NotRetrived
# 0_IsBadBuy
# 652
# NotRetrived
# 0_IsBadBuy
# 653
# NotRetrived
# 0_IsBadBuy
# 654
# NotRetrived
# 0_IsBadBuy
# 655
# NotRetrived
# 0_IsBadBuy
# 656
# NotRetrived
# 0_IsBadBuy
# 657
# NotRetrived
# 1_IsBadBuy
# 658
# NotRetrived
# 0_IsBadBuy
# 659
# NotRetrived
# 0_IsBadBuy
# 661
# NotRetrived
# 0_IsBadBuy
# 662
# NotRetrived
# 0_IsBadBuy
# 663
# NotRetrived
# 0_IsBadBuy
# 665
# NotRetrived
# 0_IsBadBuy
# 666
# NotRetrived
# 1_IsBadBuy
# 667
# NotRetrived
# 0_IsBadBuy
# 668
# NotRetrived
# 0_IsBadBuy
# 669
# NotRetrived
# 0_IsBadBuy
# 670
# NotRetrived
# 0_IsBadBuy
# 671
# NotRetrived
# 0_IsBadBuy
# 672
# NotRetrived
# 1_IsBadBuy
# 673
# NotRetrived
# 1_IsBadBuy
# 674
# NotRetrived
# 0_IsBadBuy
# 675
# NotRetrived
# 0_IsBadBuy
# 676
# NotRetrived
# 0_IsBadBuy
# 677
# NotRetrived
# 0_IsBadBuy
# 678
# NotRetrived
# 1_IsBadBuy
# 679
# NotRetrived
# 0_IsBadBuy
# 681
# NotRetrived
# 1_IsBadBuy
# 682
# NotRetrived
# 0_IsBadBuy
# 683
# NotRetrived
# 0_IsBadBuy
# 684
# NotRetrived
# 1_IsBadBuy
# 685
# NotRetrived
# 0_IsBadBuy
# 686
# NotRetrived
# 0_IsBadBuy
# 687
# NotRetrived
# 0_IsBadBuy
# 688
# NotRetrived
# 0_IsBadBuy
# 689
# NotRetrived
# 1_IsBadBuy
# 690
# NotRetrived
# 0_IsBadBuy
# 691
# NotRetrived
# 0_IsBadBuy
# 694
# NotRetrived
# 0_IsBadBuy
# 695
# NotRetrived
# 0_IsBadBuy
# 696
# NotRetrived
# 1_IsBadBuy
# 697
# NotRetrived
# 1_IsBadBuy
# 698
# NotRetrived
# 1_IsBadBuy
# 700
# NotRetrived
# 0_IsBadBuy
# 701
# NotRetrived
# 0_IsBadBuy
# 702
# NotRetrived
# 1_IsBadBuy
# 703
# NotRetrived
# 0_IsBadBuy
# 704
# NotRetrived
# 0_IsBadBuy
# 705
# NotRetrived
# 0_IsBadBuy
# 706
# NotRetrived
# 0_IsBadBuy
# 707
# NotRetrived
# 0_IsBadBuy
# 708
# NotRetrived
# 1_IsBadBuy
# 711
# NotRetrived
# 1_IsBadBuy
# 712
# NotRetrived
# 0_IsBadBuy
# 713
# NotRetrived
# 0_IsBadBuy
# 714
# NotRetrived
# 0_IsBadBuy
# 715
# NotRetrived
# 0_IsBadBuy
# 716
# NotRetrived
# 0_IsBadBuy
# 718
# NotRetrived
# 0_IsBadBuy
# 719
# NotRetrived
# 0_IsBadBuy
# 720
# NotRetrived
# 0_IsBadBuy
# 721
# NotRetrived
# 0_IsBadBuy
# 722
# NotRetrived
# 0_IsBadBuy
# 723
# NotRetrived
# 0_IsBadBuy
# 725
# NotRetrived
# 0_IsBadBuy
# 726
# NotRetrived
# 0_IsBadBuy
# 727
# NotRetrived
# 0_IsBadBuy
# 728
# NotRetrived
# 0_IsBadBuy
# 729
# NotRetrived
# 0_IsBadBuy
# 730
# NotRetrived
# 0_IsBadBuy
# 731
# NotRetrived
# 0_IsBadBuy
# 733
# NotRetrived
# 0_IsBadBuy
# 734
# NotRetrived
# 0_IsBadBuy
# 735
# NotRetrived
# 0_IsBadBuy
# 736
# NotRetrived
# 0_IsBadBuy
# 737
# NotRetrived
# 0_IsBadBuy
# 738
# NotRetrived
# 0_IsBadBuy
# 739
# NotRetrived
# 1_IsBadBuy
# 740
# NotRetrived
# 0_IsBadBuy
# 741
# NotRetrived
# 0_IsBadBuy
# 742
# NotRetrived
# 0_IsBadBuy
# 743
# NotRetrived
# 1_IsBadBuy
# 744
# NotRetrived
# 0_IsBadBuy
# 745
# NotRetrived
# 1_IsBadBuy
# 746
# NotRetrived
# 0_IsBadBuy
# 747
# NotRetrived
# 0_IsBadBuy
# 748
# NotRetrived
# 0_IsBadBuy
# 749
# NotRetrived
# 0_IsBadBuy
# 750
# NotRetrived
# 1_IsBadBuy
# 751
# NotRetrived
# 1_IsBadBuy
# 752
# NotRetrived
# 0_IsBadBuy
# 753
# NotRetrived
# 1_IsBadBuy
# 754
# NotRetrived
# 0_IsBadBuy
# 755
# NotRetrived
# 1_IsBadBuy
# 756
# NotRetrived
# 0_IsBadBuy
# 757
# NotRetrived
# 1_IsBadBuy
# 758
# NotRetrived
# 0_IsBadBuy
# 760
# NotRetrived
# 0_IsBadBuy
# 761
# NotRetrived
# 0_IsBadBuy
# 762
# NotRetrived
# 0_IsBadBuy
# 763
# NotRetrived
# 0_IsBadBuy
# 764
# NotRetrived
# 0_IsBadBuy
# 765
# NotRetrived
# 1_IsBadBuy
# 766
# NotRetrived
# 0_IsBadBuy
# 767
# NotRetrived
# 0_IsBadBuy
# 768
# NotRetrived
# 0_IsBadBuy
# 769
# NotRetrived
# 0_IsBadBuy
# 770
# NotRetrived
# 0_IsBadBuy
# 771
# NotRetrived
# 0_IsBadBuy
# 772
# NotRetrived
# 0_IsBadBuy
# 773
# NotRetrived
# 1_IsBadBuy
# 774
# NotRetrived
# 0_IsBadBuy
# 775
# NotRetrived
# 0_IsBadBuy
# 776
# NotRetrived
# 1_IsBadBuy
# 777
# NotRetrived
# 0_IsBadBuy
# 778
# NotRetrived
# 1_IsBadBuy
# 779
# NotRetrived
# 0_IsBadBuy
# 780
# NotRetrived
# 1_IsBadBuy
# 782
# NotRetrived
# 0_IsBadBuy
# 784
# NotRetrived
# 0_IsBadBuy
# 785
# NotRetrived
# 1_IsBadBuy
# 786
# NotRetrived
# 1_IsBadBuy
# 787
# NotRetrived
# 1_IsBadBuy
# 789
# NotRetrived
# 0_IsBadBuy
# 790
# NotRetrived
# 0_IsBadBuy
# 791
# NotRetrived
# 0_IsBadBuy
# 792
# NotRetrived
# 0_IsBadBuy
# 793
# NotRetrived
# 0_IsBadBuy
# 794
# NotRetrived
# 0_IsBadBuy
# 796
# NotRetrived
# 0_IsBadBuy
# 797
# NotRetrived
# 1_IsBadBuy
# 799
# NotRetrived
# 0_IsBadBuy
# 800
# NotRetrived
# 0_IsBadBuy
# 801
# NotRetrived
# 0_IsBadBuy
# 802
# NotRetrived
# 1_IsBadBuy
# 803
# NotRetrived
# 0_IsBadBuy
# 804
# NotRetrived
# 1_IsBadBuy
# 805
# NotRetrived
# 0_IsBadBuy
# 806
# NotRetrived
# 1_IsBadBuy
# 807
# NotRetrived
# 1_IsBadBuy
# 808
# NotRetrived
# 0_IsBadBuy
# 809
# NotRetrived
# 0_IsBadBuy
# 810
# NotRetrived
# 0_IsBadBuy
# 811
# NotRetrived
# 1_IsBadBuy
# 812
# NotRetrived
# 0_IsBadBuy
# 813
# NotRetrived
# 0_IsBadBuy
# 814
# NotRetrived
# 0_IsBadBuy
# 816
# NotRetrived
# 0_IsBadBuy
# 817
# NotRetrived
# 0_IsBadBuy
# 818
# NotRetrived
# 0_IsBadBuy
# 819
# NotRetrived
# 0_IsBadBuy
# 820
# NotRetrived
# 0_IsBadBuy
# 821
# NotRetrived
# 0_IsBadBuy
# 822
# NotRetrived
# 1_IsBadBuy
# 823
# NotRetrived
# 0_IsBadBuy
# 824
# NotRetrived
# 0_IsBadBuy
# 825
# NotRetrived
# 1_IsBadBuy
# 826
# NotRetrived
# 1_IsBadBuy
# 827
# NotRetrived
# 0_IsBadBuy
# 828
# NotRetrived
# 1_IsBadBuy
# 829
# NotRetrived
# 0_IsBadBuy
# 831
# NotRetrived
# 0_IsBadBuy
# 832
# NotRetrived
# 0_IsBadBuy
# 834
# NotRetrived
# 0_IsBadBuy
# 835
# NotRetrived
# 0_IsBadBuy
# 836
# NotRetrived
# 0_IsBadBuy
# 837
# NotRetrived
# 1_IsBadBuy
# 838
# NotRetrived
# 0_IsBadBuy
# 839
# NotRetrived
# 0_IsBadBuy
# 840
# NotRetrived
# 1_IsBadBuy
# 841
# NotRetrived
# 0_IsBadBuy
# 842
# NotRetrived
# 0_IsBadBuy
# 843
# NotRetrived
# 0_IsBadBuy
# 844
# NotRetrived
# 0_IsBadBuy
# 845
# NotRetrived
# 1_IsBadBuy
# 846
# NotRetrived
# 0_IsBadBuy
# 847
# NotRetrived
# 1_IsBadBuy
# 848
# NotRetrived
# 0_IsBadBuy
# 849
# NotRetrived
# 0_IsBadBuy
# 850
# NotRetrived
# 0_IsBadBuy
# 851
# NotRetrived
# 0_IsBadBuy
# 852
# NotRetrived
# 0_IsBadBuy
# 853
# NotRetrived
# 0_IsBadBuy
# 854
# NotRetrived
# 1_IsBadBuy
# 855
# NotRetrived
# 0_IsBadBuy
# 856
# NotRetrived
# 0_IsBadBuy
# 857
# NotRetrived
# 0_IsBadBuy
# 858
# NotRetrived
# 0_IsBadBuy
# 859
# NotRetrived
# 0_IsBadBuy
# 860
# NotRetrived
# 0_IsBadBuy
# 861
# NotRetrived
# 0_IsBadBuy
# 862
# NotRetrived
# 1_IsBadBuy
# 863
# NotRetrived
# 0_IsBadBuy
# 865
# NotRetrived
# 0_IsBadBuy
# 867
# NotRetrived
# 0_IsBadBuy
# 868
# NotRetrived
# 0_IsBadBuy
# 869
# NotRetrived
# 0_IsBadBuy
# 870
# NotRetrived
# 0_IsBadBuy
# 871
# NotRetrived
# 1_IsBadBuy
# 872
# NotRetrived
# 0_IsBadBuy
# 873
# NotRetrived
# 1_IsBadBuy
# 874
# NotRetrived
# 1_IsBadBuy
# 875
# NotRetrived
# 1_IsBadBuy
# 876
# NotRetrived
# 0_IsBadBuy
# 877
# NotRetrived
# 0_IsBadBuy
# 878
# NotRetrived
# 0_IsBadBuy
# 879
# NotRetrived
# 0_IsBadBuy
# 880
# NotRetrived
# 0_IsBadBuy
# 881
# NotRetrived
# 1_IsBadBuy
# 882
# NotRetrived
# 0_IsBadBuy
# 883
# NotRetrived
# 0_IsBadBuy
# 884
# NotRetrived
# 0_IsBadBuy
# 885
# NotRetrived
# 1_IsBadBuy
# 886
# NotRetrived
# 0_IsBadBuy
# 887
# NotRetrived
# 0_IsBadBuy
# 888
# NotRetrived
# 0_IsBadBuy
# 889
# NotRetrived
# 0_IsBadBuy
# 890
# NotRetrived
# 0_IsBadBuy
# 891
# NotRetrived
# 1_IsBadBuy
# 892
# NotRetrived
# 0_IsBadBuy
# 893
# NotRetrived
# 0_IsBadBuy
# 894
# NotRetrived
# 1_IsBadBuy
# 897
# NotRetrived
# 0_IsBadBuy
# 898
# NotRetrived
# 0_IsBadBuy
# 900
# NotRetrived
# 0_IsBadBuy
# 901
# NotRetrived
# 0_IsBadBuy
# 902
# NotRetrived
# 0_IsBadBuy
# 903
# NotRetrived
# 0_IsBadBuy
# 904
# NotRetrived
# 0_IsBadBuy
# 905
# NotRetrived
# 0_IsBadBuy
# 906
# NotRetrived
# 0_IsBadBuy
# 907
# NotRetrived
# 1_IsBadBuy
# 908
# NotRetrived
# 0_IsBadBuy
# 909
# NotRetrived
# 0_IsBadBuy
# 910
# NotRetrived
# 0_IsBadBuy
# 911
# NotRetrived
# 0_IsBadBuy
# 912
# NotRetrived
# 0_IsBadBuy
# 913
# NotRetrived
# 0_IsBadBuy
# 914
# NotRetrived
# 1_IsBadBuy
# 915
# NotRetrived
# 0_IsBadBuy
# 916
# NotRetrived
# 1_IsBadBuy
# 917
# NotRetrived
# 0_IsBadBuy
# 918
# NotRetrived
# 1_IsBadBuy
# 919
# NotRetrived
# 0_IsBadBuy
# 920
# NotRetrived
# 1_IsBadBuy
# 921
# NotRetrived
# 0_IsBadBuy
# 922
# NotRetrived
# 0_IsBadBuy
# 923
# NotRetrived
# 0_IsBadBuy
# 924
# NotRetrived
# 0_IsBadBuy
# 926
# NotRetrived
# 0_IsBadBuy
# 927
# NotRetrived
# 1_IsBadBuy
# 928
# NotRetrived
# 0_IsBadBuy
# 930
# NotRetrived
# 0_IsBadBuy
# 931
# NotRetrived
# 1_IsBadBuy
# 932
# NotRetrived
# 0_IsBadBuy
# 933
# NotRetrived
# 0_IsBadBuy
# 934
# NotRetrived
# 0_IsBadBuy
# 935
# NotRetrived
# 1_IsBadBuy
# 936
# NotRetrived
# 1_IsBadBuy
# 937
# NotRetrived
# 0_IsBadBuy
# 938
# NotRetrived
# 0_IsBadBuy
# 939
# NotRetrived
# 0_IsBadBuy
# 940
# NotRetrived
# 0_IsBadBuy
# 941
# NotRetrived
# 0_IsBadBuy
# 942
# NotRetrived
# 0_IsBadBuy
# 943
# NotRetrived
# 0_IsBadBuy
# 944
# NotRetrived
# 0_IsBadBuy
# 945
# NotRetrived
# 0_IsBadBuy
# 946
# NotRetrived
# 0_IsBadBuy
# 947
# NotRetrived
# 0_IsBadBuy
# 948
# NotRetrived
# 1_IsBadBuy
# 949
# NotRetrived
# 1_IsBadBuy
# 950
# NotRetrived
# 0_IsBadBuy
# 951
# NotRetrived
# 0_IsBadBuy
# 952
# NotRetrived
# 0_IsBadBuy
# 953
# NotRetrived
# 1_IsBadBuy
# 954
# NotRetrived
# 0_IsBadBuy
# 955
# NotRetrived
# 0_IsBadBuy
# 956
# NotRetrived
# 0_IsBadBuy
# 958
# NotRetrived
# 0_IsBadBuy
# 960
# NotRetrived
# 0_IsBadBuy
# 961
# NotRetrived
# 0_IsBadBuy
# 965
# NotRetrived
# 0_IsBadBuy
# 966
# NotRetrived
# 0_IsBadBuy
# 967
# NotRetrived
# 1_IsBadBuy
# 968
# NotRetrived
# 0_IsBadBuy
# 969
# NotRetrived
# 1_IsBadBuy
# 970
# NotRetrived
# 1_IsBadBuy
# 971
# NotRetrived
# 0_IsBadBuy
# 972
# NotRetrived
# 0_IsBadBuy
# 973
# NotRetrived
# 1_IsBadBuy
# 974
# NotRetrived
# 0_IsBadBuy
# 975
# NotRetrived
# 0_IsBadBuy
# 976
# NotRetrived
# 0_IsBadBuy
# 977
# NotRetrived
# 0_IsBadBuy
# 978
# NotRetrived
# 0_IsBadBuy
# 979
# NotRetrived
# 0_IsBadBuy
# 980
# NotRetrived
# 0_IsBadBuy
# 981
# NotRetrived
# 0_IsBadBuy
# 982
# NotRetrived
# 0_IsBadBuy
# 984
# NotRetrived
# 0_IsBadBuy
# 985
# NotRetrived
# 0_IsBadBuy
# 986
# NotRetrived
# 0_IsBadBuy
# 987
# NotRetrived
# 0_IsBadBuy
# 988
# NotRetrived
# 0_IsBadBuy
# 989
# NotRetrived
# 1_IsBadBuy
# 990
# NotRetrived
# 1_IsBadBuy
# 991
# NotRetrived
# 0_IsBadBuy
# 992
# NotRetrived
# 0_IsBadBuy
# 993
# NotRetrived
# 0_IsBadBuy
# 994
# NotRetrived
# 1_IsBadBuy
# 995
# NotRetrived
# 1_IsBadBuy
# 996
# NotRetrived
# 0_IsBadBuy
# 997
# NotRetrived
# 1_IsBadBuy
# 998
# NotRetrived
# 1_IsBadBuy
# 999
# NotRetrived
# 0_IsBadBuy
# 1000
# NotRetrived
# 0_IsBadBuy
# 1001
# NotRetrived
# 0_IsBadBuy
# 1003
# NotRetrived
# 0_IsBadBuy
# 1004
# NotRetrived
# 1_IsBadBuy
# 1005
# NotRetrived
# 0_IsBadBuy
# 1006
# NotRetrived
# 0_IsBadBuy
# 1007
# NotRetrived
# 0_IsBadBuy
# 1008
# NotRetrived
# 0_IsBadBuy
# 1010
# NotRetrived
# 0_IsBadBuy
# 1011
# NotRetrived
# 0_IsBadBuy
# 1012
# NotRetrived
# 0_IsBadBuy
# 1013
# NotRetrived
# 1_IsBadBuy
# 1014
# NotRetrived
# 0_IsBadBuy
# 1015
# NotRetrived
# 1_IsBadBuy
# 1016
# NotRetrived
# 1_IsBadBuy
# 1017
# NotRetrived
# 0_IsBadBuy
# 1018
# NotRetrived
# 0_IsBadBuy
# 1019
# NotRetrived
# 0_IsBadBuy
# 1020
# NotRetrived
# 1_IsBadBuy
# 1021
# NotRetrived
# 0_IsBadBuy
# 1022
# NotRetrived
# 1_IsBadBuy
# 1023
# NotRetrived
# 1_IsBadBuy
# 1024
# NotRetrived
# 0_IsBadBuy
# 1025
# NotRetrived
# 1_IsBadBuy
# 1026
# NotRetrived
# 0_IsBadBuy
# 1027
# NotRetrived
# 0_IsBadBuy
# 1028
# NotRetrived
# 1_IsBadBuy
# 1029
# NotRetrived
# 0_IsBadBuy
# 1030
# NotRetrived
# 1_IsBadBuy
# 1031
# NotRetrived
# 0_IsBadBuy
# 1033
# NotRetrived
# 0_IsBadBuy
# 1034
# NotRetrived
# 0_IsBadBuy
# 1035
# NotRetrived
# 1_IsBadBuy
# 1036
# NotRetrived
# 0_IsBadBuy
# 1037
# NotRetrived
# 0_IsBadBuy
# 1038
# NotRetrived
# 1_IsBadBuy
# 1039
# NotRetrived
# 1_IsBadBuy
# 1040
# NotRetrived
# 0_IsBadBuy
# 1041
# NotRetrived
# 1_IsBadBuy
# 1042
# NotRetrived
# 0_IsBadBuy
# 1043
# NotRetrived
# 1_IsBadBuy
# 1044
# NotRetrived
# 1_IsBadBuy
# 1046
# NotRetrived
# 1_IsBadBuy
# 1047
# NotRetrived
# 0_IsBadBuy
# 1048
# NotRetrived
# 0_IsBadBuy
# 1049
# NotRetrived
# 0_IsBadBuy
# 1050
# NotRetrived
# 0_IsBadBuy
# 1051
# NotRetrived
# 0_IsBadBuy
# 1052
# NotRetrived
# 0_IsBadBuy
# 1053
# NotRetrived
# 1_IsBadBuy
# 1054
# NotRetrived
# 0_IsBadBuy
# 1055
# NotRetrived
# 1_IsBadBuy
# 1056
# NotRetrived
# 0_IsBadBuy
# 1057
# NotRetrived
# 0_IsBadBuy
# 1058
# NotRetrived
# 0_IsBadBuy
# 1059
# NotRetrived
# 0_IsBadBuy
# 1060
# NotRetrived
# 0_IsBadBuy
# 1061
# NotRetrived
# 0_IsBadBuy
# 1062
# NotRetrived
# 0_IsBadBuy
# 1063
# NotRetrived
# 0_IsBadBuy
# 1065
# NotRetrived
# 1_IsBadBuy
# 1066
# NotRetrived
# 0_IsBadBuy
# 1067
# NotRetrived
# 0_IsBadBuy
# 1068
# NotRetrived
# 1_IsBadBuy
# 1069
# NotRetrived
# 0_IsBadBuy
# 1070
# NotRetrived
# 0_IsBadBuy
# 1071
# NotRetrived
# 0_IsBadBuy
# 1072
# NotRetrived
# 0_IsBadBuy
# 1073
# NotRetrived
# 1_IsBadBuy
# 1074
# NotRetrived
# 0_IsBadBuy
# 1075
# NotRetrived
# 0_IsBadBuy
# 1076
# NotRetrived
# 0_IsBadBuy
# 1077
# NotRetrived
# 1_IsBadBuy
# 1078
# NotRetrived
# 0_IsBadBuy
# 1080
# NotRetrived
# 0_IsBadBuy
# 1081
# NotRetrived
# 0_IsBadBuy
# 1082
# NotRetrived
# 0_IsBadBuy
# 1083
# NotRetrived
# 0_IsBadBuy
# 1084
# NotRetrived
# 1_IsBadBuy
# 1085
# NotRetrived
# 0_IsBadBuy
# 1086
# NotRetrived
# 0_IsBadBuy
# 1087
# NotRetrived
# 0_IsBadBuy
# 1088
# NotRetrived
# 0_IsBadBuy
# 1089
# NotRetrived
# 0_IsBadBuy
# 1090
# NotRetrived
# 0_IsBadBuy
# 1091
# NotRetrived
# 0_IsBadBuy
# 1092
# NotRetrived
# 0_IsBadBuy
# 1093
# NotRetrived
# 0_IsBadBuy
# 1094
# NotRetrived
# 1_IsBadBuy
# 1095
# NotRetrived
# 0_IsBadBuy
# 1097
# NotRetrived
# 0_IsBadBuy
# 1099
# NotRetrived
# 1_IsBadBuy
# 1100
# NotRetrived
# 0_IsBadBuy
# 1101
# NotRetrived
# 1_IsBadBuy
# 1102
# NotRetrived
# 0_IsBadBuy
# 1103
# NotRetrived
# 0_IsBadBuy
# 1104
# NotRetrived
# 0_IsBadBuy
# 1105
# NotRetrived
# 0_IsBadBuy
# 1106
# NotRetrived
# 0_IsBadBuy
# 1107
# NotRetrived
# 0_IsBadBuy
# 1108
# NotRetrived
# 0_IsBadBuy
# 1109
# NotRetrived
# 0_IsBadBuy
# 1110
# NotRetrived
# 1_IsBadBuy
# 1111
# NotRetrived
# 0_IsBadBuy
# 1112
# NotRetrived
# 0_IsBadBuy
# 1113
# NotRetrived
# 0_IsBadBuy
# 1114
# NotRetrived
# 0_IsBadBuy
# 1115
# NotRetrived
# 0_IsBadBuy
# 1116
# NotRetrived
# 1_IsBadBuy
# 1118
# NotRetrived
# 0_IsBadBuy
# 1119
# NotRetrived
# 0_IsBadBuy
# 1120
# NotRetrived
# 0_IsBadBuy
# 1122
# NotRetrived
# 0_IsBadBuy
# 1124
# NotRetrived
# 0_IsBadBuy
# 1125
# NotRetrived
# 0_IsBadBuy
# 1126
# NotRetrived
# 0_IsBadBuy
# 1127
# NotRetrived
# 0_IsBadBuy
# 1128
# NotRetrived
# 1_IsBadBuy
# 1129
# NotRetrived
# 0_IsBadBuy
# 1130
# NotRetrived
# 0_IsBadBuy
# 1131
# NotRetrived
# 0_IsBadBuy
# 1132
# NotRetrived
# 1_IsBadBuy
# 1134
# NotRetrived
# 1_IsBadBuy
# 1135
# NotRetrived
# 0_IsBadBuy
# 1136
# NotRetrived
# 0_IsBadBuy
# 1137
# NotRetrived
# 1_IsBadBuy
# 1138
# NotRetrived
# 0_IsBadBuy
# 1139
# NotRetrived
# 1_IsBadBuy
# 1140
# NotRetrived
# 1_IsBadBuy
# 1141
# NotRetrived
# 0_IsBadBuy
# 1142
# NotRetrived
# 0_IsBadBuy
# 1143
# NotRetrived
# 0_IsBadBuy
# 1144
# NotRetrived
# 0_IsBadBuy
# 1145
# NotRetrived
# 0_IsBadBuy
# 1146
# NotRetrived
# 0_IsBadBuy
# 1147
# NotRetrived
# 0_IsBadBuy
# 1148
# NotRetrived
# 0_IsBadBuy
# 1149
# NotRetrived
# 0_IsBadBuy
# 1150
# NotRetrived
# 0_IsBadBuy
# 1151
# NotRetrived
# 0_IsBadBuy
# 1152
# NotRetrived
# 0_IsBadBuy
# 1153
# NotRetrived
# 0_IsBadBuy
# 1154
# NotRetrived
# 0_IsBadBuy
# 1155
# NotRetrived
# 1_IsBadBuy
# 1156
# NotRetrived
# 0_IsBadBuy
# 1157
# NotRetrived
# 0_IsBadBuy
# 1158
# NotRetrived
# 1_IsBadBuy
# 1159
# NotRetrived
# 1_IsBadBuy
# 1160
# NotRetrived
# 1_IsBadBuy
# 1161
# NotRetrived
# 0_IsBadBuy
# 1162
# NotRetrived
# 0_IsBadBuy
# 1163
# NotRetrived
# 0_IsBadBuy
# 1164
# NotRetrived
# 0_IsBadBuy
# 1166
# NotRetrived
# 0_IsBadBuy
# 1167
# NotRetrived
# 1_IsBadBuy
# 1168
# NotRetrived
# 0_IsBadBuy
# 1170
# NotRetrived
# 1_IsBadBuy
# 1171
# NotRetrived
# 0_IsBadBuy
# 1172
# NotRetrived
# 0_IsBadBuy
# 1173
# NotRetrived
# 0_IsBadBuy
# 1175
# NotRetrived
# 0_IsBadBuy
# 1176
# NotRetrived
# 0_IsBadBuy
# 1179
# NotRetrived
# 0_IsBadBuy
# 1180
# NotRetrived
# 0_IsBadBuy
# 1181
# NotRetrived
# 0_IsBadBuy
# 1182
# NotRetrived
# 0_IsBadBuy
# 1183
# NotRetrived
# 0_IsBadBuy
# 1184
# NotRetrived
# 0_IsBadBuy
# 1185
# NotRetrived
# 0_IsBadBuy
# 1187
# NotRetrived
# 0_IsBadBuy
# 1188
# NotRetrived
# 1_IsBadBuy
# 1189
# NotRetrived
# 0_IsBadBuy
# 1190
# NotRetrived
# 1_IsBadBuy
# 1191
# NotRetrived
# 0_IsBadBuy
# 1192
# NotRetrived
# 1_IsBadBuy
# 1193
# NotRetrived
# 1_IsBadBuy
# 1194
# NotRetrived
# 1_IsBadBuy
# 1195
# NotRetrived
# 0_IsBadBuy
# 1198
# NotRetrived
# 0_IsBadBuy
# 1199
# NotRetrived
# 0_IsBadBuy
# 1200
# NotRetrived
# 0_IsBadBuy
# 1201
# NotRetrived
# 0_IsBadBuy
# 1202
# NotRetrived
# 0_IsBadBuy
# 1203
# NotRetrived
# 0_IsBadBuy
# 1204
# NotRetrived
# 0_IsBadBuy
# 1205
# NotRetrived
# 0_IsBadBuy
# 1206
# NotRetrived
# 0_IsBadBuy
# 1207
# NotRetrived
# 0_IsBadBuy
# 1208
# NotRetrived
# 0_IsBadBuy
# 1209
# NotRetrived
# 0_IsBadBuy
# 1210
# NotRetrived
# 0_IsBadBuy
# 1211
# NotRetrived
# 1_IsBadBuy
# 1212
# NotRetrived
# 0_IsBadBuy
# 1214
# NotRetrived
# 1_IsBadBuy
# 1215
# NotRetrived
# 0_IsBadBuy
# 1216
# NotRetrived
# 1_IsBadBuy
# 1217
# NotRetrived
# 0_IsBadBuy
# 1218
# NotRetrived
# 0_IsBadBuy
# 1219
# NotRetrived
# 0_IsBadBuy
# 1220
# NotRetrived
# 0_IsBadBuy
# 1221
# NotRetrived
# 0_IsBadBuy
# 1223
# NotRetrived
# 0_IsBadBuy
# 1224
# NotRetrived
# 0_IsBadBuy
# 1225
# NotRetrived
# 1_IsBadBuy
# 1227
# NotRetrived
# 0_IsBadBuy
# 1228
# NotRetrived
# 1_IsBadBuy
# 1229
# NotRetrived
# 1_IsBadBuy
# 1230
# NotRetrived
# 0_IsBadBuy
# 1232
# NotRetrived
# 1_IsBadBuy
# 1233
# NotRetrived
# 0_IsBadBuy
# 1234
# NotRetrived
# 0_IsBadBuy
# 1235
# NotRetrived
# 0_IsBadBuy
# 1236
# NotRetrived
# 0_IsBadBuy
# 1238
# NotRetrived
# 0_IsBadBuy
# 1239
# NotRetrived
# 0_IsBadBuy
# 1240
# NotRetrived
# 0_IsBadBuy
# 1241
# NotRetrived
# 1_IsBadBuy
# 1242
# NotRetrived
# 0_IsBadBuy
# 1243
# NotRetrived
# 0_IsBadBuy
# 1245
# NotRetrived
# 0_IsBadBuy
# 1247
# NotRetrived
# 0_IsBadBuy
# 1248
# NotRetrived
# 0_IsBadBuy
# 1249
# NotRetrived
# 1_IsBadBuy
# 1250
# NotRetrived
# 0_IsBadBuy
# 1251
# NotRetrived
# 0_IsBadBuy
# 1252
# NotRetrived
# 0_IsBadBuy
# 1253
# NotRetrived
# 0_IsBadBuy
# 1254
# NotRetrived
# 1_IsBadBuy
# 1255
# NotRetrived
# 1_IsBadBuy
# 1256
# NotRetrived
# 0_IsBadBuy
# 1257
# NotRetrived
# 0_IsBadBuy
# 1258
# NotRetrived
# 0_IsBadBuy
# 1259
# NotRetrived
# 0_IsBadBuy
# 1260
# NotRetrived
# 0_IsBadBuy
# 1261
# NotRetrived
# 0_IsBadBuy
# 1262
# NotRetrived
# 0_IsBadBuy
# 1263
# NotRetrived
# 1_IsBadBuy
# 1264
# NotRetrived
# 0_IsBadBuy
# 1265
# NotRetrived
# 0_IsBadBuy
# 1266
# NotRetrived
# 0_IsBadBuy
# 1267
# NotRetrived
# 0_IsBadBuy
# 1268
# NotRetrived
# 1_IsBadBuy
# 1269
# NotRetrived
# 0_IsBadBuy
# 1270
# NotRetrived
# 1_IsBadBuy
# 1271
# NotRetrived
# 0_IsBadBuy
# 1272
# NotRetrived
# 1_IsBadBuy
# 1273
# NotRetrived
# 0_IsBadBuy
# 1274
# NotRetrived
# 0_IsBadBuy
# 1275
# NotRetrived
# 0_IsBadBuy
# 1276
# NotRetrived
# 0_IsBadBuy
# 1277
# NotRetrived
# 0_IsBadBuy
# 1278
# NotRetrived
# 0_IsBadBuy
# 1279
# NotRetrived
# 0_IsBadBuy
# 1280
# NotRetrived
# 0_IsBadBuy
# 1281
# NotRetrived
# 0_IsBadBuy
# 1282
# NotRetrived
# 0_IsBadBuy
# 1283
# NotRetrived
# 0_IsBadBuy
# 1284
# NotRetrived
# 1_IsBadBuy
# 1285
# NotRetrived
# 0_IsBadBuy
# 1286
# NotRetrived
# 0_IsBadBuy
# 1287
# NotRetrived
# 0_IsBadBuy
# 1288
# NotRetrived
# 1_IsBadBuy
# 1289
# NotRetrived
# 1_IsBadBuy
# 1290
# NotRetrived
# 1_IsBadBuy
# 1291
# NotRetrived
# 1_IsBadBuy
# 1292
# NotRetrived
# 0_IsBadBuy
# 1293
# NotRetrived
# 1_IsBadBuy
# 1294
# NotRetrived
# 0_IsBadBuy
# 1295
# NotRetrived
# 0_IsBadBuy
# 1296
# NotRetrived
# 0_IsBadBuy
# 1297
# NotRetrived
# 0_IsBadBuy
# 1299
# NotRetrived
# 1_IsBadBuy
# 1300
# NotRetrived
# 1_IsBadBuy
# 1301
# NotRetrived
# 0_IsBadBuy
# 1302
# NotRetrived
# 0_IsBadBuy
# 1303
# NotRetrived
# 1_IsBadBuy
# 1304
# NotRetrived
# 1_IsBadBuy
# 1305
# NotRetrived
# 1_IsBadBuy
# 1306
# NotRetrived
# 0_IsBadBuy
# 1307
# NotRetrived
# 1_IsBadBuy
# 1308
# NotRetrived
# 1_IsBadBuy
# 1309
# NotRetrived
# 1_IsBadBuy
# 1310
# NotRetrived
# 0_IsBadBuy
# 1312
# NotRetrived
# 0_IsBadBuy
# 1313
# NotRetrived
# 0_IsBadBuy
# 1315
# NotRetrived
# 0_IsBadBuy
# 1316
# NotRetrived
# 1_IsBadBuy
# 1317
# NotRetrived
# 0_IsBadBuy
# 1318
# NotRetrived
# 0_IsBadBuy
# 1319
# NotRetrived
# 1_IsBadBuy
# 1320
# NotRetrived
# 0_IsBadBuy
# 1321
# NotRetrived
# 0_IsBadBuy
# 1322
# NotRetrived
# 1_IsBadBuy
# 1324
# NotRetrived
# 0_IsBadBuy
# 1325
# NotRetrived
# 1_IsBadBuy
# 1326
# NotRetrived
# 0_IsBadBuy
# 1327
# NotRetrived
# 1_IsBadBuy
# 1328
# NotRetrived
# 0_IsBadBuy
# 1329
# NotRetrived
# 1_IsBadBuy
# 1330
# NotRetrived
# 0_IsBadBuy
# 1331
# NotRetrived
# 0_IsBadBuy
# 1332
# NotRetrived
# 0_IsBadBuy
# 1333
# NotRetrived
# 0_IsBadBuy
# 1334
# NotRetrived
# 1_IsBadBuy
# 1335
# NotRetrived
# 1_IsBadBuy
# 1336
# NotRetrived
# 0_IsBadBuy
# 1337
# NotRetrived
# 0_IsBadBuy
# 1338
# NotRetrived
# 1_IsBadBuy
# 1339
# NotRetrived
# 0_IsBadBuy
# 1340
# NotRetrived
# 0_IsBadBuy
# 1341
# NotRetrived
# 0_IsBadBuy
# 1342
# NotRetrived
# 1_IsBadBuy
# 1343
# NotRetrived
# 1_IsBadBuy
# 1344
# NotRetrived
# 1_IsBadBuy
# 1346
# NotRetrived
# 0_IsBadBuy
# 1347
# NotRetrived
# 0_IsBadBuy
# 1348
# NotRetrived
# 1_IsBadBuy
# 1349
# NotRetrived
# 1_IsBadBuy
# 1350
# NotRetrived
# 0_IsBadBuy
# 1351
# NotRetrived
# 0_IsBadBuy
# 1352
# NotRetrived
# 0_IsBadBuy
# 1353
# NotRetrived
# 0_IsBadBuy
# 1354
# NotRetrived
# 1_IsBadBuy
# 1355
# NotRetrived
# 1_IsBadBuy
# 1356
# NotRetrived
# 0_IsBadBuy
# 1357
# NotRetrived
# 0_IsBadBuy
# 1358
# NotRetrived
# 1_IsBadBuy
# 1359
# NotRetrived
# 0_IsBadBuy
# 1360
# NotRetrived
# 1_IsBadBuy
# 1361
# NotRetrived
# 0_IsBadBuy
# 1362
# NotRetrived
# 0_IsBadBuy
# 1363
# NotRetrived
# 0_IsBadBuy
# 1364
# NotRetrived
# 1_IsBadBuy
# 1365
# NotRetrived
# 0_IsBadBuy
# 1366
# NotRetrived
# 1_IsBadBuy
# 1367
# NotRetrived
# 0_IsBadBuy
# 1368
# NotRetrived
# 1_IsBadBuy
# 1369
# NotRetrived
# 0_IsBadBuy
# 1370
# NotRetrived
# 1_IsBadBuy
# 1371
# NotRetrived
# 1_IsBadBuy
# 1372
# NotRetrived
# 0_IsBadBuy
# 1373
# NotRetrived
# 0_IsBadBuy
# 1374
# NotRetrived
# 0_IsBadBuy
# 1375
# NotRetrived
# 0_IsBadBuy
# 1376
# NotRetrived
# 0_IsBadBuy
# 1377
# NotRetrived
# 0_IsBadBuy
# 1378
# NotRetrived
# 0_IsBadBuy
# 1379
# NotRetrived
# 0_IsBadBuy
# 1380
# NotRetrived
# 0_IsBadBuy
# 1381
# NotRetrived
# 0_IsBadBuy
# 1382
# NotRetrived
# 0_IsBadBuy
# 1383
# NotRetrived
# 0_IsBadBuy
# 1384
# NotRetrived
# 0_IsBadBuy
# 1385
# NotRetrived
# 0_IsBadBuy
# 1386
# NotRetrived
# 0_IsBadBuy
# 1387
# NotRetrived
# 0_IsBadBuy
# 1388
# NotRetrived
# 0_IsBadBuy
# 1389
# NotRetrived
# 0_IsBadBuy
# 1390
# NotRetrived
# 0_IsBadBuy
# 1392
# NotRetrived
# 0_IsBadBuy
# 1393
# NotRetrived
# 0_IsBadBuy
# 1394
# NotRetrived
# 0_IsBadBuy
# 1395
# NotRetrived
# 1_IsBadBuy
# 1396
# NotRetrived
# 0_IsBadBuy
# 1397
# NotRetrived
# 1_IsBadBuy
# 1398
# NotRetrived
# 1_IsBadBuy
# 1399
# NotRetrived
# 1_IsBadBuy
# 1400
# NotRetrived
# 0_IsBadBuy
# 1401
# NotRetrived
# 0_IsBadBuy
# 1403
# NotRetrived
# 0_IsBadBuy
# 1404
# NotRetrived
# 0_IsBadBuy
# 1405
# NotRetrived
# 0_IsBadBuy
# 1406
# NotRetrived
# 1_IsBadBuy
# 1407
# NotRetrived
# 0_IsBadBuy
# 1408
# NotRetrived
# 0_IsBadBuy
# 1410
# NotRetrived
# 1_IsBadBuy
# 1411
# NotRetrived
# 0_IsBadBuy
# 1412
# NotRetrived
# 0_IsBadBuy
# 1413
# NotRetrived
# 0_IsBadBuy
# 1414
# NotRetrived
# 1_IsBadBuy
# 1415
# NotRetrived
# 0_IsBadBuy
# 1416
# NotRetrived
# 0_IsBadBuy
# 1417
# NotRetrived
# 0_IsBadBuy
# 1418
# NotRetrived
# 0_IsBadBuy
# 1419
# NotRetrived
# 0_IsBadBuy
# 1420
# NotRetrived
# 0_IsBadBuy
# 1421
# NotRetrived
# 0_IsBadBuy
# 1422
# NotRetrived
# 0_IsBadBuy
# 1423
# NotRetrived
# 0_IsBadBuy
# 1424
# NotRetrived
# 0_IsBadBuy
# 1425
# NotRetrived
# 0_IsBadBuy
# 1426
# NotRetrived
# 0_IsBadBuy
# 1427
# NotRetrived
# 0_IsBadBuy
# 1428
# NotRetrived
# 0_IsBadBuy
# 1429
# NotRetrived
# 1_IsBadBuy
# 1430
# NotRetrived
# 1_IsBadBuy
# 1431
# NotRetrived
# 0_IsBadBuy
# 1432
# NotRetrived
# 1_IsBadBuy
# 1433
# NotRetrived
# 0_IsBadBuy
# 1434
# NotRetrived
# 1_IsBadBuy
# 1435
# NotRetrived
# 1_IsBadBuy
# 1436
# NotRetrived
# 0_IsBadBuy
# 1437
# NotRetrived
# 0_IsBadBuy
# 1438
# NotRetrived
# 0_IsBadBuy
# 1439
# NotRetrived
# 0_IsBadBuy
# 1440
# NotRetrived
# 0_IsBadBuy
# 1441
# NotRetrived
# 0_IsBadBuy
# 1442
# NotRetrived
# 1_IsBadBuy
# 1443
# NotRetrived
# 0_IsBadBuy
# 1444
# NotRetrived
# 0_IsBadBuy
# 1445
# NotRetrived
# 0_IsBadBuy
# 1446
# NotRetrived
# 1_IsBadBuy
# 1447
# NotRetrived
# 0_IsBadBuy
# 1448
# NotRetrived
# 0_IsBadBuy
# 1449
# NotRetrived
# 1_IsBadBuy
# 1450
# NotRetrived
# 0_IsBadBuy
# 1451
# NotRetrived
# 0_IsBadBuy
# 1452
# NotRetrived
# 0_IsBadBuy
# 1453
# NotRetrived
# 0_IsBadBuy
# 1454
# NotRetrived
# 0_IsBadBuy
# 1455
# NotRetrived
# 1_IsBadBuy
# 1456
# NotRetrived
# 1_IsBadBuy
# 1457
# NotRetrived
# 1_IsBadBuy
# 1458
# NotRetrived
# 0_IsBadBuy
# 1459
# NotRetrived
# 1_IsBadBuy
# 1460
# NotRetrived
# 0_IsBadBuy
# 1462
# NotRetrived
# 0_IsBadBuy
# 1463
# NotRetrived
# 1_IsBadBuy
# 1464
# NotRetrived
# 0_IsBadBuy
# 1465
# NotRetrived
# 0_IsBadBuy
# 1466
# NotRetrived
# 1_IsBadBuy
# 1467
# NotRetrived
# 0_IsBadBuy
# 1469
# NotRetrived
# 1_IsBadBuy
# 1470
# NotRetrived
# 1_IsBadBuy
# 1471
# NotRetrived
# 0_IsBadBuy
# 1472
# NotRetrived
# 1_IsBadBuy
# 1473
# NotRetrived
# 0_IsBadBuy
# 1474
# NotRetrived
# 0_IsBadBuy
# 1475
# NotRetrived
# 1_IsBadBuy
# 1476
# NotRetrived
# 0_IsBadBuy
# 1477
# NotRetrived
# 0_IsBadBuy
# 1478
# NotRetrived
# 0_IsBadBuy
# 1479
# NotRetrived
# 1_IsBadBuy
# 1480
# NotRetrived
# 0_IsBadBuy
# 1481
# NotRetrived
# 0_IsBadBuy
# 1482
# NotRetrived
# 0_IsBadBuy
# 1483
# NotRetrived
# 1_IsBadBuy
# 1484
# NotRetrived
# 1_IsBadBuy
# 1485
# NotRetrived
# 1_IsBadBuy
# 1486
# NotRetrived
# 0_IsBadBuy
# 1487
# NotRetrived
# 0_IsBadBuy
# 1489
# NotRetrived
# 0_IsBadBuy
# 1490
# NotRetrived
# 0_IsBadBuy
# 1491
# NotRetrived
# 0_IsBadBuy
# 1492
# NotRetrived
# 0_IsBadBuy
# 1493
# NotRetrived
# 1_IsBadBuy
# 1494
# NotRetrived
# 0_IsBadBuy
# 1495
# NotRetrived
# 0_IsBadBuy
# 1496
# NotRetrived
# 0_IsBadBuy
# 1497
# NotRetrived
# 1_IsBadBuy
# 1498
# NotRetrived
# 1_IsBadBuy
# 1499
# NotRetrived
# 0_IsBadBuy
# 1500
# NotRetrived
# 1_IsBadBuy
# 1501
# NotRetrived
# 0_IsBadBuy
# 1502
# NotRetrived
# 0_IsBadBuy
# 1503
# NotRetrived
# 1_IsBadBuy
# 1505
# NotRetrived
# 1_IsBadBuy
# 1506
# NotRetrived
# 1_IsBadBuy
# 1507
# NotRetrived
# 0_IsBadBuy
# 1508
# NotRetrived
# 0_IsBadBuy
# 1509
# NotRetrived
# 1_IsBadBuy
# 1510
# NotRetrived
# 0_IsBadBuy
# 1511
# NotRetrived
# 0_IsBadBuy
# 1512
# NotRetrived
# 0_IsBadBuy
# 1513
# NotRetrived
# 0_IsBadBuy
# 1514
# NotRetrived
# 0_IsBadBuy
# 1515
# NotRetrived
# 0_IsBadBuy
# 1517
# NotRetrived
# 0_IsBadBuy
# 1518
# NotRetrived
# 0_IsBadBuy
# 1520
# NotRetrived
# 0_IsBadBuy
# 1521
# NotRetrived
# 0_IsBadBuy
# 1522
# NotRetrived
# 0_IsBadBuy
# 1523
# NotRetrived
# 0_IsBadBuy
# 1524
# NotRetrived
# 1_IsBadBuy
# 1525
# NotRetrived
# 0_IsBadBuy
# 1526
# NotRetrived
# 1_IsBadBuy
# 1527
# NotRetrived
# 1_IsBadBuy
# 1528
# NotRetrived
# 0_IsBadBuy
# 1529
# NotRetrived
# 0_IsBadBuy
# 1530
# NotRetrived
# 0_IsBadBuy
# 1532
# NotRetrived
# 1_IsBadBuy
# 1533
# NotRetrived
# 0_IsBadBuy
# 1534
# NotRetrived
# 0_IsBadBuy
# 1535
# NotRetrived
# 0_IsBadBuy
# 1536
# NotRetrived
# 0_IsBadBuy
# 1537
# NotRetrived
# 0_IsBadBuy
# 1538
# NotRetrived
# 0_IsBadBuy
# 1539
# NotRetrived
# 0_IsBadBuy
# 1540
# NotRetrived
# 0_IsBadBuy
# 1541
# NotRetrived
# 0_IsBadBuy
# 1542
# NotRetrived
# 0_IsBadBuy
# 1543
# NotRetrived
# 1_IsBadBuy
# 1544
# NotRetrived
# 0_IsBadBuy
# 1545
# NotRetrived
# 0_IsBadBuy
# 1546
# NotRetrived
# 0_IsBadBuy
# 1547
# NotRetrived
# 0_IsBadBuy
# 1548
# NotRetrived
# 0_IsBadBuy
# 1549
# NotRetrived
# 1_IsBadBuy
# 1550
# NotRetrived
# 1_IsBadBuy
# 1552
# NotRetrived
# 0_IsBadBuy
# 1554
# NotRetrived
# 1_IsBadBuy
# 1555
# NotRetrived
# 0_IsBadBuy
# 1556
# NotRetrived
# 0_IsBadBuy
# 1557
# NotRetrived
# 0_IsBadBuy
# 1558
# NotRetrived
# 0_IsBadBuy
# 1559
# NotRetrived
# 0_IsBadBuy
# 1560
# NotRetrived
# 0_IsBadBuy
# 1561
# NotRetrived
# 0_IsBadBuy
# 1562
# NotRetrived
# 0_IsBadBuy
# 1563
# NotRetrived
# 0_IsBadBuy
# 1564
# NotRetrived
# 0_IsBadBuy
# 1565
# NotRetrived
# 1_IsBadBuy
# 1566
# NotRetrived
# 0_IsBadBuy
# 1567
# NotRetrived
# 0_IsBadBuy
# 1568
# NotRetrived
# 0_IsBadBuy
# 1570
# NotRetrived
# 1_IsBadBuy
# 1571
# NotRetrived
# 0_IsBadBuy
# 1572
# NotRetrived
# 0_IsBadBuy
# 1573
# NotRetrived
# 0_IsBadBuy
# 1574
# NotRetrived
# 0_IsBadBuy
# 1575
# NotRetrived
# 0_IsBadBuy
# 1576
# NotRetrived
# 0_IsBadBuy
# 1577
# NotRetrived
# 0_IsBadBuy
# 1578
# NotRetrived
# 0_IsBadBuy
# 1579
# NotRetrived
# 0_IsBadBuy
# 1580
# NotRetrived
# 0_IsBadBuy
# 1581
# NotRetrived
# 0_IsBadBuy
# 1582
# NotRetrived
# 0_IsBadBuy
# 1584
# NotRetrived
# 1_IsBadBuy
# 1585
# NotRetrived
# 1_IsBadBuy
# 1586
# NotRetrived
# 0_IsBadBuy
# 1587
# NotRetrived
# 0_IsBadBuy
# 1588
# NotRetrived
# 0_IsBadBuy
# 1589
# NotRetrived
# 1_IsBadBuy
# 1590
# NotRetrived
# 0_IsBadBuy
# 1591
# NotRetrived
# 0_IsBadBuy
# 1592
# NotRetrived
# 0_IsBadBuy
# 1593
# NotRetrived
# 0_IsBadBuy
# 1594
# NotRetrived
# 0_IsBadBuy
# 1595
# NotRetrived
# 0_IsBadBuy
# 1596
# NotRetrived
# 1_IsBadBuy
# 1597
# NotRetrived
# 0_IsBadBuy
# 1598
# NotRetrived
# 0_IsBadBuy
# 1599
# NotRetrived
# 0_IsBadBuy
# 1600
# NotRetrived
# 0_IsBadBuy
# 1601
# NotRetrived
# 1_IsBadBuy
# 1602
# NotRetrived
# 0_IsBadBuy
# 1603
# NotRetrived
# 0_IsBadBuy
# 1604
# NotRetrived
# 0_IsBadBuy
# 1605
# NotRetrived
# 0_IsBadBuy
# 1606
# NotRetrived
# 0_IsBadBuy
# 1607
# NotRetrived
# 0_IsBadBuy
# 1608
# NotRetrived
# 1_IsBadBuy
# 1609
# NotRetrived
# 0_IsBadBuy
# 1610
# NotRetrived
# 1_IsBadBuy
# 1611
# NotRetrived
# 0_IsBadBuy
# 1612
# NotRetrived
# 0_IsBadBuy
# 1613
# NotRetrived
# 0_IsBadBuy
# 1614
# NotRetrived
# 1_IsBadBuy
# 1615
# NotRetrived
# 1_IsBadBuy
# 1616
# NotRetrived
# 0_IsBadBuy
# 1617
# NotRetrived
# 0_IsBadBuy
# 1618
# NotRetrived
# 1_IsBadBuy
# 1619
# NotRetrived
# 0_IsBadBuy
# 1620
# NotRetrived
# 1_IsBadBuy
# 1621
# NotRetrived
# 0_IsBadBuy
# 1622
# NotRetrived
# 1_IsBadBuy
# 1623
# NotRetrived
# 0_IsBadBuy
# 1624
# NotRetrived
# 0_IsBadBuy
# 1625
# NotRetrived
# 0_IsBadBuy
# 1626
# NotRetrived
# 1_IsBadBuy
# 1627
# NotRetrived
# 1_IsBadBuy
# 1628
# NotRetrived
# 0_IsBadBuy
# 1629
# NotRetrived
# 1_IsBadBuy
# 1631
# NotRetrived
# 0_IsBadBuy
# 1632
# NotRetrived
# 0_IsBadBuy
# 1633
# NotRetrived
# 0_IsBadBuy
# 1634
# NotRetrived
# 1_IsBadBuy
# 1635
# NotRetrived
# 0_IsBadBuy
# 1636
# NotRetrived
# 0_IsBadBuy
# 1637
# NotRetrived
# 1_IsBadBuy
# 1638
# NotRetrived
# 0_IsBadBuy
# 1639
# NotRetrived
# 0_IsBadBuy
# 1640
# NotRetrived
# 1_IsBadBuy
# 1641
# NotRetrived
# 1_IsBadBuy
# 1642
# NotRetrived
# 0_IsBadBuy
# 1643
# NotRetrived
# 0_IsBadBuy
# 1644
# NotRetrived
# 0_IsBadBuy
# 1645
# NotRetrived
# 0_IsBadBuy
# 1646
# NotRetrived
# 0_IsBadBuy
# 1647
# NotRetrived
# 0_IsBadBuy
# 1648
# NotRetrived
# 1_IsBadBuy
# 1650
# NotRetrived
# 0_IsBadBuy
# 1652
# NotRetrived
# 0_IsBadBuy
# 1654
# NotRetrived
# 1_IsBadBuy
# 1656
# NotRetrived
# 1_IsBadBuy
# 1657
# NotRetrived
# 0_IsBadBuy
# 1658
# NotRetrived
# 0_IsBadBuy
# 1659
# NotRetrived
# 0_IsBadBuy
# 1660
# NotRetrived
# 0_IsBadBuy
# 1661
# NotRetrived
# 0_IsBadBuy
# 1662
# NotRetrived
# 0_IsBadBuy
# 1663
# NotRetrived
# 0_IsBadBuy
# 1665
# NotRetrived
# 0_IsBadBuy
# 1666
# NotRetrived
# 1_IsBadBuy
# 1667
# NotRetrived
# 1_IsBadBuy
# 1668
# NotRetrived
# 0_IsBadBuy
# 1669
# NotRetrived
# 0_IsBadBuy
# 1670
# NotRetrived
# 0_IsBadBuy
# 1671
# NotRetrived
# 0_IsBadBuy
# 1672
# NotRetrived
# 0_IsBadBuy
# 1673
# NotRetrived
# 0_IsBadBuy
# 1674
# NotRetrived
# 0_IsBadBuy
# 1675
# NotRetrived
# 0_IsBadBuy
# 1676
# NotRetrived
# 1_IsBadBuy
# 1678
# NotRetrived
# 0_IsBadBuy
# 1679
# NotRetrived
# 1_IsBadBuy
# 1680
# NotRetrived
# 0_IsBadBuy
# 1681
# NotRetrived
# 0_IsBadBuy
# 1682
# NotRetrived
# 0_IsBadBuy
# 1683
# NotRetrived
# 0_IsBadBuy
# 1684
# NotRetrived
# 1_IsBadBuy
# 1685
# NotRetrived
# 0_IsBadBuy
# 1686
# NotRetrived
# 0_IsBadBuy
# 1687
# NotRetrived
# 1_IsBadBuy
# 1689
# NotRetrived
# 0_IsBadBuy
# 1690
# NotRetrived
# 0_IsBadBuy
# 1691
# NotRetrived
# 0_IsBadBuy
# 1692
# NotRetrived
# 0_IsBadBuy
# 1693
# NotRetrived
# 1_IsBadBuy
# 1694
# NotRetrived
# 0_IsBadBuy
# 1695
# NotRetrived
# 0_IsBadBuy
# 1696
# NotRetrived
# 0_IsBadBuy
# 1697
# NotRetrived
# 0_IsBadBuy
# 1698
# NotRetrived
# 0_IsBadBuy
# 1699
# NotRetrived
# 0_IsBadBuy
# 1700
# NotRetrived
# 0_IsBadBuy
# 1701
# NotRetrived
# 0_IsBadBuy
# 1702
# NotRetrived
# 1_IsBadBuy
# 1703
# NotRetrived
# 1_IsBadBuy
# 1704
# NotRetrived
# 1_IsBadBuy
# 1705
# NotRetrived
# 0_IsBadBuy
# 1707
# NotRetrived
# 0_IsBadBuy
# 1709
# NotRetrived
# 0_IsBadBuy
# 1711
# NotRetrived
# 0_IsBadBuy
# 1712
# NotRetrived
# 0_IsBadBuy
# 1713
# NotRetrived
# 0_IsBadBuy
# 1714
# NotRetrived
# 0_IsBadBuy
# 1715
# NotRetrived
# 0_IsBadBuy
# 1716
# NotRetrived
# 0_IsBadBuy
# 1717
# NotRetrived
# 1_IsBadBuy
# 1718
# NotRetrived
# 0_IsBadBuy
# 1719
# NotRetrived
# 0_IsBadBuy
# 1720
# NotRetrived
# 1_IsBadBuy
# 1721
# NotRetrived
# 1_IsBadBuy
# 1722
# NotRetrived
# 0_IsBadBuy
# 1723
# NotRetrived
# 1_IsBadBuy
# 1724
# NotRetrived
# 0_IsBadBuy
# 1725
# NotRetrived
# 1_IsBadBuy
# 1726
# NotRetrived
# 0_IsBadBuy
# 1727
# NotRetrived
# 0_IsBadBuy
# 1729
# NotRetrived
# 0_IsBadBuy
# 1730
# NotRetrived
# 0_IsBadBuy
# 1731
# NotRetrived
# 0_IsBadBuy
# 1732
# NotRetrived
# 1_IsBadBuy
# 1733
# NotRetrived
# 0_IsBadBuy
# 1734
# NotRetrived
# 0_IsBadBuy
# 1735
# NotRetrived
# 0_IsBadBuy
# 1736
# NotRetrived
# 1_IsBadBuy
# 1737
# NotRetrived
# 0_IsBadBuy
# 1738
# NotRetrived
# 0_IsBadBuy
# 1739
# NotRetrived
# 0_IsBadBuy
# 1740
# NotRetrived
# 0_IsBadBuy
# 1741
# NotRetrived
# 0_IsBadBuy
# 1743
# NotRetrived
# 0_IsBadBuy
# 1744
# NotRetrived
# 0_IsBadBuy
# 1745
# NotRetrived
# 1_IsBadBuy
# 1746
# NotRetrived
# 0_IsBadBuy
# 1747
# NotRetrived
# 0_IsBadBuy
# 1748
# NotRetrived
# 0_IsBadBuy
# 1749
# NotRetrived
# 0_IsBadBuy
# 1750
# NotRetrived
# 0_IsBadBuy
# 1751
# NotRetrived
# 0_IsBadBuy
# 1752
# NotRetrived
# 0_IsBadBuy
# 1753
# NotRetrived
# 0_IsBadBuy
# 1754
# NotRetrived
# 0_IsBadBuy
# 1755
# NotRetrived
# 0_IsBadBuy
# 1756
# NotRetrived
# 1_IsBadBuy
# 1758
# NotRetrived
# 1_IsBadBuy
# 1759
# NotRetrived
# 0_IsBadBuy
# 1760
# NotRetrived
# 0_IsBadBuy
# 1761
# NotRetrived
# 1_IsBadBuy
# 1762
# NotRetrived
# 1_IsBadBuy
# 1763
# NotRetrived
# 0_IsBadBuy
# 1764
# NotRetrived
# 0_IsBadBuy
# 1765
# NotRetrived
# 0_IsBadBuy
# 1766
# NotRetrived
# 0_IsBadBuy
# 1767
# NotRetrived
# 0_IsBadBuy
# 1768
# NotRetrived
# 0_IsBadBuy
# 1769
# NotRetrived
# 1_IsBadBuy
# 1770
# NotRetrived
# 0_IsBadBuy
# 1771
# NotRetrived
# 0_IsBadBuy
# 1772
# NotRetrived
# 0_IsBadBuy
# 1773
# NotRetrived
# 0_IsBadBuy
# 1774
# NotRetrived
# 0_IsBadBuy
# 1775
# NotRetrived
# 0_IsBadBuy
# 1776
# NotRetrived
# 0_IsBadBuy
# 1777
# NotRetrived
# 0_IsBadBuy
# 1778
# NotRetrived
# 0_IsBadBuy
# 1779
# NotRetrived
# 1_IsBadBuy
# 1780
# NotRetrived
# 1_IsBadBuy
# 1782
# NotRetrived
# 0_IsBadBuy
# 1783
# NotRetrived
# 0_IsBadBuy
# 1784
# NotRetrived
# 0_IsBadBuy
# 1785
# NotRetrived
# 0_IsBadBuy
# 1786
# NotRetrived
# 0_IsBadBuy
# 1787
# NotRetrived
# 0_IsBadBuy
# 1788
# NotRetrived
# 0_IsBadBuy
# 1789
# NotRetrived
# 0_IsBadBuy
# 1791
# NotRetrived
# 0_IsBadBuy
# 1792
# NotRetrived
# 0_IsBadBuy
# 1793
# NotRetrived
# 0_IsBadBuy
# 1794
# NotRetrived
# 0_IsBadBuy
# 1795
# NotRetrived
# 1_IsBadBuy
# 1796
# NotRetrived
# 0_IsBadBuy
# 1797
# NotRetrived
# 0_IsBadBuy
# 1798
# NotRetrived
# 0_IsBadBuy
# 1799
# NotRetrived
# 0_IsBadBuy
# 1800
# NotRetrived
# 0_IsBadBuy
# 1801
# NotRetrived
# 0_IsBadBuy
# 1802
# NotRetrived
# 0_IsBadBuy
# 1803
# NotRetrived
# 1_IsBadBuy
# 1804
# NotRetrived
# 1_IsBadBuy
# 1805
# NotRetrived
# 0_IsBadBuy
# 1806
# NotRetrived
# 0_IsBadBuy
# 1807
# NotRetrived
# 1_IsBadBuy
# 1808
# NotRetrived
# 0_IsBadBuy
# 1809
# NotRetrived
# 0_IsBadBuy
# 1810
# NotRetrived
# 0_IsBadBuy
# 1811
# NotRetrived
# 0_IsBadBuy
# 1812
# NotRetrived
# 0_IsBadBuy
# 1813
# NotRetrived
# 0_IsBadBuy
# 1814
# NotRetrived
# 0_IsBadBuy
# 1815
# NotRetrived
# 0_IsBadBuy
# 1816
# NotRetrived
# 0_IsBadBuy
# 1817
# NotRetrived
# 0_IsBadBuy
# 1818
# NotRetrived
# 0_IsBadBuy
# 1819
# NotRetrived
# 1_IsBadBuy
# 1820
# NotRetrived
# 1_IsBadBuy
# 1821
# NotRetrived
# 1_IsBadBuy
# 1822
# NotRetrived
# 0_IsBadBuy
# 1823
# NotRetrived
# 0_IsBadBuy
# 1824
# NotRetrived
# 0_IsBadBuy
# 1825
# NotRetrived
# 0_IsBadBuy
# 1826
# NotRetrived
# 0_IsBadBuy
# 1827
# NotRetrived
# 0_IsBadBuy
# 1828
# NotRetrived
# 0_IsBadBuy
# 1829
# NotRetrived
# 0_IsBadBuy
# 1830
# NotRetrived
# 0_IsBadBuy
# 1831
# NotRetrived
# 0_IsBadBuy
# 1832
# NotRetrived
# 0_IsBadBuy
# 1833
# NotRetrived
# 1_IsBadBuy
# 1834
# NotRetrived
# 0_IsBadBuy
# 1835
# NotRetrived
# 0_IsBadBuy
# 1836
# NotRetrived
# 1_IsBadBuy
# 1837
# NotRetrived
# 0_IsBadBuy
# 1838
# NotRetrived
# 0_IsBadBuy
# 1840
# NotRetrived
# 1_IsBadBuy
# 1841
# NotRetrived
# 0_IsBadBuy
# 1843
# NotRetrived
# 0_IsBadBuy
# 1844
# NotRetrived
# 0_IsBadBuy
# 1845
# NotRetrived
# 0_IsBadBuy
# 1846
# NotRetrived
# 1_IsBadBuy
# 1847
# NotRetrived
# 0_IsBadBuy
# 1848
# NotRetrived
# 1_IsBadBuy
# 1849
# NotRetrived
# 0_IsBadBuy
# 1850
# NotRetrived
# 0_IsBadBuy
# 1851
# NotRetrived
# 1_IsBadBuy
# 1853
# NotRetrived
# 0_IsBadBuy
# 1854
# NotRetrived
# 0_IsBadBuy
# 1855
# NotRetrived
# 0_IsBadBuy
# 1856
# NotRetrived
# 1_IsBadBuy
# 1857
# NotRetrived
# 0_IsBadBuy
# 1858
# NotRetrived
# 0_IsBadBuy
# 1859
# NotRetrived
# 0_IsBadBuy
# 1860
# NotRetrived
# 1_IsBadBuy
# 1861
# NotRetrived
# 0_IsBadBuy
# 1862
# NotRetrived
# 0_IsBadBuy
# 1863
# NotRetrived
# 0_IsBadBuy
# 1864
# NotRetrived
# 0_IsBadBuy
# 1865
# NotRetrived
# 0_IsBadBuy
# 1866
# NotRetrived
# 0_IsBadBuy
# 1867
# NotRetrived
# 0_IsBadBuy
# 1868
# NotRetrived
# 0_IsBadBuy
# 1869
# NotRetrived
# 1_IsBadBuy
# 1870
# NotRetrived
# 0_IsBadBuy
# 1871
# NotRetrived
# 0_IsBadBuy
# 1872
# NotRetrived
# 0_IsBadBuy
# 1873
# NotRetrived
# 0_IsBadBuy
# 1874
# NotRetrived
# 0_IsBadBuy
# 1875
# NotRetrived
# 0_IsBadBuy
# 1876
# NotRetrived
# 0_IsBadBuy
# 1877
# NotRetrived
# 0_IsBadBuy
# 1878
# NotRetrived
# 0_IsBadBuy
# 1879
# NotRetrived
# 0_IsBadBuy
# 1881
# NotRetrived
# 0_IsBadBuy
# 1882
# NotRetrived
# 1_IsBadBuy
# 1884
# NotRetrived
# 0_IsBadBuy
# 1885
# NotRetrived
# 0_IsBadBuy
# 1886
# NotRetrived
# 0_IsBadBuy
# 1887
# NotRetrived
# 1_IsBadBuy
# 1888
# NotRetrived
# 1_IsBadBuy
# 1889
# NotRetrived
# 1_IsBadBuy
# 1890
# NotRetrived
# 1_IsBadBuy
# 1891
# NotRetrived
# 0_IsBadBuy
# 1892
# NotRetrived
# 0_IsBadBuy
# 1893
# NotRetrived
# 0_IsBadBuy
# 1894
# NotRetrived
# 0_IsBadBuy
# 1895
# NotRetrived
# 0_IsBadBuy
# 1896
# NotRetrived
# 1_IsBadBuy
# 1897
# NotRetrived
# 0_IsBadBuy
# 1898
# NotRetrived
# 0_IsBadBuy
# 1899
# NotRetrived
# 1_IsBadBuy
# 1900
# NotRetrived
# 0_IsBadBuy
# 1902
# NotRetrived
# 0_IsBadBuy
# 1903
# ...
# 13      SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 14      LE_Trim         AUTO  2_WheelTypeID  TOP LINE ASIAN      MEDIUM
# 15      SE_Trim         AUTO  1_WheelTypeID        AMERICAN         VAN
# 16     SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 17      LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 18      LS_Trim         AUTO  2_WheelTypeID        AMERICAN     COMPACT
# 19     SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 20     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 21     Lar_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 22     SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 23      LX_Trim         AUTO  2_WheelTypeID        AMERICAN     COMPACT
# 24     SEL_Trim         AUTO  1_WheelTypeID        AMERICAN       LARGE
# 25      SE_Trim         AUTO  3_WheelTypeID        AMERICAN     COMPACT
# 26     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 27     Bas_Trim         AUTO  1_WheelTypeID        AMERICAN     COMPACT
# 28      SE_Trim         AUTO  2_WheelTypeID        AMERICAN         VAN
# 29     Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# ...         ...          ...            ...             ...         ...
# 12524   LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12525  SLE_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12526   LS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12527  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN         VAN
# 12528  XLT_Trim         AUTO  1_WheelTypeID        AMERICAN   SMALL SUV
# 12529   SE_Trim         AUTO  1_WheelTypeID  TOP LINE ASIAN       LARGE
# 12530   LS_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12531   SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12532   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12533  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12534   LS_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12535  SXT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12536  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12537  SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12538   SE_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12539  SLT_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12540   LX_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12541  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12542   SE_Trim         AUTO  1_WheelTypeID        AMERICAN   CROSSOVER
# 12543   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12544  Bas_Trim         AUTO  2_WheelTypeID        AMERICAN   SPECIALTY
# 12545   ES_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12546   SE_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12547  Bas_Trim         AUTO  1_WheelTypeID        AMERICAN      MEDIUM
# 12548  XLS_Trim         AUTO  1_WheelTypeID        AMERICAN  MEDIUM SUV
# 12549  Bas_Trim         AUTO  3_WheelTypeID        AMERICAN      SPORTS
# 12550   LT_Trim         AUTO  2_WheelTypeID        AMERICAN      MEDIUM
# 12551   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN      MEDIUM
# 12552   LS_Trim         AUTO  1_WheelTypeID     OTHER ASIAN       LARGE
# 12553   EX_Trim         AUTO  1_WheelTypeID     OTHER ASIAN  MEDIUM SUV
#
#                                VehBCostBin                         VehOdoBin  \
# 0       [76713.492, 77122.849)_VehBCostBin   [73798.18, 73829.373)_VehOdoBin
# 1       [56654.995, 57064.352)_VehBCostBin   [74203.696, 74234.89)_VehOdoBin
# 2        [51333.353, 51742.71)_VehBCostBin  [77978.121, 78009.315)_VehOdoBin
# 3       [67707.636, 68116.993)_VehBCostBin   [77790.96, 77822.153)_VehOdoBin
# 4       [56654.995, 57064.352)_VehBCostBin  [79568.995, 79600.188)_VehOdoBin
# 5       [79988.348, 80397.706)_VehBCostBin  [86774.715, 86805.909)_VehOdoBin
# 6       [49695.925, 50105.282)_VehBCostBin  [84871.906, 84903.099)_VehOdoBin
# 7       [97181.346, 97590.703)_VehBCostBin  [75638.602, 75669.795)_VehOdoBin
# 8       [48877.211, 49286.568)_VehBCostBin  [65157.554, 65188.748)_VehOdoBin
# 9        [84900.633, 85309.99)_VehBCostBin  [65999.781, 66030.975)_VehOdoBin
# 10       [71391.85, 71801.207)_VehBCostBin  [83873.711, 83904.904)_VehOdoBin
# 11      [70163.779, 70573.136)_VehBCostBin  [64564.876, 64596.069)_VehOdoBin
# 12      [68935.707, 69345.065)_VehBCostBin  [71396.273, 71427.467)_VehOdoBin
# 13      [39871.355, 40280.712)_VehBCostBin   [85776.52, 85807.714)_VehOdoBin
# 14      [75894.778, 76304.135)_VehBCostBin  [82594.773, 82625.967)_VehOdoBin
# 15      [66479.565, 66888.922)_VehBCostBin   [70990.756, 71021.95)_VehOdoBin
# 16       [94725.203, 95134.56)_VehBCostBin  [73080.727, 73111.921)_VehOdoBin
# 17      [75076.064, 75485.421)_VehBCostBin  [74515.632, 74546.826)_VehOdoBin
# 18      [43555.569, 43964.926)_VehBCostBin  [66374.104, 66405.298)_VehOdoBin
# 19      [52970.782, 53380.139)_VehBCostBin  [45287.234, 45318.428)_VehOdoBin
# 20      [88994.204, 89403.561)_VehBCostBin  [59854.643, 59885.837)_VehOdoBin
# 21      [58701.781, 59111.138)_VehBCostBin  [71521.047, 71552.241)_VehOdoBin
# 22      [55426.924, 55836.281)_VehBCostBin  [62412.518, 62443.711)_VehOdoBin
# 23       [54198.853, 54608.21)_VehBCostBin  [91266.593, 91297.786)_VehOdoBin
# 24      [79578.991, 79988.348)_VehBCostBin   [72581.63, 72612.823)_VehOdoBin
# 25      [40280.712, 40690.069)_VehBCostBin  [44070.684, 44101.878)_VehOdoBin
# 26      [56654.995, 57064.352)_VehBCostBin   [75420.247, 75451.44)_VehOdoBin
# 27      [48877.211, 49286.568)_VehBCostBin  [76075.312, 76106.506)_VehOdoBin
# 28      [59929.852, 60339.209)_VehBCostBin   [77447.83, 77479.024)_VehOdoBin
# 29       [44783.64, 45192.997)_VehBCostBin  [76356.054, 76387.248)_VehOdoBin
# ...                                    ...                               ...
# 12524    [80807.063, 81216.42)_VehBCostBin  [82282.837, 82314.031)_VehOdoBin
# 12525   [72619.921, 73029.278)_VehBCostBin  [63161.164, 63192.358)_VehOdoBin
# 12526   [91859.704, 92269.061)_VehBCostBin  [81159.868, 81191.062)_VehOdoBin
# 12527   [49695.925, 50105.282)_VehBCostBin  [99907.218, 99938.412)_VehOdoBin
# 12528   [72210.564, 72619.921)_VehBCostBin  [71333.886, 71365.079)_VehOdoBin
# 12529  [99637.488, 100046.845)_VehBCostBin  [78040.509, 78071.702)_VehOdoBin
# 12530   [55017.567, 55426.924)_VehBCostBin   [76636.797, 76667.99)_VehOdoBin
# 12531   [37005.856, 37415.213)_VehBCostBin  [93013.434, 93044.628)_VehOdoBin
# 12532   [76713.492, 77122.849)_VehBCostBin  [60010.611, 60041.804)_VehOdoBin
# 12533   [71801.207, 72210.564)_VehBCostBin  [80286.447, 80317.641)_VehOdoBin
# 12534   [66479.565, 66888.922)_VehBCostBin  [87554.555, 87585.749)_VehOdoBin
# 12535   [55836.281, 56245.638)_VehBCostBin  [41294.454, 41325.648)_VehOdoBin
# 12536   [86538.062, 86947.419)_VehBCostBin  [71957.758, 71988.951)_VehOdoBin
# 12537    [87766.133, 88175.49)_VehBCostBin  [72051.338, 72082.532)_VehOdoBin
# 12538   [74257.349, 74666.707)_VehBCostBin  [65719.039, 65750.232)_VehOdoBin
# 12539   [56245.638, 56654.995)_VehBCostBin  [80442.415, 80473.609)_VehOdoBin
# 12540   [76713.492, 77122.849)_VehBCostBin  [51525.953, 51557.147)_VehOdoBin
# 12541   [74257.349, 74666.707)_VehBCostBin   [45599.17, 45630.364)_VehOdoBin
# 12542    [84900.633, 85309.99)_VehBCostBin  [63785.036, 63816.229)_VehOdoBin
# 12543    [61567.28, 61976.637)_VehBCostBin  [59511.513, 59542.707)_VehOdoBin
# 12544    [95134.56, 95543.917)_VehBCostBin  [70834.788, 70865.982)_VehOdoBin
# 12545     [30865.5, 31274.857)_VehBCostBin  [80348.835, 80380.028)_VehOdoBin
# 12546   [60748.566, 61157.923)_VehBCostBin  [50091.048, 50122.241)_VehOdoBin
# 12547   [53380.139, 53789.496)_VehBCostBin  [95945.632, 95976.826)_VehOdoBin
# 12548   [86947.419, 87356.776)_VehBCostBin  [68526.462, 68557.656)_VehOdoBin
# 12549   [75894.778, 76304.135)_VehBCostBin  [78040.509, 78071.702)_VehOdoBin
# 12550   [63614.065, 64023.423)_VehBCostBin  [72799.985, 72831.178)_VehOdoBin
# 12551   [53380.139, 53789.496)_VehBCostBin  [80286.447, 80317.641)_VehOdoBin
# 12552   [72210.564, 72619.921)_VehBCostBin  [54863.668, 54894.861)_VehOdoBin
# 12553    [68116.993, 68526.35)_VehBCostBin   [68214.526, 68245.72)_VehOdoBin
#
#                     MMRAcquisitionAuctionAveragePriceBin  \
# 0      [88381.549, 88429.417)_MMRAcquisitionAuctionAv...
# 1      [28498.595, 28546.463)_MMRAcquisitionAuctionAv...
# 2      [40513.48, 40561.348)_MMRAcquisitionAuctionAve...
# 3      [65404.876, 65452.744)_MMRAcquisitionAuctionAv...
# 4      [48028.767, 48076.635)_MMRAcquisitionAuctionAv...
# 5      [79717.428, 79765.296)_MMRAcquisitionAuctionAv...
# 6      [33189.665, 33237.533)_MMRAcquisitionAuctionAv...
# 7      [95705.363, 95753.231)_MMRAcquisitionAuctionAv...
# 8      [36253.222, 36301.09)_MMRAcquisitionAuctionAve...
# 9      [74978.489, 75026.358)_MMRAcquisitionAuctionAv...
# 10     [40944.293, 40992.161)_MMRAcquisitionAuctionAv...
# 11     [69090.717, 69138.585)_MMRAcquisitionAuctionAv...
# 12     [68755.641, 68803.509)_MMRAcquisitionAuctionAv...
# 13     [40178.403, 40226.272)_MMRAcquisitionAuctionAv...
# 14     [62820.0, 62867.868)_MMRAcquisitionAuctionAver...
# 15     [61431.826, 61479.694)_MMRAcquisitionAuctionAv...
# 16     [91157.897, 91205.765)_MMRAcquisitionAuctionAv...
# 17     [100204.962, 100252.83)_MMRAcquisitionAuctionA...
# 18     [43672.772, 43720.641)_MMRAcquisitionAuctionAv...
# 19     [55687.658, 55735.526)_MMRAcquisitionAuctionAv...
# 20     [86610.43, 86658.298)_MMRAcquisitionAuctionAve...
# 21     [47789.426, 47837.294)_MMRAcquisitionAuctionAv...
# 22     [55879.13, 55926.998)_MMRAcquisitionAuctionAve...
# 23     [26775.344, 26823.212)_MMRAcquisitionAuctionAv...
# 24     [76270.927, 76318.795)_MMRAcquisitionAuctionAv...
# 25     [28450.727, 28498.595)_MMRAcquisitionAuctionAv...
# 26     [65883.556, 65931.424)_MMRAcquisitionAuctionAv...
# 27     [48842.524, 48890.392)_MMRAcquisitionAuctionAv...
# 28     [52480.497, 52528.365)_MMRAcquisitionAuctionAv...
# 29     [29073.011, 29120.88)_MMRAcquisitionAuctionAve...
# ...                                                  ...
# 12524  [66697.314, 66745.182)_MMRAcquisitionAuctionAv...
# 12525  [48028.767, 48076.635)_MMRAcquisitionAuctionAv...
# 12526  [96375.516, 96423.384)_MMRAcquisitionAuctionAv...
# 12527  [69856.606, 69904.474)_MMRAcquisitionAuctionAv...
# 12528  [55974.866, 56022.734)_MMRAcquisitionAuctionAv...
# 12529  [91253.633, 91301.501)_MMRAcquisitionAuctionAv...
# 12530  [66840.918, 66888.786)_MMRAcquisitionAuctionAv...
# 12531  [20073.815, 20121.683)_MMRAcquisitionAuctionAv...
# 12532  [73207.371, 73255.239)_MMRAcquisitionAuctionAv...
# 12533  [80339.713, 80387.581)_MMRAcquisitionAuctionAv...
# 12534  [45683.231, 45731.099)_MMRAcquisitionAuctionAv...
# 12535  [54682.428, 54730.296)_MMRAcquisitionAuctionAv...
# 12536  [99534.809, 99582.677)_MMRAcquisitionAuctionAv...
# 12537  [75648.642, 75696.511)_MMRAcquisitionAuctionAv...
# 12538  [72393.614, 72441.482)_MMRAcquisitionAuctionAv...
# 12539  [40417.744, 40465.612)_MMRAcquisitionAuctionAv...
# 12540  [84982.916, 85030.784)_MMRAcquisitionAuctionAv...
# 12541  [70766.099, 70813.967)_MMRAcquisitionAuctionAv...
# 12542  [76558.136, 76606.004)_MMRAcquisitionAuctionAv...
# 12543  [51523.136, 51571.004)_MMRAcquisitionAuctionAv...
# 12544  [107241.568, 107289.436)_MMRAcquisitionAuction...
# 12545  [26248.795, 26296.663)_MMRAcquisitionAuctionAv...
# 12546  [29503.824, 29551.692)_MMRAcquisitionAuctionAv...
# 12547  [61192.486, 61240.354)_MMRAcquisitionAuctionAv...
# 12548  [85796.673, 85844.541)_MMRAcquisitionAuctionAv...
# 12549  [68037.62, 68085.488)_MMRAcquisitionAuctionAve...
# 12550  [71723.461, 71771.329)_MMRAcquisitionAuctionAv...
# 12551  [28115.65, 28163.518)_MMRAcquisitionAuctionAve...
# 12552  [74356.205, 74404.073)_MMRAcquisitionAuctionAv...
# 12553  [78999.407, 79047.275)_MMRAcquisitionAuctionAv...
#
#                             WarrantyCostBin   Prediction
# 0        [802.545, 803.496)_WarrantyCostBin  NotRetrived
# 1      [1388.511, 1389.462)_WarrantyCostBin   0_IsBadBuy
# 2        [919.548, 920.499)_WarrantyCostBin  NotRetrived
# 3      [1154.505, 1155.456)_WarrantyCostBin   0_IsBadBuy
# 4      [1154.505, 1155.456)_WarrantyCostBin   1_IsBadBuy
# 5      [2151.407, 2152.359)_WarrantyCostBin   0_IsBadBuy
# 6      [1802.301, 1803.252)_WarrantyCostBin   1_IsBadBuy
# 7      [1271.508, 1272.459)_WarrantyCostBin   0_IsBadBuy
# 8      [2002.062, 2003.013)_WarrantyCostBin   0_IsBadBuy
# 9      [1214.433, 1215.384)_WarrantyCostBin   0_IsBadBuy
# 10       [593.272, 594.223)_WarrantyCostBin   1_IsBadBuy
# 11       [727.397, 728.348)_WarrantyCostBin  NotRetrived
# 12       [802.545, 803.496)_WarrantyCostBin   0_IsBadBuy
# 13        [982.33, 983.281)_WarrantyCostBin   0_IsBadBuy
# 14       [893.864, 894.815)_WarrantyCostBin   0_IsBadBuy
# 15     [1505.513, 1506.465)_WarrantyCostBin   0_IsBadBuy
# 16     [1622.516, 1623.467)_WarrantyCostBin   0_IsBadBuy
# 17     [1154.505, 1155.456)_WarrantyCostBin   0_IsBadBuy
# 18       [727.397, 728.348)_WarrantyCostBin   0_IsBadBuy
# 19        [974.72, 975.671)_WarrantyCostBin   0_IsBadBuy
# 20        [836.79, 837.741)_WarrantyCostBin   0_IsBadBuy
# 21     [2039.161, 2040.112)_WarrantyCostBin   1_IsBadBuy
# 22     [1214.433, 1215.384)_WarrantyCostBin   0_IsBadBuy
# 23      [1640.59, 1641.541)_WarrantyCostBin   0_IsBadBuy
# 24     [1505.513, 1506.465)_WarrantyCostBin   0_IsBadBuy
# 25     [1133.577, 1134.529)_WarrantyCostBin   1_IsBadBuy
# 26       [919.548, 920.499)_WarrantyCostBin   0_IsBadBuy
# 27       [802.545, 803.496)_WarrantyCostBin   1_IsBadBuy
# 28     [1622.516, 1623.467)_WarrantyCostBin   0_IsBadBuy
# 29     [1688.152, 1689.103)_WarrantyCostBin   1_IsBadBuy
# ...                                     ...          ...
# 12524   [1242.97, 1243.922)_WarrantyCostBin   0_IsBadBuy
# 12525  [2002.062, 2003.013)_WarrantyCostBin   1_IsBadBuy
# 12526   [1242.97, 1243.922)_WarrantyCostBin   0_IsBadBuy
# 12527  [1917.402, 1918.353)_WarrantyCostBin   0_IsBadBuy
# 12528    [919.548, 920.499)_WarrantyCostBin   1_IsBadBuy
# 12529  [1154.505, 1155.456)_WarrantyCostBin   1_IsBadBuy
# 12530  [1271.508, 1272.459)_WarrantyCostBin   0_IsBadBuy
# 12531   [1640.59, 1641.541)_WarrantyCostBin   0_IsBadBuy
# 12532    [727.397, 728.348)_WarrantyCostBin  NotRetrived
# 12533   [1242.97, 1243.922)_WarrantyCostBin   0_IsBadBuy
# 12534  [1372.339, 1373.291)_WarrantyCostBin   0_IsBadBuy
# 12535     [974.72, 975.671)_WarrantyCostBin   0_IsBadBuy
# 12536  [1388.511, 1389.462)_WarrantyCostBin   0_IsBadBuy
# 12537  [1388.511, 1389.462)_WarrantyCostBin   0_IsBadBuy
# 12538  [1214.433, 1215.384)_WarrantyCostBin   0_IsBadBuy
# 12539  [1802.301, 1803.252)_WarrantyCostBin   1_IsBadBuy
# 12540    [919.548, 920.499)_WarrantyCostBin   1_IsBadBuy
# 12541    [692.201, 693.152)_WarrantyCostBin   0_IsBadBuy
# 12542  [1312.411, 1313.362)_WarrantyCostBin   1_IsBadBuy
# 12543    [504.806, 505.757)_WarrantyCostBin   0_IsBadBuy
# 12544  [1388.511, 1389.462)_WarrantyCostBin   0_IsBadBuy
# 12545   [1502.66, 1503.611)_WarrantyCostBin   0_IsBadBuy
# 12546     [753.08, 754.032)_WarrantyCostBin   0_IsBadBuy
# 12547  [1196.359, 1197.311)_WarrantyCostBin   1_IsBadBuy
# 12548  [1807.057, 1808.009)_WarrantyCostBin   1_IsBadBuy
# 12549    [802.545, 803.496)_WarrantyCostBin   1_IsBadBuy
# 12550  [1037.502, 1038.453)_WarrantyCostBin   0_IsBadBuy
# 12551    [852.961, 853.912)_WarrantyCostBin  NotRetrived
# 12552  [1002.306, 1003.257)_WarrantyCostBin  NotRetrived
# 12553  [1507.416, 1508.367)_WarrantyCostBin   1_IsBadBuy
#
# [12554 rows x 15 columns]

# %% [markdown]
# #### Evaluating accuracy

# %%
#We drop the 'NotRetrived' entries
df2=df2[df2['Prediction']!='NotRetrived']
df2.index= range(len(df2.index))
tp=0
tn=0
fp=0
fn=0
for i in df2.index:
    if((df2.values[i][0] == df2.values[i][14]) and df2.values[i][0]=='0_IsBadBuy'):
        tp=tp+1
    if((df2.values[i][0] == df2.values[i][14]) and df2.values[i][0]=='1_IsBadBuy'):
        tn=tn+1
    if((df2.values[i][0] != df2.values[i][14]) and df2.values[i][14]=='0_IsBadBuy'):
        fp=fp+1
    if((df2.values[i][0] != df2.values[i][14]) and df2.values[i][14]=='1_IsBadBuy'):
        fn=fn+1
confmat0=([tp,fp],[tn,fn])
confmat0
# Out:
# ([7609, 791], [525, 2674])

# %%
precision=tp/(tp+fp)
recall=tp/(tp+fn)
F1=2/((1/precision)+(1/recall))
print("Precision 0 :", precision)
print("Recall 0 :", recall)
print("F1 0 :", F1)
# Out:
# Precision 0 : 0.9058333333333334
# Recall 0 : 0.7399591558883595
# F1 0 : 0.8145372798801048

# %%
df2=df2[df2['Prediction']!='NotRetrived']
df2.index= range(len(df2.index))
tp=0
tn=0
fp=0
fn=0
for i in df2.index:
    if((df2.values[i][0] == df2.values[i][14]) and df2.values[i][0]=='1_IsBadBuy'):
        tp=tp+1
    if((df2.values[i][0] == df2.values[i][14]) and df2.values[i][0]=='0_IsBadBuy'):
        tn=tn+1
    if((df2.values[i][0] != df2.values[i][14]) and df2.values[i][14]=='1_IsBadBuy'):
        fp=fp+1
    if((df2.values[i][0] != df2.values[i][14]) and df2.values[i][14]=='0_IsBadBuy'):
        fn=fn+1
confmat1=([tp,fp],[tn,fn])
confmat1
# Out:
# ([525, 2674], [7609, 791])

# %%
precision=tp/(tp+fp)
recall=tp/(tp+fn)
F1=2/((1/precision)+(1/recall))
print("Precision 1 :", precision)
print("Recall 1 :", recall)
print("F1 1 :", F1)
# Out:
# Precision 1 : 0.16411378555798686
# Recall 1 : 0.39893617021276595
# F1 1 : 0.2325581395348837
